# %%
import gym
from gym import spaces
from gym.utils import seeding
import numpy as np
from enum import Enum
import matplotlib.pyplot as plt


#Agent的行動
class Actions(Enum):
    Sell = 0
    Buy = 1

#在Env裡面所代表的
class Positions(Enum):
    Short = 0
    Long = 1

    def opposite(self):
        return Positions.Short if self == Positions.Long else Positions.Long

    
class TradingEnv(gym.Env):

    metadata = {'render.modes': ['human']}
    
    #__init__為魔法函數，意義為：無論你願不願意，只要你執行TradingEnv，就會把__init__底下的資料執行，可以用作變數定義？
    def __init__(self, df, window_size): 
        assert df.ndim == 2 #判斷所輸入的df維度是否等於2

        self.seed() #隨機種子設定
        self.df = df #輸入df
        self.window_size = window_size #輸入Windows size
        self.open, self.close, self.high, self.low, self.volume, self.signal_features = self._process_data() #輸入【價錢, 特征資料】
        self.shape = (window_size, self.signal_features.shape[1]) #輸入【Windows size, 特征資料的長度】

        # spaces
        self.action_space = spaces.Discrete(len(Actions)) # 行動空間為：2（Sell、Buy）
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=self.shape, dtype=np.float64) #觀察空間最低和最高為無限（因為不知股票價錢為多少）

        # episode
        #「_」為私有化，即import的時候不會引入參數
        self._start_tick = self.window_size #開始日期：Windows_size設定的數字
        self._end_tick = len(self.close)-1 #結束日期：【價錢】的長度-1
        self._done = None 
        self._current_tick = None
        self._last_trade_tick = None
        self._position = None
        self._position_history = None
#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓        
        self._reward_history = []#記錄Reward獎勵，方便畫圖
        self._Total_profit = []#記錄Profit，方便畫圖
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑
        self._total_reward = None
        self._total_profit = None
        self._first_rendering = None
        self.history = None

    #定義一個隨機種子   
    def seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    #重設
    def reset(self):
        self._done = False #尚未完成
        self._current_tick = self._start_tick # Windows_size設定的數字
        self._last_trade_tick = self._current_tick -1 #Windows_size設定的數字-1
        self._position = Positions.Short #第一天交易必定為Short
        self._position_history = (self.window_size * [None]) + [self._position] #記錄位置
        self._total_reward = 0. #初始化的reward為：0
        self._total_profit = 1. #初始化的Profit為：1
        self._first_rendering = True
        self.history = {}
        return self._get_observation()

    #交易中的步驟
    def step(self, action):
        self._done = False #尚未完成動作
        
        
        #如果當前日期 = 完結日期，就結束步驟
        if self._current_tick == self._end_tick:
            self._done = True

#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓
#如果機器人進行買的動作，他的Position就會變成Long，反之亦然
        if(action == Actions.Buy.value):
            self._position = Positions.Long
#             print("action: ", action)
#             print("position: ", self._position)
        elif(action == Actions.Sell.value):
            self._position = Positions.Short
#             print("action: ", action)
#             print("position: ", self._position)
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑               
        self._last_trade_tick = self._current_tick      
        #記錄步驟
        self._position_history.append(self._position)
        
        #獎勵：調用計算獎勵的function，然後將它累積起來計算總和
        step_reward = self._calculate_reward(action)
        step_profit = self._update_profit(action)#記錄profit，方便畫圖
#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓
        self._reward_history.append(step_reward)#記錄Reward獎勵，方便畫圖
        self._Total_profit.append(step_profit)#記錄profit，方便畫圖
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑ 
        self._total_reward += step_reward
        #根據agent的action更新他的 profit
        
        
        observation = self._get_observation()
        info = dict(
            total_reward = self._total_reward,
            total_profit = self._total_profit,
            position = self._position.value
        )
        self._update_history(info)
        
        self._current_tick += 1 #當前日期+1

        return observation, step_reward, self._done, info

    #取得觀察值，觀察值為signal_features
    #若window_size為10
    #則使用0 ~ 9日的觀察值，下一次交易則使用1 ~ 10日的觀察值
    def _get_observation(self):
        return self.signal_features[(self._current_tick-self.window_size+1):self._current_tick+1]

    #更新歷史資料
    def _update_history(self, info):
        if not self.history:
            self.history = {key: [] for key in info.keys()}

        for key, value in info.items():
            self.history[key].append(value)

    #render：將環境實體化，以股票交易為例即是畫圖
    def render(self, mode='human'):
        pass


    #畫圖
#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓    
    def render_Close(self, mode='human'):
            window_ticks = np.arange(len(self._position_history))#[1,2,3,4,5,....]矩陣
            plt.plot(self.close)#根據收盤價進行繪畫

            short_ticks = []
            long_ticks = []
            # i：控制position_history的位置
            # tick：控制要塞進Long還是Short的位置
            #如果機器人在之前就是做Long的話就把它記錄在long_ticks裡面，反之亦然
            for i, tick in enumerate(window_ticks-1):
                if self._position_history[i] == Positions.Short:
                    short_ticks.append(tick)
                elif self._position_history[i] == Positions.Long:
                    long_ticks.append(tick)      

            del(short_ticks[0])

            plt.plot(short_ticks, self.close[short_ticks], 'ro', label = 'Short')#根據收盤價進行畫圖
            plt.plot(long_ticks, self.close[long_ticks], 'go', label = 'Long')#根據收盤價進行畫圖
            
            plt.legend()
            plt.title("Close", fontsize=20)
            plt.suptitle(
                "Total Reward: %.6f" % self._total_reward + ' ~ ' +
                "Total Profit: %.6f" % self._total_profit
            )
            print("↓↓↓ 大立光(3008)在交易當天收盤時進行的交易策略(Long Or Short) ↓↓↓")
        
        
    #畫圖2   
    def render_Reward(self, mode='human'):
        window_ticks = np.arange(len(self._position_history))
        short_ticks = []
        long_ticks = []
        for i, tick in enumerate(window_ticks-1):
            if self._position_history[i] == Positions.Short:
                short_ticks.append(tick)
            elif self._position_history[i] == Positions.Long:
                long_ticks.append(tick)
        
        del(short_ticks[0])
        self._reward_history = np.array(self._reward_history)
        short_ticks = (np.array(short_ticks)-10).tolist()
        long_ticks = (np.array(long_ticks)-10).tolist()
        
        plt.bar(short_ticks,self._reward_history[short_ticks], color='r', label = 'Short')#根據獎勵進行繪畫
        plt.bar(long_ticks,self._reward_history[long_ticks], color='g', label = 'Long')#根據獎勵進行繪畫
            
        plt.legend()   
        plt.title("Reward", fontsize=20)
        plt.suptitle(
            "Total Reward: %.6f" % self._total_reward + ' ~ ' +
            "Total Profit: %.6f" % self._total_profit
        )
        print("↓↓↓ 大立光(3008)在使用交易策略(Long Or Short)後，隔日早上平倉時的盈虧(含手續費) ↓↓↓")
        
        
    def render_TotalProfit(self, mode='human'):
        window_ticks = np.arange(len(self._position_history))
        
        del self._Total_profit[-1]
        plt.plot(self._Total_profit)
        
        
#         short_ticks = []
#         long_ticks = []
#         for i, tick in enumerate(window_ticks-1):
#             if self._position_history[i] == Positions.Short:
#                 short_ticks.append(tick)
#             elif self._position_history[i] == Positions.Long:
#                 long_ticks.append(tick)
        
#         del(short_ticks[0])
#         self._Total_profit = np.array(self._Total_profit)
#         short_ticks = (np.array(short_ticks)-10).tolist()
#         long_ticks = (np.array(long_ticks)-10).tolist()
        
#         plt.plot(short_ticks, self._Total_profit[short_ticks], 'ro', label = 'Short')#根據獎勵進行畫圖
#         plt.plot(long_ticks, self._Total_profit[long_ticks], 'go', label = 'Long')#根據獎勵進行畫圖
            
#         plt.legend() 

        plt.title("TotalProfit", fontsize=20)
        plt.suptitle(
            "Total Reward: %.6f" % self._total_reward + ' ~ ' +
            "Total Profit: %.6f" % self._total_profit
        )
        print("↓↓↓ 根據預測出的交易策略交易大立光(3008)，所得到的累積利潤(含手續費) ↓↓↓")
        plt.savefig('3008_MACD_TotalProfit.jpg')
        
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑         
        


    
    
    #關閉環境，即關閉畫圖    
    def close(self):
        plt.close()

    #保存圖片
    def save_rendering(self, filepath):
        plt.savefig(filepath)

    #暫停畫圖
    def pause_rendering(self):
        plt.show()

    #在TradingEnv中，為了保持結構完整，因此使用pass不做任何事情
    def _process_data(self):
        pass

    #在TradingEnv中，為了保持結構完整，因此使用pass不做任何事情
    def _calculate_reward(self, action):
        pass

    #在TradingEnv中，為了保持結構完整，因此使用pass不做任何事情
    def _update_profit(self, action):
        pass

    #在TradingEnv中，為了保持結構完整，因此使用pass不做任何事情
    def max_possible_profit(self):  # trade fees are ignored
        pass

# %%
import numpy as np

class StocksEnv(TradingEnv):
    

    def __init__(self, df, window_size, frame_bound):
        assert len(frame_bound) == 2 #判斷所輸入的df維度是否等於2

        self.frame_bound = frame_bound #輸入範圍值
        super().__init__(df, window_size)

        self.trade_fee_percent = 0.001425+0.003
        #https://rich01.com/what-is-next-day-trading/
        
    #資料處理
    def _process_data(self):
        open = self.df.loc[:, 'open'].to_numpy() #prices：開市價
        close = self.df.loc[:, 'close'].to_numpy() #prices：收盤價
        high = self.df.loc[:, 'high'].to_numpy() #prices：最高
        low = self.df.loc[:, 'low'].to_numpy() #prices：最低
        volume = self.df.loc[:, 'volume'].to_numpy() #prices：成交量
        close[self.frame_bound[0] - self.window_size] # validate index (TODO: Improve validation)#驗證資料：10-10
        close = close[self.frame_bound[0]-self.window_size:self.frame_bound[1]]#【10-10:5600】

        diff = np.insert(np.diff(close), 0, 0)#計算價差【今天 - 昨天】
        signal_features = np.column_stack((close, diff))#默認的signal_features為：收盤價，價差

        return open, close ,high, low, volume, signal_features

#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓
    #計算獎勵
    def _calculate_reward(self, action):
        step_reward = 0
        price_diff = 0
       
        
        if(self._current_tick < self._end_tick):
            if(action == Actions.Buy.value):
                current_price = self.close[self._current_tick]*1000#【今天收盤】
                last_trade_price = self.open[self._current_tick+1]*1000#【明天開盤】
                
                Buy_trade_fee = (current_price * 0.001425)*0.5 #(買*手續費) * 證券商折扣
                if Buy_trade_fee<20:
                    Buy_trade_fee=20
                Sold_trade_fee = (last_trade_price * 0.001425)*0.5 #(賣*手續費) * 證券商折扣
                if Sold_trade_fee<20:
                    Sold_trade_fee=20
                Transfer_tax = last_trade_price * 0.003 #證交稅
                
                Buy = current_price + Buy_trade_fee#買入的成本
                Sold = last_trade_price - Sold_trade_fee - Transfer_tax#賣出的成本
                
                price_diff = Sold - Buy#最後賺到的錢
                
                
                
            elif(action == Actions.Sell.value):
                current_price = self.close[self._current_tick]*1000#【今天收盤】
                last_trade_price = self.open[self._current_tick+1]*1000#【明天開盤】
                
                Buy_trade_fee = (last_trade_price * 0.001425)*0.5 #(買*手續費) * 證券商折扣
                if Buy_trade_fee<20:
                    Buy_trade_fee=20
                Sold_trade_fee = (current_price * 0.001425)*0.5 #(賣*手續費) * 證券商折扣
                if Sold_trade_fee<20:
                    Sold_trade_fee=20
                Transfer_tax = last_trade_price * 0.003 #證交稅
                
                Buy = last_trade_price + Buy_trade_fee#買入的成本
                Sold = current_price - Sold_trade_fee - Transfer_tax#賣出的成本
                
                price_diff = Sold - Buy#最後賺到的錢
        
        step_reward =  step_reward + price_diff
        
        return step_reward


    def _update_profit(self, action):
        
        long_profit_percentage = 0.0
        short_profit_percentage = 0.0
        Total_long_profit_percentage = 0.0
        Total_short_profit_percentage = 0.0
        
        step_profit = 0
        if(self._current_tick < self._end_tick):
            if(action == Actions.Buy.value):
                
                current_price = self.close[self._current_tick]*1000#【今天收盤】
                last_trade_price = self.open[self._current_tick+1]*1000#【明天開盤】
                    
                Buy_trade_fee = (current_price * 0.001425)*0.5 #(買*手續費) * 證券商折扣
                if Buy_trade_fee<20:
                    Buy_trade_fee=20
                Sold_trade_fee = (last_trade_price * 0.001425)*0.5 #(賣*手續費) * 證券商折扣
                if Sold_trade_fee<20:
                    Sold_trade_fee=20
                Transfer_tax = last_trade_price * 0.003 #證交稅
                
                Buy = current_price + Buy_trade_fee#買入的成本
                Sold = last_trade_price - Sold_trade_fee - Transfer_tax#賣出的成本
                
                price_diff = Sold - Buy#最後賺到的錢
                long_profit_percentage = (Sold - Buy)/Buy
                self._total_profit += long_profit_percentage
                
            elif(action == Actions.Sell.value):

                current_price = self.close[self._current_tick]*1000#【今天收盤】
                last_trade_price = self.open[self._current_tick+1]*1000#【明天開盤】
                
                Buy_trade_fee = (last_trade_price * 0.001425)*0.5 #(買*手續費) * 證券商折扣
                if Buy_trade_fee<20:
                    Buy_trade_fee=20
                Sold_trade_fee = (current_price * 0.001425)*0.5 #(賣*手續費) * 證券商折扣
                if Sold_trade_fee<20:
                    Sold_trade_fee=20
                Transfer_tax = last_trade_price * 0.003 #證交稅
                
                Buy = last_trade_price + Buy_trade_fee#買入的成本
                Sold = current_price - Sold_trade_fee - Transfer_tax#賣出的成本
                
                price_diff = Sold - Buy#最後賺到的錢
                short_profit_percentage = (Sold - Buy)/Buy 
                self._total_profit += short_profit_percentage  
                       
                
        step_profit += self._total_profit #記錄profit，方便畫圖
        return step_profit#記錄profit，方便畫圖
        
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑  
                
    #https://github.com/AminHP/gym-anytrading/blob/master/README.ipynb
    #不論交易費用如何，agent在股票交易中所獲得的profit
    def max_possible_profit(self):
        pass

# %%
# import gym_anytrading
import numpy as np
import pandas as pd
import quantstats as qs
from stable_baselines import A2C
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\__init__.py:33: UserWarning: stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation.
#   "stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation."

# %%
from yahoo_fin import stock_info as si
from sklearn.preprocessing import Normalizer
if isinstance('3008.TW', str):
    # load it from yahoo_fin library
    df = si.get_data('3008.TW')
df = df.dropna()#丟棄空值
df = df.reset_index()

#---------------------------------------------------------------------------
#定義參數

open = df['open']
close = df['close']
high = df['high']
low = df['low']
UpLine_max = []
UpLine = [] #上引線
DownLine_min = []
DownLine = [] #下引線
UpMean = []#計算RSI——上漲平均5天
DownMean = []#計算RSI——下跌平均5天
RSI = []#計算RSI
#---------------------------------------------------------------------------
#上引線；下引線

for i in range(close.size):
    UpLine_max.append(max(open[i], close[i]))
for i in range(close.size):
    UpLine.append(high[i] - UpLine_max[i])#上影線
for i in range(close.size):
    DownLine_min.append(min(open[i], close[i]))
for i in range(close.size):
    DownLine.append(DownLine_min[i] - low[i])#下影線
#---------------------------------------------------------------------------
#RSI

UpDownValue = close - close.shift(1) #計算漲跌值
Only_UpValue = pd.Series(index=UpDownValue.index, data=UpDownValue[UpDownValue>0])#將上漲日子篩出
Only_UpValue = Only_UpValue.fillna(0)#下跌的日子為0
Only_DownValue = pd.Series(index=UpDownValue.index, data=-UpDownValue[UpDownValue<0])#將下跌日子篩出
Only_DownValue = Only_DownValue.fillna(0)#上漲的日子為0
for i in range(13, len(Only_UpValue)+1):#由第六日開始，直到現在
    UpMean.append(np.mean(Only_UpValue.values[i-12:i]))#計算出最近五日的平均，因為有補0，所以可以計算出。
    DownMean.append(np.mean(Only_DownValue.values[i-12:i]))#計算出最近五日的平均
for i in range(len(UpMean)):
    RSI.append( (UpMean[i] / ( UpMean[i] + DownMean[i] )) * 100  )#計算RSI
RSI = pd.Series(index = close.index[12:], data = RSI) #轉換格式
#---------------------------------------------------------------------------
#FH；FL
FH = ((high - open) / open) #FH
FL = ((open - low) / open) #FL
FH = pd.DataFrame(FH, columns=['FH'])#FH參數
FL = pd.DataFrame(FL, columns=['FL'])#FL參數
#---------------------------------------------------------------------------
# KD
K = []
D = []
K_Value = []
D_Value = []
def RSV(df):
    df['MinLow'] = df['low'].rolling(9, min_periods=9).min()#9天最低位
    df['MinLow'].fillna(value = df['low'].expanding().min(), inplace = True)#填滿NA
    df['MaxHigh'] = df['high'].rolling(9, min_periods=9).max()#9天最高位
    df['MaxHigh'].fillna(value = df['high'].expanding().max(), inplace = True)#填滿NA
    df['RSV'] = (df['close'] - df['MinLow']) / (df['MaxHigh'] - df['MinLow']) * 100 #計算RSV
    return df
RSV_df = RSV(df)#使用RSV函數計算
RSV = RSV_df['RSV']#獲得RSV
for i in range(len(RSV)):
    if i<=9 :
        K.append(50)
        D.append(50)
    elif i > 9:
        K.append((K[i-1] * 2/3) + (1/3 * RSV[i]))
        D.append((D[i-1] * 2/3) + (1/3 * K[i]))
K_Value = pd.Series(index = close.index[0:], data = K) #轉換格式
D_Value = pd.Series(index = close.index[0:], data = D) #轉換格式
#---------------------------------------------------------------------------
# MACD
DIF = []
MACD = []
ShortEMA=close.ewm(span=12,adjust=False).mean()#12日移動平均
LongEMA=close.ewm(span=26,adjust=False).mean()#26日移動平均
FastLine_DIF=ShortEMA-LongEMA#DIF = （12日移動平均 - 26日移動平均）
SlowLine_MACD=FastLine_DIF.ewm(span=9,adjust=False).mean()#取DIF數值得到9日移動平均
FastLine_DIF = pd.DataFrame(FastLine_DIF)#轉換格式
SlowLine_MACD = pd.DataFrame(SlowLine_MACD)#轉換格式
FastLine_DIF = FastLine_DIF.rename(columns={'close':'DIF'})#轉換格式
SlowLine_MACD = SlowLine_MACD.rename(columns={'close':'MACD'})#轉換格式
#---------------------------------------------------------------------------                                                             
#BBands
def BBands(df,Day=20,Times=2):#20天平均, 2倍標準差
    Up_Track=pd.Series(0.0,index=df.index)#建立全0的陣列
    Mid_Track=pd.Series(0.0,index=df.index)#建立全0的陣列
    Down_Track=pd.Series(0.0,index=df.index)#建立全0的陣列
    SD=pd.Series(0.0,index=df.index)#建立全0的陣列
    
    for i in range(Day-1,len(df)):#19~5600   
        Mid_Track[i]=np.mean(df[i-(Day-1):(i+1)])#中軌 = 0-20平均 -> 1-21平均 -> 2-22平均...（移動平均線）
        SD[i]=np.std(df[i-(Day-1):(i+1)])#0-20標準差 -> 1-21標準差 ->2-22標準差...（標準差）
        Up_Track[i]=Mid_Track[i]+(Times*SD[i])#上軌 = 中軌+（2倍標準差）
        Down_Track[i]=Mid_Track[i]-(Times*SD[i])#下軌 = 中軌-（2倍標準差）
        
        #慢慢地將上半部分建立的全0函式更新
        df_BBands=pd.DataFrame({'Up_Track':Up_Track[(Day-1):],#由第19日開始載入布林通道（上）
                             'Mid_Track':Mid_Track[(Day-1):],#由第19日開始載入布林通道（中）
                             'Down_Track':Down_Track[(Day-1):]#由第19日開始載入布林通道（下）
                            })
    return(df_BBands)
BBands_Up_Mid_Down_Trak = BBands(close, 20, 2)
#---------------------------------------------------------------------------
#合拼df
df2330 = pd.merge(df, FH,left_index=True,right_index=True) #合拼FH
df2330 = pd.merge(df2330, FL,left_index=True,right_index=True) #合拼FL
df2330 = pd.merge(df2330, pd.DataFrame(UpLine, columns=['UpLine']),left_index=True,right_index=True) #合併上影線
df2330 = pd.merge(df2330, pd.DataFrame(DownLine, columns=['DownLine']),left_index=True,right_index=True) #合併下影線
df2330 = pd.merge(df2330, pd.DataFrame(RSI, columns=['RSI']),left_index=True,right_index=True) #合併RSI
df2330 = pd.merge(df2330, pd.DataFrame(K_Value, columns=['K_Value']),left_index=True,right_index=True) #合併K值
df2330 = pd.merge(df2330, pd.DataFrame(D_Value, columns=['D_Value']),left_index=True,right_index=True) #合併D值
df2330 = pd.merge(df2330, pd.DataFrame(FastLine_DIF),left_index=True,right_index=True) #合併DIF
df2330 = pd.merge(df2330, pd.DataFrame(SlowLine_MACD),left_index=True,right_index=True) #合併MACD
df2330 = pd.merge(df2330,BBands_Up_Mid_Down_Trak,left_index=True,right_index=True) #合併布林通道
df2330.index = range(len(df2330))#更新index

# %% [markdown]
# # 是否將特徵資料標準化？

# %%
#---------------------------------------------------------------------------
# normalizer = Normalizer()#創建標準化函數
# df2330_AllFeatures = df2330[['MinLow','MaxHigh','RSV','FH','FL','UpLine','DownLine','RSI','K_Value','D_Value','DIF','MACD','Up_Track','Mid_Track','Down_Track']]#取得需要標準化的特徵
# df2330_FeaturesNormalize = normalizer.fit_transform(df2330_AllFeatures)#進行標準化
# df2330_FeaturesNormalize = pd.DataFrame(df2330_FeaturesNormalize)#將array變成df
# df2330_FeaturesNormalize = df2330_FeaturesNormalize.rename(columns={0:'MinLow',1:'MaxHigh',2:'RSV',
#                                                       3:'FH',4:'FL',
#                                                       5:'UpLine',6:'DownLine',
#                                                       7:'RSI',
#                                                       8:'K_Value',9:'D_Value',
#                                                       10:'DIF',11:'MACD',
#                                                       12:'Up_Track',13:'Mid_Track',14:'Down_Track'})#更改名字
# df2330_OriginData = df2330[['index','open','high','low','close','adjclose','volume','ticker']]#取得市場基本資料
# df2330_Normalized = pd.merge(df2330_OriginData, df2330_FeaturesNormalize, left_index=True,right_index=True) #基本資料與標準化後特徵資料合併
# df2330 = df2330_Normalized
#---------------------------------------------------------------------------

#---------------------------------------------------------------------------
#輸出最終Dataframe
df = df2330
df
# Out:
#           index         open         high          low        close  \
# 0    2002-04-05   103.632324   103.632324   103.632324   103.632324
# 1    2002-04-08    99.796707   105.553665    99.796707   105.165154
# 2    2002-04-09   104.783714   104.783714   102.862373   102.862373
# 3    2002-04-10   102.862373   105.553665   102.480934   105.553665
# 4    2002-04-11   107.467941   109.389282   106.705055   109.007835
# ...         ...          ...          ...          ...          ...
# 5156 2023-02-23  2215.000000  2250.000000  2215.000000  2225.000000
# 5157 2023-02-24  2245.000000  2255.000000  2205.000000  2205.000000
# 5158 2023-03-01  2155.000000  2185.000000  2155.000000  2165.000000
# 5159 2023-03-02  2165.000000  2215.000000  2135.000000  2210.000000
# 5160 2023-03-03  2220.000000  2260.000000  2220.000000  2230.000000
#
#          adjclose    volume   ticker       MinLow      MaxHigh  ...  \
# 0       67.701019       0.0  3008.TW   101.329536   121.284645  ...
# 1       68.702370  971809.0  3008.TW    99.796707   120.903198  ...
# 2       67.198029  528893.0  3008.TW    99.796707   115.527679  ...
# 3       68.956192  455941.0  3008.TW    99.796707   114.764801  ...
# 4       71.212746  956175.0  3008.TW    99.796707   113.224899  ...
# ...           ...       ...      ...          ...          ...  ...
# 5156  2225.000000  285036.0  3008.TW  2165.000000  2270.000000  ...
# 5157  2205.000000  405228.0  3008.TW  2165.000000  2270.000000  ...
# 5158  2165.000000  556733.0  3008.TW  2155.000000  2270.000000  ...
# 5159  2210.000000  482042.0  3008.TW  2135.000000  2270.000000  ...
# 5160  2230.000000  602611.0  3008.TW  2135.000000  2270.000000  ...
#
#          UpLine   DownLine        RSI    K_Value    D_Value        DIF  \
# 0      0.000000   0.000000  28.351649  15.737990  25.210904  -9.183556
# 1      0.388512   0.000000  27.272716  18.970343  23.130717  -8.990700
# 2      0.000000   0.000000  20.573908  19.142926  21.801453  -8.920842
# 3      0.000000   0.381439  28.769552  25.582461  23.061789  -8.549757
# 4      0.381447   0.762886  31.581485  39.920122  28.681233  -7.886042
# ...         ...        ...        ...        ...        ...        ...
# 5156  25.000000   0.000000  51.250000  45.739478  42.111814  16.128969
# 5157  10.000000   0.000000  46.250000  43.191398  42.471675  14.293006
# 5158  20.000000   0.000000  44.578313  31.692816  38.878722   9.500808
# 5159   5.000000  30.000000  44.578313  39.647062  39.134835   9.227709
# 5160  30.000000   0.000000  52.564103  49.888165  42.719279  10.504025
#
#            MACD     Up_Track    Mid_Track   Down_Track
# 0     -9.270268   136.775099   112.152976    87.530853
# 1     -9.214355   124.825565   109.676424    94.527282
# 2     -9.155652   122.906133   110.328761    97.751390
# 3     -9.034473   121.786104   110.808743    99.831383
# 4     -8.804787   121.472139   111.135088   100.798038
# ...         ...          ...          ...          ...
# 5156  16.553873  2292.310672  2205.750000  2119.189328
# 5157  16.101699  2274.737999  2212.250000  2149.762001
# 5158  14.781521  2274.737999  2212.250000  2149.762001
# 5159  13.670759  2264.572861  2216.500000  2168.427139
# 5160  13.037412  2265.672619  2217.250000  2168.827381
#
# [5161 rows x 23 columns]

# %% [markdown]
# # 查找DF的標籤

# %%
dfStartDate_Train = df[(df['index']=='2020-01-02')].index.values
dfStartDate_Train = dfStartDate_Train[0]
dfStartDate_Train
# Out:
# 4393

# %%
dfEndDate_Train = df[(df['index']=='2022-12-30')].index.values
dfEndDate_Train = dfEndDate_Train[0]
dfEndDate_Train
# Out:
# 5126

# %%
df[dfStartDate_Train:dfEndDate_Train+1]
# Out:
#           index    open    high     low   close     adjclose     volume  \
# 4393 2020-01-02  5055.0  5090.0  5015.0  5030.0  4531.391602   398147.0
# 4394 2020-01-03  5105.0  5155.0  4875.0  4880.0  4396.260742   892399.0
# 4395 2020-01-06  4780.0  4865.0  4680.0  4695.0  4229.599121  1276386.0
# 4396 2020-01-07  4740.0  4785.0  4640.0  4740.0  4270.139160   846521.0
# 4397 2020-01-08  4700.0  4820.0  4670.0  4785.0  4310.678223   510126.0
# ...         ...     ...     ...     ...     ...          ...        ...
# 5122 2022-12-26  2160.0  2160.0  2110.0  2120.0  2120.000000   146374.0
# 5123 2022-12-27  2130.0  2165.0  2130.0  2165.0  2165.000000   190969.0
# 5124 2022-12-28  2145.0  2150.0  2105.0  2110.0  2110.000000   275648.0
# 5125 2022-12-29  2075.0  2075.0  2040.0  2050.0  2050.000000   509610.0
# 5126 2022-12-30  2065.0  2085.0  2040.0  2040.0  2040.000000   303129.0
#
#        ticker  MinLow  MaxHigh  ...  UpLine  DownLine        RSI    K_Value  \
# 4393  3008.TW  4860.0   5130.0  ...    35.0      15.0  65.354331  46.801609
# 4394  3008.TW  4860.0   5155.0  ...    50.0       5.0  36.206897  33.460960
# 4395  3008.TW  4680.0   5155.0  ...    85.0      15.0  27.450980  23.359938
# 4396  3008.TW  4640.0   5155.0  ...    45.0     100.0  29.746835  22.045784
# 4397  3008.TW  4640.0   5155.0  ...    35.0      30.0  34.782609  24.082303
# ...       ...     ...      ...  ...     ...       ...        ...        ...
# 5122  3008.TW  2110.0   2280.0  ...     0.0      10.0  32.394366  16.278754
# 5123  3008.TW  2110.0   2280.0  ...     0.0       0.0  46.376812  21.636816
# 5124  3008.TW  2105.0   2280.0  ...     5.0       5.0  38.461538  15.376925
# 5125  3008.TW  2040.0   2280.0  ...     0.0      10.0  34.090909  11.640172
# 5126  3008.TW  2040.0   2270.0  ...    20.0       0.0  21.052632   7.760115
#
#         D_Value         DIF        MACD     Up_Track  Mid_Track   Down_Track
# 4393  44.691211  112.624010  114.305162  5144.945513    4889.75  4634.554487
# 4394  40.947794   99.557963  111.355722  5139.895919    4898.25  4656.604081
# 4395  35.085175   73.428633  103.770304  5139.292442    4898.50  4657.707558
# 4396  30.738712   55.709886   94.158220  5142.912963    4894.50  4646.087037
# 4397  28.519909   44.782550   84.283086  5133.130865    4900.00  4666.869135
# ...         ...         ...         ...          ...        ...          ...
# 5122  25.960075    6.368110   32.395522  2339.215224    2230.50  2121.784776
# 5123  24.518989    3.887431   26.693904  2335.951174    2225.25  2114.548826
# 5124  21.471634   -2.487886   20.857546  2332.601887    2216.00  2099.398113
# 5125  18.194480  -12.240766   14.237883  2336.045447    2204.00  2071.954553
# 5126  14.716358  -20.540136    7.282280  2335.413168    2191.50  2047.586832
#
# [734 rows x 23 columns]

# %%
def my_process_data(df, window_size, frame_bound):
    start = frame_bound[0] - window_size #start = 5 - 5
    end = frame_bound[1] #end = 5600 
    close = df.loc[:, 'close'].to_numpy()[start:end]#抓取Close
    open = df.loc[:, 'open'].to_numpy()[start:end]#抓取open
    high = df.loc[:, 'high'].to_numpy()[start:end]#抓取high
    low = df.loc[:, 'low'].to_numpy()[start:end]#抓取low
    volnume = df.loc[:, 'volume'].to_numpy()[start:end]#抓取volume
    signal_features = df.loc[:, ['DIF', 'MACD']].to_numpy()[start:end]#抓取特徵資料
    return open, close, high, low, volnume, signal_features


class MyStocksEnv(StocksEnv):
    
    def __init__(self, open, close, high, low, volnume, signal_features, **kwargs):
        self._open = open
        self._close = close
        self._high = high
        self._low = low
        self._volnume = volnume
        self._signal_features = signal_features
        super().__init__(**kwargs)

    def _process_data(self):
        return self._open, self._close, self._high, self._low, self._volnume, self._signal_features

    
open, close, high, low, volume, signal_features = my_process_data(df=df, window_size=10, frame_bound=(dfStartDate_Train, dfEndDate_Train+1))#Close與特徵資料
env = MyStocksEnv(open, close, high, low, volume, signal_features, df=df, window_size=10, frame_bound=(dfStartDate_Train, dfEndDate_Train+1))#「環境」整合

# %%
policy_kwargs = dict(net_arch=[32, 'lstm', dict(vf=[16,16,16], pi=[16,16,16])])#要傳遞給policy的參數

model = A2C('MlpLstmPolicy', env, verbose=1, policy_kwargs=policy_kwargs, learning_rate=0.000000001)
# model = A2C('MlpLstmPolicy', env, verbose=1)
#policy: The policy model to use (MlpPolicy, CnnPolicy, …)""
#verbose: 0 no output, 1 info, 2 debug
#policy_kwargs: additional arguments to be passed to the policy on creation要傳遞給policy的參數
model.learn(total_timesteps=2000000)
# Out:
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | explained_variance | -3.58e-07 |
# | fps                | 2         |
# | nupdates           | 1         |
# | policy_entropy     | 0.688     |
# | total_timesteps    | 5         |
# | value_loss         | 3.97e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 7.15e-07 |
# | fps                | 129      |
# | nupdates           | 100      |
# | policy_entropy     | 0.69     |
# | total_timesteps    | 500      |
# | value_loss         | 1.75e+10 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -8.34e-07 |
# | fps                | 159       |
# | nupdates           | 200       |
# | policy_entropy     | 0.69      |
# | total_timesteps    | 1000      |
# | value_loss         | 4.87e+08  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 4.17e-07 |
# | fps                | 179      |
# | nupdates           | 300      |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 1500     |
# | value_loss         | 1.02e+10 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 191      |
# | nupdates           | 400      |
# | policy_entropy     | 0.689    |
# | total_timesteps    | 2000     |
# | value_loss         | 3.7e+08  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 6.56e-07 |
# | fps                | 201      |
# | nupdates           | 500      |
# | policy_entropy     | 0.686    |
# | total_timesteps    | 2500     |
# | value_loss         | 1.28e+10 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -7.15e-07 |
# | fps                | 206       |
# | nupdates           | 600       |
# | policy_entropy     | 0.688     |
# | total_timesteps    | 3000      |
# | value_loss         | 4.17e+08  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -1.91e-06 |
# | fps                | 210       |
# | nupdates           | 700       |
# | policy_entropy     | 0.688     |
# | total_timesteps    | 3500      |
# | value_loss         | 3.96e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 214      |
# | nupdates           | 800      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 4000     |
# | value_loss         | 2.1e+10  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 7.75e-07 |
# | fps                | 218      |
# | nupdates           | 900      |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 4500     |
# | value_loss         | 6.18e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.19e-06 |
# | fps                | 221      |
# | nupdates           | 1000     |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 5000     |
# | value_loss         | 1.15e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -4.77e-06 |
# | fps                | 223       |
# | nupdates           | 1100      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 5500      |
# | value_loss         | 6.13e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 1.55e-06 |
# | fps                | 224      |
# | nupdates           | 1200     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 6000     |
# | value_loss         | 3.39e+10 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.38e-06 |
# | fps                | 226      |
# | nupdates           | 1300     |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 6500     |
# | value_loss         | 9.22e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -9.54e-07 |
# | fps                | 228       |
# | nupdates           | 1400      |
# | policy_entropy     | 0.69      |
# | total_timesteps    | 7000      |
# | value_loss         | 1.02e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 8.34e-07 |
# | fps                | 229      |
# | nupdates           | 1500     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 7500     |
# | value_loss         | 7.51e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -5.84e-06 |
# | fps                | 230       |
# | nupdates           | 1600      |
# | policy_entropy     | 0.686     |
# | total_timesteps    | 8000      |
# | value_loss         | 5.15e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -2.5e-06 |
# | fps                | 231      |
# | nupdates           | 1700     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 8500     |
# | value_loss         | 3.15e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -4.77e-07 |
# | fps                | 231       |
# | nupdates           | 1800      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 9000      |
# | value_loss         | 5.16e+08  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -7.15e-07 |
# | fps                | 231       |
# | nupdates           | 1900      |
# | policy_entropy     | 0.688     |
# | total_timesteps    | 9500      |
# | value_loss         | 1.44e+09  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -1.19e-07 |
# | fps                | 231       |
# | nupdates           | 2000      |
# | policy_entropy     | 0.688     |
# | total_timesteps    | 10000     |
# | value_loss         | 1.6e+08   |
# ----------------------------------
# ---------------------------------
# | explained_variance | 2.98e-06 |
# | fps                | 231      |
# | nupdates           | 2100     |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 10500    |
# | value_loss         | 2.15e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.98e-07 |
# | fps                | 232      |
# | nupdates           | 2200     |
# | policy_entropy     | 0.685    |
# | total_timesteps    | 11000    |
# | value_loss         | 3.95e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.19e-06 |
# | fps                | 231      |
# | nupdates           | 2300     |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 11500    |
# | value_loss         | 2.31e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.67e-06 |
# | fps                | 230      |
# | nupdates           | 2400     |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 12000    |
# | value_loss         | 3.8e+09  |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.38e-07 |
# | fps                | 229       |
# | nupdates           | 2500      |
# | policy_entropy     | 0.69      |
# | total_timesteps    | 12500     |
# | value_loss         | 2.49e+10  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -2.5e-06 |
# | fps                | 228      |
# | nupdates           | 2600     |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 13000    |
# | value_loss         | 2.06e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 4.77e-07 |
# | fps                | 228      |
# | nupdates           | 2700     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 13500    |
# | value_loss         | 1.11e+10 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.98e-07 |
# | fps                | 227      |
# | nupdates           | 2800     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 14000    |
# | value_loss         | 3.15e+10 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.91e-06 |
# | fps                | 226       |
# | nupdates           | 2900      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 14500     |
# | value_loss         | 1.52e+08  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -1.43e-06 |
# | fps                | 225       |
# | nupdates           | 3000      |
# | policy_entropy     | 0.689     |
# | total_timesteps    | 15000     |
# | value_loss         | 2.96e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 3.52e-06 |
# | fps                | 225      |
# | nupdates           | 3100     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 15500    |
# | value_loss         | 1.46e+10 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 224      |
# | nupdates           | 3200     |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 16000    |
# | value_loss         | 6.26e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.27e-05 |
# | fps                | 223      |
# | nupdates           | 3300     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 16500    |
# | value_loss         | 5.9e+08  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.19e-07 |
# | fps                | 222      |
# | nupdates           | 3400     |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 17000    |
# | value_loss         | 8.88e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -3.1e-06 |
# | fps                | 221      |
# | nupdates           | 3500     |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 17500    |
# | value_loss         | 2.46e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -7.03e-06 |
# | fps                | 220       |
# | nupdates           | 3600      |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 18000     |
# | value_loss         | 1.11e+09  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -2.62e-06 |
# | fps                | 220       |
# | nupdates           | 3700      |
# | policy_entropy     | 0.687     |
# | total_timesteps    | 18500     |
# | value_loss         | 8.45e+09  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -1.19e-07 |
# | fps                | 219       |
# | nupdates           | 3800      |
# | policy_entropy     | 0.69      |
# | total_timesteps    | 19000     |
# | value_loss         | 4.36e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 7.15e-07 |
# | fps                | 219      |
# | nupdates           | 3900     |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 19500    |
# | value_loss         | 1.5e+09  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 6.56e-07 |
# | fps                | 218      |
# | nupdates           | 4000     |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 20000    |
# | value_loss         | 1.45e+10 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.07e-06 |
# | fps                | 217       |
# | nupdates           | 4100      |
# | policy_entropy     | 0.689     |
# | total_timesteps    | 20500     |
# | value_loss         | 8.25e+09  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -2.38e-07 |
# | fps                | 216       |
# | nupdates           | 4200      |
# | policy_entropy     | 0.688     |
# | total_timesteps    | 21000     |
# | value_loss         | 3.6e+09   |
# ----------------------------------
# ----------------------------------
# | explained_variance | -7.15e-07 |
# | fps                | 214       |
# | nupdates           | 4300      |
# | policy_entropy     | 0.69      |
# | total_timesteps    | 21500     |
# | value_loss         | 1.64e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 2.56e-06 |
# | fps                | 214      |
# | nupdates           | 4400     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 22000    |
# | value_loss         | 4.59e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -9.54e-07 |
# | fps                | 213       |
# | nupdates           | 4500      |
# | policy_entropy     | 0.688     |
# | total_timesteps    | 22500     |
# | value_loss         | 1.6e+09   |
# ----------------------------------
# ----------------------------------
# | explained_variance | -2.03e-06 |
# | fps                | 211       |
# | nupdates           | 4600      |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 23000     |
# | value_loss         | 4.83e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 1.79e-07 |
# | fps                | 210      |
# | nupdates           | 4700     |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 23500    |
# | value_loss         | 1e+10    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -5.48e-06 |
# | fps                | 209       |
# | nupdates           | 4800      |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 24000     |
# | value_loss         | 2.07e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 3.81e-06 |
# | fps                | 208      |
# | nupdates           | 4900     |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 24500    |
# | value_loss         | 2e+10    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.19e-07 |
# | fps                | 207       |
# | nupdates           | 5000      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 25000     |
# | value_loss         | 9.67e+10  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -3.58e-07 |
# | fps                | 207       |
# | nupdates           | 5100      |
# | policy_entropy     | 0.688     |
# | total_timesteps    | 25500     |
# | value_loss         | 2.3e+09   |
# ----------------------------------
# ----------------------------------
# | explained_variance | -6.68e-06 |
# | fps                | 206       |
# | nupdates           | 5200      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 26000     |
# | value_loss         | 4.16e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 206      |
# | nupdates           | 5300     |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 26500    |
# | value_loss         | 4.46e+10 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 205      |
# | nupdates           | 5400     |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 27000    |
# | value_loss         | 1e+09    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -3.58e-06 |
# | fps                | 205       |
# | nupdates           | 5500      |
# | policy_entropy     | 0.687     |
# | total_timesteps    | 27500     |
# | value_loss         | 3.1e+08   |
# ----------------------------------
# ---------------------------------
# | explained_variance | 1.67e-06 |
# | fps                | 204      |
# | nupdates           | 5600     |
# | policy_entropy     | 0.69     |
# | total_timesteps    | 28000    |
# | value_loss         | 2.06e+10 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 9.3e-06  |
# | fps                | 204      |
# | nupdates           | 5700     |
# | policy_entropy     | 0.687    |
# | total_timesteps    | 28500    |
# | value_loss         | 1.67e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.03e-06 |
# | fps                | 203      |
# | nupdates           | 5800     |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 29000    |
# | value_loss         | 6.19e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -3.1e-06 |
# | fps                | 203      |
# | nupdates           | 5900     |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 29500    |
# | value_loss         | 1.87e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 9.54e-07 |
# | fps                | 202      |
# | nupdates           | 6000     |
# | policy_entropy     | 0.687    |
# | total_timesteps    | 30000    |
# | value_loss         | 5.53e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -3.22e-06 |
# | fps                | 201       |
# | nupdates           | 6100      |
# | policy_entropy     | 0.688     |
# | total_timesteps    | 30500     |
# | value_loss         | 1.43e+09  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -2.15e-06 |
# | fps                | 200       |
# | nupdates           | 6200      |
# | policy_entropy     | 0.687     |
# | total_timesteps    | 31000     |
# | value_loss         | 9.66e+09  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -1.19e-06 |
# | fps                | 199       |
# | nupdates           | 6300      |
# | policy_entropy     | 0.691     |
# | total_timesteps    | 31500     |
# | value_loss         | 8.48e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 3.04e-06 |
# | fps                | 198      |
# | nupdates           | 6400     |
# | policy_entropy     | 0.69     |
# | total_timesteps    | 32000    |
# | value_loss         | 1.42e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.67e-06 |
# | fps                | 197       |
# | nupdates           | 6500      |
# | policy_entropy     | 0.687     |
# | total_timesteps    | 32500     |
# | value_loss         | 4.14e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 4.17e-07 |
# | fps                | 196      |
# | nupdates           | 6600     |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 33000    |
# | value_loss         | 1.89e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.92e-06 |
# | fps                | 195      |
# | nupdates           | 6700     |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 33500    |
# | value_loss         | 5.35e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -7.15e-07 |
# | fps                | 195       |
# | nupdates           | 6800      |
# | policy_entropy     | 0.686     |
# | total_timesteps    | 34000     |
# | value_loss         | 4e+09     |
# ----------------------------------
# ----------------------------------
# | explained_variance | -2.38e-07 |
# | fps                | 194       |
# | nupdates           | 6900      |
# | policy_entropy     | 0.69      |
# | total_timesteps    | 34500     |
# | value_loss         | 1.43e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 5.01e-06 |
# | fps                | 194      |
# | nupdates           | 7000     |
# | policy_entropy     | 0.69     |
# | total_timesteps    | 35000    |
# | value_loss         | 3.09e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -4.77e-07 |
# | fps                | 194       |
# | nupdates           | 7100      |
# | policy_entropy     | 0.689     |
# | total_timesteps    | 35500     |
# | value_loss         | 4.78e+08  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -3.58e-07 |
# | fps                | 193       |
# | nupdates           | 7200      |
# | policy_entropy     | 0.69      |
# | total_timesteps    | 36000     |
# | value_loss         | 1.18e+10  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -1.19e-07 |
# | fps                | 193       |
# | nupdates           | 7300      |
# | policy_entropy     | 0.689     |
# | total_timesteps    | 36500     |
# | value_loss         | 1.12e+09  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -2.38e-07 |
# | fps                | 193       |
# | nupdates           | 7400      |
# | policy_entropy     | 0.687     |
# | total_timesteps    | 37000     |
# | value_loss         | 3.57e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 2.38e-07 |
# | fps                | 192      |
# | nupdates           | 7500     |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 37500    |
# | value_loss         | 2.33e+10 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.85e-06 |
# | fps                | 192      |
# | nupdates           | 7600     |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 38000    |
# | value_loss         | 6.46e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 5.96e-07 |
# | fps                | 192      |
# | nupdates           | 7700     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 38500    |
# | value_loss         | 2.48e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -3.58e-07 |
# | fps                | 191       |
# | nupdates           | 7800      |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 39000     |
# | value_loss         | 2.22e+10  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -7.63e-06 |
# | fps                | 190       |
# | nupdates           | 7900      |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 39500     |
# | value_loss         | 1.22e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -2.5e-06 |
# | fps                | 189      |
# | nupdates           | 8000     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 40000    |
# | value_loss         | 1.65e+10 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.25e-06 |
# | fps                | 188      |
# | nupdates           | 8100     |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 40500    |
# | value_loss         | 4.96e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 5.96e-07 |
# | fps                | 188      |
# | nupdates           | 8200     |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 41000    |
# | value_loss         | 5.02e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.98e-06 |
# | fps                | 187       |
# | nupdates           | 8300      |
# | policy_entropy     | 0.691     |
# | total_timesteps    | 41500     |
# | value_loss         | 5.35e+08  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 1.49e-06 |
# | fps                | 186      |
# | nupdates           | 8400     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 42000    |
# | value_loss         | 1.41e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 3.7e-06  |
# | fps                | 185      |
# | nupdates           | 8500     |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 42500    |
# | value_loss         | 2.9e+08  |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.67e-06 |
# | fps                | 184       |
# | nupdates           | 8600      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 43000     |
# | value_loss         | 1.8e+08   |
# ----------------------------------
# ----------------------------------
# | explained_variance | -3.58e-07 |
# | fps                | 183       |
# | nupdates           | 8700      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 43500     |
# | value_loss         | 5.43e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 8.94e-07 |
# | fps                | 182      |
# | nupdates           | 8800     |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 44000    |
# | value_loss         | 2.39e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.98e-07 |
# | fps                | 181      |
# | nupdates           | 8900     |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 44500    |
# | value_loss         | 1.15e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 3.52e-06 |
# | fps                | 180      |
# | nupdates           | 9000     |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 45000    |
# | value_loss         | 3.33e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 179      |
# | nupdates           | 9100     |
# | policy_entropy     | 0.684    |
# | total_timesteps    | 45500    |
# | value_loss         | 3.01e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.37e-06 |
# | fps                | 178      |
# | nupdates           | 9200     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 46000    |
# | value_loss         | 6.3e+09  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.37e-06 |
# | fps                | 177      |
# | nupdates           | 9300     |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 46500    |
# | value_loss         | 1.32e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 9.54e-07 |
# | fps                | 176      |
# | nupdates           | 9400     |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 47000    |
# | value_loss         | 1.3e+10  |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.74e-06 |
# | fps                | 175       |
# | nupdates           | 9500      |
# | policy_entropy     | 0.688     |
# | total_timesteps    | 47500     |
# | value_loss         | 9.2e+08   |
# ----------------------------------
# ---------------------------------
# | explained_variance | 1.25e-06 |
# | fps                | 174      |
# | nupdates           | 9600     |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 48000    |
# | value_loss         | 4.84e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 7.15e-07 |
# | fps                | 173      |
# | nupdates           | 9700     |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 48500    |
# | value_loss         | 2.37e+10 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 5.96e-08 |
# | fps                | 172      |
# | nupdates           | 9800     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 49000    |
# | value_loss         | 2.74e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.25e-06 |
# | fps                | 171      |
# | nupdates           | 9900     |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 49500    |
# | value_loss         | 3.93e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -3.58e-07 |
# | fps                | 170       |
# | nupdates           | 10000     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 50000     |
# | value_loss         | 1.67e+10  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -1.19e-07 |
# | fps                | 170       |
# | nupdates           | 10100     |
# | policy_entropy     | 0.688     |
# | total_timesteps    | 50500     |
# | value_loss         | 2.5e+09   |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 169      |
# | nupdates           | 10200    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 51000    |
# | value_loss         | 1.38e+10 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.38e-07 |
# | fps                | 168       |
# | nupdates           | 10300     |
# | policy_entropy     | 0.691     |
# | total_timesteps    | 51500     |
# | value_loss         | 4.78e+09  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -3.81e-06 |
# | fps                | 168       |
# | nupdates           | 10400     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 52000     |
# | value_loss         | 3.21e+08  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -3.46e-06 |
# | fps                | 167       |
# | nupdates           | 10500     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 52500     |
# | value_loss         | 4.92e+09  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -5.96e-07 |
# | fps                | 167       |
# | nupdates           | 10600     |
# | policy_entropy     | 0.687     |
# | total_timesteps    | 53000     |
# | value_loss         | 1.68e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 2.86e-06 |
# | fps                | 166      |
# | nupdates           | 10700    |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 53500    |
# | value_loss         | 1.71e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.73e-06 |
# | fps                | 165      |
# | nupdates           | 10800    |
# | policy_entropy     | 0.689    |
# | total_timesteps    | 54000    |
# | value_loss         | 1.74e+10 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 6.56e-07 |
# | fps                | 164      |
# | nupdates           | 10900    |
# | policy_entropy     | 0.689    |
# | total_timesteps    | 54500    |
# | value_loss         | 2.38e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.55e-06 |
# | fps                | 163       |
# | nupdates           | 11000     |
# | policy_entropy     | 0.688     |
# | total_timesteps    | 55000     |
# | value_loss         | 3.97e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 162      |
# | nupdates           | 11100    |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 55500    |
# | value_loss         | 7.8e+08  |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.15e-06 |
# | fps                | 162       |
# | nupdates           | 11200     |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 56000     |
# | value_loss         | 8.37e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 3.64e-06 |
# | fps                | 161      |
# | nupdates           | 11300    |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 56500    |
# | value_loss         | 2.12e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.19e-06 |
# | fps                | 160       |
# | nupdates           | 11400     |
# | policy_entropy     | 0.689     |
# | total_timesteps    | 57000     |
# | value_loss         | 6.52e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 4.95e-06 |
# | fps                | 160      |
# | nupdates           | 11500    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 57500    |
# | value_loss         | 1.33e+10 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 3.58e-07 |
# | fps                | 159      |
# | nupdates           | 11600    |
# | policy_entropy     | 0.69     |
# | total_timesteps    | 58000    |
# | value_loss         | 2.45e+10 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -8.34e-07 |
# | fps                | 159       |
# | nupdates           | 11700     |
# | policy_entropy     | 0.691     |
# | total_timesteps    | 58500     |
# | value_loss         | 1.99e+09  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -1.19e-06 |
# | fps                | 158       |
# | nupdates           | 11800     |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 59000     |
# | value_loss         | 9.46e+09  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -1.19e-07 |
# | fps                | 158       |
# | nupdates           | 11900     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 59500     |
# | value_loss         | 9.22e+10  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -2.98e-06 |
# | fps                | 157       |
# | nupdates           | 12000     |
# | policy_entropy     | 0.688     |
# | total_timesteps    | 60000     |
# | value_loss         | 1.24e+09  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -3.81e-06 |
# | fps                | 156       |
# | nupdates           | 12100     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 60500     |
# | value_loss         | 8.63e+08  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 5.96e-08 |
# | fps                | 156      |
# | nupdates           | 12200    |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 61000    |
# | value_loss         | 2.32e+10 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 155      |
# | nupdates           | 12300    |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 61500    |
# | value_loss         | 3.23e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -3.58e-07 |
# | fps                | 155       |
# | nupdates           | 12400     |
# | policy_entropy     | 0.687     |
# | total_timesteps    | 62000     |
# | value_loss         | 5.83e+08  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -5.96e-07 |
# | fps                | 154       |
# | nupdates           | 12500     |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 62500     |
# | value_loss         | 5.55e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 8.34e-06 |
# | fps                | 154      |
# | nupdates           | 12600    |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 63000    |
# | value_loss         | 1.03e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 7.75e-07 |
# | fps                | 154      |
# | nupdates           | 12700    |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 63500    |
# | value_loss         | 2.24e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.98e-07 |
# | fps                | 154      |
# | nupdates           | 12800    |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 64000    |
# | value_loss         | 3.29e+10 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -5.96e-07 |
# | fps                | 154       |
# | nupdates           | 12900     |
# | policy_entropy     | 0.686     |
# | total_timesteps    | 64500     |
# | value_loss         | 8.21e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 1.73e-06 |
# | fps                | 154      |
# | nupdates           | 13000    |
# | policy_entropy     | 0.687    |
# | total_timesteps    | 65000    |
# | value_loss         | 3.44e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -3.58e-07 |
# | fps                | 153       |
# | nupdates           | 13100     |
# | policy_entropy     | 0.687     |
# | total_timesteps    | 65500     |
# | value_loss         | 7.99e+08  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -4.77e-07 |
# | fps                | 153       |
# | nupdates           | 13200     |
# | policy_entropy     | 0.691     |
# | total_timesteps    | 66000     |
# | value_loss         | 1.41e+10  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 1.05e-05 |
# | fps                | 153      |
# | nupdates           | 13300    |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 66500    |
# | value_loss         | 2.39e+10 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.98e-07 |
# | fps                | 153      |
# | nupdates           | 13400    |
# | policy_entropy     | 0.687    |
# | total_timesteps    | 67000    |
# | value_loss         | 7.09e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 3.34e-06 |
# | fps                | 152      |
# | nupdates           | 13500    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 67500    |
# | value_loss         | 3.33e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.19e-06 |
# | fps                | 152      |
# | nupdates           | 13600    |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 68000    |
# | value_loss         | 1.36e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.13e-06 |
# | fps                | 152      |
# | nupdates           | 13700    |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 68500    |
# | value_loss         | 5.86e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 152      |
# | nupdates           | 13800    |
# | policy_entropy     | 0.689    |
# | total_timesteps    | 69000    |
# | value_loss         | 1.87e+10 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.68e-06 |
# | fps                | 152      |
# | nupdates           | 13900    |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 69500    |
# | value_loss         | 8.86e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.79e-06 |
# | fps                | 152       |
# | nupdates           | 14000     |
# | policy_entropy     | 0.688     |
# | total_timesteps    | 70000     |
# | value_loss         | 1.05e+10  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 1.79e-07 |
# | fps                | 152      |
# | nupdates           | 14100    |
# | policy_entropy     | 0.689    |
# | total_timesteps    | 70500    |
# | value_loss         | 1.45e+10 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 6.56e-07 |
# | fps                | 152      |
# | nupdates           | 14200    |
# | policy_entropy     | 0.689    |
# | total_timesteps    | 71000    |
# | value_loss         | 1.9e+09  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 4.77e-07 |
# | fps                | 152      |
# | nupdates           | 14300    |
# | policy_entropy     | 0.69     |
# | total_timesteps    | 71500    |
# | value_loss         | 1.12e+10 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.19e-07 |
# | fps                | 151       |
# | nupdates           | 14400     |
# | policy_entropy     | 0.688     |
# | total_timesteps    | 72000     |
# | value_loss         | 5.45e+09  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -7.15e-07 |
# | fps                | 151       |
# | nupdates           | 14500     |
# | policy_entropy     | 0.687     |
# | total_timesteps    | 72500     |
# | value_loss         | 7.53e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 6.56e-07 |
# | fps                | 151      |
# | nupdates           | 14600    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 73000    |
# | value_loss         | 2.5e+09  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.09e-06 |
# | fps                | 151      |
# | nupdates           | 14700    |
# | policy_entropy     | 0.689    |
# | total_timesteps    | 73500    |
# | value_loss         | 3.83e+10 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -5.13e-06 |
# | fps                | 151       |
# | nupdates           | 14800     |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 74000     |
# | value_loss         | 2.19e+08  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -2.03e-06 |
# | fps                | 151       |
# | nupdates           | 14900     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 74500     |
# | value_loss         | 1.47e+10  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 1.49e-06 |
# | fps                | 151      |
# | nupdates           | 15000    |
# | policy_entropy     | 0.69     |
# | total_timesteps    | 75000    |
# | value_loss         | 1.05e+10 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -3.93e-06 |
# | fps                | 151       |
# | nupdates           | 15100     |
# | policy_entropy     | 0.69      |
# | total_timesteps    | 75500     |
# | value_loss         | 2.9e+08   |
# ----------------------------------
# ----------------------------------
# | explained_variance | -2.86e-06 |
# | fps                | 151       |
# | nupdates           | 15200     |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 76000     |
# | value_loss         | 3.27e+09  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -7.15e-07 |
# | fps                | 151       |
# | nupdates           | 15300     |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 76500     |
# | value_loss         | 1.01e+10  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 3.46e-06 |
# | fps                | 150      |
# | nupdates           | 15400    |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 77000    |
# | value_loss         | 2.69e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -5.96e-07 |
# | fps                | 150       |
# | nupdates           | 15500     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 77500     |
# | value_loss         | 1.5e+09   |
# ----------------------------------
# ----------------------------------
# | explained_variance | -5.96e-07 |
# | fps                | 150       |
# | nupdates           | 15600     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 78000     |
# | value_loss         | 1.04e+10  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 8.94e-07 |
# | fps                | 150      |
# | nupdates           | 15700    |
# | policy_entropy     | 0.69     |
# | total_timesteps    | 78500    |
# | value_loss         | 3.37e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -8.34e-07 |
# | fps                | 150       |
# | nupdates           | 15800     |
# | policy_entropy     | 0.69      |
# | total_timesteps    | 79000     |
# | value_loss         | 1.06e+08  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -2.38e-06 |
# | fps                | 150       |
# | nupdates           | 15900     |
# | policy_entropy     | 0.689     |
# | total_timesteps    | 79500     |
# | value_loss         | 3.97e+08  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -3.58e-07 |
# | fps                | 150       |
# | nupdates           | 16000     |
# | policy_entropy     | 0.685     |
# | total_timesteps    | 80000     |
# | value_loss         | 7.74e+08  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 1.49e-06 |
# | fps                | 150      |
# | nupdates           | 16100    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 80500    |
# | value_loss         | 2.06e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -7.15e-07 |
# | fps                | 150       |
# | nupdates           | 16200     |
# | policy_entropy     | 0.691     |
# | total_timesteps    | 81000     |
# | value_loss         | 3.14e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 7.99e-06 |
# | fps                | 150      |
# | nupdates           | 16300    |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 81500    |
# | value_loss         | 3.23e+10 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.09e-06 |
# | fps                | 150      |
# | nupdates           | 16400    |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 82000    |
# | value_loss         | 1.84e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.91e-06 |
# | fps                | 150      |
# | nupdates           | 16500    |
# | policy_entropy     | 0.69     |
# | total_timesteps    | 82500    |
# | value_loss         | 4.34e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.19e-07 |
# | fps                | 150      |
# | nupdates           | 16600    |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 83000    |
# | value_loss         | 4.63e+10 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.79e-06 |
# | fps                | 149       |
# | nupdates           | 16700     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 83500     |
# | value_loss         | 1.92e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 1.01e-06 |
# | fps                | 149      |
# | nupdates           | 16800    |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 84000    |
# | value_loss         | 9.42e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -3.58e-07 |
# | fps                | 149       |
# | nupdates           | 16900     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 84500     |
# | value_loss         | 2.48e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 149      |
# | nupdates           | 17000    |
# | policy_entropy     | 0.69     |
# | total_timesteps    | 85000    |
# | value_loss         | 2.64e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.19e-05 |
# | fps                | 149       |
# | nupdates           | 17100     |
# | policy_entropy     | 0.691     |
# | total_timesteps    | 85500     |
# | value_loss         | 2.56e+09  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -1.67e-06 |
# | fps                | 149       |
# | nupdates           | 17200     |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 86000     |
# | value_loss         | 7.8e+09   |
# ----------------------------------
# ---------------------------------
# | explained_variance | 5.9e-06  |
# | fps                | 149      |
# | nupdates           | 17300    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 86500    |
# | value_loss         | 8.15e+08 |
# ---------------------------------
# ...
# ---------------------------------
# ---------------------------------
# | explained_variance | 5.96e-08 |
# | fps                | 192      |
# | nupdates           | 394300   |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 1971500  |
# | value_loss         | 8.92e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 5.48e-06 |
# | fps                | 192      |
# | nupdates           | 394400   |
# | policy_entropy     | 0.689    |
# | total_timesteps    | 1972000  |
# | value_loss         | 9.35e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 8.88e-06 |
# | fps                | 192      |
# | nupdates           | 394500   |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 1972500  |
# | value_loss         | 2.99e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 4.17e-07 |
# | fps                | 192      |
# | nupdates           | 394600   |
# | policy_entropy     | 0.686    |
# | total_timesteps    | 1973000  |
# | value_loss         | 1.18e+10 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.28e-05 |
# | fps                | 192      |
# | nupdates           | 394700   |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 1973500  |
# | value_loss         | 3.25e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -4.77e-07 |
# | fps                | 192       |
# | nupdates           | 394800    |
# | policy_entropy     | 0.687     |
# | total_timesteps    | 1974000   |
# | value_loss         | 7.52e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 1.61e-06 |
# | fps                | 192      |
# | nupdates           | 394900   |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 1974500  |
# | value_loss         | 1.83e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -4.65e-06 |
# | fps                | 192       |
# | nupdates           | 395000    |
# | policy_entropy     | 0.687     |
# | total_timesteps    | 1975000   |
# | value_loss         | 1.26e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 1.39e-05 |
# | fps                | 192      |
# | nupdates           | 395100   |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 1975500  |
# | value_loss         | 2.36e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 192      |
# | nupdates           | 395200   |
# | policy_entropy     | 0.687    |
# | total_timesteps    | 1976000  |
# | value_loss         | 3.07e+10 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 192      |
# | nupdates           | 395300   |
# | policy_entropy     | 0.687    |
# | total_timesteps    | 1976500  |
# | value_loss         | 5.19e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -5.96e-07 |
# | fps                | 192       |
# | nupdates           | 395400    |
# | policy_entropy     | 0.689     |
# | total_timesteps    | 1977000   |
# | value_loss         | 4.11e+09  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -1.07e-06 |
# | fps                | 192       |
# | nupdates           | 395500    |
# | policy_entropy     | 0.674     |
# | total_timesteps    | 1977500   |
# | value_loss         | 6.73e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 4.17e-06 |
# | fps                | 192      |
# | nupdates           | 395600   |
# | policy_entropy     | 0.689    |
# | total_timesteps    | 1978000  |
# | value_loss         | 1.66e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.67e-06 |
# | fps                | 192      |
# | nupdates           | 395700   |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 1978500  |
# | value_loss         | 3.07e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -7.75e-06 |
# | fps                | 192       |
# | nupdates           | 395800    |
# | policy_entropy     | 0.69      |
# | total_timesteps    | 1979000   |
# | value_loss         | 2.29e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 2.98e-07 |
# | fps                | 192      |
# | nupdates           | 395900   |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 1979500  |
# | value_loss         | 2.04e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -3.1e-06 |
# | fps                | 192      |
# | nupdates           | 396000   |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 1980000  |
# | value_loss         | 5.01e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.79e-06 |
# | fps                | 192       |
# | nupdates           | 396100    |
# | policy_entropy     | 0.69      |
# | total_timesteps    | 1980500   |
# | value_loss         | 2.6e+09   |
# ----------------------------------
# ---------------------------------
# | explained_variance | 3.76e-06 |
# | fps                | 192      |
# | nupdates           | 396200   |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 1981000  |
# | value_loss         | 5.02e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -6.91e-06 |
# | fps                | 192       |
# | nupdates           | 396300    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 1981500   |
# | value_loss         | 5.22e+08  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 1.49e-06 |
# | fps                | 192      |
# | nupdates           | 396400   |
# | policy_entropy     | 0.689    |
# | total_timesteps    | 1982000  |
# | value_loss         | 1.55e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.86e-06 |
# | fps                | 192       |
# | nupdates           | 396500    |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 1982500   |
# | value_loss         | 2.74e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 192      |
# | nupdates           | 396600   |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 1983000  |
# | value_loss         | 1.3e+08  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 192      |
# | nupdates           | 396700   |
# | policy_entropy     | 0.682    |
# | total_timesteps    | 1983500  |
# | value_loss         | 1.08e+10 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 192      |
# | nupdates           | 396800   |
# | policy_entropy     | 0.685    |
# | total_timesteps    | 1984000  |
# | value_loss         | 3.06e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.19e-07 |
# | fps                | 192       |
# | nupdates           | 396900    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 1984500   |
# | value_loss         | 4.97e+09  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -3.81e-06 |
# | fps                | 192       |
# | nupdates           | 397000    |
# | policy_entropy     | 0.691     |
# | total_timesteps    | 1985000   |
# | value_loss         | 6.65e+09  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -7.15e-07 |
# | fps                | 192       |
# | nupdates           | 397100    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 1985500   |
# | value_loss         | 6.79e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 4.77e-07 |
# | fps                | 192      |
# | nupdates           | 397200   |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 1986000  |
# | value_loss         | 3.43e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.13e-06 |
# | fps                | 192      |
# | nupdates           | 397300   |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 1986500  |
# | value_loss         | 1.44e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 4.17e-07 |
# | fps                | 192      |
# | nupdates           | 397400   |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 1987000  |
# | value_loss         | 3.31e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.19e-06 |
# | fps                | 192       |
# | nupdates           | 397500    |
# | policy_entropy     | 0.69      |
# | total_timesteps    | 1987500   |
# | value_loss         | 2.23e+09  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -2.15e-06 |
# | fps                | 192       |
# | nupdates           | 397600    |
# | policy_entropy     | 0.691     |
# | total_timesteps    | 1988000   |
# | value_loss         | 2.35e+10  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 1.79e-06 |
# | fps                | 192      |
# | nupdates           | 397700   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 1988500  |
# | value_loss         | 2.45e+10 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -8.82e-06 |
# | fps                | 192       |
# | nupdates           | 397800    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 1989000   |
# | value_loss         | 4.5e+08   |
# ----------------------------------
# ---------------------------------
# | explained_variance | 4.29e-06 |
# | fps                | 192      |
# | nupdates           | 397900   |
# | policy_entropy     | 0.69     |
# | total_timesteps    | 1989500  |
# | value_loss         | 8.98e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.55e-06 |
# | fps                | 192      |
# | nupdates           | 398000   |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 1990000  |
# | value_loss         | 6.71e+10 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.8e-06  |
# | fps                | 192      |
# | nupdates           | 398100   |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 1990500  |
# | value_loss         | 2.29e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.07e-06 |
# | fps                | 193      |
# | nupdates           | 398200   |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 1991000  |
# | value_loss         | 3.31e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.49e-06 |
# | fps                | 193      |
# | nupdates           | 398300   |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 1991500  |
# | value_loss         | 4.56e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -4.17e-06 |
# | fps                | 193       |
# | nupdates           | 398400    |
# | policy_entropy     | 0.686     |
# | total_timesteps    | 1992000   |
# | value_loss         | 1.56e+10  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 2.98e-07 |
# | fps                | 193      |
# | nupdates           | 398500   |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 1992500  |
# | value_loss         | 5.12e+07 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -3.58e-07 |
# | fps                | 193       |
# | nupdates           | 398600    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 1993000   |
# | value_loss         | 3.27e+09  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -1.31e-06 |
# | fps                | 193       |
# | nupdates           | 398700    |
# | policy_entropy     | 0.687     |
# | total_timesteps    | 1993500   |
# | value_loss         | 5.44e+08  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -4.77e-07 |
# | fps                | 193       |
# | nupdates           | 398800    |
# | policy_entropy     | 0.688     |
# | total_timesteps    | 1994000   |
# | value_loss         | 9.12e+08  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 3.4e-06  |
# | fps                | 193      |
# | nupdates           | 398900   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 1994500  |
# | value_loss         | 2.64e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.79e-06 |
# | fps                | 193      |
# | nupdates           | 399000   |
# | policy_entropy     | 0.687    |
# | total_timesteps    | 1995000  |
# | value_loss         | 2.09e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 4.17e-07 |
# | fps                | 193      |
# | nupdates           | 399100   |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 1995500  |
# | value_loss         | 2.51e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.5e-06 |
# | fps                | 193      |
# | nupdates           | 399200   |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 1996000  |
# | value_loss         | 1.92e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 5.96e-07 |
# | fps                | 193      |
# | nupdates           | 399300   |
# | policy_entropy     | 0.686    |
# | total_timesteps    | 1996500  |
# | value_loss         | 1.92e+10 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 5.96e-07 |
# | fps                | 193      |
# | nupdates           | 399400   |
# | policy_entropy     | 0.689    |
# | total_timesteps    | 1997000  |
# | value_loss         | 1.63e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -3.46e-06 |
# | fps                | 193       |
# | nupdates           | 399500    |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 1997500   |
# | value_loss         | 9.3e+08   |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 193      |
# | nupdates           | 399600   |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 1998000  |
# | value_loss         | 4.23e+10 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 8.05e-06 |
# | fps                | 193      |
# | nupdates           | 399700   |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 1998500  |
# | value_loss         | 1.18e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.68e-06 |
# | fps                | 193      |
# | nupdates           | 399800   |
# | policy_entropy     | 0.69     |
# | total_timesteps    | 1999000  |
# | value_loss         | 1.11e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -5.96e-07 |
# | fps                | 193       |
# | nupdates           | 399900    |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 1999500   |
# | value_loss         | 4.4e+09   |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 193      |
# | nupdates           | 400000   |
# | policy_entropy     | 0.687    |
# | total_timesteps    | 2000000  |
# | value_loss         | 7.66e+08 |
# ---------------------------------

# %%
model.save("3008TW_5MTimestep_20200102_20220831Training_128_64_64_MACD")

# %%
model = A2C.load("3008TW_5MTimestep_20200102_20220831Training_128_64_64_MACD")
# Out:
# Loading a model without an environment, this model cannot be trained until it has a valid environment.
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\policies.py:442: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From C:\Users\cherr\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\layers\core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:160: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From C:\Users\cherr\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\ops\clip_ops.py:301: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:184: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From C:\Users\cherr\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\training\rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:194: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:196: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.

# %% [markdown]
# # 獲取今天的Dataframe索引，方便填寫frame_bound

# %%
# today = df2330.iloc[-1:]
# today = today.index.values
# totay = today[0]

# %%
dfStartDate_Test = df[(df['index']=='2023-01-03')].index.values
dfStartDate_Test = dfStartDate_Test[0]

dfEndDate_Test = df[(df['index']=='2023-02-24')].index.values
dfEndDate_Test = dfEndDate_Test[0]

# %% [markdown]
# # 在今天早上開盤時進行交易

# %%
open, close, high, low, volume, signal_features = my_process_data(df=df, window_size=10, frame_bound=(dfStartDate_Test, dfEndDate_Test))#Close與特徵資料
env = MyStocksEnv(open, close, high, low, volume, signal_features, df=df, window_size=10, frame_bound=(dfStartDate_Test, dfEndDate_Test))#「環境」整合
obs = env.reset()#初始化「環境」（特徵初始化）
env.seed()
Day = 0
while True: 
    obs = obs[np.newaxis, ...]#1.先抓取【0】~【9】的特徵
    action, _states = model.predict(obs)#2.Agent觀看obs, 進行action的行為，即買【1】賣【0】
    obs, rewards, done, info = env.step(action)#3.使用【1】~【10】的特徵'記錄'獎罰，驗證是否完成，輸出資料
    Day+=1
    print("Day",Day, "Rewards", rewards, end="\n")
    if done:#4.如果完成迴圈，則輸出資料
        print("info", info)
        break
# Out:
# Day 1 Rewards 10892.375
# Day 2 Rewards 5651.8125
# Day 3 Rewards 15800.3125
# Day 4 Rewards 10279.25
# Day 5 Rewards 15247.1875
# Day 6 Rewards -4665.0625
# Day 7 Rewards 5364.9375
# Day 8 Rewards 50664.75
# Day 9 Rewards -18909.25
# Day 10 Rewards -9071.25
# Day 11 Rewards -64386.0625
# Day 12 Rewards -39468.75
# Day 13 Rewards -19440.25
# Day 14 Rewards 161.5
# Day 15 Rewards 15269.3125
# Day 16 Rewards -34841.3125
# Day 17 Rewards -14782.8125
# Day 18 Rewards 5142.9375
# Day 19 Rewards -14908.4375
# Day 20 Rewards 10146.5
# Day 21 Rewards -9978.375
# Day 22 Rewards 5165.0625
# Day 23 Rewards -14827.0625
# Day 24 Rewards -19949.125
# Day 25 Rewards -9801.375
# Day 26 Rewards -9580.125
# Day 27 Rewards -29765.0
# Day 28 Rewards 15092.3125
# Day 29 Rewards -4797.8125
# Day 30 Rewards 0
# info {'total_reward': -154293.8125, 'total_profit': 0.9301201888870797, 'position': 1}

# %% [markdown]
# # 根據模型預測，position為今天收盤時需要進行的交易策略(Long or Short)

# %%
plt.figure(figsize=(16, 6))
env.render_Close()#將「環境」畫出來
# Out:
# ↓↓↓ 大立光(3008)在交易當天收盤時進行的交易策略(Long Or Short) ↓↓↓

# %%
plt.figure(figsize=(16, 6))
env.render_Reward()
# Out:
# ↓↓↓ 大立光(3008)在使用交易策略(Long Or Short)後，隔日早上平倉時的盈虧(含手續費) ↓↓↓

# %%
plt.figure(figsize=(16, 6))
env.render_TotalProfit()
# Out:
# ↓↓↓ 根據預測出的交易策略交易大立光(3008)，所得到的累積利潤(含手續費) ↓↓↓

# %% [markdown]
# # ------------------------------------------------

# %% [markdown]
# # 不同技術分析合併進行資料萃取，需要轉換矩陣格式，解釋如下：

# %%
# a = np.array([
#     [
#         [1,2,3,4,5,6],
#         [2,4,5,6,5,6],
#         [2,4,5,6,5,6],
#         [2,4,5,6,5,6]
#     ]
# ])
# #-----------------------
# b = np.array([
#     [
#         [1,2],[3,4],[5,6]
#     ],
#     [
#         [2,4],[5,6],[5,6]
#     ],
#     [
#         [2,4],[5,6],[5,6]
#     ],
#     [
#         [2,4],[5,6],[5,6]
#     ]
# ])
# #-----------------------
# print('目的：將原本矩陣a，變成矩陣b。因為在機器訓練時，需要讓機器意識到為兩組獨立的參數')
# print('注意：入面組嘅大小必須相同，例如[1,2],[3,4]，但不可以[1,2],[3,4,5]\n\n')
# print('第一個數字：大括號\n第二個數字：有四個打橫\n第三個數字：打橫入面有幾多個數字')
# print(a.shape)
# print(a,'\n')
# print('第一個數字：有幾多大組嘅數字\n第二個數字：入面有幾多個小組\n第三個數字：每個小組入面有幾多個數字')
# print(b.shape)
# print(b)
