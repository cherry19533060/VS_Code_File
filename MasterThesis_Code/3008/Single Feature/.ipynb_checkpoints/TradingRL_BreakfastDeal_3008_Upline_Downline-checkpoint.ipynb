# %%
import gym
from gym import spaces
from gym.utils import seeding
import numpy as np
from enum import Enum
import matplotlib.pyplot as plt


#Agent的行動
class Actions(Enum):
    Sell = 0
    Buy = 1

#在Env裡面所代表的
class Positions(Enum):
    Short = 0
    Long = 1

    def opposite(self):
        return Positions.Short if self == Positions.Long else Positions.Long

    
class TradingEnv(gym.Env):

    metadata = {'render.modes': ['human']}
    
    #__init__為魔法函數，意義為：無論你願不願意，只要你執行TradingEnv，就會把__init__底下的資料執行，可以用作變數定義？
    def __init__(self, df, window_size): 
        assert df.ndim == 2 #判斷所輸入的df維度是否等於2

        self.seed() #隨機種子設定
        self.df = df #輸入df
        self.window_size = window_size #輸入Windows size
        self.open, self.close, self.high, self.low, self.volume, self.date, self.signal_features = self._process_data() #輸入【價錢, 特征資料】
        self.shape = (window_size, self.signal_features.shape[1]) #輸入【Windows size, 特征資料的長度】

        # spaces
        self.action_space = spaces.Discrete(len(Actions)) # 行動空間為：2（Sell、Buy）
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=self.shape, dtype=np.float64) #觀察空間最低和最高為無限（因為不知股票價錢為多少）

        # episode
        #「_」為私有化，即import的時候不會引入參數
        self._start_tick = self.window_size #開始日期：Windows_size設定的數字
        self._end_tick = len(self.close)-1 #結束日期：【價錢】的長度-1
        self._done = None 
        self._current_tick = None
        self._last_trade_tick = None
        self._position = None
        self._position_history = None
        
        #股息
        import yfinance as yf
        self.Ticker = yf.Ticker("2330.TW")#抓取股票
        self.Dividends = self.Ticker.actions['Dividends']#抓取股息資料
        self.Dividends_Date = self.Dividends.index.astype('string')#將股息日期->String
        self.Dividends_Date = np.array(self.Dividends_Date)#將股息日期->np.array
        self.Dividends = np.array(self.Dividends) #抓取股息價錢
#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓        
        self._reward_history = []#記錄Reward獎勵，方便畫圖
        self._Total_profit = []#記錄Profit，方便畫圖
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑
        self._total_reward = None
        self._total_profit = None
        self._first_rendering = None
        self.history = None

    #定義一個隨機種子   
    def seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    #重設
    def reset(self):
        self._done = False #尚未完成
        self._current_tick = self._start_tick # Windows_size設定的數字
        self._last_trade_tick = self._current_tick -1 #Windows_size設定的數字-1
        self._position = Positions.Short #第一天交易必定為Short
        self._position_history = (self.window_size * [None]) + [self._position] #記錄位置
        self._total_reward = 0. #初始化的reward為：0
        self._total_profit = 1. #初始化的Profit為：1
        self._first_rendering = True
        self.history = {}
        return self._get_observation()

    #交易中的步驟
    def step(self, action):
        self._done = False #尚未完成動作
        
        
        #如果當前日期 = 完結日期，就結束步驟
        if self._current_tick == self._end_tick:
            self._done = True

#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓
#如果機器人進行買的動作，他的Position就會變成Long，反之亦然
        if(action == Actions.Buy.value):
            self._position = Positions.Long
#             print("action: ", action)
#             print("position: ", self._position)
        elif(action == Actions.Sell.value):
            self._position = Positions.Short
#             print("action: ", action)
#             print("position: ", self._position)
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑               
        self._last_trade_tick = self._current_tick      
        #記錄步驟
        self._position_history.append(self._position)
        
        #獎勵：調用計算獎勵的function，然後將它累積起來計算總和
        step_reward = self._calculate_reward(action)
        step_profit = self._update_profit(action)#記錄profit，方便畫圖
#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓
        self._reward_history.append(step_reward)#記錄Reward獎勵，方便畫圖
        self._Total_profit.append(step_profit)#記錄profit，方便畫圖
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑ 
        self._total_reward += step_reward
        #根據agent的action更新他的 profit
        
        
        observation = self._get_observation()
        info = dict(
            total_reward = self._total_reward,
            total_profit = self._total_profit,
            position = self._position.value
        )
        self._update_history(info)
        
        self._current_tick += 1 #當前日期+1

        return observation, step_reward, self._done, info

    #取得觀察值，觀察值為signal_features
    #若window_size為10
    #則使用0 ~ 9日的觀察值，下一次交易則使用1 ~ 10日的觀察值
    def _get_observation(self):
        return self.signal_features[(self._current_tick-self.window_size+1):self._current_tick+1]

    #更新歷史資料
    def _update_history(self, info):
        if not self.history:
            self.history = {key: [] for key in info.keys()}

        for key, value in info.items():
            self.history[key].append(value)

    #render：將環境實體化，以股票交易為例即是畫圖
    def render(self, mode='human'):
        pass


    #畫圖
#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓    
    def render_Close(self, mode='human'):
            window_ticks = np.arange(len(self._position_history))#[1,2,3,4,5,....]矩陣
            plt.plot(self.close)#根據收盤價進行繪畫

            short_ticks = []
            long_ticks = []
            # i：控制position_history的位置
            # tick：控制要塞進Long還是Short的位置
            #如果機器人在之前就是做Long的話就把它記錄在long_ticks裡面，反之亦然
            for i, tick in enumerate(window_ticks-1):
                if self._position_history[i] == Positions.Short:
                    short_ticks.append(tick)
                elif self._position_history[i] == Positions.Long:
                    long_ticks.append(tick)      

            del(short_ticks[0])

            plt.plot(short_ticks, self.close[short_ticks], 'ro', label = 'Short')#根據收盤價進行畫圖
            plt.plot(long_ticks, self.close[long_ticks], 'go', label = 'Long')#根據收盤價進行畫圖
            
            plt.legend()
            plt.title("Close", fontsize=20)
            plt.suptitle(
                "Total Reward: %.6f" % self._total_reward + ' ~ ' +
                "Total Profit: %.6f" % self._total_profit
            )
            print("↓↓↓ 台積電(2330)在交易當天收盤時進行的交易策略(Long Or Short) ↓↓↓")
        
        
    #畫圖2   
    def render_Reward(self, mode='human'):
        window_ticks = np.arange(len(self._position_history))
        short_ticks = []
        long_ticks = []
        for i, tick in enumerate(window_ticks-1):
            if self._position_history[i] == Positions.Short:
                short_ticks.append(tick)
            elif self._position_history[i] == Positions.Long:
                long_ticks.append(tick)
        
        del(short_ticks[0])
        self._reward_history = np.array(self._reward_history)
        short_ticks = (np.array(short_ticks)-10).tolist()
        long_ticks = (np.array(long_ticks)-10).tolist()
        
        plt.bar(short_ticks,self._reward_history[short_ticks], color='r', label = 'Short')#根據獎勵進行繪畫
        plt.bar(long_ticks,self._reward_history[long_ticks], color='g', label = 'Long')#根據獎勵進行繪畫
            
        plt.legend()   
        plt.title("Reward", fontsize=20)
        plt.suptitle(
            "Total Reward: %.6f" % self._total_reward + ' ~ ' +
            "Total Profit: %.6f" % self._total_profit
        )
        print("↓↓↓ 台積電(2330)在使用交易策略(Long Or Short)後，隔日早上平倉時的盈虧(含手續費) ↓↓↓")
        
        
    def render_TotalProfit(self, mode='human'):
        window_ticks = np.arange(len(self._position_history))
        
        del self._Total_profit[-1]
        plt.plot(self._Total_profit)
        
        
#         short_ticks = []
#         long_ticks = []
#         for i, tick in enumerate(window_ticks-1):
#             if self._position_history[i] == Positions.Short:
#                 short_ticks.append(tick)
#             elif self._position_history[i] == Positions.Long:
#                 long_ticks.append(tick)
        
#         del(short_ticks[0])
#         self._Total_profit = np.array(self._Total_profit)
#         short_ticks = (np.array(short_ticks)-10).tolist()
#         long_ticks = (np.array(long_ticks)-10).tolist()
        
#         plt.plot(short_ticks, self._Total_profit[short_ticks], 'ro', label = 'Short')#根據獎勵進行畫圖
#         plt.plot(long_ticks, self._Total_profit[long_ticks], 'go', label = 'Long')#根據獎勵進行畫圖
            
#         plt.legend() 

        plt.title("TotalProfit", fontsize=20)
        plt.suptitle(
            "Total Reward: %.6f" % self._total_reward + ' ~ ' +
            "Total Profit: %.6f" % self._total_profit
        )
        print("↓↓↓ 根據預測出的交易策略交易台積電(2330)，所得到的累積利潤(含手續費) ↓↓↓")
        plt.savefig('2330_BBands_TotalProfit.jpg')
        
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑         
        


    
    
    #關閉環境，即關閉畫圖    
    def close(self):
        plt.close()

    #保存圖片
    def save_rendering(self, filepath):
        plt.savefig(filepath)

    #暫停畫圖
    def pause_rendering(self):
        plt.show()

    #在TradingEnv中，為了保持結構完整，因此使用pass不做任何事情
    def _process_data(self):
        pass

    #在TradingEnv中，為了保持結構完整，因此使用pass不做任何事情
    def _calculate_reward(self, action):
        pass

    #在TradingEnv中，為了保持結構完整，因此使用pass不做任何事情
    def _update_profit(self, action):
        pass

    #在TradingEnv中，為了保持結構完整，因此使用pass不做任何事情
    def max_possible_profit(self):  # trade fees are ignored
        pass

# %%
import numpy as np

class StocksEnv(TradingEnv):
    

    def __init__(self, df, window_size, frame_bound):
        assert len(frame_bound) == 2 #判斷所輸入的df維度是否等於2

        self.frame_bound = frame_bound #輸入範圍值
        super().__init__(df, window_size)

        self.trade_fee_percent = 0.001425+0.003
        #https://rich01.com/what-is-next-day-trading/
        
    #資料處理
    def _process_data(self):
        open = self.df.loc[:, 'open'].to_numpy() #prices：開市價
        close = self.df.loc[:, 'close'].to_numpy() #prices：收盤價
        high = self.df.loc[:, 'high'].to_numpy() #prices：最高
        low = self.df.loc[:, 'low'].to_numpy() #prices：最低
        volume = self.df.loc[:, 'volume'].to_numpy() #prices：成交量
        date = self.df.loc[:, 'index'].to_numpy() #prices：日期
        close[self.frame_bound[0] - self.window_size] # validate index (TODO: Improve validation)#驗證資料：10-10
        close = close[self.frame_bound[0]-self.window_size:self.frame_bound[1]]#【10-10:5600】
        
        
        diff = np.insert(np.diff(close), 0, 0)#計算價差【今天 - 昨天】
        signal_features = np.column_stack((close, diff))#默認的signal_features為：收盤價，價差

        return open, close ,high, low, volume, date, signal_features

#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓
    #計算獎勵
    def _calculate_reward(self, action):
        step_reward = 0
        price_diff = 0
        date = self.date[self._current_tick].astype('datetime64[D]') #日期格式 -> yyyy-mm-dd格式
        date = date.astype('str')#日期格式 -> string

        
        if(self._current_tick < self._end_tick):
            if( date not in self.Dividends_Date):#遇上除淨日不交易
                if(action == Actions.Buy.value):
                    current_price = self.close[self._current_tick]*1000 #【今天收盤】
                    last_trade_price = self.open[self._current_tick+1]*1000 #【明天開盤】

                    Buy_trade_fee = (current_price * 0.001425)*0.5 #買入手續費 = (今天收盤 * 手續費） * 折扣
                    if Buy_trade_fee<20:
                        Buy_trade_fee=20
                    Sold_trade_fee = (last_trade_price * 0.001425)*0.5 #賣出手續費 = (明天開盤 * 手續費） * 折扣
                    if Sold_trade_fee<20:
                        Sold_trade_fee=20
                    Transfer_tax = last_trade_price * 0.003 #證交稅 = 明天開盤 * 稅率

                    Buy = current_price + Buy_trade_fee #買入成本 = 今天收盤 + 買入手續費
                    Sold = last_trade_price - Sold_trade_fee - Transfer_tax #賣出成本 = 明天開盤 - 賣出手續費 - 證交稅


                    TodayDividends = 0 #今日是否有股息？如果沒有為：0
                    for i in range(len(self.Dividends_Date)):#抓取股息日期 i
                        if(date in self.Dividends_Date[i]):#如果 [今日日期] 在 [股息日期 i] 中
                            TodayDividends = self.Dividends[i]*1000 #將股息*1000

                    price_diff = Sold - Buy + TodayDividends #盈虧 = 賣出成本 - 買入成本 + 股息（若無股息，+$0）
                
                
                
                
                elif(action == Actions.Sell.value):
                    current_price = self.close[self._current_tick]*1000 #【今天收盤】
                    last_trade_price = self.open[self._current_tick+1]*1000 #【明天開盤】

                    Buy_trade_fee = (last_trade_price * 0.001425)*0.5 #買入手續費 = (明天開盤 * 手續費） * 折扣
                    if Buy_trade_fee<20:
                        Buy_trade_fee=20
                    Sold_trade_fee = (current_price * 0.001425)*0.5 #賣出手續費 = (今天收盤 * 手續費） * 折扣
                    if Sold_trade_fee<20:
                        Sold_trade_fee=20
                    Transfer_tax = last_trade_price * 0.003 #證交稅 = 今天收盤 * 稅率

                    Buy = last_trade_price + Buy_trade_fee #買入成本 = 明天開盤 + 買入手續費
                    Sold = current_price - Sold_trade_fee - Transfer_tax #賣出成本 = 今天收盤 - 賣出手續費 - 證交稅    

                    TodayDividends = 0 #今日是否有股息？如果沒有為：0             
                    for i in range(len(self.Dividends_Date)):#抓取股息日期 i
                        if(date in self.Dividends_Date[i]):#如果 [今日日期] 在 [股息日期 i] 中
                            TodayDividends = self.Dividends[i]*1000 #將股息*1000          

                    price_diff = Sold - Buy + TodayDividends #盈虧 = 賣出成本 - 買入成本 + 股息（若無股息，+$0）

        
            step_reward =  step_reward + price_diff
        
        return step_reward


    def _update_profit(self, action):
        
        long_profit_percentage = 0.0
        short_profit_percentage = 0.0
        Total_long_profit_percentage = 0.0
        Total_short_profit_percentage = 0.0
        
        date = self.date[self._current_tick].astype('datetime64[D]') #日期格式 -> yyyy-mm-dd格式
        date = date.astype('str')#日期格式 -> string
        
        step_profit = 0
        if(self._current_tick < self._end_tick):
            if( date not in self.Dividends_Date):#遇上除淨日不交易
                if(action == Actions.Buy.value):

                    current_price = self.close[self._current_tick]*1000#【今天收盤】
                    last_trade_price = self.open[self._current_tick+1]*1000#【明天開盤】

                    Buy_trade_fee = (current_price * 0.001425)*0.5 #(買*手續費) * 證券商折扣
                    if Buy_trade_fee<20:
                        Buy_trade_fee=20
                    Sold_trade_fee = (last_trade_price * 0.001425)*0.5 #(賣*手續費) * 證券商折扣
                    if Sold_trade_fee<20:
                        Sold_trade_fee=20
                    Transfer_tax = last_trade_price * 0.003 #證交稅

                    Buy = current_price + Buy_trade_fee#買入的成本
                    Sold = last_trade_price - Sold_trade_fee - Transfer_tax#賣出的成本

                    TodayDividends = 0 #今日是否有股息？如果沒有為：0
                    for i in range(len(self.Dividends_Date)):#抓取股息日期 i
                        if(date in self.Dividends_Date[i]):#如果 [今日日期] 在 [股息日期 i] 中
                            TodayDividends = self.Dividends[i]*1000 #將股息*1000

                    price_diff = Sold - Buy + TodayDividends #盈虧 = 賣出成本 - 買入成本 + 股息（若無股息，+$0）

                    long_profit_percentage = (Sold - Buy + TodayDividends)/Buy 
                    self._total_profit += long_profit_percentage

                elif(action == Actions.Sell.value):

                    current_price = self.close[self._current_tick]*1000#【今天收盤】
                    last_trade_price = self.open[self._current_tick+1]*1000#【明天開盤】

                    Buy_trade_fee = (last_trade_price * 0.001425)*0.5 #(買*手續費) * 證券商折扣
                    if Buy_trade_fee<20:
                        Buy_trade_fee=20
                    Sold_trade_fee = (current_price * 0.001425)*0.5 #(賣*手續費) * 證券商折扣
                    if Sold_trade_fee<20:
                        Sold_trade_fee=20
                    Transfer_tax = last_trade_price * 0.003 #證交稅

                    Buy = last_trade_price + Buy_trade_fee#買入的成本
                    Sold = current_price - Sold_trade_fee - Transfer_tax#賣出的成本


                    TodayDividends = 0 #今日是否有股息？如果沒有為：0
                    for i in range(len(self.Dividends_Date)):#抓取股息日期 i
                        if(date in self.Dividends_Date[i]):#如果 [今日日期] 在 [股息日期 i] 中
                            TodayDividends = self.Dividends[i]*1000 #將股息*1000

                    price_diff = Sold - Buy + TodayDividends #盈虧 = 賣出成本 - 買入成本 + 股息（若無股息，+$0）

                    short_profit_percentage = (Sold - Buy + TodayDividends)/Buy 
                    self._total_profit += short_profit_percentage  
                       
                
            step_profit += self._total_profit #記錄profit，方便畫圖
        return step_profit#記錄profit，方便畫圖
        
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑  
                
    #https://github.com/AminHP/gym-anytrading/blob/master/README.ipynb
    #不論交易費用如何，agent在股票交易中所獲得的profit
    def max_possible_profit(self):
        pass

# %%
# import gym_anytrading
import numpy as np
import pandas as pd
import quantstats as qs
from stable_baselines import A2C
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\__init__.py:33: UserWarning: stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation.
#   "stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation."

# %%
from yahoo_fin import stock_info as si
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
if isinstance('3008.TW', str):
    # load it from yahoo_fin library
    df = si.get_data('3008.TW')
df = df.dropna()#丟棄空值
df = df.reset_index()
pd.set_option('display.float_format', lambda x: '%.3f' % x)#設定顯示小數點後3位數

#---------------------------------------------------------------------------
#定義參數

open = df['open']
close = df['close']
high = df['high']
low = df['low']
volume = df['volume']
UpLine_max = []
UpLine = [] #上引線
DownLine_min = []
DownLine = [] #下引線
UpMean = []#計算RSI——上漲平均5天
DownMean = []#計算RSI——下跌平均5天
RSI = []#計算RSI

#---------------------------------------------------------------------------
#上引線；下引線

for i in range(close.size):
    UpLine_max.append(max(open[i], close[i]))
for i in range(close.size):
    UpLine.append(high[i] - UpLine_max[i])#上影線
for i in range(close.size):
    DownLine_min.append(min(open[i], close[i]))
for i in range(close.size):
    DownLine.append(DownLine_min[i] - low[i])#下影線
#---------------------------------------------------------------------------
#RSI

UpDownValue = close - close.shift(1) #計算漲跌值
Only_UpValue = pd.Series(index=UpDownValue.index, data=UpDownValue[UpDownValue>0])#將上漲日子篩出
Only_UpValue = Only_UpValue.fillna(0)#下跌的日子為0
Only_DownValue = pd.Series(index=UpDownValue.index, data=-UpDownValue[UpDownValue<0])#將下跌日子篩出
Only_DownValue = Only_DownValue.fillna(0)#上漲的日子為0
for i in range(13, len(Only_UpValue)+1):#由第六日開始，直到現在
    UpMean.append(np.mean(Only_UpValue.values[i-12:i]))#計算出最近五日的平均，因為有補0，所以可以計算出。
    DownMean.append(np.mean(Only_DownValue.values[i-12:i]))#計算出最近五日的平均
for i in range(len(UpMean)):
    RSI.append( (UpMean[i] / ( UpMean[i] + DownMean[i] )) * 100  )#計算RSI
RSI = pd.Series(index = close.index[12:], data = RSI) #轉換格式
#---------------------------------------------------------------------------
#FH；FL
FH = ((high - open) / open) #FH
FL = ((open - low) / open) #FL
FH = pd.DataFrame(FH, columns=['FH'])#FH參數
FL = pd.DataFrame(FL, columns=['FL'])#FL參數
#---------------------------------------------------------------------------
# KD
K = []
D = []
K_Value = []
D_Value = []
def RSV(df):
    df['MinLow'] = df['low'].rolling(9, min_periods=9).min()#9天最低位
    df['MinLow'].fillna(value = df['low'].expanding().min(), inplace = True)#填滿NA
    df['MaxHigh'] = df['high'].rolling(9, min_periods=9).max()#9天最高位
    df['MaxHigh'].fillna(value = df['high'].expanding().max(), inplace = True)#填滿NA
    df['RSV'] = (df['close'] - df['MinLow']) / (df['MaxHigh'] - df['MinLow']) * 100 #計算RSV
    return df
RSV_df = RSV(df)#使用RSV函數計算
RSV = RSV_df['RSV']#獲得RSV
for i in range(len(RSV)):
    if i<=9 :
        K.append(50)
        D.append(50)
    elif i > 9:
        K.append((K[i-1] * 2/3) + (1/3 * RSV[i]))
        D.append((D[i-1] * 2/3) + (1/3 * K[i]))
K_Value = pd.Series(index = close.index[0:], data = K) #轉換格式
D_Value = pd.Series(index = close.index[0:], data = D) #轉換格式
#---------------------------------------------------------------------------
# MACD
DIF = []
MACD = []
ShortEMA=close.ewm(span=12,adjust=False).mean()#12日移動平均
LongEMA=close.ewm(span=26,adjust=False).mean()#26日移動平均
FastLine_DIF=ShortEMA-LongEMA#DIF = （12日移動平均 - 26日移動平均）
SlowLine_MACD=FastLine_DIF.ewm(span=9,adjust=False).mean()#取DIF數值得到9日移動平均
FastLine_DIF = pd.DataFrame(FastLine_DIF)#轉換格式
SlowLine_MACD = pd.DataFrame(SlowLine_MACD)#轉換格式
FastLine_DIF = FastLine_DIF.rename(columns={'close':'DIF'})#轉換格式
SlowLine_MACD = SlowLine_MACD.rename(columns={'close':'MACD'})#轉換格式
#---------------------------------------------------------------------------                                                             
#BBands
def BBands(df,Day=20,Times=2):#20天平均, 2倍標準差
    Up_Track=pd.Series(0.0,index=df.index)#建立全0的陣列
    Mid_Track=pd.Series(0.0,index=df.index)#建立全0的陣列
    Down_Track=pd.Series(0.0,index=df.index)#建立全0的陣列
    SD=pd.Series(0.0,index=df.index)#建立全0的陣列
    
    for i in range(Day-1,len(df)):#19~5600   
        Mid_Track[i]=np.mean(df[i-(Day-1):(i+1)])#中軌 = 0-20平均 -> 1-21平均 -> 2-22平均...（移動平均線）
        SD[i]=np.std(df[i-(Day-1):(i+1)])#0-20標準差 -> 1-21標準差 ->2-22標準差...（標準差）
        Up_Track[i]=Mid_Track[i]+(Times*SD[i])#上軌 = 中軌+（2倍標準差）
        Down_Track[i]=Mid_Track[i]-(Times*SD[i])#下軌 = 中軌-（2倍標準差）
        
        #慢慢地將上半部分建立的全0函式更新
        df_BBands=pd.DataFrame({'Up_Track':Up_Track[(Day-1):],#由第19日開始載入布林通道（上）
                             'Mid_Track':Mid_Track[(Day-1):],#由第19日開始載入布林通道（中）
                             'Down_Track':Down_Track[(Day-1):]#由第19日開始載入布林通道（下）
                            })
    return(df_BBands)
BBands_Up_Mid_Down_Trak = BBands(close, 20, 2)
#---------------------------------------------------------------------------
#成交量均線
volume10Day_mean=volume.ewm(span=10,adjust=False).mean() #10日移動平均成交量
volume10Day_mean = volume10Day_mean>volume #10日移動平均成交量 > 當日成交量【**技術指標**】
df_volume10day_mean=pd.DataFrame(volume10Day_mean) #變成DataFrame
labelencoder = LabelEncoder() #將True False 變成 1 0
df_volume10day_mean['volume'] = labelencoder.fit_transform(df_volume10day_mean['volume'])#將True False 變成 1 0
ct = ColumnTransformer([("volume", OneHotEncoder(), [0])], remainder = 'passthrough') #將1 0 變成 OneHotEncoder
df_volume10day_mean = ct.fit_transform(df_volume10day_mean)#將1 0 變成 OneHotEncoder
df_volume10day_mean = pd.DataFrame(df_volume10day_mean, columns = ['Volume_lower','Volume_greater'])
df_volume10day_mean['Volume_lower'] = pd.to_numeric(df_volume10day_mean['Volume_lower'], downcast='integer')
df_volume10day_mean['Volume_greater'] = pd.to_numeric(df_volume10day_mean['Volume_greater'], downcast='integer')







#合拼df
df2330 = pd.merge(df, FH,left_index=True,right_index=True) #合拼FH
df2330 = pd.merge(df2330, FL,left_index=True,right_index=True) #合拼FL
df2330 = pd.merge(df2330, pd.DataFrame(UpLine, columns=['UpLine']),left_index=True,right_index=True) #合併上影線
df2330 = pd.merge(df2330, pd.DataFrame(DownLine, columns=['DownLine']),left_index=True,right_index=True) #合併下影線
df2330 = pd.merge(df2330, pd.DataFrame(RSI, columns=['RSI']),left_index=True,right_index=True) #合併RSI
df2330 = pd.merge(df2330, pd.DataFrame(K_Value, columns=['K_Value']),left_index=True,right_index=True) #合併K值
df2330 = pd.merge(df2330, pd.DataFrame(D_Value, columns=['D_Value']),left_index=True,right_index=True) #合併D值
df2330 = pd.merge(df2330, pd.DataFrame(FastLine_DIF),left_index=True,right_index=True) #合併DIF
df2330 = pd.merge(df2330, pd.DataFrame(SlowLine_MACD),left_index=True,right_index=True) #合併MACD
df2330 = pd.merge(df2330,BBands_Up_Mid_Down_Trak,left_index=True,right_index=True) #合併布林通道
df2330 = pd.merge(df2330,df_volume10day_mean,left_index=True,right_index=True) #合併布林通道

df2330.index = range(len(df2330))#更新index

# %% [markdown]
# # 是否將特徵資料標準化？

# %%
#---------------------------------------------------------------------------
# normalizer = Normalizer()#創建標準化函數
# df2330_AllFeatures = df2330[['MinLow','MaxHigh','RSV','FH','FL','UpLine','DownLine','RSI','K_Value','D_Value','DIF','MACD','Up_Track','Mid_Track','Down_Track']]#取得需要標準化的特徵
# df2330_FeaturesNormalize = normalizer.fit_transform(df2330_AllFeatures)#進行標準化
# df2330_FeaturesNormalize = pd.DataFrame(df2330_FeaturesNormalize)#將array變成df
# df2330_FeaturesNormalize = df2330_FeaturesNormalize.rename(columns={0:'MinLow',1:'MaxHigh',2:'RSV',
#                                                       3:'FH',4:'FL',
#                                                       5:'UpLine',6:'DownLine',
#                                                       7:'RSI',
#                                                       8:'K_Value',9:'D_Value',
#                                                       10:'DIF',11:'MACD',
#                                                       12:'Up_Track',13:'Mid_Track',14:'Down_Track'})#更改名字
# df2330_OriginData = df2330[['index','open','high','low','close','adjclose','volume','ticker']]#取得市場基本資料
# df2330_Normalized = pd.merge(df2330_OriginData, df2330_FeaturesNormalize, left_index=True,right_index=True) #基本資料與標準化後特徵資料合併
# df2330 = df2330_Normalized
#---------------------------------------------------------------------------

#---------------------------------------------------------------------------
#輸出最終Dataframe
df = df2330
df
# Out:
#           index     open     high      low    close  adjclose     volume  \
# 0    2002-04-05  103.632  103.632  103.632  103.632    67.701      0.000
# 1    2002-04-08   99.797  105.554   99.797  105.165    68.702 971809.000
# 2    2002-04-09  104.784  104.784  102.862  102.862    67.198 528893.000
# 3    2002-04-10  102.862  105.554  102.481  105.554    68.956 455941.000
# 4    2002-04-11  107.468  109.389  106.705  109.008    71.213 956175.000
# ...         ...      ...      ...      ...      ...       ...        ...
# 5156 2023-02-23 2215.000 2250.000 2215.000 2225.000  2225.000 285036.000
# 5157 2023-02-24 2245.000 2255.000 2205.000 2205.000  2205.000 405228.000
# 5158 2023-03-01 2155.000 2185.000 2155.000 2165.000  2165.000 556733.000
# 5159 2023-03-02 2165.000 2215.000 2135.000 2210.000  2210.000 482042.000
# 5160 2023-03-03 2220.000 2260.000 2220.000 2230.000  2230.000 602611.000
#
#        ticker   MinLow  MaxHigh  ...    RSI  K_Value  D_Value    DIF   MACD  \
# 0     3008.TW  101.330  121.285  ... 28.352   15.738   25.211 -9.184 -9.270
# 1     3008.TW   99.797  120.903  ... 27.273   18.970   23.131 -8.991 -9.214
# 2     3008.TW   99.797  115.528  ... 20.574   19.143   21.801 -8.921 -9.156
# 3     3008.TW   99.797  114.765  ... 28.770   25.582   23.062 -8.550 -9.034
# 4     3008.TW   99.797  113.225  ... 31.581   39.920   28.681 -7.886 -8.805
# ...       ...      ...      ...  ...    ...      ...      ...    ...    ...
# 5156  3008.TW 2165.000 2270.000  ... 51.250   45.739   42.112 16.129 16.554
# 5157  3008.TW 2165.000 2270.000  ... 46.250   43.191   42.472 14.293 16.102
# 5158  3008.TW 2155.000 2270.000  ... 44.578   31.693   38.879  9.501 14.782
# 5159  3008.TW 2135.000 2270.000  ... 44.578   39.647   39.135  9.228 13.671
# 5160  3008.TW 2135.000 2270.000  ... 52.564   49.888   42.719 10.504 13.037
#
#       Up_Track  Mid_Track  Down_Track  Volume_lower  Volume_greater
# 0      136.775    112.153      87.531             0               1
# 1      124.826    109.676      94.527             0               1
# 2      122.906    110.329      97.751             0               1
# 3      121.786    110.809      99.831             0               1
# 4      121.472    111.135     100.798             0               1
# ...        ...        ...         ...           ...             ...
# 5156  2292.311   2205.750    2119.189             0               1
# 5157  2274.738   2212.250    2149.762             1               0
# 5158  2274.738   2212.250    2149.762             1               0
# 5159  2264.573   2216.500    2168.427             1               0
# 5160  2265.673   2217.250    2168.827             1               0
#
# [5161 rows x 25 columns]

# %% [markdown]
# # 查找DF的標籤

# %%
dfStartDate_Train = df[(df['index']=='2022-01-03')].index.values
dfStartDate_Train = dfStartDate_Train[0]
dfStartDate_Train
# Out:
# 4881

# %%
dfEndDate_Train = df[(df['index']=='2022-12-30')].index.values
dfEndDate_Train = dfEndDate_Train[0]
dfEndDate_Train
# Out:
# 5126

# %%
df[dfStartDate_Train:dfEndDate_Train+1]
# Out:
#           index     open     high      low    close  adjclose      volume  \
# 4881 2022-01-03 2500.000 2590.000 2480.000 2500.000  2374.608 1960732.000
# 4882 2022-01-04 2535.000 2700.000 2530.000 2695.000  2559.828 2655806.000
# 4883 2022-01-05 2700.000 2710.000 2605.000 2610.000  2479.091 1652458.000
# 4884 2022-01-06 2600.000 2645.000 2570.000 2585.000  2455.345 1250704.000
# 4885 2022-01-07 2615.000 2625.000 2480.000 2485.000  2360.361 1515420.000
# ...         ...      ...      ...      ...      ...       ...         ...
# 5122 2022-12-26 2160.000 2160.000 2110.000 2120.000  2120.000  146374.000
# 5123 2022-12-27 2130.000 2165.000 2130.000 2165.000  2165.000  190969.000
# 5124 2022-12-28 2145.000 2150.000 2105.000 2110.000  2110.000  275648.000
# 5125 2022-12-29 2075.000 2075.000 2040.000 2050.000  2050.000  509610.000
# 5126 2022-12-30 2065.000 2085.000 2040.000 2040.000  2040.000  303129.000
#
#        ticker   MinLow  MaxHigh  ...    RSI  K_Value  D_Value     DIF    MACD  \
# 4881  3008.TW 2275.000 2590.000  ... 87.805   76.008   77.905 109.448  84.134
# 4882  3008.TW 2380.000 2700.000  ... 90.741   83.484   79.765 127.130  92.733
# 4883  3008.TW 2380.000 2710.000  ... 76.978   78.889   79.473 132.754 100.737
# 4884  3008.TW 2380.000 2710.000  ... 72.993   73.299   77.415 133.653 107.320
# 4885  3008.TW 2380.000 2710.000  ... 55.814   59.472   71.434 124.857 110.828
# ...       ...      ...      ...  ...    ...      ...      ...     ...     ...
# 5122  3008.TW 2110.000 2280.000  ... 32.394   16.279   25.960   6.368  32.396
# 5123  3008.TW 2110.000 2280.000  ... 46.377   21.637   24.519   3.887  26.694
# 5124  3008.TW 2105.000 2280.000  ... 38.462   15.377   21.472  -2.488  20.858
# 5125  3008.TW 2040.000 2280.000  ... 34.091   11.640   18.194 -12.241  14.238
# 5126  3008.TW 2040.000 2270.000  ... 21.053    7.760   14.716 -20.540   7.282
#
#       Up_Track  Mid_Track  Down_Track  Volume_lower  Volume_greater
# 4881  2633.651   2243.250    1852.849             1               0
# 4882  2700.423   2276.500    1852.577             1               0
# 4883  2739.684   2303.750    1867.816             1               0
# 4884  2767.287   2330.000    1892.713             0               1
# 4885  2772.220   2352.750    1933.280             0               1
# ...        ...        ...         ...           ...             ...
# 5122  2339.215   2230.500    2121.785             0               1
# 5123  2335.951   2225.250    2114.549             0               1
# 5124  2332.602   2216.000    2099.398             0               1
# 5125  2336.045   2204.000    2071.955             1               0
# 5126  2335.413   2191.500    2047.587             0               1
#
# [246 rows x 25 columns]

# %%
def my_process_data(df, window_size, frame_bound):
    start = frame_bound[0] - window_size #start = 5 - 5
    end = frame_bound[1] #end = 5600 
    close = df.loc[:, 'close'].to_numpy()[start:end]#抓取Close
    open = df.loc[:, 'open'].to_numpy()[start:end]#抓取open
    high = df.loc[:, 'high'].to_numpy()[start:end]#抓取high
    low = df.loc[:, 'low'].to_numpy()[start:end]#抓取low
    volnume = df.loc[:, 'volume'].to_numpy()[start:end]#抓取volume
    date = df.loc[:, 'index'].to_numpy()[start:end]#抓取Date
    signal_features = df.loc[:, ['UpLine', 'DownLine']].to_numpy()[start:end]#抓取特徵資料
    return open, close, high, low, volnume, date, signal_features


class MyStocksEnv(StocksEnv):
    
    def __init__(self, open, close, high, low, volnume, date,signal_features, **kwargs):
        self._open = open
        self._close = close
        self._high = high
        self._low = low
        self._volnume = volnume
        self._date = date
        self._signal_features = signal_features
        super().__init__(**kwargs)

    def _process_data(self):
        return self._open, self._close, self._high, self._low, self._volnume, self._date, self._signal_features

    
open, close, high, low, volume, date,signal_features = my_process_data(df=df, window_size=10, frame_bound=(dfStartDate_Train, dfEndDate_Train+1))#Close與特徵資料
env = MyStocksEnv(open, close, high, low, volume, date, signal_features, df=df, window_size=10, frame_bound=(dfStartDate_Train, dfEndDate_Train+1))#「環境」整合

# %%
# policy_kwargs = dict(net_arch=[128, 'lstm', dict(vf=[64,64,64], pi=[64,64,64])])#要傳遞給policy的參數

# model = A2C('MlpLstmPolicy', env, verbose=1, policy_kwargs=policy_kwargs)
model = A2C('MlpLstmPolicy', env, verbose=1)
#policy: The policy model to use (MlpPolicy, CnnPolicy, …)""
#verbose: 0 no output, 1 info, 2 debug
#policy_kwargs: additional arguments to be passed to the policy on creation要傳遞給policy的參數
model.learn(total_timesteps=2000000)
# Out:
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | explained_variance | -1.07e-06 |
# | fps                | 1         |
# | nupdates           | 1         |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 5         |
# | value_loss         | 7.19e+08  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -4.77e-07 |
# | fps                | 83        |
# | nupdates           | 100       |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 500       |
# | value_loss         | 5.02e+08  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 8.34e-07 |
# | fps                | 112      |
# | nupdates           | 200      |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 1000     |
# | value_loss         | 8.13e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.25e-06 |
# | fps                | 127      |
# | nupdates           | 300      |
# | policy_entropy     | 0.689    |
# | total_timesteps    | 1500     |
# | value_loss         | 5.84e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -3.7e-06 |
# | fps                | 136      |
# | nupdates           | 400      |
# | policy_entropy     | 0.689    |
# | total_timesteps    | 2000     |
# | value_loss         | 1.33e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.31e-06 |
# | fps                | 141       |
# | nupdates           | 500       |
# | policy_entropy     | 0.673     |
# | total_timesteps    | 2500      |
# | value_loss         | 2.41e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -2.5e-06 |
# | fps                | 143      |
# | nupdates           | 600      |
# | policy_entropy     | 0.669    |
# | total_timesteps    | 3000     |
# | value_loss         | 9.27e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 5.42e-06 |
# | fps                | 146      |
# | nupdates           | 700      |
# | policy_entropy     | 0.627    |
# | total_timesteps    | 3500     |
# | value_loss         | 4.18e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -6.84e-05 |
# | fps                | 148       |
# | nupdates           | 800       |
# | policy_entropy     | 0.548     |
# | total_timesteps    | 4000      |
# | value_loss         | 1.36e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 1.44e-05 |
# | fps                | 150      |
# | nupdates           | 900      |
# | policy_entropy     | 0.464    |
# | total_timesteps    | 4500     |
# | value_loss         | 3.28e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -4.29e-06 |
# | fps                | 153       |
# | nupdates           | 1000      |
# | policy_entropy     | 0.185     |
# | total_timesteps    | 5000      |
# | value_loss         | 6.35e+09  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -2.74e-06 |
# | fps                | 154       |
# | nupdates           | 1100      |
# | policy_entropy     | 0.0884    |
# | total_timesteps    | 5500      |
# | value_loss         | 2.4e+08   |
# ----------------------------------
# ----------------------------------
# | explained_variance | -7.39e-06 |
# | fps                | 155       |
# | nupdates           | 1200      |
# | policy_entropy     | 0.0133    |
# | total_timesteps    | 6000      |
# | value_loss         | 4.57e+08  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -8.34e-07 |
# | fps                | 157       |
# | nupdates           | 1300      |
# | policy_entropy     | 0.0103    |
# | total_timesteps    | 6500      |
# | value_loss         | 6.97e+09  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -3.22e-06 |
# | fps                | 158       |
# | nupdates           | 1400      |
# | policy_entropy     | 0.00226   |
# | total_timesteps    | 7000      |
# | value_loss         | 2.19e+08  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 1.61e-06 |
# | fps                | 159      |
# | nupdates           | 1500     |
# | policy_entropy     | 0.00234  |
# | total_timesteps    | 7500     |
# | value_loss         | 1.33e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 3.58e-06 |
# | fps                | 160      |
# | nupdates           | 1600     |
# | policy_entropy     | 0.000674 |
# | total_timesteps    | 8000     |
# | value_loss         | 1.04e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 3.22e-06 |
# | fps                | 160      |
# | nupdates           | 1700     |
# | policy_entropy     | 0.000636 |
# | total_timesteps    | 8500     |
# | value_loss         | 2.9e+08  |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.19e-07 |
# | fps                | 161       |
# | nupdates           | 1800      |
# | policy_entropy     | 0.000103  |
# | total_timesteps    | 9000      |
# | value_loss         | 3.54e+08  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 161      |
# | nupdates           | 1900     |
# | policy_entropy     | 0.000101 |
# | total_timesteps    | 9500     |
# | value_loss         | 2.03e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 161      |
# | nupdates           | 2000     |
# | policy_entropy     | 9.95e-05 |
# | total_timesteps    | 10000    |
# | value_loss         | 5.86e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.79e-07 |
# | fps                | 160      |
# | nupdates           | 2100     |
# | policy_entropy     | 9.73e-05 |
# | total_timesteps    | 10500    |
# | value_loss         | 4.63e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.85e-06 |
# | fps                | 159      |
# | nupdates           | 2200     |
# | policy_entropy     | 9.57e-05 |
# | total_timesteps    | 11000    |
# | value_loss         | 3.08e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.67e-06 |
# | fps                | 158      |
# | nupdates           | 2300     |
# | policy_entropy     | 9.43e-05 |
# | total_timesteps    | 11500    |
# | value_loss         | 1.38e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 3.58e-07 |
# | fps                | 158      |
# | nupdates           | 2400     |
# | policy_entropy     | 9.23e-05 |
# | total_timesteps    | 12000    |
# | value_loss         | 6.26e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 9.18e-06 |
# | fps                | 157      |
# | nupdates           | 2500     |
# | policy_entropy     | 9.21e-05 |
# | total_timesteps    | 12500    |
# | value_loss         | 2.06e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 3.58e-06 |
# | fps                | 157      |
# | nupdates           | 2600     |
# | policy_entropy     | 9.07e-05 |
# | total_timesteps    | 13000    |
# | value_loss         | 1.07e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.32e-06 |
# | fps                | 157      |
# | nupdates           | 2700     |
# | policy_entropy     | 8.92e-05 |
# | total_timesteps    | 13500    |
# | value_loss         | 6.96e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 9.54e-07 |
# | fps                | 157      |
# | nupdates           | 2800     |
# | policy_entropy     | 8.79e-05 |
# | total_timesteps    | 14000    |
# | value_loss         | 1.26e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.09e-06 |
# | fps                | 158      |
# | nupdates           | 2900     |
# | policy_entropy     | 8.72e-05 |
# | total_timesteps    | 14500    |
# | value_loss         | 4.04e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.37e-06 |
# | fps                | 158      |
# | nupdates           | 3000     |
# | policy_entropy     | 8.68e-05 |
# | total_timesteps    | 15000    |
# | value_loss         | 7.74e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00258  |
# | fps                | 158      |
# | nupdates           | 3100     |
# | policy_entropy     | 0.00682  |
# | total_timesteps    | 15500    |
# | value_loss         | 3.66e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.43e-06 |
# | fps                | 159       |
# | nupdates           | 3200      |
# | policy_entropy     | 8.53e-05  |
# | total_timesteps    | 16000     |
# | value_loss         | 3.34e+10  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 1.19e-07 |
# | fps                | 159      |
# | nupdates           | 3300     |
# | policy_entropy     | 8.39e-05 |
# | total_timesteps    | 16500    |
# | value_loss         | 2.21e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.13e-06 |
# | fps                | 159      |
# | nupdates           | 3400     |
# | policy_entropy     | 8.33e-05 |
# | total_timesteps    | 17000    |
# | value_loss         | 5.74e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.19e-07 |
# | fps                | 159       |
# | nupdates           | 3500      |
# | policy_entropy     | 8.23e-05  |
# | total_timesteps    | 17500     |
# | value_loss         | 1.97e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 1.73e-06 |
# | fps                | 159      |
# | nupdates           | 3600     |
# | policy_entropy     | 8.2e-05  |
# | total_timesteps    | 18000    |
# | value_loss         | 8.46e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 3.1e-06  |
# | fps                | 159      |
# | nupdates           | 3700     |
# | policy_entropy     | 8.19e-05 |
# | total_timesteps    | 18500    |
# | value_loss         | 8.63e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 5.96e-07 |
# | fps                | 158      |
# | nupdates           | 3800     |
# | policy_entropy     | 8.12e-05 |
# | total_timesteps    | 19000    |
# | value_loss         | 5.23e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.07e-06 |
# | fps                | 157       |
# | nupdates           | 3900      |
# | policy_entropy     | 8.06e-05  |
# | total_timesteps    | 19500     |
# | value_loss         | 1.57e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 3.58e-06 |
# | fps                | 156      |
# | nupdates           | 4000     |
# | policy_entropy     | 8.01e-05 |
# | total_timesteps    | 20000    |
# | value_loss         | 6.17e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -4.77e-07 |
# | fps                | 155       |
# | nupdates           | 4100      |
# | policy_entropy     | 7.96e-05  |
# | total_timesteps    | 20500     |
# | value_loss         | 4.61e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 3.58e-07 |
# | fps                | 154      |
# | nupdates           | 4200     |
# | policy_entropy     | 7.94e-05 |
# | total_timesteps    | 21000    |
# | value_loss         | 2.93e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 4.77e-07 |
# | fps                | 153      |
# | nupdates           | 4300     |
# | policy_entropy     | 7.9e-05  |
# | total_timesteps    | 21500    |
# | value_loss         | 1.59e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 7.15e-07 |
# | fps                | 152      |
# | nupdates           | 4400     |
# | policy_entropy     | 7.85e-05 |
# | total_timesteps    | 22000    |
# | value_loss         | 2.15e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.19e-07 |
# | fps                | 151      |
# | nupdates           | 4500     |
# | policy_entropy     | 7.79e-05 |
# | total_timesteps    | 22500    |
# | value_loss         | 4.94e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 3.99e-06 |
# | fps                | 151      |
# | nupdates           | 4600     |
# | policy_entropy     | 7.78e-05 |
# | total_timesteps    | 23000    |
# | value_loss         | 1.3e+09  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 4.71e-06 |
# | fps                | 150      |
# | nupdates           | 4700     |
# | policy_entropy     | 7.76e-05 |
# | total_timesteps    | 23500    |
# | value_loss         | 3.57e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.55e-06 |
# | fps                | 149      |
# | nupdates           | 4800     |
# | policy_entropy     | 7.72e-05 |
# | total_timesteps    | 24000    |
# | value_loss         | 5.56e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 7.81e-06 |
# | fps                | 147      |
# | nupdates           | 4900     |
# | policy_entropy     | 7.67e-05 |
# | total_timesteps    | 24500    |
# | value_loss         | 3.76e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.19e-07 |
# | fps                | 146       |
# | nupdates           | 5000      |
# | policy_entropy     | 7.62e-05  |
# | total_timesteps    | 25000     |
# | value_loss         | 1.43e+10  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 3.58e-07 |
# | fps                | 145      |
# | nupdates           | 5100     |
# | policy_entropy     | 7.61e-05 |
# | total_timesteps    | 25500    |
# | value_loss         | 3.78e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.19e-07 |
# | fps                | 144       |
# | nupdates           | 5200      |
# | policy_entropy     | 7.6e-05   |
# | total_timesteps    | 26000     |
# | value_loss         | 5.85e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 1.79e-06 |
# | fps                | 143      |
# | nupdates           | 5300     |
# | policy_entropy     | 7.57e-05 |
# | total_timesteps    | 26500    |
# | value_loss         | 3.36e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 3.4e-06  |
# | fps                | 142      |
# | nupdates           | 5400     |
# | policy_entropy     | 7.56e-05 |
# | total_timesteps    | 27000    |
# | value_loss         | 2.14e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.38e-07 |
# | fps                | 141      |
# | nupdates           | 5500     |
# | policy_entropy     | 7.49e-05 |
# | total_timesteps    | 27500    |
# | value_loss         | 1.6e+09  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 3.1e-06  |
# | fps                | 140      |
# | nupdates           | 5600     |
# | policy_entropy     | 7.48e-05 |
# | total_timesteps    | 28000    |
# | value_loss         | 5.73e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.49e-06 |
# | fps                | 139      |
# | nupdates           | 5700     |
# | policy_entropy     | 7.49e-05 |
# | total_timesteps    | 28500    |
# | value_loss         | 5.15e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.74e-05 |
# | fps                | 138      |
# | nupdates           | 5800     |
# | policy_entropy     | 7.46e-05 |
# | total_timesteps    | 29000    |
# | value_loss         | 2.38e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -5.36e-06 |
# | fps                | 138       |
# | nupdates           | 5900      |
# | policy_entropy     | 7.42e-05  |
# | total_timesteps    | 29500     |
# | value_loss         | 1.39e+08  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 4.23e-06 |
# | fps                | 138      |
# | nupdates           | 6000     |
# | policy_entropy     | 7.38e-05 |
# | total_timesteps    | 30000    |
# | value_loss         | 4.96e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 4.85e-05 |
# | fps                | 137      |
# | nupdates           | 6100     |
# | policy_entropy     | 7.38e-05 |
# | total_timesteps    | 30500    |
# | value_loss         | 5.33e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00505  |
# | fps                | 137      |
# | nupdates           | 6200     |
# | policy_entropy     | 0.00508  |
# | total_timesteps    | 31000    |
# | value_loss         | 1.28e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.01e-06 |
# | fps                | 137      |
# | nupdates           | 6300     |
# | policy_entropy     | 7.31e-05 |
# | total_timesteps    | 31500    |
# | value_loss         | 1.94e+10 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.19e-07 |
# | fps                | 136       |
# | nupdates           | 6400      |
# | policy_entropy     | 7.3e-05   |
# | total_timesteps    | 32000     |
# | value_loss         | 3.39e+08  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 1.75e-05 |
# | fps                | 135      |
# | nupdates           | 6500     |
# | policy_entropy     | 7.3e-05  |
# | total_timesteps    | 32500    |
# | value_loss         | 1.65e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.31e-06 |
# | fps                | 134       |
# | nupdates           | 6600      |
# | policy_entropy     | 7.25e-05  |
# | total_timesteps    | 33000     |
# | value_loss         | 1.55e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 2.71e-05 |
# | fps                | 134      |
# | nupdates           | 6700     |
# | policy_entropy     | 7.25e-05 |
# | total_timesteps    | 33500    |
# | value_loss         | 1.31e+09 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -6.91e-06 |
# | fps                | 133       |
# | nupdates           | 6800      |
# | policy_entropy     | 7.25e-05  |
# | total_timesteps    | 34000     |
# | value_loss         | 6.42e+08  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 5.07e-06 |
# | fps                | 132      |
# | nupdates           | 6900     |
# | policy_entropy     | 7.24e-05 |
# | total_timesteps    | 34500    |
# | value_loss         | 2.36e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.8e-06  |
# | fps                | 132      |
# | nupdates           | 7000     |
# | policy_entropy     | 7.22e-05 |
# | total_timesteps    | 35000    |
# | value_loss         | 2.68e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 8.9e-05  |
# | fps                | 132      |
# | nupdates           | 7100     |
# | policy_entropy     | 7.23e-05 |
# | total_timesteps    | 35500    |
# | value_loss         | 8.39e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 3.58e-07 |
# | fps                | 131      |
# | nupdates           | 7200     |
# | policy_entropy     | 7.18e-05 |
# | total_timesteps    | 36000    |
# | value_loss         | 3.4e+08  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 9.77e-05 |
# | fps                | 130      |
# | nupdates           | 7300     |
# | policy_entropy     | 7.2e-05  |
# | total_timesteps    | 36500    |
# | value_loss         | 8.22e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 8.58e-06 |
# | fps                | 130      |
# | nupdates           | 7400     |
# | policy_entropy     | 7.19e-05 |
# | total_timesteps    | 37000    |
# | value_loss         | 1.42e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000307 |
# | fps                | 130      |
# | nupdates           | 7500     |
# | policy_entropy     | 7.22e-05 |
# | total_timesteps    | 37500    |
# | value_loss         | 8.4e+07  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.28e-05 |
# | fps                | 129      |
# | nupdates           | 7600     |
# | policy_entropy     | 7.23e-05 |
# | total_timesteps    | 38000    |
# | value_loss         | 1.71e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 7.71e-05 |
# | fps                | 129      |
# | nupdates           | 7700     |
# | policy_entropy     | 7.29e-05 |
# | total_timesteps    | 38500    |
# | value_loss         | 1.52e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000384 |
# | fps                | 128      |
# | nupdates           | 7800     |
# | policy_entropy     | 7.35e-05 |
# | total_timesteps    | 39000    |
# | value_loss         | 1.41e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 7.45e-06 |
# | fps                | 128      |
# | nupdates           | 7900     |
# | policy_entropy     | 7.22e-05 |
# | total_timesteps    | 39500    |
# | value_loss         | 1.4e+09  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000803 |
# | fps                | 128      |
# | nupdates           | 8000     |
# | policy_entropy     | 7.97e-05 |
# | total_timesteps    | 40000    |
# | value_loss         | 6.84e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000139 |
# | fps                | 128      |
# | nupdates           | 8100     |
# | policy_entropy     | 7.6e-05  |
# | total_timesteps    | 40500    |
# | value_loss         | 2.99e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00135  |
# | fps                | 128      |
# | nupdates           | 8200     |
# | policy_entropy     | 7.9e-05  |
# | total_timesteps    | 41000    |
# | value_loss         | 7.34e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000135 |
# | fps                | 128      |
# | nupdates           | 8300     |
# | policy_entropy     | 7.84e-05 |
# | total_timesteps    | 41500    |
# | value_loss         | 3.62e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00149  |
# | fps                | 128      |
# | nupdates           | 8400     |
# | policy_entropy     | 8.26e-05 |
# | total_timesteps    | 42000    |
# | value_loss         | 2.22e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000131 |
# | fps                | 128      |
# | nupdates           | 8500     |
# | policy_entropy     | 7.9e-05  |
# | total_timesteps    | 42500    |
# | value_loss         | 5.05e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00169  |
# | fps                | 128      |
# | nupdates           | 8600     |
# | policy_entropy     | 9.92e-05 |
# | total_timesteps    | 43000    |
# | value_loss         | 4.12e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000227 |
# | fps                | 128       |
# | nupdates           | 8700      |
# | policy_entropy     | 8.04e-05  |
# | total_timesteps    | 43500     |
# | value_loss         | 1.43e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.00082  |
# | fps                | 127      |
# | nupdates           | 8800     |
# | policy_entropy     | 0.000107 |
# | total_timesteps    | 44000    |
# | value_loss         | 1.91e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00269  |
# | fps                | 127      |
# | nupdates           | 8900     |
# | policy_entropy     | 9.08e-05 |
# | total_timesteps    | 44500    |
# | value_loss         | 9.54e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -8.7e-05 |
# | fps                | 127      |
# | nupdates           | 9000     |
# | policy_entropy     | 7.66e-05 |
# | total_timesteps    | 45000    |
# | value_loss         | 4.93e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000461 |
# | fps                | 127      |
# | nupdates           | 9100     |
# | policy_entropy     | 7.84e-05 |
# | total_timesteps    | 45500    |
# | value_loss         | 2.68e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00025 |
# | fps                | 127      |
# | nupdates           | 9200     |
# | policy_entropy     | 0.000142 |
# | total_timesteps    | 46000    |
# | value_loss         | 4.5e+09  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00389 |
# | fps                | 127      |
# | nupdates           | 9300     |
# | policy_entropy     | 0.00012  |
# | total_timesteps    | 46500    |
# | value_loss         | 1.18e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -4.77e-06 |
# | fps                | 127       |
# | nupdates           | 9400      |
# | policy_entropy     | 7.34e-05  |
# | total_timesteps    | 47000     |
# | value_loss         | 2.69e+09  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -4.97e-05 |
# | fps                | 127       |
# | nupdates           | 9500      |
# | policy_entropy     | 7.3e-05   |
# | total_timesteps    | 47500     |
# | value_loss         | 1.93e+08  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -3.27e-05 |
# | fps                | 127       |
# | nupdates           | 9600      |
# | policy_entropy     | 7.41e-05  |
# | total_timesteps    | 48000     |
# | value_loss         | 3.75e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 3.58e-07 |
# | fps                | 128      |
# | nupdates           | 9700     |
# | policy_entropy     | 7.31e-05 |
# | total_timesteps    | 48500    |
# | value_loss         | 3.22e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00327  |
# | fps                | 128      |
# | nupdates           | 9800     |
# | policy_entropy     | 0.000197 |
# | total_timesteps    | 49000    |
# | value_loss         | 4.92e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0022   |
# | fps                | 128      |
# | nupdates           | 9900     |
# | policy_entropy     | 8.79e-05 |
# | total_timesteps    | 49500    |
# | value_loss         | 1.42e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00115  |
# | fps                | 128      |
# | nupdates           | 10000    |
# | policy_entropy     | 0.000147 |
# | total_timesteps    | 50000    |
# | value_loss         | 3.33e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.24e-05 |
# | fps                | 128      |
# | nupdates           | 10100    |
# | policy_entropy     | 7.37e-05 |
# | total_timesteps    | 50500    |
# | value_loss         | 6.56e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000821 |
# | fps                | 128      |
# | nupdates           | 10200    |
# | policy_entropy     | 7.96e-05 |
# | total_timesteps    | 51000    |
# | value_loss         | 1.02e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000652 |
# | fps                | 128      |
# | nupdates           | 10300    |
# | policy_entropy     | 0.000123 |
# | total_timesteps    | 51500    |
# | value_loss         | 2.46e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.57e-05 |
# | fps                | 128      |
# | nupdates           | 10400    |
# | policy_entropy     | 7.35e-05 |
# | total_timesteps    | 52000    |
# | value_loss         | 9.68e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00355  |
# | fps                | 128      |
# | nupdates           | 10500    |
# | policy_entropy     | 0.000138 |
# | total_timesteps    | 52500    |
# | value_loss         | 1.61e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0138   |
# | fps                | 128      |
# | nupdates           | 10600    |
# | policy_entropy     | 0.000611 |
# | total_timesteps    | 53000    |
# | value_loss         | 1.25e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00677  |
# | fps                | 128      |
# | nupdates           | 10700    |
# | policy_entropy     | 0.000868 |
# | total_timesteps    | 53500    |
# | value_loss         | 1.64e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00795  |
# | fps                | 128      |
# | nupdates           | 10800    |
# | policy_entropy     | 0.000533 |
# | total_timesteps    | 54000    |
# | value_loss         | 1e+09    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0124   |
# | fps                | 128      |
# | nupdates           | 10900    |
# | policy_entropy     | 0.000355 |
# | total_timesteps    | 54500    |
# | value_loss         | 1.32e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 8.52e-06 |
# | fps                | 128      |
# | nupdates           | 11000    |
# | policy_entropy     | 5.26e-05 |
# | total_timesteps    | 55000    |
# | value_loss         | 1.12e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.011    |
# | fps                | 128      |
# | nupdates           | 11100    |
# | policy_entropy     | 0.000933 |
# | total_timesteps    | 55500    |
# | value_loss         | 3.78e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00418  |
# | fps                | 128      |
# | nupdates           | 11200    |
# | policy_entropy     | 0.000406 |
# | total_timesteps    | 56000    |
# | value_loss         | 1.08e+10 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0134   |
# | fps                | 128      |
# | nupdates           | 11300    |
# | policy_entropy     | 0.00332  |
# | total_timesteps    | 56500    |
# | value_loss         | 8.13e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00605  |
# | fps                | 128      |
# | nupdates           | 11400    |
# | policy_entropy     | 0.0039   |
# | total_timesteps    | 57000    |
# | value_loss         | 2.62e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0146   |
# | fps                | 128      |
# | nupdates           | 11500    |
# | policy_entropy     | 0.00364  |
# | total_timesteps    | 57500    |
# | value_loss         | 5.44e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00235  |
# | fps                | 128      |
# | nupdates           | 11600    |
# | policy_entropy     | 0.000746 |
# | total_timesteps    | 58000    |
# | value_loss         | 3.03e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0337   |
# | fps                | 128      |
# | nupdates           | 11700    |
# | policy_entropy     | 0.0127   |
# | total_timesteps    | 58500    |
# | value_loss         | 3.74e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0209   |
# | fps                | 128      |
# | nupdates           | 11800    |
# | policy_entropy     | 0.0242   |
# | total_timesteps    | 59000    |
# | value_loss         | 1.17e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0314   |
# | fps                | 128      |
# | nupdates           | 11900    |
# | policy_entropy     | 0.105    |
# | total_timesteps    | 59500    |
# | value_loss         | 4.01e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00361  |
# | fps                | 128      |
# | nupdates           | 12000    |
# | policy_entropy     | 0.00561  |
# | total_timesteps    | 60000    |
# | value_loss         | 3.94e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000115 |
# | fps                | 128      |
# | nupdates           | 12100    |
# | policy_entropy     | 2.66e-05 |
# | total_timesteps    | 60500    |
# | value_loss         | 2.51e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.11e-05 |
# | fps                | 128      |
# | nupdates           | 12200    |
# | policy_entropy     | 2.57e-05 |
# | total_timesteps    | 61000    |
# | value_loss         | 8.96e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00327 |
# | fps                | 128      |
# | nupdates           | 12300    |
# | policy_entropy     | 0.034    |
# | total_timesteps    | 61500    |
# | value_loss         | 2.05e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0185   |
# | fps                | 128      |
# | nupdates           | 12400    |
# | policy_entropy     | 0.00399  |
# | total_timesteps    | 62000    |
# | value_loss         | 1.31e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 9.7e-05  |
# | fps                | 129      |
# | nupdates           | 12500    |
# | policy_entropy     | 2.13e-05 |
# | total_timesteps    | 62500    |
# | value_loss         | 3.21e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000686 |
# | fps                | 128      |
# | nupdates           | 12600    |
# | policy_entropy     | 2e-05    |
# | total_timesteps    | 63000    |
# | value_loss         | 2.04e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.53e-05 |
# | fps                | 129      |
# | nupdates           | 12700    |
# | policy_entropy     | 1.79e-05 |
# | total_timesteps    | 63500    |
# | value_loss         | 3.87e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00052  |
# | fps                | 129      |
# | nupdates           | 12800    |
# | policy_entropy     | 1.85e-05 |
# | total_timesteps    | 64000    |
# | value_loss         | 1.07e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0832  |
# | fps                | 129      |
# | nupdates           | 12900    |
# | policy_entropy     | 0.166    |
# | total_timesteps    | 64500    |
# | value_loss         | 2.64e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0466   |
# | fps                | 129      |
# | nupdates           | 13000    |
# | policy_entropy     | 0.0114   |
# | total_timesteps    | 65000    |
# | value_loss         | 4.19e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000324 |
# | fps                | 129       |
# | nupdates           | 13100     |
# | policy_entropy     | 1.19e-05  |
# | total_timesteps    | 65500     |
# | value_loss         | 1.36e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.00242  |
# | fps                | 129      |
# | nupdates           | 13200    |
# | policy_entropy     | 1.22e-05 |
# | total_timesteps    | 66000    |
# | value_loss         | 3.2e+09  |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.19e-06 |
# | fps                | 129       |
# | nupdates           | 13300     |
# | policy_entropy     | 1.05e-05  |
# | total_timesteps    | 66500     |
# | value_loss         | 6.35e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.0374   |
# | fps                | 129      |
# | nupdates           | 13400    |
# | policy_entropy     | 0.0206   |
# | total_timesteps    | 67000    |
# | value_loss         | 2.32e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000193 |
# | fps                | 129      |
# | nupdates           | 13500    |
# | policy_entropy     | 8.46e-06 |
# | total_timesteps    | 67500    |
# | value_loss         | 4.25e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -4.16e-05 |
# | fps                | 129       |
# | nupdates           | 13600     |
# | policy_entropy     | 7.07e-06  |
# | total_timesteps    | 68000     |
# | value_loss         | 6.84e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.101    |
# | fps                | 129      |
# | nupdates           | 13700    |
# | policy_entropy     | 0.0565   |
# | total_timesteps    | 68500    |
# | value_loss         | 2.06e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0614   |
# | fps                | 129      |
# | nupdates           | 13800    |
# | policy_entropy     | 0.304    |
# | total_timesteps    | 69000    |
# | value_loss         | 1.29e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0389   |
# | fps                | 129      |
# | nupdates           | 13900    |
# | policy_entropy     | 0.0928   |
# | total_timesteps    | 69500    |
# | value_loss         | 1.01e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0113   |
# | fps                | 130      |
# | nupdates           | 14000    |
# | policy_entropy     | 0.00289  |
# | total_timesteps    | 70000    |
# | value_loss         | 2.82e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 6.96e-05 |
# | fps                | 130      |
# | nupdates           | 14100    |
# | policy_entropy     | 4.31e-06 |
# | total_timesteps    | 70500    |
# | value_loss         | 3.5e+08  |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.79e-05 |
# | fps                | 130       |
# | nupdates           | 14200     |
# | policy_entropy     | 3.83e-06  |
# | total_timesteps    | 71000     |
# | value_loss         | 2.03e+09  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -5.91e-05 |
# | fps                | 130       |
# | nupdates           | 14300     |
# | policy_entropy     | 3.69e-06  |
# | total_timesteps    | 71500     |
# | value_loss         | 5.85e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -0.00253 |
# | fps                | 130      |
# | nupdates           | 14400    |
# | policy_entropy     | 0.000119 |
# | total_timesteps    | 72000    |
# | value_loss         | 4.62e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0442  |
# | fps                | 130      |
# | nupdates           | 14500    |
# | policy_entropy     | 0.128    |
# | total_timesteps    | 72500    |
# | value_loss         | 4.51e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0296   |
# | fps                | 130      |
# | nupdates           | 14600    |
# | policy_entropy     | 0.234    |
# | total_timesteps    | 73000    |
# | value_loss         | 1.33e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0154   |
# | fps                | 130      |
# | nupdates           | 14700    |
# | policy_entropy     | 0.0242   |
# | total_timesteps    | 73500    |
# | value_loss         | 6.14e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0745   |
# | fps                | 130      |
# | nupdates           | 14800    |
# | policy_entropy     | 0.12     |
# | total_timesteps    | 74000    |
# | value_loss         | 1.98e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0415   |
# | fps                | 130      |
# | nupdates           | 14900    |
# | policy_entropy     | 0.302    |
# | total_timesteps    | 74500    |
# | value_loss         | 1.08e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00308 |
# | fps                | 130      |
# | nupdates           | 15000    |
# | policy_entropy     | 2.22e-06 |
# | total_timesteps    | 75000    |
# | value_loss         | 6.95e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0172   |
# | fps                | 130      |
# | nupdates           | 15100    |
# | policy_entropy     | 0.0481   |
# | total_timesteps    | 75500    |
# | value_loss         | 1.25e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0516   |
# | fps                | 130      |
# | nupdates           | 15200    |
# | policy_entropy     | 0.0209   |
# | total_timesteps    | 76000    |
# | value_loss         | 4e+08    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.81e-05 |
# | fps                | 130       |
# | nupdates           | 15300     |
# | policy_entropy     | 1.27e-06  |
# | total_timesteps    | 76500     |
# | value_loss         | 7.14e+08  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.0282   |
# | fps                | 130      |
# | nupdates           | 15400    |
# | policy_entropy     | 0.0552   |
# | total_timesteps    | 77000    |
# | value_loss         | 3.46e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -7.99e-06 |
# | fps                | 130       |
# | nupdates           | 15500     |
# | policy_entropy     | 1.16e-06  |
# | total_timesteps    | 77500     |
# | value_loss         | 3.34e+10  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 2.56e-06 |
# | fps                | 130      |
# | nupdates           | 15600    |
# | policy_entropy     | 9.31e-07 |
# | total_timesteps    | 78000    |
# | value_loss         | 2.2e+09  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0297   |
# | fps                | 130      |
# | nupdates           | 15700    |
# | policy_entropy     | 0.0123   |
# | total_timesteps    | 78500    |
# | value_loss         | 5.57e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -5.6e-06 |
# | fps                | 130      |
# | nupdates           | 15800    |
# | policy_entropy     | 7.62e-07 |
# | total_timesteps    | 79000    |
# | value_loss         | 1.96e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000253 |
# | fps                | 130      |
# | nupdates           | 15900    |
# | policy_entropy     | 7.36e-07 |
# | total_timesteps    | 79500    |
# | value_loss         | 8.42e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.117   |
# | fps                | 130      |
# | nupdates           | 16000    |
# | policy_entropy     | 0.127    |
# | total_timesteps    | 80000    |
# | value_loss         | 2.69e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000295 |
# | fps                | 130       |
# | nupdates           | 16100     |
# | policy_entropy     | 6.35e-07  |
# | total_timesteps    | 80500     |
# | value_loss         | 5.22e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.00145  |
# | fps                | 131      |
# | nupdates           | 16200    |
# | policy_entropy     | 6.64e-07 |
# | total_timesteps    | 81000    |
# | value_loss         | 1.57e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0462   |
# | fps                | 131      |
# | nupdates           | 16300    |
# | policy_entropy     | 0.0714   |
# | total_timesteps    | 81500    |
# | value_loss         | 5.84e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0133   |
# | fps                | 131      |
# | nupdates           | 16400    |
# | policy_entropy     | 0.0743   |
# | total_timesteps    | 82000    |
# | value_loss         | 4.61e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0614   |
# | fps                | 131      |
# | nupdates           | 16500    |
# | policy_entropy     | 0.0796   |
# | total_timesteps    | 82500    |
# | value_loss         | 2.61e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0765   |
# | fps                | 131      |
# | nupdates           | 16600    |
# | policy_entropy     | 0.214    |
# | total_timesteps    | 83000    |
# | value_loss         | 1.54e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0246   |
# | fps                | 131      |
# | nupdates           | 16700    |
# | policy_entropy     | 0.209    |
# | total_timesteps    | 83500    |
# | value_loss         | 7.86e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0464   |
# | fps                | 131      |
# | nupdates           | 16800    |
# | policy_entropy     | 0.0903   |
# | total_timesteps    | 84000    |
# | value_loss         | 4.73e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0845   |
# | fps                | 131      |
# | nupdates           | 16900    |
# | policy_entropy     | 0.375    |
# | total_timesteps    | 84500    |
# | value_loss         | 1.22e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0817   |
# | fps                | 131      |
# | nupdates           | 17000    |
# | policy_entropy     | 0.142    |
# | total_timesteps    | 85000    |
# | value_loss         | 3.26e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0327   |
# | fps                | 131      |
# | nupdates           | 17100    |
# | policy_entropy     | 0.0915   |
# | total_timesteps    | 85500    |
# | value_loss         | 5.31e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0575   |
# | fps                | 131      |
# | nupdates           | 17200    |
# | policy_entropy     | 0.149    |
# | total_timesteps    | 86000    |
# | value_loss         | 3.54e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -4.41e-06 |
# | fps                | 131       |
# | nupdates           | 17300     |
# | policy_entropy     | 3.96e-07  |
# | total_timesteps    | 86500     |
# | value_loss         | 1.4e+10   |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.00966  |
# | fps                | 131      |
# | nupdates           | 17400    |
# | policy_entropy     | 0.0366   |
# | total_timesteps    | 87000    |
# | value_loss         | 3.66e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0145   |
# ...
# | nupdates           | 394200   |
# | policy_entropy     | 1.12e-09 |
# | total_timesteps    | 1971000  |
# | value_loss         | 1.57e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.348    |
# | fps                | 188      |
# | nupdates           | 394300   |
# | policy_entropy     | 3.24e-09 |
# | total_timesteps    | 1971500  |
# | value_loss         | 3.95e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 6.38e-06 |
# | fps                | 188      |
# | nupdates           | 394400   |
# | policy_entropy     | 2.34e-09 |
# | total_timesteps    | 1972000  |
# | value_loss         | 1.26e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.576    |
# | fps                | 188      |
# | nupdates           | 394500   |
# | policy_entropy     | 5.64e-06 |
# | total_timesteps    | 1972500  |
# | value_loss         | 5.61e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00238 |
# | fps                | 188      |
# | nupdates           | 394600   |
# | policy_entropy     | 2.33e-09 |
# | total_timesteps    | 1973000  |
# | value_loss         | 4.24e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 188      |
# | nupdates           | 394700   |
# | policy_entropy     | 1.58e-05 |
# | total_timesteps    | 1973500  |
# | value_loss         | 6.67e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.527    |
# | fps                | 188      |
# | nupdates           | 394800   |
# | policy_entropy     | 3.73e-06 |
# | total_timesteps    | 1974000  |
# | value_loss         | 2.56e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.233    |
# | fps                | 189      |
# | nupdates           | 394900   |
# | policy_entropy     | 2.24e-06 |
# | total_timesteps    | 1974500  |
# | value_loss         | 3.41e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.731    |
# | fps                | 189      |
# | nupdates           | 395000   |
# | policy_entropy     | 1.57e-05 |
# | total_timesteps    | 1975000  |
# | value_loss         | 3.66e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.226    |
# | fps                | 189      |
# | nupdates           | 395100   |
# | policy_entropy     | 0.137    |
# | total_timesteps    | 1975500  |
# | value_loss         | 1.21e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.846    |
# | fps                | 189      |
# | nupdates           | 395200   |
# | policy_entropy     | 0.133    |
# | total_timesteps    | 1976000  |
# | value_loss         | 1.45e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.907    |
# | fps                | 189      |
# | nupdates           | 395300   |
# | policy_entropy     | 7.57e-05 |
# | total_timesteps    | 1976500  |
# | value_loss         | 1.3e+07  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.202    |
# | fps                | 189      |
# | nupdates           | 395400   |
# | policy_entropy     | 5.56e-09 |
# | total_timesteps    | 1977000  |
# | value_loss         | 1.24e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00596 |
# | fps                | 189      |
# | nupdates           | 395500   |
# | policy_entropy     | 2.42e-09 |
# | total_timesteps    | 1977500  |
# | value_loss         | 1.93e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.342    |
# | fps                | 189      |
# | nupdates           | 395600   |
# | policy_entropy     | 1.71e-09 |
# | total_timesteps    | 1978000  |
# | value_loss         | 4.02e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.894    |
# | fps                | 189      |
# | nupdates           | 395700   |
# | policy_entropy     | 4.41e-08 |
# | total_timesteps    | 1978500  |
# | value_loss         | 2.87e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0452   |
# | fps                | 189      |
# | nupdates           | 395800   |
# | policy_entropy     | 2.29e-09 |
# | total_timesteps    | 1979000  |
# | value_loss         | 1.22e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.954    |
# | fps                | 189      |
# | nupdates           | 395900   |
# | policy_entropy     | 0.113    |
# | total_timesteps    | 1979500  |
# | value_loss         | 1.08e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.403    |
# | fps                | 189      |
# | nupdates           | 396000   |
# | policy_entropy     | 6.2e-06  |
# | total_timesteps    | 1980000  |
# | value_loss         | 3.64e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.92     |
# | fps                | 189      |
# | nupdates           | 396100   |
# | policy_entropy     | 1.64e-09 |
# | total_timesteps    | 1980500  |
# | value_loss         | 1.92e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.845    |
# | fps                | 189      |
# | nupdates           | 396200   |
# | policy_entropy     | 0.179    |
# | total_timesteps    | 1981000  |
# | value_loss         | 9.73e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0346  |
# | fps                | 189      |
# | nupdates           | 396300   |
# | policy_entropy     | 2.36e-09 |
# | total_timesteps    | 1981500  |
# | value_loss         | 5.47e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0324   |
# | fps                | 189      |
# | nupdates           | 396400   |
# | policy_entropy     | 2.07e-09 |
# | total_timesteps    | 1982000  |
# | value_loss         | 1.18e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.172    |
# | fps                | 189      |
# | nupdates           | 396500   |
# | policy_entropy     | 1.88e-09 |
# | total_timesteps    | 1982500  |
# | value_loss         | 3.57e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 8.94e-07 |
# | fps                | 189      |
# | nupdates           | 396600   |
# | policy_entropy     | 2.19e-09 |
# | total_timesteps    | 1983000  |
# | value_loss         | 6.91e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.945    |
# | fps                | 189      |
# | nupdates           | 396700   |
# | policy_entropy     | 0.237    |
# | total_timesteps    | 1983500  |
# | value_loss         | 2.56e+07 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.12e-05 |
# | fps                | 189       |
# | nupdates           | 396800    |
# | policy_entropy     | 2.16e-09  |
# | total_timesteps    | 1984000   |
# | value_loss         | 3.29e+10  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -3.22e-06 |
# | fps                | 189       |
# | nupdates           | 396900    |
# | policy_entropy     | 2.15e-09  |
# | total_timesteps    | 1984500   |
# | value_loss         | 2.08e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.406    |
# | fps                | 189      |
# | nupdates           | 397000   |
# | policy_entropy     | 3.99e-08 |
# | total_timesteps    | 1985000  |
# | value_loss         | 3.36e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -4.65e-06 |
# | fps                | 189       |
# | nupdates           | 397100    |
# | policy_entropy     | 2.13e-09  |
# | total_timesteps    | 1985500   |
# | value_loss         | 1.85e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 5.33e-05 |
# | fps                | 189      |
# | nupdates           | 397200   |
# | policy_entropy     | 2.1e-09  |
# | total_timesteps    | 1986000  |
# | value_loss         | 7.21e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.606    |
# | fps                | 189      |
# | nupdates           | 397300   |
# | policy_entropy     | 1.62e-09 |
# | total_timesteps    | 1986500  |
# | value_loss         | 8.1e+07  |
# ---------------------------------
# ----------------------------------
# | explained_variance | -4.77e-07 |
# | fps                | 189       |
# | nupdates           | 397400    |
# | policy_entropy     | 2.08e-09  |
# | total_timesteps    | 1987000   |
# | value_loss         | 4.64e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.212    |
# | fps                | 189      |
# | nupdates           | 397500   |
# | policy_entropy     | 2.33e-09 |
# | total_timesteps    | 1987500  |
# | value_loss         | 7.24e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.786    |
# | fps                | 189      |
# | nupdates           | 397600   |
# | policy_entropy     | 0.014    |
# | total_timesteps    | 1988000  |
# | value_loss         | 1.34e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.28     |
# | fps                | 189      |
# | nupdates           | 397700   |
# | policy_entropy     | 4.1e-05  |
# | total_timesteps    | 1988500  |
# | value_loss         | 2.14e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.812    |
# | fps                | 189      |
# | nupdates           | 397800   |
# | policy_entropy     | 0.0223   |
# | total_timesteps    | 1989000  |
# | value_loss         | 5.96e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.623    |
# | fps                | 189      |
# | nupdates           | 397900   |
# | policy_entropy     | 0.106    |
# | total_timesteps    | 1989500  |
# | value_loss         | 9.28e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.527    |
# | fps                | 189      |
# | nupdates           | 398000   |
# | policy_entropy     | 0.0161   |
# | total_timesteps    | 1990000  |
# | value_loss         | 1.06e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.589    |
# | fps                | 189      |
# | nupdates           | 398100   |
# | policy_entropy     | 1.17e-09 |
# | total_timesteps    | 1990500  |
# | value_loss         | 1.66e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.696   |
# | fps                | 189      |
# | nupdates           | 398200   |
# | policy_entropy     | 0.13     |
# | total_timesteps    | 1991000  |
# | value_loss         | 4.26e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.952    |
# | fps                | 189      |
# | nupdates           | 398300   |
# | policy_entropy     | 1.02e-05 |
# | total_timesteps    | 1991500  |
# | value_loss         | 1.31e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.619    |
# | fps                | 189      |
# | nupdates           | 398400   |
# | policy_entropy     | 3.61e-05 |
# | total_timesteps    | 1992000  |
# | value_loss         | 1.52e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.916    |
# | fps                | 189      |
# | nupdates           | 398500   |
# | policy_entropy     | 0.000107 |
# | total_timesteps    | 1992500  |
# | value_loss         | 5.14e+07 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000366 |
# | fps                | 189       |
# | nupdates           | 398600    |
# | policy_entropy     | 1.94e-09  |
# | total_timesteps    | 1993000   |
# | value_loss         | 1.23e+10  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.44     |
# | fps                | 189      |
# | nupdates           | 398700   |
# | policy_entropy     | 1.95e-06 |
# | total_timesteps    | 1993500  |
# | value_loss         | 1.6e+09  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.308    |
# | fps                | 189      |
# | nupdates           | 398800   |
# | policy_entropy     | 5.11e-09 |
# | total_timesteps    | 1994000  |
# | value_loss         | 5.87e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.555    |
# | fps                | 189      |
# | nupdates           | 398900   |
# | policy_entropy     | 2.68e-09 |
# | total_timesteps    | 1994500  |
# | value_loss         | 1.46e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.582    |
# | fps                | 189      |
# | nupdates           | 399000   |
# | policy_entropy     | 0.0344   |
# | total_timesteps    | 1995000  |
# | value_loss         | 1.62e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.375    |
# | fps                | 189      |
# | nupdates           | 399100   |
# | policy_entropy     | 0.000122 |
# | total_timesteps    | 1995500  |
# | value_loss         | 4.43e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0392  |
# | fps                | 189      |
# | nupdates           | 399200   |
# | policy_entropy     | 1.86e-09 |
# | total_timesteps    | 1996000  |
# | value_loss         | 5.17e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.686   |
# | fps                | 189      |
# | nupdates           | 399300   |
# | policy_entropy     | 0.169    |
# | total_timesteps    | 1996500  |
# | value_loss         | 4.1e+08  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.681    |
# | fps                | 189      |
# | nupdates           | 399400   |
# | policy_entropy     | 1.26e-09 |
# | total_timesteps    | 1997000  |
# | value_loss         | 1.17e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.31     |
# | fps                | 189      |
# | nupdates           | 399500   |
# | policy_entropy     | 1.93e-09 |
# | total_timesteps    | 1997500  |
# | value_loss         | 1.02e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0718   |
# | fps                | 189      |
# | nupdates           | 399600   |
# | policy_entropy     | 1.5e-09  |
# | total_timesteps    | 1998000  |
# | value_loss         | 4.47e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00388  |
# | fps                | 189      |
# | nupdates           | 399700   |
# | policy_entropy     | 1.82e-09 |
# | total_timesteps    | 1998500  |
# | value_loss         | 4.59e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.889    |
# | fps                | 189      |
# | nupdates           | 399800   |
# | policy_entropy     | 0.0992   |
# | total_timesteps    | 1999000  |
# | value_loss         | 3.7e+07  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 5.96e-07 |
# | fps                | 189      |
# | nupdates           | 399900   |
# | policy_entropy     | 1.79e-09 |
# | total_timesteps    | 1999500  |
# | value_loss         | 1.9e+10  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0044   |
# | fps                | 189      |
# | nupdates           | 400000   |
# | policy_entropy     | 1.87e-09 |
# | total_timesteps    | 2000000  |
# | value_loss         | 3.06e+08 |
# ---------------------------------

# %%
model.save("3008TW_5MTimestep_20200102_20220831Training_128_64_64_UpDownLine")

# %%
model = A2C.load("3008TW_5MTimestep_20200102_20220831Training_128_64_64_UpDownLine")
# Out:
# Loading a model without an environment, this model cannot be trained until it has a valid environment.
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\policies.py:420: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From C:\Users\cherr\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\layers\core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:160: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From C:\Users\cherr\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\ops\clip_ops.py:301: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:184: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From C:\Users\cherr\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\training\rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:194: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:196: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.

# %% [markdown]
# # 獲取今天的Dataframe索引，方便填寫frame_bound

# %%
# today = df2330.iloc[-1:]
# today = today.index.values
# totay = today[0]

# %%
dfStartDate_Test = df[(df['index']=='2023-01-03')].index.values
dfStartDate_Test = dfStartDate_Test[0]

dfEndDate_Test = df[(df['index']=='2023-02-24')].index.values
dfEndDate_Test = dfEndDate_Test[0]

# %% [markdown]
# # 在今天早上開盤時進行交易

# %%
open, close, high, low, volume, date,signal_features = my_process_data(df=df, window_size=10, frame_bound=(dfStartDate_Test, dfEndDate_Test))#Close與特徵資料
env = MyStocksEnv(open, close, high, low, volume, date,signal_features, df=df, window_size=10, frame_bound=(dfStartDate_Test, dfEndDate_Test))#「環境」整合
obs = env.reset()#初始化「環境」（特徵初始化）
env.seed()
Day = 0
while True: 
    obs = obs[np.newaxis, ...]#1.先抓取【0】~【9】的特徵
    action, _states = model.predict(obs)#2.Agent觀看obs, 進行action的行為，即買【1】賣【0】
    obs, rewards, done, info = env.step(action)#3.使用【1】~【10】的特徵'記錄'獎罰，驗證是否完成，輸出資料
    Day+=1
    print("Day",Day, "Rewards", rewards, end="\n")
    if done:#4.如果完成迴圈，則輸出資料
        print("info", info)
        break
# Out:
# Day 1 Rewards -29107.625
# Day 2 Rewards 5651.8125
# Day 3 Rewards -34199.6875
# Day 4 Rewards 10279.25
# Day 5 Rewards -34752.8125
# Day 6 Rewards -4665.0625
# Day 7 Rewards -24635.0625
# Day 8 Rewards -69335.25
# Day 9 Rewards 1090.75
# Day 10 Rewards -9071.25
# Day 11 Rewards 45613.9375
# Day 12 Rewards -39468.75
# Day 13 Rewards 559.75
# Day 14 Rewards 161.5
# Day 15 Rewards -34730.6875
# Day 16 Rewards -34841.3125
# Day 17 Rewards -14782.8125
# Day 18 Rewards 5142.9375
# Day 19 Rewards -4908.4375
# Day 20 Rewards 10146.5
# Day 21 Rewards -9978.375
# Day 22 Rewards 5165.0625
# Day 23 Rewards -14827.0625
# Day 24 Rewards 50.875
# Day 25 Rewards -9801.375
# Day 26 Rewards -9580.125
# Day 27 Rewards 10235.0
# Day 28 Rewards -34907.6875
# Day 29 Rewards -4797.8125
# Day 30 Rewards 0
# info {'total_reward': -324293.8125, 'total_profit': 0.8526547367913281, 'position': 0}

# %% [markdown]
# # 根據模型預測，position為今天收盤時需要進行的交易策略(Long or Short)

# %%
plt.figure(figsize=(16, 6))
env.render_Close()#將「環境」畫出來
# Out:
# ↓↓↓ 台積電(2330)在交易當天收盤時進行的交易策略(Long Or Short) ↓↓↓

# %%
plt.figure(figsize=(16, 6))
env.render_Reward()
# Out:
# ↓↓↓ 台積電(2330)在使用交易策略(Long Or Short)後，隔日早上平倉時的盈虧(含手續費) ↓↓↓

# %%
plt.figure(figsize=(16, 6))
env.render_TotalProfit()
# Out:
# ↓↓↓ 根據預測出的交易策略交易台積電(2330)，所得到的累積利潤(含手續費) ↓↓↓

# %% [markdown]
# # ------------------------------------------------

# %% [markdown]
# # 不同技術分析合併進行資料萃取，需要轉換矩陣格式，解釋如下：

# %%
# a = np.array([
#     [
#         [1,2,3,4,5,6],
#         [2,4,5,6,5,6],
#         [2,4,5,6,5,6],
#         [2,4,5,6,5,6]
#     ]
# ])
# #-----------------------
# b = np.array([
#     [
#         [1,2],[3,4],[5,6]
#     ],
#     [
#         [2,4],[5,6],[5,6]
#     ],
#     [
#         [2,4],[5,6],[5,6]
#     ],
#     [
#         [2,4],[5,6],[5,6]
#     ]
# ])
# #-----------------------
# print('目的：將原本矩陣a，變成矩陣b。因為在機器訓練時，需要讓機器意識到為兩組獨立的參數')
# print('注意：入面組嘅大小必須相同，例如[1,2],[3,4]，但不可以[1,2],[3,4,5]\n\n')
# print('第一個數字：大括號\n第二個數字：有四個打橫\n第三個數字：打橫入面有幾多個數字')
# print(a.shape)
# print(a,'\n')
# print('第一個數字：有幾多大組嘅數字\n第二個數字：入面有幾多個小組\n第三個數字：每個小組入面有幾多個數字')
# print(b.shape)
# print(b)
