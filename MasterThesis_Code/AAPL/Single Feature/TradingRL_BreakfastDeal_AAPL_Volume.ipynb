# %%
import gym
from gym import spaces
from gym.utils import seeding
import numpy as np
from enum import Enum
import matplotlib.pyplot as plt


#Agent的行動
class Actions(Enum):
    Sell = 0
    Buy = 1

#在Env裡面所代表的
class Positions(Enum):
    Short = 0
    Long = 1

    def opposite(self):
        return Positions.Short if self == Positions.Long else Positions.Long

    
class TradingEnv(gym.Env):

    metadata = {'render.modes': ['human']}
    
    #__init__為魔法函數，意義為：無論你願不願意，只要你執行TradingEnv，就會把__init__底下的資料執行，可以用作變數定義？
    def __init__(self, df, window_size): 
        assert df.ndim == 2 #判斷所輸入的df維度是否等於2

        self.seed() #隨機種子設定
        self.df = df #輸入df
        self.window_size = window_size #輸入Windows size
        self.open, self.close, self.high, self.low, self.volume, self.date, self.signal_features = self._process_data() #輸入【價錢, 特征資料】
        self.shape = (window_size, self.signal_features.shape[1]) #輸入【Windows size, 特征資料的長度】

        # spaces
        self.action_space = spaces.Discrete(len(Actions)) # 行動空間為：2（Sell、Buy）
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=self.shape, dtype=np.float64) #觀察空間最低和最高為無限（因為不知股票價錢為多少）

        # episode
        #「_」為私有化，即import的時候不會引入參數
        self._start_tick = self.window_size #開始日期：Windows_size設定的數字
        self._end_tick = len(self.close)-1 #結束日期：【價錢】的長度-1
        self._done = None 
        self._current_tick = None
        self._last_trade_tick = None
        self._position = None
        self._position_history = None
        
        #股息
        import yfinance as yf
        self.Ticker = yf.Ticker("2330.TW")#抓取股票
        self.Dividends = self.Ticker.actions['Dividends']#抓取股息資料
        self.Dividends_Date = self.Dividends.index.astype('string')#將股息日期->String
        self.Dividends_Date = np.array(self.Dividends_Date)#將股息日期->np.array
        self.Dividends = np.array(self.Dividends) #抓取股息價錢
#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓        
        self._reward_history = []#記錄Reward獎勵，方便畫圖
        self._Total_profit = []#記錄Profit，方便畫圖
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑
        self._total_reward = None
        self._total_profit = None
        self._first_rendering = None
        self.history = None

    #定義一個隨機種子   
    def seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    #重設
    def reset(self):
        self._done = False #尚未完成
        self._current_tick = self._start_tick # Windows_size設定的數字
        self._last_trade_tick = self._current_tick -1 #Windows_size設定的數字-1
        self._position = Positions.Short #第一天交易必定為Short
        self._position_history = (self.window_size * [None]) + [self._position] #記錄位置
        self._total_reward = 0. #初始化的reward為：0
        self._total_profit = 1. #初始化的Profit為：1
        self._first_rendering = True
        self.history = {}
        return self._get_observation()

    #交易中的步驟
    def step(self, action):
        self._done = False #尚未完成動作
        
        
        #如果當前日期 = 完結日期，就結束步驟
        if self._current_tick == self._end_tick:
            self._done = True

#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓
#如果機器人進行買的動作，他的Position就會變成Long，反之亦然
        if(action == Actions.Buy.value):
            self._position = Positions.Long
#             print("action: ", action)
#             print("position: ", self._position)
        elif(action == Actions.Sell.value):
            self._position = Positions.Short
#             print("action: ", action)
#             print("position: ", self._position)
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑               
        self._last_trade_tick = self._current_tick      
        #記錄步驟
        self._position_history.append(self._position)
        
        #獎勵：調用計算獎勵的function，然後將它累積起來計算總和
        step_reward = self._calculate_reward(action)
        step_profit = self._update_profit(action)#記錄profit，方便畫圖
#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓
        self._reward_history.append(step_reward)#記錄Reward獎勵，方便畫圖
        self._Total_profit.append(step_profit)#記錄profit，方便畫圖
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑ 
        self._total_reward += step_reward
        #根據agent的action更新他的 profit
        
        
        observation = self._get_observation()
        info = dict(
            total_reward = self._total_reward,
            total_profit = self._total_profit,
            position = self._position.value
        )
        self._update_history(info)
        
        self._current_tick += 1 #當前日期+1

        return observation, step_reward, self._done, info

    #取得觀察值，觀察值為signal_features
    #若window_size為10
    #則使用0 ~ 9日的觀察值，下一次交易則使用1 ~ 10日的觀察值
    def _get_observation(self):
        return self.signal_features[(self._current_tick-self.window_size+1):self._current_tick+1]

    #更新歷史資料
    def _update_history(self, info):
        if not self.history:
            self.history = {key: [] for key in info.keys()}

        for key, value in info.items():
            self.history[key].append(value)

    #render：將環境實體化，以股票交易為例即是畫圖
    def render(self, mode='human'):
        pass


    #畫圖
#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓    
    def render_Close(self, mode='human'):
            window_ticks = np.arange(len(self._position_history))#[1,2,3,4,5,....]矩陣
            plt.plot(self.close)#根據收盤價進行繪畫

            short_ticks = []
            long_ticks = []
            # i：控制position_history的位置
            # tick：控制要塞進Long還是Short的位置
            #如果機器人在之前就是做Long的話就把它記錄在long_ticks裡面，反之亦然
            for i, tick in enumerate(window_ticks-1):
                if self._position_history[i] == Positions.Short:
                    short_ticks.append(tick)
                elif self._position_history[i] == Positions.Long:
                    long_ticks.append(tick)      

            del(short_ticks[0])

            plt.plot(short_ticks, self.close[short_ticks], 'ro', label = 'Short')#根據收盤價進行畫圖
            plt.plot(long_ticks, self.close[long_ticks], 'go', label = 'Long')#根據收盤價進行畫圖
            
            plt.legend()
            plt.title("Close", fontsize=20)
            plt.suptitle(
                "Total Reward: %.6f" % self._total_reward + ' ~ ' +
                "Total Profit: %.6f" % self._total_profit
            )
            print("↓↓↓ 台積電(2330)在交易當天收盤時進行的交易策略(Long Or Short) ↓↓↓")
        
        
    #畫圖2   
    def render_Reward(self, mode='human'):
        window_ticks = np.arange(len(self._position_history))
        short_ticks = []
        long_ticks = []
        for i, tick in enumerate(window_ticks-1):
            if self._position_history[i] == Positions.Short:
                short_ticks.append(tick)
            elif self._position_history[i] == Positions.Long:
                long_ticks.append(tick)
        
        del(short_ticks[0])
        self._reward_history = np.array(self._reward_history)
        short_ticks = (np.array(short_ticks)-10).tolist()
        long_ticks = (np.array(long_ticks)-10).tolist()
        
        plt.bar(short_ticks,self._reward_history[short_ticks], color='r', label = 'Short')#根據獎勵進行繪畫
        plt.bar(long_ticks,self._reward_history[long_ticks], color='g', label = 'Long')#根據獎勵進行繪畫
            
        plt.legend()   
        plt.title("Reward", fontsize=20)
        plt.suptitle(
            "Total Reward: %.6f" % self._total_reward + ' ~ ' +
            "Total Profit: %.6f" % self._total_profit
        )
        print("↓↓↓ 台積電(2330)在使用交易策略(Long Or Short)後，隔日早上平倉時的盈虧(含手續費) ↓↓↓")
        
        
    def render_TotalProfit(self, mode='human'):
        window_ticks = np.arange(len(self._position_history))
        
        del self._Total_profit[-1]
        plt.plot(self._Total_profit)
        
        
#         short_ticks = []
#         long_ticks = []
#         for i, tick in enumerate(window_ticks-1):
#             if self._position_history[i] == Positions.Short:
#                 short_ticks.append(tick)
#             elif self._position_history[i] == Positions.Long:
#                 long_ticks.append(tick)
        
#         del(short_ticks[0])
#         self._Total_profit = np.array(self._Total_profit)
#         short_ticks = (np.array(short_ticks)-10).tolist()
#         long_ticks = (np.array(long_ticks)-10).tolist()
        
#         plt.plot(short_ticks, self._Total_profit[short_ticks], 'ro', label = 'Short')#根據獎勵進行畫圖
#         plt.plot(long_ticks, self._Total_profit[long_ticks], 'go', label = 'Long')#根據獎勵進行畫圖
            
#         plt.legend() 

        plt.title("TotalProfit", fontsize=20)
        plt.suptitle(
            "Total Reward: %.6f" % self._total_reward + ' ~ ' +
            "Total Profit: %.6f" % self._total_profit
        )
        print("↓↓↓ 根據預測出的交易策略交易台積電(2330)，所得到的累積利潤(含手續費) ↓↓↓")
        plt.savefig('2330_BBands_TotalProfit.jpg')
        
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑         
        


    
    
    #關閉環境，即關閉畫圖    
    def close(self):
        plt.close()

    #保存圖片
    def save_rendering(self, filepath):
        plt.savefig(filepath)

    #暫停畫圖
    def pause_rendering(self):
        plt.show()

    #在TradingEnv中，為了保持結構完整，因此使用pass不做任何事情
    def _process_data(self):
        pass

    #在TradingEnv中，為了保持結構完整，因此使用pass不做任何事情
    def _calculate_reward(self, action):
        pass

    #在TradingEnv中，為了保持結構完整，因此使用pass不做任何事情
    def _update_profit(self, action):
        pass

    #在TradingEnv中，為了保持結構完整，因此使用pass不做任何事情
    def max_possible_profit(self):  # trade fees are ignored
        pass

# %%
import numpy as np

class StocksEnv(TradingEnv):
    

    def __init__(self, df, window_size, frame_bound):
        assert len(frame_bound) == 2 #判斷所輸入的df維度是否等於2

        self.frame_bound = frame_bound #輸入範圍值
        super().__init__(df, window_size)

        self.trade_fee_percent = 0.001425+0.003
        #https://rich01.com/what-is-next-day-trading/
        
    #資料處理
    def _process_data(self):
        open = self.df.loc[:, 'open'].to_numpy() #prices：開市價
        close = self.df.loc[:, 'close'].to_numpy() #prices：收盤價
        high = self.df.loc[:, 'high'].to_numpy() #prices：最高
        low = self.df.loc[:, 'low'].to_numpy() #prices：最低
        volume = self.df.loc[:, 'volume'].to_numpy() #prices：成交量
        date = self.df.loc[:, 'index'].to_numpy() #prices：日期
        close[self.frame_bound[0] - self.window_size] # validate index (TODO: Improve validation)#驗證資料：10-10
        close = close[self.frame_bound[0]-self.window_size:self.frame_bound[1]]#【10-10:5600】
        
        
        diff = np.insert(np.diff(close), 0, 0)#計算價差【今天 - 昨天】
        signal_features = np.column_stack((close, diff))#默認的signal_features為：收盤價，價差

        return open, close ,high, low, volume, date, signal_features

#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓
    #計算獎勵
    def _calculate_reward(self, action):
        step_reward = 0
        price_diff = 0
        date = self.date[self._current_tick].astype('datetime64[D]') #日期格式 -> yyyy-mm-dd格式
        date = date.astype('str')#日期格式 -> string

        
        if(self._current_tick < self._end_tick):
            if( date not in self.Dividends_Date):#遇上除淨日不交易
                if(action == Actions.Buy.value):
                    
                    current_price = self.close[self._current_tick]#【今天收盤】
                    last_trade_price = self.open[self._current_tick+1]#【明天開盤】

                    Buy = current_price #買入成本 = 今天收盤
                    Sold = last_trade_price #賣出成本 = 明天開盤

                    price_diff = Sold - Buy #盈虧 = 賣出成本 - 買入成本




                elif(action == Actions.Sell.value):

                    current_price = self.close[self._current_tick]#【今天收盤】
                    last_trade_price = self.open[self._current_tick+1]#【明天開盤】

                    Buy = last_trade_price #買入成本 = 明天開盤
                    Sold = current_price #賣出成本 = 今天收盤

                    price_diff = Sold - Buy #盈虧 = 賣出成本 - 買入成本

        
            step_reward =  step_reward + price_diff
        
        return step_reward


    def _update_profit(self, action):
        
        long_profit_percentage = 0.0
        short_profit_percentage = 0.0
        Total_long_profit_percentage = 0.0
        Total_short_profit_percentage = 0.0
        
        date = self.date[self._current_tick].astype('datetime64[D]') #日期格式 -> yyyy-mm-dd格式
        date = date.astype('str')#日期格式 -> string
        
        step_profit = 0
        if(self._current_tick < self._end_tick):
            if( date not in self.Dividends_Date):#遇上除淨日不交易
                if(action == Actions.Buy.value):
                
                    current_price = self.close[self._current_tick]#【今天收盤】
                    last_trade_price = self.open[self._current_tick+1]#【明天開盤】

                    Buy = current_price
                    Sold = last_trade_price

                    price_diff = Sold - Buy#最後賺到的錢
                    long_profit_percentage = (Sold - Buy)/Buy
                    self._total_profit += long_profit_percentage

                elif(action == Actions.Sell.value):

                    current_price = self.close[self._current_tick]#【今天收盤】
                    last_trade_price = self.open[self._current_tick+1]#【明天開盤】

                    Buy = last_trade_price
                    Sold = current_price

                    price_diff = Sold - Buy#最後賺到的錢
                    short_profit_percentage = (Sold - Buy)/Buy 
                    self._total_profit += short_profit_percentage  
                       
                
            step_profit += self._total_profit #記錄profit，方便畫圖
        return step_profit#記錄profit，方便畫圖
        
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑  
                
    #https://github.com/AminHP/gym-anytrading/blob/master/README.ipynb
    #不論交易費用如何，agent在股票交易中所獲得的profit
    def max_possible_profit(self):
        pass

# %%
# import gym_anytrading
import numpy as np
import pandas as pd
import quantstats as qs
from stable_baselines import A2C
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\__init__.py:33: UserWarning: stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation.
#   "stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation."

# %%
from yahoo_fin import stock_info as si
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
if isinstance('AAPL', str):
    # load it from yahoo_fin library
    df = si.get_data('AAPL')
df = df.dropna()#丟棄空值
df = df.reset_index()
pd.set_option('display.float_format', lambda x: '%.3f' % x)#設定顯示小數點後3位數

#---------------------------------------------------------------------------
#定義參數

open = df['open']
close = df['close']
high = df['high']
low = df['low']
volume = df['volume']
UpLine_max = []
UpLine = [] #上引線
DownLine_min = []
DownLine = [] #下引線
UpMean = []#計算RSI——上漲平均5天
DownMean = []#計算RSI——下跌平均5天
RSI = []#計算RSI

#---------------------------------------------------------------------------
#上引線；下引線

for i in range(close.size):
    UpLine_max.append(max(open[i], close[i]))
for i in range(close.size):
    UpLine.append(high[i] - UpLine_max[i])#上影線
for i in range(close.size):
    DownLine_min.append(min(open[i], close[i]))
for i in range(close.size):
    DownLine.append(DownLine_min[i] - low[i])#下影線
#---------------------------------------------------------------------------
#RSI

UpDownValue = close - close.shift(1) #計算漲跌值
Only_UpValue = pd.Series(index=UpDownValue.index, data=UpDownValue[UpDownValue>0])#將上漲日子篩出
Only_UpValue = Only_UpValue.fillna(0)#下跌的日子為0
Only_DownValue = pd.Series(index=UpDownValue.index, data=-UpDownValue[UpDownValue<0])#將下跌日子篩出
Only_DownValue = Only_DownValue.fillna(0)#上漲的日子為0
for i in range(13, len(Only_UpValue)+1):#由第六日開始，直到現在
    UpMean.append(np.mean(Only_UpValue.values[i-12:i]))#計算出最近五日的平均，因為有補0，所以可以計算出。
    DownMean.append(np.mean(Only_DownValue.values[i-12:i]))#計算出最近五日的平均
for i in range(len(UpMean)):
    RSI.append( (UpMean[i] / ( UpMean[i] + DownMean[i] )) * 100  )#計算RSI
RSI = pd.Series(index = close.index[12:], data = RSI) #轉換格式
#---------------------------------------------------------------------------
#FH；FL
FH = ((high - open) / open) #FH
FL = ((open - low) / open) #FL
FH = pd.DataFrame(FH, columns=['FH'])#FH參數
FL = pd.DataFrame(FL, columns=['FL'])#FL參數
#---------------------------------------------------------------------------
# KD
K = []
D = []
K_Value = []
D_Value = []
def RSV(df):
    df['MinLow'] = df['low'].rolling(9, min_periods=9).min()#9天最低位
    df['MinLow'].fillna(value = df['low'].expanding().min(), inplace = True)#填滿NA
    df['MaxHigh'] = df['high'].rolling(9, min_periods=9).max()#9天最高位
    df['MaxHigh'].fillna(value = df['high'].expanding().max(), inplace = True)#填滿NA
    df['RSV'] = (df['close'] - df['MinLow']) / (df['MaxHigh'] - df['MinLow']) * 100 #計算RSV
    return df
RSV_df = RSV(df)#使用RSV函數計算
RSV = RSV_df['RSV']#獲得RSV
for i in range(len(RSV)):
    if i<=9 :
        K.append(50)
        D.append(50)
    elif i > 9:
        K.append((K[i-1] * 2/3) + (1/3 * RSV[i]))
        D.append((D[i-1] * 2/3) + (1/3 * K[i]))
K_Value = pd.Series(index = close.index[0:], data = K) #轉換格式
D_Value = pd.Series(index = close.index[0:], data = D) #轉換格式
#---------------------------------------------------------------------------
# MACD
DIF = []
MACD = []
ShortEMA=close.ewm(span=12,adjust=False).mean()#12日移動平均
LongEMA=close.ewm(span=26,adjust=False).mean()#26日移動平均
FastLine_DIF=ShortEMA-LongEMA#DIF = （12日移動平均 - 26日移動平均）
SlowLine_MACD=FastLine_DIF.ewm(span=9,adjust=False).mean()#取DIF數值得到9日移動平均
FastLine_DIF = pd.DataFrame(FastLine_DIF)#轉換格式
SlowLine_MACD = pd.DataFrame(SlowLine_MACD)#轉換格式
FastLine_DIF = FastLine_DIF.rename(columns={'close':'DIF'})#轉換格式
SlowLine_MACD = SlowLine_MACD.rename(columns={'close':'MACD'})#轉換格式
#---------------------------------------------------------------------------                                                             
#BBands
def BBands(df,Day=20,Times=2):#20天平均, 2倍標準差
    Up_Track=pd.Series(0.0,index=df.index)#建立全0的陣列
    Mid_Track=pd.Series(0.0,index=df.index)#建立全0的陣列
    Down_Track=pd.Series(0.0,index=df.index)#建立全0的陣列
    SD=pd.Series(0.0,index=df.index)#建立全0的陣列
    
    for i in range(Day-1,len(df)):#19~5600   
        Mid_Track[i]=np.mean(df[i-(Day-1):(i+1)])#中軌 = 0-20平均 -> 1-21平均 -> 2-22平均...（移動平均線）
        SD[i]=np.std(df[i-(Day-1):(i+1)])#0-20標準差 -> 1-21標準差 ->2-22標準差...（標準差）
        Up_Track[i]=Mid_Track[i]+(Times*SD[i])#上軌 = 中軌+（2倍標準差）
        Down_Track[i]=Mid_Track[i]-(Times*SD[i])#下軌 = 中軌-（2倍標準差）
        
        #慢慢地將上半部分建立的全0函式更新
        df_BBands=pd.DataFrame({'Up_Track':Up_Track[(Day-1):],#由第19日開始載入布林通道（上）
                             'Mid_Track':Mid_Track[(Day-1):],#由第19日開始載入布林通道（中）
                             'Down_Track':Down_Track[(Day-1):]#由第19日開始載入布林通道（下）
                            })
    return(df_BBands)
BBands_Up_Mid_Down_Trak = BBands(close, 20, 2)
#---------------------------------------------------------------------------
#成交量均線
volume10Day_mean=volume.ewm(span=10,adjust=False).mean() #10日移動平均成交量
volume10Day_mean = volume10Day_mean>volume #10日移動平均成交量 > 當日成交量【**技術指標**】
df_volume10day_mean=pd.DataFrame(volume10Day_mean) #變成DataFrame
labelencoder = LabelEncoder() #將True False 變成 1 0
df_volume10day_mean['volume'] = labelencoder.fit_transform(df_volume10day_mean['volume'])#將True False 變成 1 0
ct = ColumnTransformer([("volume", OneHotEncoder(), [0])], remainder = 'passthrough') #將1 0 變成 OneHotEncoder
df_volume10day_mean = ct.fit_transform(df_volume10day_mean)#將1 0 變成 OneHotEncoder
df_volume10day_mean = pd.DataFrame(df_volume10day_mean, columns = ['Volume_lower','Volume_greater'])
df_volume10day_mean['Volume_lower'] = pd.to_numeric(df_volume10day_mean['Volume_lower'], downcast='integer')
df_volume10day_mean['Volume_greater'] = pd.to_numeric(df_volume10day_mean['Volume_greater'], downcast='integer')







#合拼df
df2330 = pd.merge(df, FH,left_index=True,right_index=True) #合拼FH
df2330 = pd.merge(df2330, FL,left_index=True,right_index=True) #合拼FL
df2330 = pd.merge(df2330, pd.DataFrame(UpLine, columns=['UpLine']),left_index=True,right_index=True) #合併上影線
df2330 = pd.merge(df2330, pd.DataFrame(DownLine, columns=['DownLine']),left_index=True,right_index=True) #合併下影線
df2330 = pd.merge(df2330, pd.DataFrame(RSI, columns=['RSI']),left_index=True,right_index=True) #合併RSI
df2330 = pd.merge(df2330, pd.DataFrame(K_Value, columns=['K_Value']),left_index=True,right_index=True) #合併K值
df2330 = pd.merge(df2330, pd.DataFrame(D_Value, columns=['D_Value']),left_index=True,right_index=True) #合併D值
df2330 = pd.merge(df2330, pd.DataFrame(FastLine_DIF),left_index=True,right_index=True) #合併DIF
df2330 = pd.merge(df2330, pd.DataFrame(SlowLine_MACD),left_index=True,right_index=True) #合併MACD
df2330 = pd.merge(df2330,BBands_Up_Mid_Down_Trak,left_index=True,right_index=True) #合併布林通道
df2330 = pd.merge(df2330,df_volume10day_mean,left_index=True,right_index=True) #合併布林通道

df2330.index = range(len(df2330))#更新index

# %% [markdown]
# # 是否將特徵資料標準化？

# %%
#---------------------------------------------------------------------------
# normalizer = Normalizer()#創建標準化函數
# df2330_AllFeatures = df2330[['MinLow','MaxHigh','RSV','FH','FL','UpLine','DownLine','RSI','K_Value','D_Value','DIF','MACD','Up_Track','Mid_Track','Down_Track']]#取得需要標準化的特徵
# df2330_FeaturesNormalize = normalizer.fit_transform(df2330_AllFeatures)#進行標準化
# df2330_FeaturesNormalize = pd.DataFrame(df2330_FeaturesNormalize)#將array變成df
# df2330_FeaturesNormalize = df2330_FeaturesNormalize.rename(columns={0:'MinLow',1:'MaxHigh',2:'RSV',
#                                                       3:'FH',4:'FL',
#                                                       5:'UpLine',6:'DownLine',
#                                                       7:'RSI',
#                                                       8:'K_Value',9:'D_Value',
#                                                       10:'DIF',11:'MACD',
#                                                       12:'Up_Track',13:'Mid_Track',14:'Down_Track'})#更改名字
# df2330_OriginData = df2330[['index','open','high','low','close','adjclose','volume','ticker']]#取得市場基本資料
# df2330_Normalized = pd.merge(df2330_OriginData, df2330_FeaturesNormalize, left_index=True,right_index=True) #基本資料與標準化後特徵資料合併
# df2330 = df2330_Normalized
#---------------------------------------------------------------------------

#---------------------------------------------------------------------------
#輸出最終Dataframe
df = df2330
df
# Out:
#            index    open    high     low   close  adjclose    volume ticker  \
# 0     1981-01-12   0.142   0.142   0.141   0.141     0.110  23699200   AAPL
# 1     1981-01-13   0.137   0.137   0.136   0.136     0.106  23049600   AAPL
# 2     1981-01-14   0.137   0.137   0.137   0.137     0.106  14291200   AAPL
# 3     1981-01-15   0.140   0.141   0.140   0.140     0.108  14067200   AAPL
# 4     1981-01-16   0.139   0.139   0.138   0.138     0.108  13395200   AAPL
# ...          ...     ...     ...     ...     ...       ...       ...    ...
# 10620 2023-02-24 147.110 147.190 145.720 146.710   146.710  55469600   AAPL
# 10621 2023-02-27 147.710 149.170 147.450 147.920   147.920  44998500   AAPL
# 10622 2023-02-28 147.050 149.080 146.830 147.410   147.410  50547000   AAPL
# 10623 2023-03-01 146.830 147.230 145.010 145.310   145.310  55479000   AAPL
# 10624 2023-03-02 144.380 146.710 143.900 145.910   145.910  52238100   AAPL
#
#        MinLow  MaxHigh  ...    RSI  K_Value  D_Value   DIF  MACD  Up_Track  \
# 0       0.135    0.157  ... 52.778   26.583   35.261 0.004 0.005     0.167
# 1       0.135    0.155  ... 42.308   19.574   30.032 0.003 0.004     0.167
# 2       0.135    0.155  ... 25.925   15.827   25.297 0.002 0.004     0.167
# 3       0.135    0.151  ... 26.829   19.746   23.447 0.002 0.004     0.165
# 4       0.135    0.145  ... 28.571   24.929   23.941 0.002 0.003     0.163
# ...       ...      ...  ...    ...      ...      ...   ...   ...       ...
# 10620 145.720  156.330  ... 30.150   23.470   36.798 2.336 3.394   157.477
# 10621 145.720  156.330  ... 39.177   22.558   32.051 2.003 3.116   157.383
# 10622 145.720  156.330  ... 40.357   20.348   28.150 1.679 2.828   156.894
# 10623 145.010  156.330  ... 35.678   14.449   23.583 1.238 2.510   156.751
# 10624 143.900  153.000  ... 27.520   16.995   21.387 0.927 2.194   156.695
#
#        Mid_Track  Down_Track  Volume_lower  Volume_greater
# 0          0.139       0.110             0               1
# 1          0.139       0.111             0               1
# 2          0.140       0.113             0               1
# 3          0.141       0.117             0               1
# 4          0.142       0.121             0               1
# ...          ...         ...           ...             ...
# 10620    150.314     143.152             0               1
# 10621    150.414     143.445             0               1
# 10622    150.634     144.375             0               1
# 10623    150.685     144.620             0               1
# 10624    150.710     144.724             0               1
#
# [10625 rows x 25 columns]

# %% [markdown]
# # 查找DF的標籤

# %%
dfStartDate_Train = df[(df['index']=='2020-01-02')].index.values
dfStartDate_Train = dfStartDate_Train[0]
dfStartDate_Train
# Out:
# 9828

# %%
dfEndDate_Train = df[(df['index']=='2022-12-30')].index.values
dfEndDate_Train = dfEndDate_Train[0]
dfEndDate_Train
# Out:
# 10583

# %%
df[dfStartDate_Train:dfEndDate_Train+1]
# Out:
#            index    open    high     low   close  adjclose     volume ticker  \
# 9828  2020-01-02  74.060  75.150  73.798  75.088    73.449  135480400   AAPL
# 9829  2020-01-03  74.287  75.145  74.125  74.357    72.735  146322800   AAPL
# 9830  2020-01-06  73.448  74.990  73.188  74.950    73.315  118387200   AAPL
# 9831  2020-01-07  74.960  75.225  74.370  74.598    72.970  108872000   AAPL
# 9832  2020-01-08  74.290  76.110  74.290  75.798    74.144  132079200   AAPL
# ...          ...     ...     ...     ...     ...       ...        ...    ...
# 10579 2022-12-23 130.920 132.420 129.640 131.860   131.659   63814900   AAPL
# 10580 2022-12-27 131.380 131.410 128.720 130.030   129.832   69007800   AAPL
# 10581 2022-12-28 129.670 131.030 125.870 126.040   125.848   85438400   AAPL
# 10582 2022-12-29 127.990 130.480 127.730 129.610   129.412   75703700   AAPL
# 10583 2022-12-30 128.410 129.950 127.430 129.930   129.732   76960600   AAPL
#
#        MinLow  MaxHigh  ...    RSI  K_Value  D_Value    DIF   MACD  Up_Track  \
# 9828   69.640   75.150  ... 95.129   93.401   91.092  2.177  1.832    74.874
# 9829   69.640   75.150  ... 83.620   90.807   90.997  2.229  1.911    75.277
# 9830   70.092   75.150  ... 84.687   92.553   91.516  2.290  1.987    75.777
# 9831   70.730   75.225  ... 82.503   90.382   91.138  2.285  2.046    76.202
# 9832   71.175   76.110  ... 84.884   91.477   91.251  2.350  2.107    76.662
# ...       ...      ...  ...    ...      ...      ...    ...    ...       ...
# 10579 129.640  149.970  ... 32.140   14.227   16.660 -3.671 -2.570   151.953
# 10580 128.720  146.660  ... 25.294   11.918   15.080 -3.936 -2.843   152.017
# 10581 125.870  141.800  ... 22.245    8.301   12.820 -4.418 -3.158   152.674
# 10582 125.870  137.650  ... 25.429   16.117   13.919 -4.460 -3.419   151.730
# 10583 125.870  136.810  ... 23.768   23.115   16.985 -4.416 -3.618   150.449
#
#        Mid_Track  Down_Track  Volume_lower  Volume_greater
# 9828      69.797      64.720             1               0
# 9829      70.243      65.210             1               0
# 9830      70.671      65.565             0               1
# 9831      71.017      65.832             0               1
# 9832      71.470      66.279             1               0
# ...          ...         ...           ...             ...
# 10579    140.661     129.369             0               1
# 10580    139.951     127.886             0               1
# 10581    139.195     125.716             1               0
# 10582    138.274     124.818             0               1
# 10583    137.355     124.261             0               1
#
# [756 rows x 25 columns]

# %%
def my_process_data(df, window_size, frame_bound):
    start = frame_bound[0] - window_size #start = 5 - 5
    end = frame_bound[1] #end = 5600 
    close = df.loc[:, 'close'].to_numpy()[start:end]#抓取Close
    open = df.loc[:, 'open'].to_numpy()[start:end]#抓取open
    high = df.loc[:, 'high'].to_numpy()[start:end]#抓取high
    low = df.loc[:, 'low'].to_numpy()[start:end]#抓取low
    volnume = df.loc[:, 'volume'].to_numpy()[start:end]#抓取volume
    date = df.loc[:, 'index'].to_numpy()[start:end]#抓取Date
    signal_features = df.loc[:, ['Volume_lower', 'Volume_greater']].to_numpy()[start:end]#抓取特徵資料
    return open, close, high, low, volnume, date, signal_features


class MyStocksEnv(StocksEnv):
    
    def __init__(self, open, close, high, low, volnume, date,signal_features, **kwargs):
        self._open = open
        self._close = close
        self._high = high
        self._low = low
        self._volnume = volnume
        self._date = date
        self._signal_features = signal_features
        super().__init__(**kwargs)

    def _process_data(self):
        return self._open, self._close, self._high, self._low, self._volnume, self._date, self._signal_features

    
open, close, high, low, volume, date,signal_features = my_process_data(df=df, window_size=10, frame_bound=(dfStartDate_Train, dfEndDate_Train+1))#Close與特徵資料
env = MyStocksEnv(open, close, high, low, volume, date, signal_features, df=df, window_size=10, frame_bound=(dfStartDate_Train, dfEndDate_Train+1))#「環境」整合

# %%
policy_kwargs = dict(net_arch=[128, 'lstm', dict(vf=[64,64,64], pi=[64,64,64])])#要傳遞給policy的參數

model = A2C('MlpLstmPolicy', env, verbose=1, policy_kwargs=policy_kwargs)
# model = A2C('MlpLstmPolicy', env, verbose=1)
#policy: The policy model to use (MlpPolicy, CnnPolicy, …)""
#verbose: 0 no output, 1 info, 2 debug
#policy_kwargs: additional arguments to be passed to the policy on creation要傳遞給policy的參數
model.learn(total_timesteps=5000000)
# Out:
# Wrapping the env in a DummyVecEnv.
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\policies.py:442: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From C:\Users\cherr\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\layers\core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:160: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From C:\Users\cherr\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\ops\clip_ops.py:301: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:184: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From C:\Users\cherr\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\training\rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:194: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:196: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# ---------------------------------
# | explained_variance | 0.268    |
# | fps                | 1        |
# | nupdates           | 1        |
# | policy_entropy     | 0.686    |
# | total_timesteps    | 5        |
# | value_loss         | 0.479    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0673   |
# | fps                | 59       |
# | nupdates           | 100      |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 500      |
# | value_loss         | 3.04     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0524   |
# | fps                | 81       |
# | nupdates           | 200      |
# | policy_entropy     | 0.672    |
# | total_timesteps    | 1000     |
# | value_loss         | 3.77     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0718  |
# | fps                | 94       |
# | nupdates           | 300      |
# | policy_entropy     | 0.672    |
# | total_timesteps    | 1500     |
# | value_loss         | 21.1     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0239  |
# | fps                | 100      |
# | nupdates           | 400      |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 2000     |
# | value_loss         | 56.1     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0705  |
# | fps                | 105      |
# | nupdates           | 500      |
# | policy_entropy     | 0.682    |
# | total_timesteps    | 2500     |
# | value_loss         | 5.92     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00432 |
# | fps                | 107      |
# | nupdates           | 600      |
# | policy_entropy     | 0.669    |
# | total_timesteps    | 3000     |
# | value_loss         | 29.7     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.126    |
# | fps                | 109      |
# | nupdates           | 700      |
# | policy_entropy     | 0.679    |
# | total_timesteps    | 3500     |
# | value_loss         | 0.0942   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.149   |
# | fps                | 111      |
# | nupdates           | 800      |
# | policy_entropy     | 0.684    |
# | total_timesteps    | 4000     |
# | value_loss         | 5.55     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0199  |
# | fps                | 113      |
# | nupdates           | 900      |
# | policy_entropy     | 0.623    |
# | total_timesteps    | 4500     |
# | value_loss         | 32.7     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0279   |
# | fps                | 114      |
# | nupdates           | 1000     |
# | policy_entropy     | 0.312    |
# | total_timesteps    | 5000     |
# | value_loss         | 12.4     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0207  |
# | fps                | 115      |
# | nupdates           | 1100     |
# | policy_entropy     | 0.52     |
# | total_timesteps    | 5500     |
# | value_loss         | 2        |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.151   |
# | fps                | 116      |
# | nupdates           | 1200     |
# | policy_entropy     | 0.355    |
# | total_timesteps    | 6000     |
# | value_loss         | 1.19     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.143   |
# | fps                | 117      |
# | nupdates           | 1300     |
# | policy_entropy     | 0.658    |
# | total_timesteps    | 6500     |
# | value_loss         | 5.51     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0536  |
# | fps                | 118      |
# | nupdates           | 1400     |
# | policy_entropy     | 0.24     |
# | total_timesteps    | 7000     |
# | value_loss         | 19.3     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0193  |
# | fps                | 119      |
# | nupdates           | 1500     |
# | policy_entropy     | 0.114    |
# | total_timesteps    | 7500     |
# | value_loss         | 1.98     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0124  |
# | fps                | 120      |
# | nupdates           | 1600     |
# | policy_entropy     | 0.0513   |
# | total_timesteps    | 8000     |
# | value_loss         | 4.51     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0126  |
# | fps                | 120      |
# | nupdates           | 1700     |
# | policy_entropy     | 0.189    |
# | total_timesteps    | 8500     |
# | value_loss         | 3.12     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.119   |
# | fps                | 121      |
# | nupdates           | 1800     |
# | policy_entropy     | 0.154    |
# | total_timesteps    | 9000     |
# | value_loss         | 0.397    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0251   |
# | fps                | 121      |
# | nupdates           | 1900     |
# | policy_entropy     | 0.0797   |
# | total_timesteps    | 9500     |
# | value_loss         | 8.1      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.01     |
# | fps                | 122      |
# | nupdates           | 2000     |
# | policy_entropy     | 0.0991   |
# | total_timesteps    | 10000    |
# | value_loss         | 73.1     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0151  |
# | fps                | 122      |
# | nupdates           | 2100     |
# | policy_entropy     | 0.143    |
# | total_timesteps    | 10500    |
# | value_loss         | 0.929    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00357  |
# | fps                | 122      |
# | nupdates           | 2200     |
# | policy_entropy     | 0.0439   |
# | total_timesteps    | 11000    |
# | value_loss         | 0.198    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.247    |
# | fps                | 122      |
# | nupdates           | 2300     |
# | policy_entropy     | 0.0611   |
# | total_timesteps    | 11500    |
# | value_loss         | 0.406    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0245   |
# | fps                | 123      |
# | nupdates           | 2400     |
# | policy_entropy     | 0.0712   |
# | total_timesteps    | 12000    |
# | value_loss         | 3.38     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.195   |
# | fps                | 123      |
# | nupdates           | 2500     |
# | policy_entropy     | 0.0346   |
# | total_timesteps    | 12500    |
# | value_loss         | 0.227    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0126  |
# | fps                | 123      |
# | nupdates           | 2600     |
# | policy_entropy     | 0.156    |
# | total_timesteps    | 13000    |
# | value_loss         | 41.8     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.447   |
# | fps                | 124      |
# | nupdates           | 2700     |
# | policy_entropy     | 0.567    |
# | total_timesteps    | 13500    |
# | value_loss         | 14.5     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0848  |
# | fps                | 123      |
# | nupdates           | 2800     |
# | policy_entropy     | 0.326    |
# | total_timesteps    | 14000    |
# | value_loss         | 1.09     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0519  |
# | fps                | 124      |
# | nupdates           | 2900     |
# | policy_entropy     | 0.461    |
# | total_timesteps    | 14500    |
# | value_loss         | 1.13     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0173  |
# | fps                | 124      |
# | nupdates           | 3000     |
# | policy_entropy     | 0.15     |
# | total_timesteps    | 15000    |
# | value_loss         | 12.7     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.174   |
# | fps                | 124      |
# | nupdates           | 3100     |
# | policy_entropy     | 0.197    |
# | total_timesteps    | 15500    |
# | value_loss         | 3.18     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.277    |
# | fps                | 124      |
# | nupdates           | 3200     |
# | policy_entropy     | 0.653    |
# | total_timesteps    | 16000    |
# | value_loss         | 0.298    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.126    |
# | fps                | 124      |
# | nupdates           | 3300     |
# | policy_entropy     | 0.0849   |
# | total_timesteps    | 16500    |
# | value_loss         | 7.58     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0263  |
# | fps                | 124      |
# | nupdates           | 3400     |
# | policy_entropy     | 0.105    |
# | total_timesteps    | 17000    |
# | value_loss         | 0.0868   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.434   |
# | fps                | 124      |
# | nupdates           | 3500     |
# | policy_entropy     | 0.431    |
# | total_timesteps    | 17500    |
# | value_loss         | 11.6     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0263   |
# | fps                | 125      |
# | nupdates           | 3600     |
# | policy_entropy     | 0.146    |
# | total_timesteps    | 18000    |
# | value_loss         | 18.5     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.149   |
# | fps                | 125      |
# | nupdates           | 3700     |
# | policy_entropy     | 0.102    |
# | total_timesteps    | 18500    |
# | value_loss         | 0.156    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.297    |
# | fps                | 125      |
# | nupdates           | 3800     |
# | policy_entropy     | 0.0324   |
# | total_timesteps    | 19000    |
# | value_loss         | 0.319    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00227  |
# | fps                | 125      |
# | nupdates           | 3900     |
# | policy_entropy     | 0.0178   |
# | total_timesteps    | 19500    |
# | value_loss         | 3.44     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0271  |
# | fps                | 125      |
# | nupdates           | 4000     |
# | policy_entropy     | 0.0248   |
# | total_timesteps    | 20000    |
# | value_loss         | 7.05     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.177   |
# | fps                | 125      |
# | nupdates           | 4100     |
# | policy_entropy     | 0.0337   |
# | total_timesteps    | 20500    |
# | value_loss         | 3.08     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0317  |
# | fps                | 126      |
# | nupdates           | 4200     |
# | policy_entropy     | 0.0183   |
# | total_timesteps    | 21000    |
# | value_loss         | 1.9      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0511   |
# | fps                | 126      |
# | nupdates           | 4300     |
# | policy_entropy     | 0.0371   |
# | total_timesteps    | 21500    |
# | value_loss         | 0.138    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0968   |
# | fps                | 126      |
# | nupdates           | 4400     |
# | policy_entropy     | 0.105    |
# | total_timesteps    | 22000    |
# | value_loss         | 0.634    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0447  |
# | fps                | 126      |
# | nupdates           | 4500     |
# | policy_entropy     | 0.136    |
# | total_timesteps    | 22500    |
# | value_loss         | 1.81     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.16    |
# | fps                | 126      |
# | nupdates           | 4600     |
# | policy_entropy     | 0.205    |
# | total_timesteps    | 23000    |
# | value_loss         | 0.403    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.115    |
# | fps                | 126      |
# | nupdates           | 4700     |
# | policy_entropy     | 0.431    |
# | total_timesteps    | 23500    |
# | value_loss         | 2.74     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0574  |
# | fps                | 126      |
# | nupdates           | 4800     |
# | policy_entropy     | 0.132    |
# | total_timesteps    | 24000    |
# | value_loss         | 2.07     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.332   |
# | fps                | 126      |
# | nupdates           | 4900     |
# | policy_entropy     | 0.483    |
# | total_timesteps    | 24500    |
# | value_loss         | 0.145    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0736  |
# | fps                | 127      |
# | nupdates           | 5000     |
# | policy_entropy     | 0.502    |
# | total_timesteps    | 25000    |
# | value_loss         | 64.2     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00498 |
# | fps                | 127      |
# | nupdates           | 5100     |
# | policy_entropy     | 0.297    |
# | total_timesteps    | 25500    |
# | value_loss         | 30.8     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0197   |
# | fps                | 127      |
# | nupdates           | 5200     |
# | policy_entropy     | 0.337    |
# | total_timesteps    | 26000    |
# | value_loss         | 0.215    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00781  |
# | fps                | 127      |
# | nupdates           | 5300     |
# | policy_entropy     | 0.653    |
# | total_timesteps    | 26500    |
# | value_loss         | 57.7     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0333  |
# | fps                | 127      |
# | nupdates           | 5400     |
# | policy_entropy     | 0.176    |
# | total_timesteps    | 27000    |
# | value_loss         | 2.96     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0817   |
# | fps                | 127      |
# | nupdates           | 5500     |
# | policy_entropy     | 0.191    |
# | total_timesteps    | 27500    |
# | value_loss         | 11.2     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.141    |
# | fps                | 127      |
# | nupdates           | 5600     |
# | policy_entropy     | 0.684    |
# | total_timesteps    | 28000    |
# | value_loss         | 2        |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.145   |
# | fps                | 127      |
# | nupdates           | 5700     |
# | policy_entropy     | 0.26     |
# | total_timesteps    | 28500    |
# | value_loss         | 8.08     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.022   |
# | fps                | 128      |
# | nupdates           | 5800     |
# | policy_entropy     | 0.279    |
# | total_timesteps    | 29000    |
# | value_loss         | 20       |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0486   |
# | fps                | 128      |
# | nupdates           | 5900     |
# | policy_entropy     | 0.649    |
# | total_timesteps    | 29500    |
# | value_loss         | 4.76     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.113   |
# | fps                | 128      |
# | nupdates           | 6000     |
# | policy_entropy     | 0.316    |
# | total_timesteps    | 30000    |
# | value_loss         | 1.1      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0421   |
# | fps                | 128      |
# | nupdates           | 6100     |
# | policy_entropy     | 0.343    |
# | total_timesteps    | 30500    |
# | value_loss         | 3.43     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.314   |
# | fps                | 128      |
# | nupdates           | 6200     |
# | policy_entropy     | 0.539    |
# | total_timesteps    | 31000    |
# | value_loss         | 3.37     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.271    |
# | fps                | 128      |
# | nupdates           | 6300     |
# | policy_entropy     | 0.427    |
# | total_timesteps    | 31500    |
# | value_loss         | 0.0712   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0214  |
# | fps                | 128      |
# | nupdates           | 6400     |
# | policy_entropy     | 0.197    |
# | total_timesteps    | 32000    |
# | value_loss         | 4.98     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.11    |
# | fps                | 128      |
# | nupdates           | 6500     |
# | policy_entropy     | 0.541    |
# | total_timesteps    | 32500    |
# | value_loss         | 1.39     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0116   |
# | fps                | 128      |
# | nupdates           | 6600     |
# | policy_entropy     | 0.348    |
# | total_timesteps    | 33000    |
# | value_loss         | 2.53     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0247   |
# | fps                | 128      |
# | nupdates           | 6700     |
# | policy_entropy     | 0.304    |
# | total_timesteps    | 33500    |
# | value_loss         | 0.586    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0231   |
# | fps                | 128      |
# | nupdates           | 6800     |
# | policy_entropy     | 0.147    |
# | total_timesteps    | 34000    |
# | value_loss         | 8.44     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0229  |
# | fps                | 128      |
# | nupdates           | 6900     |
# | policy_entropy     | 0.0351   |
# | total_timesteps    | 34500    |
# | value_loss         | 6.53     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0732  |
# | fps                | 128      |
# | nupdates           | 7000     |
# | policy_entropy     | 0.0303   |
# | total_timesteps    | 35000    |
# | value_loss         | 3.87     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00879  |
# | fps                | 128      |
# | nupdates           | 7100     |
# | policy_entropy     | 0.052    |
# | total_timesteps    | 35500    |
# | value_loss         | 29.5     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0684   |
# | fps                | 128      |
# | nupdates           | 7200     |
# | policy_entropy     | 0.0258   |
# | total_timesteps    | 36000    |
# | value_loss         | 0.355    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0459   |
# | fps                | 128      |
# | nupdates           | 7300     |
# | policy_entropy     | 0.0826   |
# | total_timesteps    | 36500    |
# | value_loss         | 5.63     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.019   |
# | fps                | 129      |
# | nupdates           | 7400     |
# | policy_entropy     | 0.0712   |
# | total_timesteps    | 37000    |
# | value_loss         | 3.64     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.148    |
# | fps                | 129      |
# | nupdates           | 7500     |
# | policy_entropy     | 0.319    |
# | total_timesteps    | 37500    |
# | value_loss         | 1.19     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0259  |
# | fps                | 129      |
# | nupdates           | 7600     |
# | policy_entropy     | 0.13     |
# | total_timesteps    | 38000    |
# | value_loss         | 2.79     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.136   |
# | fps                | 129      |
# | nupdates           | 7700     |
# | policy_entropy     | 0.136    |
# | total_timesteps    | 38500    |
# | value_loss         | 5.71     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.304   |
# | fps                | 129      |
# | nupdates           | 7800     |
# | policy_entropy     | 0.119    |
# | total_timesteps    | 39000    |
# | value_loss         | 2.63     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0435   |
# | fps                | 129      |
# | nupdates           | 7900     |
# | policy_entropy     | 0.101    |
# | total_timesteps    | 39500    |
# | value_loss         | 1.59     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0246   |
# | fps                | 129      |
# | nupdates           | 8000     |
# | policy_entropy     | 0.0407   |
# | total_timesteps    | 40000    |
# | value_loss         | 10.3     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.209   |
# | fps                | 129      |
# | nupdates           | 8100     |
# | policy_entropy     | 0.0376   |
# | total_timesteps    | 40500    |
# | value_loss         | 5.73     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00168  |
# | fps                | 129      |
# | nupdates           | 8200     |
# | policy_entropy     | 0.0213   |
# | total_timesteps    | 41000    |
# | value_loss         | 39.3     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.114   |
# | fps                | 129      |
# | nupdates           | 8300     |
# | policy_entropy     | 0.0181   |
# | total_timesteps    | 41500    |
# | value_loss         | 1.17     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00989  |
# | fps                | 129      |
# | nupdates           | 8400     |
# | policy_entropy     | 0.0813   |
# | total_timesteps    | 42000    |
# | value_loss         | 0.689    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0101   |
# | fps                | 129      |
# | nupdates           | 8500     |
# | policy_entropy     | 0.106    |
# | total_timesteps    | 42500    |
# | value_loss         | 16       |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.225   |
# | fps                | 129      |
# | nupdates           | 8600     |
# | policy_entropy     | 0.309    |
# | total_timesteps    | 43000    |
# | value_loss         | 5.64     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.128   |
# | fps                | 129      |
# | nupdates           | 8700     |
# | policy_entropy     | 0.0466   |
# | total_timesteps    | 43500    |
# | value_loss         | 0.192    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.164    |
# | fps                | 129      |
# | nupdates           | 8800     |
# | policy_entropy     | 0.0912   |
# | total_timesteps    | 44000    |
# | value_loss         | 0.826    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0019  |
# | fps                | 129      |
# | nupdates           | 8900     |
# | policy_entropy     | 0.0787   |
# | total_timesteps    | 44500    |
# | value_loss         | 1.76     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0439   |
# | fps                | 129      |
# | nupdates           | 9000     |
# | policy_entropy     | 0.278    |
# | total_timesteps    | 45000    |
# | value_loss         | 3.9      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.038   |
# | fps                | 129      |
# | nupdates           | 9100     |
# | policy_entropy     | 0.0144   |
# | total_timesteps    | 45500    |
# | value_loss         | 0.244    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0586   |
# | fps                | 129      |
# | nupdates           | 9200     |
# | policy_entropy     | 0.0116   |
# | total_timesteps    | 46000    |
# | value_loss         | 2.75     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0468   |
# | fps                | 129      |
# | nupdates           | 9300     |
# | policy_entropy     | 0.0097   |
# | total_timesteps    | 46500    |
# | value_loss         | 2.38     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.118    |
# | fps                | 129      |
# | nupdates           | 9400     |
# | policy_entropy     | 0.03     |
# | total_timesteps    | 47000    |
# | value_loss         | 4.17     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.116    |
# | fps                | 129      |
# | nupdates           | 9500     |
# | policy_entropy     | 0.111    |
# | total_timesteps    | 47500    |
# | value_loss         | 2.25     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0752   |
# | fps                | 129      |
# | nupdates           | 9600     |
# | policy_entropy     | 0.0263   |
# | total_timesteps    | 48000    |
# | value_loss         | 0.112    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0223  |
# | fps                | 129      |
# | nupdates           | 9700     |
# | policy_entropy     | 0.109    |
# | total_timesteps    | 48500    |
# | value_loss         | 3.93     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00542  |
# | fps                | 129      |
# | nupdates           | 9800     |
# | policy_entropy     | 0.0119   |
# | total_timesteps    | 49000    |
# | value_loss         | 52.9     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0138   |
# | fps                | 129      |
# | nupdates           | 9900     |
# | policy_entropy     | 0.0445   |
# | total_timesteps    | 49500    |
# | value_loss         | 0.868    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.815   |
# | fps                | 129      |
# | nupdates           | 10000    |
# | policy_entropy     | 0.283    |
# | total_timesteps    | 50000    |
# | value_loss         | 0.0608   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.199   |
# | fps                | 129      |
# | nupdates           | 10100    |
# | policy_entropy     | 0.17     |
# | total_timesteps    | 50500    |
# | value_loss         | 19.3     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.15    |
# | fps                | 130      |
# | nupdates           | 10200    |
# | policy_entropy     | 0.0858   |
# | total_timesteps    | 51000    |
# | value_loss         | 0.938    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.685   |
# | fps                | 129      |
# | nupdates           | 10300    |
# | policy_entropy     | 0.155    |
# | total_timesteps    | 51500    |
# | value_loss         | 0.331    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0304  |
# | fps                | 130      |
# | nupdates           | 10400    |
# | policy_entropy     | 0.119    |
# | total_timesteps    | 52000    |
# | value_loss         | 19.8     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.115   |
# | fps                | 130      |
# | nupdates           | 10500    |
# | policy_entropy     | 0.246    |
# | total_timesteps    | 52500    |
# | value_loss         | 6.66     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00769 |
# | fps                | 130      |
# | nupdates           | 10600    |
# | policy_entropy     | 0.185    |
# | total_timesteps    | 53000    |
# | value_loss         | 0.51     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0245  |
# | fps                | 130      |
# | nupdates           | 10700    |
# | policy_entropy     | 0.143    |
# | total_timesteps    | 53500    |
# | value_loss         | 4.77     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.121   |
# | fps                | 130      |
# | nupdates           | 10800    |
# | policy_entropy     | 0.152    |
# | total_timesteps    | 54000    |
# | value_loss         | 1.95     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00743  |
# | fps                | 130      |
# | nupdates           | 10900    |
# | policy_entropy     | 0.243    |
# | total_timesteps    | 54500    |
# | value_loss         | 9.33     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0475   |
# | fps                | 130      |
# | nupdates           | 11000    |
# | policy_entropy     | 0.112    |
# | total_timesteps    | 55000    |
# | value_loss         | 1.02     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.535   |
# | fps                | 130      |
# | nupdates           | 11100    |
# | policy_entropy     | 0.169    |
# | total_timesteps    | 55500    |
# | value_loss         | 2.86     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0485   |
# | fps                | 130      |
# | nupdates           | 11200    |
# | policy_entropy     | 0.323    |
# | total_timesteps    | 56000    |
# | value_loss         | 11.6     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00395  |
# | fps                | 130      |
# | nupdates           | 11300    |
# | policy_entropy     | 0.0377   |
# | total_timesteps    | 56500    |
# | value_loss         | 2.48     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0146  |
# | fps                | 130      |
# | nupdates           | 11400    |
# | policy_entropy     | 0.113    |
# | total_timesteps    | 57000    |
# | value_loss         | 11.4     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0119   |
# | fps                | 130      |
# | nupdates           | 11500    |
# | policy_entropy     | 0.00571  |
# | total_timesteps    | 57500    |
# | value_loss         | 8.35     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0446   |
# | fps                | 130      |
# | nupdates           | 11600    |
# | policy_entropy     | 0.00693  |
# | total_timesteps    | 58000    |
# | value_loss         | 27.6     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0547   |
# | fps                | 130      |
# | nupdates           | 11700    |
# | policy_entropy     | 0.00678  |
# | total_timesteps    | 58500    |
# | value_loss         | 19.6     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0265  |
# | fps                | 130      |
# | nupdates           | 11800    |
# | policy_entropy     | 0.09     |
# | total_timesteps    | 59000    |
# | value_loss         | 2.59     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.169   |
# | fps                | 130      |
# | nupdates           | 11900    |
# | policy_entropy     | 0.128    |
# | total_timesteps    | 59500    |
# | value_loss         | 11.2     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0159   |
# | fps                | 130      |
# | nupdates           | 12000    |
# | policy_entropy     | 0.0563   |
# | total_timesteps    | 60000    |
# | value_loss         | 12       |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.101   |
# | fps                | 130      |
# | nupdates           | 12100    |
# | policy_entropy     | 0.185    |
# | total_timesteps    | 60500    |
# | value_loss         | 7.5      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.117   |
# | fps                | 130      |
# | nupdates           | 12200    |
# | policy_entropy     | 0.0612   |
# | total_timesteps    | 61000    |
# | value_loss         | 1.58     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.812   |
# | fps                | 130      |
# | nupdates           | 12300    |
# | policy_entropy     | 0.0135   |
# | total_timesteps    | 61500    |
# | value_loss         | 1.21     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.257   |
# | fps                | 130      |
# | nupdates           | 12400    |
# | policy_entropy     | 0.0177   |
# | total_timesteps    | 62000    |
# | value_loss         | 0.229    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.432   |
# | fps                | 130      |
# | nupdates           | 12500    |
# | policy_entropy     | 0.148    |
# | total_timesteps    | 62500    |
# | value_loss         | 3.36     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0393   |
# | fps                | 130      |
# | nupdates           | 12600    |
# | policy_entropy     | 0.00399  |
# | total_timesteps    | 63000    |
# | value_loss         | 7.72     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.358   |
# | fps                | 130      |
# | nupdates           | 12700    |
# | policy_entropy     | 0.00315  |
# | total_timesteps    | 63500    |
# | value_loss         | 7.92     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0226   |
# | fps                | 130      |
# | nupdates           | 12800    |
# | policy_entropy     | 0.149    |
# | total_timesteps    | 64000    |
# | value_loss         | 6.34     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0147   |
# | fps                | 130      |
# | nupdates           | 12900    |
# | policy_entropy     | 0.00443  |
# | total_timesteps    | 64500    |
# | value_loss         | 1.97     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0816  |
# | fps                | 130      |
# | nupdates           | 13000    |
# | policy_entropy     | 0.00369  |
# | total_timesteps    | 65000    |
# | value_loss         | 1.17     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0613   |
# | fps                | 130      |
# | nupdates           | 13100    |
# | policy_entropy     | 0.0165   |
# | total_timesteps    | 65500    |
# | value_loss         | 18.1     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.526    |
# | fps                | 130      |
# | nupdates           | 13200    |
# | policy_entropy     | 0.0104   |
# | total_timesteps    | 66000    |
# | value_loss         | 0.123    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0305  |
# | fps                | 130      |
# | nupdates           | 13300    |
# | policy_entropy     | 0.0174   |
# | total_timesteps    | 66500    |
# | value_loss         | 3.69     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.236   |
# | fps                | 130      |
# | nupdates           | 13400    |
# | policy_entropy     | 0.0056   |
# | total_timesteps    | 67000    |
# | value_loss         | 1.61     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0243   |
# | fps                | 130      |
# | nupdates           | 13500    |
# | policy_entropy     | 0.00606  |
# | total_timesteps    | 67500    |
# | value_loss         | 25.3     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00234 |
# | fps                | 130      |
# | nupdates           | 13600    |
# | policy_entropy     | 0.149    |
# | total_timesteps    | 68000    |
# | value_loss         | 3.66     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.394    |
# | fps                | 130      |
# | nupdates           | 13700    |
# | policy_entropy     | 0.0091   |
# | total_timesteps    | 68500    |
# | value_loss         | 0.989    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0747  |
# | fps                | 130      |
# | nupdates           | 13800    |
# | policy_entropy     | 0.0303   |
# | total_timesteps    | 69000    |
# | value_loss         | 0.35     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0803  |
# | fps                | 130      |
# | nupdates           | 13900    |
# | policy_entropy     | 0.0339   |
# | total_timesteps    | 69500    |
# | value_loss         | 25.5     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0267   |
# | fps                | 130      |
# | nupdates           | 14000    |
# | policy_entropy     | 0.00952  |
# | total_timesteps    | 70000    |
# | value_loss         | 0.383    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0144   |
# | fps                | 130      |
# | nupdates           | 14100    |
# | policy_entropy     | 0.00983  |
# | total_timesteps    | 70500    |
# | value_loss         | 5.51     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.136    |
# | fps                | 130      |
# | nupdates           | 14200    |
# | policy_entropy     | 0.0675   |
# | total_timesteps    | 71000    |
# | value_loss         | 4.78     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0338   |
# | fps                | 130      |
# | nupdates           | 14300    |
# | policy_entropy     | 0.164    |
# | total_timesteps    | 71500    |
# | value_loss         | 2.73     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.131    |
# | fps                | 130      |
# | nupdates           | 14400    |
# | policy_entropy     | 0.00589  |
# | total_timesteps    | 72000    |
# | value_loss         | 3.99     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00345  |
# | fps                | 130      |
# | nupdates           | 14500    |
# | policy_entropy     | 0.133    |
# | total_timesteps    | 72500    |
# | value_loss         | 7.49     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0832  |
# | fps                | 130      |
# | nupdates           | 14600    |
# | policy_entropy     | 0.0401   |
# | total_timesteps    | 73000    |
# | value_loss         | 2.57     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0831   |
# | fps                | 130      |
# | nupdates           | 14700    |
# | policy_entropy     | 0.0058   |
# | total_timesteps    | 73500    |
# | value_loss         | 46.5     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.17     |
# | fps                | 130      |
# | nupdates           | 14800    |
# | policy_entropy     | 0.00745  |
# | total_timesteps    | 74000    |
# | value_loss         | 1.32     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.114    |
# | fps                | 130      |
# | nupdates           | 14900    |
# | policy_entropy     | 0.00579  |
# | total_timesteps    | 74500    |
# | value_loss         | 2.26     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0595  |
# | fps                | 130      |
# | nupdates           | 15000    |
# | policy_entropy     | 0.00652  |
# | total_timesteps    | 75000    |
# | value_loss         | 3.43     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.181   |
# | fps                | 130      |
# | nupdates           | 15100    |
# | policy_entropy     | 0.00456  |
# | total_timesteps    | 75500    |
# | value_loss         | 3.67     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0732  |
# | fps                | 130      |
# | nupdates           | 15200    |
# | policy_entropy     | 0.167    |
# | total_timesteps    | 76000    |
# | value_loss         | 0.413    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.146    |
# | fps                | 130      |
# | nupdates           | 15300    |
# | policy_entropy     | 0.00915  |
# | total_timesteps    | 76500    |
# | value_loss         | 0.61     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0306   |
# | fps                | 130      |
# | nupdates           | 15400    |
# | policy_entropy     | 0.00501  |
# | total_timesteps    | 77000    |
# | value_loss         | 1.21     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0426   |
# | fps                | 130      |
# | nupdates           | 15500    |
# | policy_entropy     | 0.00283  |
# | total_timesteps    | 77500    |
# | value_loss         | 4.7      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0433   |
# | fps                | 130      |
# | nupdates           | 15600    |
# | policy_entropy     | 0.0423   |
# | total_timesteps    | 78000    |
# | value_loss         | 3.59     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.151   |
# | fps                | 130      |
# | nupdates           | 15700    |
# | policy_entropy     | 0.0298   |
# | total_timesteps    | 78500    |
# | value_loss         | 4.98     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.713    |
# | fps                | 130      |
# | nupdates           | 15800    |
# | policy_entropy     | 0.00284  |
# | total_timesteps    | 79000    |
# | value_loss         | 0.0385   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0718   |
# | fps                | 130      |
# | nupdates           | 15900    |
# | policy_entropy     | 0.00736  |
# | total_timesteps    | 79500    |
# | value_loss         | 0.778    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.111    |
# | fps                | 130      |
# | nupdates           | 16000    |
# | policy_entropy     | 0.00262  |
# | total_timesteps    | 80000    |
# | value_loss         | 7.41     |
# ---------------------------------
# ...
# | fps                | 237      |
# | nupdates           | 994200   |
# | policy_entropy     | 0.00139  |
# | total_timesteps    | 4971000  |
# | value_loss         | 0.0274   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.987    |
# | fps                | 237      |
# | nupdates           | 994300   |
# | policy_entropy     | 0.000461 |
# | total_timesteps    | 4971500  |
# | value_loss         | 0.0264   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 237      |
# | nupdates           | 994400   |
# | policy_entropy     | 0.00215  |
# | total_timesteps    | 4972000  |
# | value_loss         | 0.0723   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 237      |
# | nupdates           | 994500   |
# | policy_entropy     | 0.00479  |
# | total_timesteps    | 4972500  |
# | value_loss         | 0.00317  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.992    |
# | fps                | 237      |
# | nupdates           | 994600   |
# | policy_entropy     | 0.00358  |
# | total_timesteps    | 4973000  |
# | value_loss         | 0.0031   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.998    |
# | fps                | 237      |
# | nupdates           | 994700   |
# | policy_entropy     | 0.0194   |
# | total_timesteps    | 4973500  |
# | value_loss         | 0.00516  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 237      |
# | nupdates           | 994800   |
# | policy_entropy     | 0.00416  |
# | total_timesteps    | 4974000  |
# | value_loss         | 0.0102   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.896    |
# | fps                | 237      |
# | nupdates           | 994900   |
# | policy_entropy     | 0.00124  |
# | total_timesteps    | 4974500  |
# | value_loss         | 0.0873   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.99     |
# | fps                | 237      |
# | nupdates           | 995000   |
# | policy_entropy     | 0.0023   |
# | total_timesteps    | 4975000  |
# | value_loss         | 0.00677  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 237      |
# | nupdates           | 995100   |
# | policy_entropy     | 0.0044   |
# | total_timesteps    | 4975500  |
# | value_loss         | 0.00436  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 237      |
# | nupdates           | 995200   |
# | policy_entropy     | 0.000179 |
# | total_timesteps    | 4976000  |
# | value_loss         | 0.00591  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.992    |
# | fps                | 237      |
# | nupdates           | 995300   |
# | policy_entropy     | 0.00757  |
# | total_timesteps    | 4976500  |
# | value_loss         | 0.025    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 237      |
# | nupdates           | 995400   |
# | policy_entropy     | 0.00037  |
# | total_timesteps    | 4977000  |
# | value_loss         | 0.00351  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 237      |
# | nupdates           | 995500   |
# | policy_entropy     | 0.0127   |
# | total_timesteps    | 4977500  |
# | value_loss         | 0.0145   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.999    |
# | fps                | 237      |
# | nupdates           | 995600   |
# | policy_entropy     | 0.000811 |
# | total_timesteps    | 4978000  |
# | value_loss         | 0.00467  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.943    |
# | fps                | 237      |
# | nupdates           | 995700   |
# | policy_entropy     | 0.00234  |
# | total_timesteps    | 4978500  |
# | value_loss         | 0.00405  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.998    |
# | fps                | 237      |
# | nupdates           | 995800   |
# | policy_entropy     | 0.0281   |
# | total_timesteps    | 4979000  |
# | value_loss         | 0.00159  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 237      |
# | nupdates           | 995900   |
# | policy_entropy     | 0.00689  |
# | total_timesteps    | 4979500  |
# | value_loss         | 0.0109   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.999    |
# | fps                | 237      |
# | nupdates           | 996000   |
# | policy_entropy     | 0.00153  |
# | total_timesteps    | 4980000  |
# | value_loss         | 0.0114   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 237      |
# | nupdates           | 996100   |
# | policy_entropy     | 0.00178  |
# | total_timesteps    | 4980500  |
# | value_loss         | 0.00412  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.769    |
# | fps                | 237      |
# | nupdates           | 996200   |
# | policy_entropy     | 0.0035   |
# | total_timesteps    | 4981000  |
# | value_loss         | 0.146    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.999    |
# | fps                | 237      |
# | nupdates           | 996300   |
# | policy_entropy     | 0.00112  |
# | total_timesteps    | 4981500  |
# | value_loss         | 0.0112   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 237      |
# | nupdates           | 996400   |
# | policy_entropy     | 0.000515 |
# | total_timesteps    | 4982000  |
# | value_loss         | 0.00444  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 237      |
# | nupdates           | 996500   |
# | policy_entropy     | 0.04     |
# | total_timesteps    | 4982500  |
# | value_loss         | 0.000213 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 237      |
# | nupdates           | 996600   |
# | policy_entropy     | 0.00262  |
# | total_timesteps    | 4983000  |
# | value_loss         | 0.00106  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 237      |
# | nupdates           | 996700   |
# | policy_entropy     | 0.00123  |
# | total_timesteps    | 4983500  |
# | value_loss         | 0.0304   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 237      |
# | nupdates           | 996800   |
# | policy_entropy     | 0.024    |
# | total_timesteps    | 4984000  |
# | value_loss         | 0.00526  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.999    |
# | fps                | 237      |
# | nupdates           | 996900   |
# | policy_entropy     | 0.0131   |
# | total_timesteps    | 4984500  |
# | value_loss         | 0.00238  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 237      |
# | nupdates           | 997000   |
# | policy_entropy     | 0.000769 |
# | total_timesteps    | 4985000  |
# | value_loss         | 0.00402  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 237      |
# | nupdates           | 997100   |
# | policy_entropy     | 0.000256 |
# | total_timesteps    | 4985500  |
# | value_loss         | 0.0177   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.999    |
# | fps                | 237      |
# | nupdates           | 997200   |
# | policy_entropy     | 0.0284   |
# | total_timesteps    | 4986000  |
# | value_loss         | 0.00409  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.993    |
# | fps                | 237      |
# | nupdates           | 997300   |
# | policy_entropy     | 0.00251  |
# | total_timesteps    | 4986500  |
# | value_loss         | 0.0269   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.989    |
# | fps                | 237      |
# | nupdates           | 997400   |
# | policy_entropy     | 0.000878 |
# | total_timesteps    | 4987000  |
# | value_loss         | 0.00305  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.955    |
# | fps                | 237      |
# | nupdates           | 997500   |
# | policy_entropy     | 0.000183 |
# | total_timesteps    | 4987500  |
# | value_loss         | 0.0287   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.669    |
# | fps                | 237      |
# | nupdates           | 997600   |
# | policy_entropy     | 0.00172  |
# | total_timesteps    | 4988000  |
# | value_loss         | 0.0631   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.797    |
# | fps                | 237      |
# | nupdates           | 997700   |
# | policy_entropy     | 0.00146  |
# | total_timesteps    | 4988500  |
# | value_loss         | 0.0567   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.999    |
# | fps                | 237      |
# | nupdates           | 997800   |
# | policy_entropy     | 0.000355 |
# | total_timesteps    | 4989000  |
# | value_loss         | 0.000807 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.99     |
# | fps                | 237      |
# | nupdates           | 997900   |
# | policy_entropy     | 0.00086  |
# | total_timesteps    | 4989500  |
# | value_loss         | 0.0128   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.884    |
# | fps                | 237      |
# | nupdates           | 998000   |
# | policy_entropy     | 0.000709 |
# | total_timesteps    | 4990000  |
# | value_loss         | 0.0189   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.969    |
# | fps                | 237      |
# | nupdates           | 998100   |
# | policy_entropy     | 0.00488  |
# | total_timesteps    | 4990500  |
# | value_loss         | 0.00632  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.977    |
# | fps                | 237      |
# | nupdates           | 998200   |
# | policy_entropy     | 0.0284   |
# | total_timesteps    | 4991000  |
# | value_loss         | 0.00203  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.993    |
# | fps                | 237      |
# | nupdates           | 998300   |
# | policy_entropy     | 0.048    |
# | total_timesteps    | 4991500  |
# | value_loss         | 0.00296  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.753    |
# | fps                | 237      |
# | nupdates           | 998400   |
# | policy_entropy     | 0.000925 |
# | total_timesteps    | 4992000  |
# | value_loss         | 0.0909   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.978    |
# | fps                | 237      |
# | nupdates           | 998500   |
# | policy_entropy     | 0.00524  |
# | total_timesteps    | 4992500  |
# | value_loss         | 0.00804  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.974    |
# | fps                | 237      |
# | nupdates           | 998600   |
# | policy_entropy     | 0.00436  |
# | total_timesteps    | 4993000  |
# | value_loss         | 0.0144   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.999    |
# | fps                | 237      |
# | nupdates           | 998700   |
# | policy_entropy     | 0.134    |
# | total_timesteps    | 4993500  |
# | value_loss         | 0.00603  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.991    |
# | fps                | 237      |
# | nupdates           | 998800   |
# | policy_entropy     | 0.0566   |
# | total_timesteps    | 4994000  |
# | value_loss         | 0.0232   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.99     |
# | fps                | 237      |
# | nupdates           | 998900   |
# | policy_entropy     | 0.00209  |
# | total_timesteps    | 4994500  |
# | value_loss         | 0.00681  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 237      |
# | nupdates           | 999000   |
# | policy_entropy     | 0.0489   |
# | total_timesteps    | 4995000  |
# | value_loss         | 0.000567 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 237      |
# | nupdates           | 999100   |
# | policy_entropy     | 0.00184  |
# | total_timesteps    | 4995500  |
# | value_loss         | 0.00507  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.825    |
# | fps                | 237      |
# | nupdates           | 999200   |
# | policy_entropy     | 0.000873 |
# | total_timesteps    | 4996000  |
# | value_loss         | 0.00427  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.988    |
# | fps                | 237      |
# | nupdates           | 999300   |
# | policy_entropy     | 0.00256  |
# | total_timesteps    | 4996500  |
# | value_loss         | 0.0394   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 237      |
# | nupdates           | 999400   |
# | policy_entropy     | 0.00161  |
# | total_timesteps    | 4997000  |
# | value_loss         | 0.0174   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.959    |
# | fps                | 237      |
# | nupdates           | 999500   |
# | policy_entropy     | 0.00909  |
# | total_timesteps    | 4997500  |
# | value_loss         | 0.0158   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.961    |
# | fps                | 237      |
# | nupdates           | 999600   |
# | policy_entropy     | 0.00589  |
# | total_timesteps    | 4998000  |
# | value_loss         | 0.0152   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.958    |
# | fps                | 237      |
# | nupdates           | 999700   |
# | policy_entropy     | 0.0254   |
# | total_timesteps    | 4998500  |
# | value_loss         | 0.013    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.982    |
# | fps                | 237      |
# | nupdates           | 999800   |
# | policy_entropy     | 0.0125   |
# | total_timesteps    | 4999000  |
# | value_loss         | 0.0475   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.545   |
# | fps                | 237      |
# | nupdates           | 999900   |
# | policy_entropy     | 0.0553   |
# | total_timesteps    | 4999500  |
# | value_loss         | 4.25     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.987    |
# | fps                | 237      |
# | nupdates           | 1000000  |
# | policy_entropy     | 0.000781 |
# | total_timesteps    | 5000000  |
# | value_loss         | 0.0124   |
# ---------------------------------

# %%
model.save("2330TW_5MTimestep_20200102_20220831Training_128_64_64_volume")

# %%
model = A2C.load("2330TW_5MTimestep_20200102_20220831Training_128_64_64_volume")
# Out:
# Loading a model without an environment, this model cannot be trained until it has a valid environment.
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\policies.py:442: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From C:\Users\cherr\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\layers\core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:160: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From C:\Users\cherr\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\ops\clip_ops.py:301: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:184: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From C:\Users\cherr\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\training\rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:194: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:196: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.

# %% [markdown]
# # 獲取今天的Dataframe索引，方便填寫frame_bound

# %%
# today = df2330.iloc[-1:]
# today = today.index.values
# totay = today[0]

# %%
dfStartDate_Test = df[(df['index']=='2023-01-03')].index.values
dfStartDate_Test = dfStartDate_Test[0]

dfEndDate_Test = df[(df['index']=='2023-02-28')].index.values
dfEndDate_Test = dfEndDate_Test[0]

# %%
dfStartDate_Test
# Out:
# 10584

# %%
dfEndDate_Test
# Out:
# 10622

# %%
df[dfStartDate_Test:dfEndDate_Test+1]
# Out:
#            index    open    high     low   close  adjclose     volume ticker  \
# 10584 2023-01-03 130.280 130.900 124.170 125.070   124.879  112117500   AAPL
# 10585 2023-01-04 126.890 128.660 125.080 126.360   126.167   89113600   AAPL
# 10586 2023-01-05 127.130 127.770 124.760 125.020   124.829   80962700   AAPL
# 10587 2023-01-06 126.010 130.290 124.890 129.620   129.422   87686600   AAPL
# 10588 2023-01-09 130.470 133.410 129.890 130.150   129.952   70790800   AAPL
# 10589 2023-01-10 130.260 131.260 128.120 130.730   130.531   63896200   AAPL
# 10590 2023-01-11 131.250 133.510 130.460 133.490   133.286   69458900   AAPL
# 10591 2023-01-12 133.880 134.260 131.440 133.410   133.207   71379600   AAPL
# 10592 2023-01-13 132.030 134.920 131.660 134.760   134.555   57758000   AAPL
# 10593 2023-01-17 134.830 137.290 134.130 135.940   135.733   63646600   AAPL
# 10594 2023-01-18 136.820 138.610 135.030 135.210   135.004   69672800   AAPL
# 10595 2023-01-19 134.080 136.250 133.770 135.270   135.064   58280400   AAPL
# 10596 2023-01-20 135.280 138.020 134.220 137.870   137.660   79972200   AAPL
# 10597 2023-01-23 138.120 143.320 137.900 141.110   140.895   81760300   AAPL
# 10598 2023-01-24 140.310 143.160 140.300 142.530   142.313   66435100   AAPL
# 10599 2023-01-25 140.890 142.430 138.810 141.860   141.644   65799300   AAPL
# 10600 2023-01-26 143.170 144.250 141.900 143.960   143.741   54105100   AAPL
# 10601 2023-01-27 143.160 147.230 143.080 145.930   145.708   70492800   AAPL
# 10602 2023-01-30 144.960 145.550 142.850 143.000   142.782   64015300   AAPL
# 10603 2023-01-31 142.700 144.340 142.280 144.290   144.070   65874500   AAPL
# 10604 2023-02-01 143.970 146.610 141.320 145.430   145.208   77663600   AAPL
# 10605 2023-02-02 148.900 151.180 148.170 150.820   150.590  118339000   AAPL
# 10606 2023-02-03 148.030 157.380 147.830 154.500   154.264  154279900   AAPL
# 10607 2023-02-06 152.570 153.100 150.780 151.730   151.499   69858300   AAPL
# 10608 2023-02-07 150.640 155.230 150.640 154.650   154.414   83322600   AAPL
# 10609 2023-02-08 153.880 154.580 151.170 151.920   151.688   64120100   AAPL
# 10610 2023-02-09 153.780 154.330 150.420 150.870   150.640   56007100   AAPL
# 10611 2023-02-10 149.460 151.340 149.220 151.010   151.010   57409100   AAPL
# 10612 2023-02-13 150.950 154.260 150.920 153.850   153.850   62199000   AAPL
# 10613 2023-02-14 152.120 153.770 150.860 153.200   153.200   61707600   AAPL
# 10614 2023-02-15 153.110 155.500 152.880 155.330   155.330   65669300   AAPL
# 10615 2023-02-16 153.510 156.330 153.350 153.710   153.710   68167900   AAPL
# 10616 2023-02-17 152.350 153.000 150.850 152.550   152.550   59095900   AAPL
# 10617 2023-02-21 150.200 151.300 148.410 148.480   148.480   58867200   AAPL
# 10618 2023-02-22 148.870 149.950 147.160 148.910   148.910   51011300   AAPL
# 10619 2023-02-23 150.090 150.340 147.240 149.400   149.400   48394200   AAPL
# 10620 2023-02-24 147.110 147.190 145.720 146.710   146.710   55469600   AAPL
# 10621 2023-02-27 147.710 149.170 147.450 147.920   147.920   44998500   AAPL
# 10622 2023-02-28 147.050 149.080 146.830 147.410   147.410   50547000   AAPL
#
#        MinLow  MaxHigh  ...    RSI  K_Value  D_Value    DIF   MACD  Up_Track  \
# 10584 124.170  136.810  ... 21.850   17.784   17.251 -4.720 -3.838   149.432
# 10585 124.170  136.810  ... 31.082   17.631   17.378 -4.801 -4.031   148.176
# 10586 124.170  134.560  ... 31.855   14.481   16.412 -4.916 -4.208   147.498
# 10587 124.170  132.420  ... 45.194   31.674   21.499 -4.584 -4.283   146.715
# 10588 124.170  133.410  ... 46.302   42.689   28.563 -4.229 -4.272   145.505
# 10589 124.170  133.410  ... 41.094   52.125   36.417 -3.857 -4.189   144.248
# 10590 124.170  133.510  ... 52.419   68.012   46.948 -3.301 -4.012   142.358
# 10591 124.170  134.260  ... 53.010   75.866   56.588 -2.834 -3.776   139.760
# 10592 124.170  134.920  ... 59.359   83.415   65.530 -2.328 -3.486   137.576
# 10593 124.760  137.290  ... 72.039   85.352   72.137 -1.811 -3.151   137.459
# 10594 124.760  138.610  ... 64.271   82.052   75.442 -1.444 -2.810   137.577
# 10595 124.890  138.610  ... 63.791   79.920   76.935 -1.135 -2.475   137.961
# 10596 128.120  138.610  ... 87.427   84.262   79.377 -0.672 -2.114   138.836
# 10597 128.120  143.320  ... 88.714   84.661   81.138 -0.044 -1.700   140.082
# 10598 130.460  143.320  ... 95.766   87.726   83.334  0.562 -1.248   141.839
# 10599 131.440  143.320  ... 90.263   87.721   84.797  0.978 -0.803   143.215
# 10600 131.660  144.250  ... 91.175   91.046   86.880  1.459 -0.350   144.909
# 10601 133.770  147.230  ... 91.850   90.811   88.190  1.977  0.115   146.605
# 10602 133.770  147.230  ... 75.941   83.399   86.593  2.126  0.517   147.616
# 10603 133.770  147.230  ... 77.840   81.652   84.946  2.322  0.878   148.715
# 10604 134.220  147.230  ... 77.600   83.156   84.349  2.540  1.211   149.402
# 10605 137.900  151.180  ... 81.606   87.867   85.522  3.112  1.591   151.075
# 10606 138.810  157.380  ... 86.410   86.742   85.929  3.818  2.036   152.995
# 10607 138.810  157.380  ... 78.185   81.019   84.292  4.106  2.450   154.304
# 10608 141.320  157.380  ... 78.421   81.680   83.421  4.519  2.864   155.948
# 10609 141.320  157.380  ... 68.632   76.454   81.099  4.572  3.206   156.695
# 10610 141.320  157.380  ... 64.560   70.791   77.663  4.479  3.460   157.274
# 10611 141.320  157.380  ... 66.275   67.306   74.211  4.365  3.641   157.628
# 10612 141.320  157.380  ... 67.140   70.877   73.100  4.453  3.804   158.344
# 10613 147.830  157.380  ... 63.204   65.995   70.731  4.420  3.927   158.808
# 10614 147.830  157.380  ... 73.064   70.175   70.546  4.513  4.044   159.253
# 10615 149.220  156.330  ... 67.406   67.833   69.642  4.405  4.116   159.050
# 10616 149.220  156.330  ... 63.146   60.834   66.706  4.178  4.129   158.763
# 10617 148.410  156.330  ... 45.458   40.851   58.087  3.628  4.029   158.417
# 10618 147.160  156.330  ... 37.583   33.595   49.923  3.190  3.861   158.157
# 10619 147.160  156.330  ... 44.241   30.539   43.462  2.849  3.659   157.707
# 10620 145.720  156.330  ... 30.150   23.470   36.798  2.336  3.394   157.477
# 10621 145.720  156.330  ... 39.177   22.558   32.051  2.003  3.116   157.383
# 10622 145.720  156.330  ... 40.357   20.348   28.150  1.679  2.828   156.894
#
#        Mid_Track  Down_Track  Volume_lower  Volume_greater
# 10584    136.218     123.004             1               0
# 10585    135.204     122.233             1               0
# 10586    134.310     121.122             0               1
# 10587    133.744     120.773             1               0
# 10588    133.119     120.733             0               1
# 10589    132.547     120.847             0               1
# 10590    131.997     121.637             0               1
# 10591    131.394     123.029             0               1
# 10592    130.972     124.368             0               1
# 10593    130.944     124.429             0               1
# 10594    130.979     124.381             0               1
# 10595    131.124     124.287             0               1
# 10596    131.402     123.969             1               0
# 10597    131.685     123.289             1               0
# 10598    132.200     122.562             0               1
# 10599    132.700     122.186             0               1
# 10600    133.397     121.885             0               1
# 10601    134.391     122.178             1               0
# 10602    135.061     122.506             0               1
# 10603    135.779     122.843             0               1
# 10604    136.797     124.192             1               0
# 10605    138.020     124.965             1               0
# 10606    139.494     125.993             1               0
# 10607    140.599     126.895             0               1
# 10608    141.824     127.701             0               1
# 10609    142.884     129.073             0               1
# 10610    143.753     130.232             0               1
# 10611    144.633     131.638             0               1
# 10612    145.587     132.831             0               1
# 10613    146.450     134.093             0               1
# 10614    147.456     135.660             0               1
# 10615    148.378     137.707             0               1
# 10616    149.112     139.462             0               1
# 10617    149.481     140.545             0               1
# 10618    149.800     141.443             0               1
# 10619    150.177     142.647             0               1
# 10620    150.314     143.152             0               1
# 10621    150.414     143.445             0               1
# 10622    150.634     144.375             0               1
#
# [39 rows x 25 columns]

# %% [markdown]
# # 在今天早上開盤時進行交易

# %%
open, close, high, low, volume, date,signal_features = my_process_data(df=df, window_size=10, frame_bound=(dfStartDate_Test, dfEndDate_Test))#Close與特徵資料
env = MyStocksEnv(open, close, high, low, volume, date,signal_features, df=df, window_size=10, frame_bound=(dfStartDate_Test, dfEndDate_Test))#「環境」整合
obs = env.reset()#初始化「環境」（特徵初始化）
env.seed()
Day = 0
while True: 
    obs = obs[np.newaxis, ...]#1.先抓取【0】~【9】的特徵
    action, _states = model.predict(obs)#2.Agent觀看obs, 進行action的行為，即買【1】賣【0】
    obs, rewards, done, info = env.step(action)#3.使用【1】~【10】的特徵'記錄'獎罰，驗證是否完成，輸出資料
    Day+=1
    print("Day",Day, "Rewards", rewards, end="\n")
    if done:#4.如果完成迴圈，則輸出資料
        print("info", info)
        break
# Out:
# Day 1 Rewards -1.8199996948242188
# Day 2 Rewards -0.7699966430664062
# Day 3 Rewards 0.9900054931640625
# Day 4 Rewards 0.850006103515625
# Day 5 Rewards -0.1100006103515625
# Day 6 Rewards -0.5200042724609375
# Day 7 Rewards 0.3899993896484375
# Day 8 Rewards 1.3800048828125
# Day 9 Rewards -0.07000732421875
# Day 10 Rewards 0.8800048828125
# Day 11 Rewards 1.1300048828125
# Day 12 Rewards -0.0099945068359375
# Day 13 Rewards -0.25
# Day 14 Rewards 0.8000030517578125
# Day 15 Rewards -1.6399993896484375
# Day 16 Rewards 1.30999755859375
# Day 17 Rewards 0.8000030517578125
# Day 18 Rewards 0.9699859619140625
# Day 19 Rewards -0.3000030517578125
# Day 20 Rewards -0.3199920654296875
# Day 21 Rewards -3.470001220703125
# Day 22 Rewards 2.790008544921875
# Day 23 Rewards -1.92999267578125
# Day 24 Rewards -1.089996337890625
# Day 25 Rewards -0.769989013671875
# Day 26 Rewards -1.8600006103515625
# Day 27 Rewards -1.4099884033203125
# Day 28 Rewards -0.05999755859375
# Day 29 Rewards 1.730010986328125
# Day 30 Rewards 0.089996337890625
# Day 31 Rewards 1.82000732421875
# Day 32 Rewards 1.3600006103515625
# Day 33 Rewards 2.350006103515625
# Day 34 Rewards -0.3899993896484375
# Day 35 Rewards -1.17999267578125
# Day 36 Rewards 2.2899932861328125
# Day 37 Rewards -1.0
# Day 38 Rewards 0
# info {'total_reward': 2.9600830078125, 'total_profit': 1.022290358591614, 'position': 0}

# %%
plt.figure(figsize=(16, 6))
env.render_Close()#將「環境」畫出來
# Out:
# ↓↓↓ 台積電(2330)在交易當天收盤時進行的交易策略(Long Or Short) ↓↓↓

# %% [markdown]
# # 根據模型預測，position為今天收盤時需要進行的交易策略(Long or Short)

# %%
plt.figure(figsize=(16, 6))
env.render_Reward()
# Out:
# ↓↓↓ 台積電(2330)在使用交易策略(Long Or Short)後，隔日早上平倉時的盈虧(含手續費) ↓↓↓

# %%
plt.figure(figsize=(16, 6))
env.render_TotalProfit()
# Out:
# ↓↓↓ 根據預測出的交易策略交易台積電(2330)，所得到的累積利潤(含手續費) ↓↓↓

# %% [markdown]
# # ------------------------------------------------

# %% [markdown]
# # 不同技術分析合併進行資料萃取，需要轉換矩陣格式，解釋如下：

# %%
# a = np.array([
#     [
#         [1,2,3,4,5,6],
#         [2,4,5,6,5,6],
#         [2,4,5,6,5,6],
#         [2,4,5,6,5,6]
#     ]
# ])
# #-----------------------
# b = np.array([
#     [
#         [1,2],[3,4],[5,6]
#     ],
#     [
#         [2,4],[5,6],[5,6]
#     ],
#     [
#         [2,4],[5,6],[5,6]
#     ],
#     [
#         [2,4],[5,6],[5,6]
#     ]
# ])
# #-----------------------
# print('目的：將原本矩陣a，變成矩陣b。因為在機器訓練時，需要讓機器意識到為兩組獨立的參數')
# print('注意：入面組嘅大小必須相同，例如[1,2],[3,4]，但不可以[1,2],[3,4,5]\n\n')
# print('第一個數字：大括號\n第二個數字：有四個打橫\n第三個數字：打橫入面有幾多個數字')
# print(a.shape)
# print(a,'\n')
# print('第一個數字：有幾多大組嘅數字\n第二個數字：入面有幾多個小組\n第三個數字：每個小組入面有幾多個數字')
# print(b.shape)
# print(b)
