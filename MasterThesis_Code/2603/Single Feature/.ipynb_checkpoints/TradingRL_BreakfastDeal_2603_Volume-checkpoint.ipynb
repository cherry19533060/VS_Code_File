# %%
import gym
from gym import spaces
from gym.utils import seeding
import numpy as np
from enum import Enum
import matplotlib.pyplot as plt


#Agent的行動
class Actions(Enum):
    Sell = 0
    Buy = 1

#在Env裡面所代表的
class Positions(Enum):
    Short = 0
    Long = 1

    def opposite(self):
        return Positions.Short if self == Positions.Long else Positions.Long

    
class TradingEnv(gym.Env):

    metadata = {'render.modes': ['human']}
    
    #__init__為魔法函數，意義為：無論你願不願意，只要你執行TradingEnv，就會把__init__底下的資料執行，可以用作變數定義？
    def __init__(self, df, window_size): 
        assert df.ndim == 2 #判斷所輸入的df維度是否等於2

        self.seed() #隨機種子設定
        self.df = df #輸入df
        self.window_size = window_size #輸入Windows size
        self.open, self.close, self.high, self.low, self.volume, self.date, self.signal_features = self._process_data() #輸入【價錢, 特征資料】
        self.shape = (window_size, self.signal_features.shape[1]) #輸入【Windows size, 特征資料的長度】

        # spaces
        self.action_space = spaces.Discrete(len(Actions)) # 行動空間為：2（Sell、Buy）
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=self.shape, dtype=np.float64) #觀察空間最低和最高為無限（因為不知股票價錢為多少）

        # episode
        #「_」為私有化，即import的時候不會引入參數
        self._start_tick = self.window_size #開始日期：Windows_size設定的數字
        self._end_tick = len(self.close)-1 #結束日期：【價錢】的長度-1
        self._done = None 
        self._current_tick = None
        self._last_trade_tick = None
        self._position = None
        self._position_history = None
        
        #股息
        import yfinance as yf
        self.Ticker = yf.Ticker("2330.TW")#抓取股票
        self.Dividends = self.Ticker.actions['Dividends']#抓取股息資料
        self.Dividends_Date = self.Dividends.index.astype('string')#將股息日期->String
        self.Dividends_Date = np.array(self.Dividends_Date)#將股息日期->np.array
        self.Dividends = np.array(self.Dividends) #抓取股息價錢
#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓        
        self._reward_history = []#記錄Reward獎勵，方便畫圖
        self._Total_profit = []#記錄Profit，方便畫圖
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑
        self._total_reward = None
        self._total_profit = None
        self._first_rendering = None
        self.history = None

    #定義一個隨機種子   
    def seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    #重設
    def reset(self):
        self._done = False #尚未完成
        self._current_tick = self._start_tick # Windows_size設定的數字
        self._last_trade_tick = self._current_tick -1 #Windows_size設定的數字-1
        self._position = Positions.Short #第一天交易必定為Short
        self._position_history = (self.window_size * [None]) + [self._position] #記錄位置
        self._total_reward = 0. #初始化的reward為：0
        self._total_profit = 1. #初始化的Profit為：1
        self._first_rendering = True
        self.history = {}
        return self._get_observation()

    #交易中的步驟
    def step(self, action):
        self._done = False #尚未完成動作
        
        
        #如果當前日期 = 完結日期，就結束步驟
        if self._current_tick == self._end_tick:
            self._done = True

#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓
#如果機器人進行買的動作，他的Position就會變成Long，反之亦然
        if(action == Actions.Buy.value):
            self._position = Positions.Long
#             print("action: ", action)
#             print("position: ", self._position)
        elif(action == Actions.Sell.value):
            self._position = Positions.Short
#             print("action: ", action)
#             print("position: ", self._position)
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑               
        self._last_trade_tick = self._current_tick      
        #記錄步驟
        self._position_history.append(self._position)
        
        #獎勵：調用計算獎勵的function，然後將它累積起來計算總和
        step_reward = self._calculate_reward(action)
        step_profit = self._update_profit(action)#記錄profit，方便畫圖
#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓
        self._reward_history.append(step_reward)#記錄Reward獎勵，方便畫圖
        self._Total_profit.append(step_profit)#記錄profit，方便畫圖
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑ 
        self._total_reward += step_reward
        #根據agent的action更新他的 profit
        
        
        observation = self._get_observation()
        info = dict(
            total_reward = self._total_reward,
            total_profit = self._total_profit,
            position = self._position.value
        )
        self._update_history(info)
        
        self._current_tick += 1 #當前日期+1

        return observation, step_reward, self._done, info

    #取得觀察值，觀察值為signal_features
    #若window_size為10
    #則使用0 ~ 9日的觀察值，下一次交易則使用1 ~ 10日的觀察值
    def _get_observation(self):
        return self.signal_features[(self._current_tick-self.window_size+1):self._current_tick+1]

    #更新歷史資料
    def _update_history(self, info):
        if not self.history:
            self.history = {key: [] for key in info.keys()}

        for key, value in info.items():
            self.history[key].append(value)

    #render：將環境實體化，以股票交易為例即是畫圖
    def render(self, mode='human'):
        pass


    #畫圖
#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓    
    def render_Close(self, mode='human'):
            window_ticks = np.arange(len(self._position_history))#[1,2,3,4,5,....]矩陣
            plt.plot(self.close)#根據收盤價進行繪畫

            short_ticks = []
            long_ticks = []
            # i：控制position_history的位置
            # tick：控制要塞進Long還是Short的位置
            #如果機器人在之前就是做Long的話就把它記錄在long_ticks裡面，反之亦然
            for i, tick in enumerate(window_ticks-1):
                if self._position_history[i] == Positions.Short:
                    short_ticks.append(tick)
                elif self._position_history[i] == Positions.Long:
                    long_ticks.append(tick)      

            del(short_ticks[0])

            plt.plot(short_ticks, self.close[short_ticks], 'ro', label = 'Short')#根據收盤價進行畫圖
            plt.plot(long_ticks, self.close[long_ticks], 'go', label = 'Long')#根據收盤價進行畫圖
            
            plt.legend()
            plt.title("Close", fontsize=20)
            plt.suptitle(
                "Total Reward: %.6f" % self._total_reward + ' ~ ' +
                "Total Profit: %.6f" % self._total_profit
            )
            print("↓↓↓ 台積電(2330)在交易當天收盤時進行的交易策略(Long Or Short) ↓↓↓")
        
        
    #畫圖2   
    def render_Reward(self, mode='human'):
        window_ticks = np.arange(len(self._position_history))
        short_ticks = []
        long_ticks = []
        for i, tick in enumerate(window_ticks-1):
            if self._position_history[i] == Positions.Short:
                short_ticks.append(tick)
            elif self._position_history[i] == Positions.Long:
                long_ticks.append(tick)
        
        del(short_ticks[0])
        self._reward_history = np.array(self._reward_history)
        short_ticks = (np.array(short_ticks)-10).tolist()
        long_ticks = (np.array(long_ticks)-10).tolist()
        
        plt.bar(short_ticks,self._reward_history[short_ticks], color='r', label = 'Short')#根據獎勵進行繪畫
        plt.bar(long_ticks,self._reward_history[long_ticks], color='g', label = 'Long')#根據獎勵進行繪畫
            
        plt.legend()   
        plt.title("Reward", fontsize=20)
        plt.suptitle(
            "Total Reward: %.6f" % self._total_reward + ' ~ ' +
            "Total Profit: %.6f" % self._total_profit
        )
        print("↓↓↓ 台積電(2330)在使用交易策略(Long Or Short)後，隔日早上平倉時的盈虧(含手續費) ↓↓↓")
        
        
    def render_TotalProfit(self, mode='human'):
        window_ticks = np.arange(len(self._position_history))
        
        del self._Total_profit[-1]
        plt.plot(self._Total_profit)
        
        
#         short_ticks = []
#         long_ticks = []
#         for i, tick in enumerate(window_ticks-1):
#             if self._position_history[i] == Positions.Short:
#                 short_ticks.append(tick)
#             elif self._position_history[i] == Positions.Long:
#                 long_ticks.append(tick)
        
#         del(short_ticks[0])
#         self._Total_profit = np.array(self._Total_profit)
#         short_ticks = (np.array(short_ticks)-10).tolist()
#         long_ticks = (np.array(long_ticks)-10).tolist()
        
#         plt.plot(short_ticks, self._Total_profit[short_ticks], 'ro', label = 'Short')#根據獎勵進行畫圖
#         plt.plot(long_ticks, self._Total_profit[long_ticks], 'go', label = 'Long')#根據獎勵進行畫圖
            
#         plt.legend() 

        plt.title("TotalProfit", fontsize=20)
        plt.suptitle(
            "Total Reward: %.6f" % self._total_reward + ' ~ ' +
            "Total Profit: %.6f" % self._total_profit
        )
        print("↓↓↓ 根據預測出的交易策略交易台積電(2330)，所得到的累積利潤(含手續費) ↓↓↓")
        plt.savefig('2330_BBands_TotalProfit.jpg')
        
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑         
        


    
    
    #關閉環境，即關閉畫圖    
    def close(self):
        plt.close()

    #保存圖片
    def save_rendering(self, filepath):
        plt.savefig(filepath)

    #暫停畫圖
    def pause_rendering(self):
        plt.show()

    #在TradingEnv中，為了保持結構完整，因此使用pass不做任何事情
    def _process_data(self):
        pass

    #在TradingEnv中，為了保持結構完整，因此使用pass不做任何事情
    def _calculate_reward(self, action):
        pass

    #在TradingEnv中，為了保持結構完整，因此使用pass不做任何事情
    def _update_profit(self, action):
        pass

    #在TradingEnv中，為了保持結構完整，因此使用pass不做任何事情
    def max_possible_profit(self):  # trade fees are ignored
        pass

# %%
import numpy as np

class StocksEnv(TradingEnv):
    

    def __init__(self, df, window_size, frame_bound):
        assert len(frame_bound) == 2 #判斷所輸入的df維度是否等於2

        self.frame_bound = frame_bound #輸入範圍值
        super().__init__(df, window_size)

        self.trade_fee_percent = 0.001425+0.003
        #https://rich01.com/what-is-next-day-trading/
        
    #資料處理
    def _process_data(self):
        open = self.df.loc[:, 'open'].to_numpy() #prices：開市價
        close = self.df.loc[:, 'close'].to_numpy() #prices：收盤價
        high = self.df.loc[:, 'high'].to_numpy() #prices：最高
        low = self.df.loc[:, 'low'].to_numpy() #prices：最低
        volume = self.df.loc[:, 'volume'].to_numpy() #prices：成交量
        date = self.df.loc[:, 'index'].to_numpy() #prices：日期
        close[self.frame_bound[0] - self.window_size] # validate index (TODO: Improve validation)#驗證資料：10-10
        close = close[self.frame_bound[0]-self.window_size:self.frame_bound[1]]#【10-10:5600】
        
        
        diff = np.insert(np.diff(close), 0, 0)#計算價差【今天 - 昨天】
        signal_features = np.column_stack((close, diff))#默認的signal_features為：收盤價，價差

        return open, close ,high, low, volume, date, signal_features

#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓
    #計算獎勵
    def _calculate_reward(self, action):
        step_reward = 0
        price_diff = 0
        date = self.date[self._current_tick].astype('datetime64[D]') #日期格式 -> yyyy-mm-dd格式
        date = date.astype('str')#日期格式 -> string

        
        if(self._current_tick < self._end_tick):
            if( date not in self.Dividends_Date):#遇上除淨日不交易
                if(action == Actions.Buy.value):
                    current_price = self.close[self._current_tick]*1000 #【今天收盤】
                    last_trade_price = self.open[self._current_tick+1]*1000 #【明天開盤】

                    Buy_trade_fee = (current_price * 0.001425)*0.5 #買入手續費 = (今天收盤 * 手續費） * 折扣
                    if Buy_trade_fee<20:
                        Buy_trade_fee=20
                    Sold_trade_fee = (last_trade_price * 0.001425)*0.5 #賣出手續費 = (明天開盤 * 手續費） * 折扣
                    if Sold_trade_fee<20:
                        Sold_trade_fee=20
                    Transfer_tax = last_trade_price * 0.003 #證交稅 = 明天開盤 * 稅率

                    Buy = current_price + Buy_trade_fee #買入成本 = 今天收盤 + 買入手續費
                    Sold = last_trade_price - Sold_trade_fee - Transfer_tax #賣出成本 = 明天開盤 - 賣出手續費 - 證交稅


                    TodayDividends = 0 #今日是否有股息？如果沒有為：0
                    for i in range(len(self.Dividends_Date)):#抓取股息日期 i
                        if(date in self.Dividends_Date[i]):#如果 [今日日期] 在 [股息日期 i] 中
                            TodayDividends = self.Dividends[i]*1000 #將股息*1000

                    price_diff = Sold - Buy + TodayDividends #盈虧 = 賣出成本 - 買入成本 + 股息（若無股息，+$0）
                
                
                
                
                elif(action == Actions.Sell.value):
                    current_price = self.close[self._current_tick]*1000 #【今天收盤】
                    last_trade_price = self.open[self._current_tick+1]*1000 #【明天開盤】

                    Buy_trade_fee = (last_trade_price * 0.001425)*0.5 #買入手續費 = (明天開盤 * 手續費） * 折扣
                    if Buy_trade_fee<20:
                        Buy_trade_fee=20
                    Sold_trade_fee = (current_price * 0.001425)*0.5 #賣出手續費 = (今天收盤 * 手續費） * 折扣
                    if Sold_trade_fee<20:
                        Sold_trade_fee=20
                    Transfer_tax = last_trade_price * 0.003 #證交稅 = 今天收盤 * 稅率

                    Buy = last_trade_price + Buy_trade_fee #買入成本 = 明天開盤 + 買入手續費
                    Sold = current_price - Sold_trade_fee - Transfer_tax #賣出成本 = 今天收盤 - 賣出手續費 - 證交稅    

                    TodayDividends = 0 #今日是否有股息？如果沒有為：0             
                    for i in range(len(self.Dividends_Date)):#抓取股息日期 i
                        if(date in self.Dividends_Date[i]):#如果 [今日日期] 在 [股息日期 i] 中
                            TodayDividends = self.Dividends[i]*1000 #將股息*1000          

                    price_diff = Sold - Buy + TodayDividends #盈虧 = 賣出成本 - 買入成本 + 股息（若無股息，+$0）

        
            step_reward =  step_reward + price_diff
        
        return step_reward


    def _update_profit(self, action):
        
        long_profit_percentage = 0.0
        short_profit_percentage = 0.0
        Total_long_profit_percentage = 0.0
        Total_short_profit_percentage = 0.0
        
        date = self.date[self._current_tick].astype('datetime64[D]') #日期格式 -> yyyy-mm-dd格式
        date = date.astype('str')#日期格式 -> string
        
        step_profit = 0
        if(self._current_tick < self._end_tick):
            if( date not in self.Dividends_Date):#遇上除淨日不交易
                if(action == Actions.Buy.value):

                    current_price = self.close[self._current_tick]*1000#【今天收盤】
                    last_trade_price = self.open[self._current_tick+1]*1000#【明天開盤】

                    Buy_trade_fee = (current_price * 0.001425)*0.5 #(買*手續費) * 證券商折扣
                    if Buy_trade_fee<20:
                        Buy_trade_fee=20
                    Sold_trade_fee = (last_trade_price * 0.001425)*0.5 #(賣*手續費) * 證券商折扣
                    if Sold_trade_fee<20:
                        Sold_trade_fee=20
                    Transfer_tax = last_trade_price * 0.003 #證交稅

                    Buy = current_price + Buy_trade_fee#買入的成本
                    Sold = last_trade_price - Sold_trade_fee - Transfer_tax#賣出的成本

                    TodayDividends = 0 #今日是否有股息？如果沒有為：0
                    for i in range(len(self.Dividends_Date)):#抓取股息日期 i
                        if(date in self.Dividends_Date[i]):#如果 [今日日期] 在 [股息日期 i] 中
                            TodayDividends = self.Dividends[i]*1000 #將股息*1000

                    price_diff = Sold - Buy + TodayDividends #盈虧 = 賣出成本 - 買入成本 + 股息（若無股息，+$0）

                    long_profit_percentage = (Sold - Buy + TodayDividends)/Buy 
                    self._total_profit += long_profit_percentage

                elif(action == Actions.Sell.value):

                    current_price = self.close[self._current_tick]*1000#【今天收盤】
                    last_trade_price = self.open[self._current_tick+1]*1000#【明天開盤】

                    Buy_trade_fee = (last_trade_price * 0.001425)*0.5 #(買*手續費) * 證券商折扣
                    if Buy_trade_fee<20:
                        Buy_trade_fee=20
                    Sold_trade_fee = (current_price * 0.001425)*0.5 #(賣*手續費) * 證券商折扣
                    if Sold_trade_fee<20:
                        Sold_trade_fee=20
                    Transfer_tax = last_trade_price * 0.003 #證交稅

                    Buy = last_trade_price + Buy_trade_fee#買入的成本
                    Sold = current_price - Sold_trade_fee - Transfer_tax#賣出的成本


                    TodayDividends = 0 #今日是否有股息？如果沒有為：0
                    for i in range(len(self.Dividends_Date)):#抓取股息日期 i
                        if(date in self.Dividends_Date[i]):#如果 [今日日期] 在 [股息日期 i] 中
                            TodayDividends = self.Dividends[i]*1000 #將股息*1000

                    price_diff = Sold - Buy + TodayDividends #盈虧 = 賣出成本 - 買入成本 + 股息（若無股息，+$0）

                    short_profit_percentage = (Sold - Buy + TodayDividends)/Buy 
                    self._total_profit += short_profit_percentage  
                       
                
            step_profit += self._total_profit #記錄profit，方便畫圖
        return step_profit#記錄profit，方便畫圖
        
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑  
                
    #https://github.com/AminHP/gym-anytrading/blob/master/README.ipynb
    #不論交易費用如何，agent在股票交易中所獲得的profit
    def max_possible_profit(self):
        pass

# %%
# import gym_anytrading
import numpy as np
import pandas as pd
import quantstats as qs
from stable_baselines import A2C
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\__init__.py:33: UserWarning: stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation.
#   "stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation."

# %%
from yahoo_fin import stock_info as si
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
if isinstance('2603.TW', str):
    # load it from yahoo_fin library
    df = si.get_data('2603.TW')
df = df.dropna()#丟棄空值
df = df.reset_index()
pd.set_option('display.float_format', lambda x: '%.3f' % x)#設定顯示小數點後3位數

#---------------------------------------------------------------------------
#定義參數

open = df['open']
close = df['close']
high = df['high']
low = df['low']
volume = df['volume']
UpLine_max = []
UpLine = [] #上引線
DownLine_min = []
DownLine = [] #下引線
UpMean = []#計算RSI——上漲平均5天
DownMean = []#計算RSI——下跌平均5天
RSI = []#計算RSI

#---------------------------------------------------------------------------
#上引線；下引線

for i in range(close.size):
    UpLine_max.append(max(open[i], close[i]))
for i in range(close.size):
    UpLine.append(high[i] - UpLine_max[i])#上影線
for i in range(close.size):
    DownLine_min.append(min(open[i], close[i]))
for i in range(close.size):
    DownLine.append(DownLine_min[i] - low[i])#下影線
#---------------------------------------------------------------------------
#RSI

UpDownValue = close - close.shift(1) #計算漲跌值
Only_UpValue = pd.Series(index=UpDownValue.index, data=UpDownValue[UpDownValue>0])#將上漲日子篩出
Only_UpValue = Only_UpValue.fillna(0)#下跌的日子為0
Only_DownValue = pd.Series(index=UpDownValue.index, data=-UpDownValue[UpDownValue<0])#將下跌日子篩出
Only_DownValue = Only_DownValue.fillna(0)#上漲的日子為0
for i in range(13, len(Only_UpValue)+1):#由第六日開始，直到現在
    UpMean.append(np.mean(Only_UpValue.values[i-12:i]))#計算出最近五日的平均，因為有補0，所以可以計算出。
    DownMean.append(np.mean(Only_DownValue.values[i-12:i]))#計算出最近五日的平均
for i in range(len(UpMean)):
    RSI.append( (UpMean[i] / ( UpMean[i] + DownMean[i] )) * 100  )#計算RSI
RSI = pd.Series(index = close.index[12:], data = RSI) #轉換格式
#---------------------------------------------------------------------------
#FH；FL
FH = ((high - open) / open) #FH
FL = ((open - low) / open) #FL
FH = pd.DataFrame(FH, columns=['FH'])#FH參數
FL = pd.DataFrame(FL, columns=['FL'])#FL參數
#---------------------------------------------------------------------------
# KD
K = []
D = []
K_Value = []
D_Value = []
def RSV(df):
    df['MinLow'] = df['low'].rolling(9, min_periods=9).min()#9天最低位
    df['MinLow'].fillna(value = df['low'].expanding().min(), inplace = True)#填滿NA
    df['MaxHigh'] = df['high'].rolling(9, min_periods=9).max()#9天最高位
    df['MaxHigh'].fillna(value = df['high'].expanding().max(), inplace = True)#填滿NA
    df['RSV'] = (df['close'] - df['MinLow']) / (df['MaxHigh'] - df['MinLow']) * 100 #計算RSV
    return df
RSV_df = RSV(df)#使用RSV函數計算
RSV = RSV_df['RSV']#獲得RSV
for i in range(len(RSV)):
    if i<=9 :
        K.append(50)
        D.append(50)
    elif i > 9:
        K.append((K[i-1] * 2/3) + (1/3 * RSV[i]))
        D.append((D[i-1] * 2/3) + (1/3 * K[i]))
K_Value = pd.Series(index = close.index[0:], data = K) #轉換格式
D_Value = pd.Series(index = close.index[0:], data = D) #轉換格式
#---------------------------------------------------------------------------
# MACD
DIF = []
MACD = []
ShortEMA=close.ewm(span=12,adjust=False).mean()#12日移動平均
LongEMA=close.ewm(span=26,adjust=False).mean()#26日移動平均
FastLine_DIF=ShortEMA-LongEMA#DIF = （12日移動平均 - 26日移動平均）
SlowLine_MACD=FastLine_DIF.ewm(span=9,adjust=False).mean()#取DIF數值得到9日移動平均
FastLine_DIF = pd.DataFrame(FastLine_DIF)#轉換格式
SlowLine_MACD = pd.DataFrame(SlowLine_MACD)#轉換格式
FastLine_DIF = FastLine_DIF.rename(columns={'close':'DIF'})#轉換格式
SlowLine_MACD = SlowLine_MACD.rename(columns={'close':'MACD'})#轉換格式
#---------------------------------------------------------------------------                                                             
#BBands
def BBands(df,Day=20,Times=2):#20天平均, 2倍標準差
    Up_Track=pd.Series(0.0,index=df.index)#建立全0的陣列
    Mid_Track=pd.Series(0.0,index=df.index)#建立全0的陣列
    Down_Track=pd.Series(0.0,index=df.index)#建立全0的陣列
    SD=pd.Series(0.0,index=df.index)#建立全0的陣列
    
    for i in range(Day-1,len(df)):#19~5600   
        Mid_Track[i]=np.mean(df[i-(Day-1):(i+1)])#中軌 = 0-20平均 -> 1-21平均 -> 2-22平均...（移動平均線）
        SD[i]=np.std(df[i-(Day-1):(i+1)])#0-20標準差 -> 1-21標準差 ->2-22標準差...（標準差）
        Up_Track[i]=Mid_Track[i]+(Times*SD[i])#上軌 = 中軌+（2倍標準差）
        Down_Track[i]=Mid_Track[i]-(Times*SD[i])#下軌 = 中軌-（2倍標準差）
        
        #慢慢地將上半部分建立的全0函式更新
        df_BBands=pd.DataFrame({'Up_Track':Up_Track[(Day-1):],#由第19日開始載入布林通道（上）
                             'Mid_Track':Mid_Track[(Day-1):],#由第19日開始載入布林通道（中）
                             'Down_Track':Down_Track[(Day-1):]#由第19日開始載入布林通道（下）
                            })
    return(df_BBands)
BBands_Up_Mid_Down_Trak = BBands(close, 20, 2)
#---------------------------------------------------------------------------
#成交量均線
volume10Day_mean=volume.ewm(span=10,adjust=False).mean() #10日移動平均成交量
volume10Day_mean = volume10Day_mean>volume #10日移動平均成交量 > 當日成交量【**技術指標**】
df_volume10day_mean=pd.DataFrame(volume10Day_mean) #變成DataFrame
labelencoder = LabelEncoder() #將True False 變成 1 0
df_volume10day_mean['volume'] = labelencoder.fit_transform(df_volume10day_mean['volume'])#將True False 變成 1 0
ct = ColumnTransformer([("volume", OneHotEncoder(), [0])], remainder = 'passthrough') #將1 0 變成 OneHotEncoder
df_volume10day_mean = ct.fit_transform(df_volume10day_mean)#將1 0 變成 OneHotEncoder
df_volume10day_mean = pd.DataFrame(df_volume10day_mean, columns = ['Volume_lower','Volume_greater'])
df_volume10day_mean['Volume_lower'] = pd.to_numeric(df_volume10day_mean['Volume_lower'], downcast='integer')
df_volume10day_mean['Volume_greater'] = pd.to_numeric(df_volume10day_mean['Volume_greater'], downcast='integer')







#合拼df
df2330 = pd.merge(df, FH,left_index=True,right_index=True) #合拼FH
df2330 = pd.merge(df2330, FL,left_index=True,right_index=True) #合拼FL
df2330 = pd.merge(df2330, pd.DataFrame(UpLine, columns=['UpLine']),left_index=True,right_index=True) #合併上影線
df2330 = pd.merge(df2330, pd.DataFrame(DownLine, columns=['DownLine']),left_index=True,right_index=True) #合併下影線
df2330 = pd.merge(df2330, pd.DataFrame(RSI, columns=['RSI']),left_index=True,right_index=True) #合併RSI
df2330 = pd.merge(df2330, pd.DataFrame(K_Value, columns=['K_Value']),left_index=True,right_index=True) #合併K值
df2330 = pd.merge(df2330, pd.DataFrame(D_Value, columns=['D_Value']),left_index=True,right_index=True) #合併D值
df2330 = pd.merge(df2330, pd.DataFrame(FastLine_DIF),left_index=True,right_index=True) #合併DIF
df2330 = pd.merge(df2330, pd.DataFrame(SlowLine_MACD),left_index=True,right_index=True) #合併MACD
df2330 = pd.merge(df2330,BBands_Up_Mid_Down_Trak,left_index=True,right_index=True) #合併布林通道
df2330 = pd.merge(df2330,df_volume10day_mean,left_index=True,right_index=True) #合併布林通道

df2330.index = range(len(df2330))#更新index

# %% [markdown]
# # 是否將特徵資料標準化？

# %%
#---------------------------------------------------------------------------
# normalizer = Normalizer()#創建標準化函數
# df2330_AllFeatures = df2330[['MinLow','MaxHigh','RSV','FH','FL','UpLine','DownLine','RSI','K_Value','D_Value','DIF','MACD','Up_Track','Mid_Track','Down_Track']]#取得需要標準化的特徵
# df2330_FeaturesNormalize = normalizer.fit_transform(df2330_AllFeatures)#進行標準化
# df2330_FeaturesNormalize = pd.DataFrame(df2330_FeaturesNormalize)#將array變成df
# df2330_FeaturesNormalize = df2330_FeaturesNormalize.rename(columns={0:'MinLow',1:'MaxHigh',2:'RSV',
#                                                       3:'FH',4:'FL',
#                                                       5:'UpLine',6:'DownLine',
#                                                       7:'RSI',
#                                                       8:'K_Value',9:'D_Value',
#                                                       10:'DIF',11:'MACD',
#                                                       12:'Up_Track',13:'Mid_Track',14:'Down_Track'})#更改名字
# df2330_OriginData = df2330[['index','open','high','low','close','adjclose','volume','ticker']]#取得市場基本資料
# df2330_Normalized = pd.merge(df2330_OriginData, df2330_FeaturesNormalize, left_index=True,right_index=True) #基本資料與標準化後特徵資料合併
# df2330 = df2330_Normalized
#---------------------------------------------------------------------------

#---------------------------------------------------------------------------
#輸出最終Dataframe
df = df2330
df
# Out:
#           index    open    high     low   close  adjclose       volume  \
# 0    2000-01-31  32.259  32.685  31.939  32.152    16.318 16352913.000
# 1    2000-02-01  32.472  32.472  31.513  31.726    16.102 10636015.000
# 2    2000-02-02  31.726  31.726  31.726  31.726    16.102        0.000
# 3    2000-02-03  31.726  31.726  31.726  31.726    16.102        0.000
# 4    2000-02-04  31.726  31.726  31.726  31.726    16.102        0.000
# ...         ...     ...     ...     ...     ...       ...          ...
# 5756 2023-02-23 153.500 158.500 153.500 158.000   158.000 34299954.000
# 5757 2023-02-24 158.500 159.500 155.500 157.000   157.000 32154792.000
# 5758 2023-03-01 157.500 158.000 154.000 156.000   156.000 21240175.000
# 5759 2023-03-02 158.000 161.000 157.500 160.500   160.500 33776976.000
# 5760 2023-03-03 161.000 163.000 158.500 163.000   163.000 37067853.000
#
#        ticker  MinLow  MaxHigh  ...    RSI  K_Value  D_Value    DIF   MACD  \
# 0     2603.TW  28.745   32.685  ... 62.667   71.029   56.480  0.487  0.309
# 1     2603.TW  28.745   32.685  ... 62.667   72.578   61.846  0.561  0.360
# 2     2603.TW  28.958   32.685  ... 57.576   73.147   65.613  0.613  0.410
# 3     2603.TW  29.384   32.685  ... 63.333   72.421   67.882  0.646  0.458
# 4     2603.TW  29.491   32.685  ... 65.517   71.614   69.126  0.665  0.499
# ...       ...     ...      ...  ...    ...      ...      ...    ...    ...
# 5756  2603.TW 142.500  158.500  ... 59.459   74.173   55.450 -0.771 -1.805
# 5757  2603.TW 145.000  159.500  ... 57.333   77.035   62.645 -0.258 -1.495
# 5758  2603.TW 145.000  159.500  ... 58.108   76.644   67.311  0.068 -1.183
# 5759  2603.TW 145.000  161.000  ... 67.532   83.388   72.670  0.680 -0.810
# 5760  2603.TW 145.000  163.000  ... 76.000   88.925   78.088  1.352 -0.378
#
#       Up_Track  Mid_Track  Down_Track  Volume_lower  Volume_greater
# 0       31.776     29.970      28.164             1               0
# 1       31.987     30.119      28.250             0               1
# 2       32.107     30.284      28.460             0               1
# 3       32.263     30.411      28.560             0               1
# 4       32.348     30.438      28.528             0               1
# ...        ...        ...         ...           ...             ...
# 5756   158.279    150.800     143.321             1               0
# 5757   158.953    151.025     143.097             1               0
# 5758   159.512    151.300     143.088             0               1
# 5759   160.865    151.725     142.585             1               0
# 5760   162.655    152.275     141.895             1               0
#
# [5761 rows x 25 columns]

# %% [markdown]
# # 查找DF的標籤

# %%
dfStartDate_Train = df[(df['index']=='2020-01-02')].index.values
dfStartDate_Train = dfStartDate_Train[0]
dfStartDate_Train
# Out:
# 4993

# %%
dfEndDate_Train = df[(df['index']=='2022-12-30')].index.values
dfEndDate_Train = dfEndDate_Train[0]
dfEndDate_Train
# Out:
# 5726

# %%
df[dfStartDate_Train:dfEndDate_Train+1]
# Out:
#           index    open    high     low   close  adjclose       volume  \
# 4993 2020-01-02  31.500  32.000  31.500  31.750    25.206  5983333.000
# 4994 2020-01-03  32.000  32.625  31.875  32.500    25.802 13275073.000
# 4995 2020-01-06  32.500  33.000  32.250  32.500    25.802 10429668.000
# 4996 2020-01-07  32.500  32.625  32.125  32.250    25.603  5552326.000
# 4997 2020-01-08  31.875  31.875  31.500  31.500    25.008  5703694.000
# ...         ...     ...     ...     ...     ...       ...          ...
# 5722 2022-12-26 168.500 168.500 162.500 162.500   162.500 23661784.000
# 5723 2022-12-27 164.000 167.000 162.000 162.500   162.500 19106328.000
# 5724 2022-12-28 162.000 164.000 159.000 159.000   159.000 20189077.000
# 5725 2022-12-29 159.000 161.000 157.500 160.000   160.000 17346004.000
# 5726 2022-12-30 161.500 164.500 161.500 163.000   163.000 21686678.000
#
#        ticker  MinLow  MaxHigh  ...    RSI  K_Value  D_Value   DIF   MACD  \
# 4993  2603.TW  31.000   32.000  ... 60.870   47.231   47.813 0.037 -0.025
# 4994  2603.TW  31.000   32.625  ... 67.857   62.257   52.628 0.133  0.006
# 4995  2603.TW  31.000   33.000  ... 64.000   66.505   57.253 0.207  0.046
# 4996  2603.TW  31.000   33.000  ... 66.667   65.170   59.892 0.242  0.086
# 4997  2603.TW  31.000   33.000  ... 57.143   51.780   57.188 0.208  0.110
# ...       ...     ...      ...  ...    ...      ...      ...   ...    ...
# 5722  2603.TW 151.000  172.000  ... 62.366   67.278   64.430 3.172  2.330
# 5723  2603.TW 152.500  172.000  ... 59.302   61.946   63.602 3.004  2.465
# 5724  2603.TW 154.000  172.000  ... 54.839   50.557   59.253 2.559  2.483
# 5725  2603.TW 157.500  172.000  ... 55.319   39.452   52.653 2.261  2.439
# 5726  2603.TW 157.500  172.000  ... 61.702   38.945   48.083 2.241  2.399
#
#       Up_Track  Mid_Track  Down_Track  Volume_lower  Volume_greater
# 4993    31.775     31.075      30.375             1               0
# 4994    32.085     31.156      30.228             1               0
# 4995    32.314     31.250      30.186             1               0
# 4996    32.428     31.337      30.247             0               1
# 4997    32.423     31.381      30.340             0               1
# ...        ...        ...         ...           ...             ...
# 5722   170.040    159.075     148.110             0               1
# 5723   170.187    159.150     148.113             0               1
# 5724   169.844    158.950     148.056             0               1
# 5725   169.667    158.850     148.033             0               1
# 5726   170.040    159.075     148.110             0               1
#
# [734 rows x 25 columns]

# %%
def my_process_data(df, window_size, frame_bound):
    start = frame_bound[0] - window_size #start = 5 - 5
    end = frame_bound[1] #end = 5600 
    close = df.loc[:, 'close'].to_numpy()[start:end]#抓取Close
    open = df.loc[:, 'open'].to_numpy()[start:end]#抓取open
    high = df.loc[:, 'high'].to_numpy()[start:end]#抓取high
    low = df.loc[:, 'low'].to_numpy()[start:end]#抓取low
    volnume = df.loc[:, 'volume'].to_numpy()[start:end]#抓取volume
    date = df.loc[:, 'index'].to_numpy()[start:end]#抓取Date
    signal_features = df.loc[:, ['Volume_lower', 'Volume_greater']].to_numpy()[start:end]#抓取特徵資料
    return open, close, high, low, volnume, date, signal_features


class MyStocksEnv(StocksEnv):
    
    def __init__(self, open, close, high, low, volnume, date,signal_features, **kwargs):
        self._open = open
        self._close = close
        self._high = high
        self._low = low
        self._volnume = volnume
        self._date = date
        self._signal_features = signal_features
        super().__init__(**kwargs)

    def _process_data(self):
        return self._open, self._close, self._high, self._low, self._volnume, self._date, self._signal_features

    
open, close, high, low, volume, date,signal_features = my_process_data(df=df, window_size=10, frame_bound=(dfStartDate_Train, dfEndDate_Train+1))#Close與特徵資料
env = MyStocksEnv(open, close, high, low, volume, date, signal_features, df=df, window_size=10, frame_bound=(dfStartDate_Train, dfEndDate_Train+1))#「環境」整合

# %%
policy_kwargs = dict(net_arch=[128, 'lstm', dict(vf=[64,64,64], pi=[64,64,64])])#要傳遞給policy的參數

model = A2C('MlpLstmPolicy', env, verbose=1, policy_kwargs=policy_kwargs)
# model = A2C('MlpLstmPolicy', env, verbose=1)
#policy: The policy model to use (MlpPolicy, CnnPolicy, …)""
#verbose: 0 no output, 1 info, 2 debug
#policy_kwargs: additional arguments to be passed to the policy on creation要傳遞給policy的參數
model.learn(total_timesteps=5000000)
# Out:
# Wrapping the env in a DummyVecEnv.
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\policies.py:442: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From C:\Users\cherr\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\layers\core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:160: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From C:\Users\cherr\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\ops\clip_ops.py:301: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:184: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From C:\Users\cherr\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\training\rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:194: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:196: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# ---------------------------------
# | explained_variance | 0.000128 |
# | fps                | 6        |
# | nupdates           | 1        |
# | policy_entropy     | 0.682    |
# | total_timesteps    | 5        |
# | value_loss         | 2.05e+05 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -7.39e-06 |
# | fps                | 211       |
# | nupdates           | 100       |
# | policy_entropy     | 0.689     |
# | total_timesteps    | 500       |
# | value_loss         | 3.64e+06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 1.2e-05  |
# | fps                | 249      |
# | nupdates           | 200      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 1000     |
# | value_loss         | 5.32e+06 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000573 |
# | fps                | 261       |
# | nupdates           | 300       |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 1500      |
# | value_loss         | 8.48e+05  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 8.94e-06 |
# | fps                | 265      |
# | nupdates           | 400      |
# | policy_entropy     | 0.675    |
# | total_timesteps    | 2000     |
# | value_loss         | 2.58e+07 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000105 |
# | fps                | 266       |
# | nupdates           | 500       |
# | policy_entropy     | 0.612     |
# | total_timesteps    | 2500      |
# | value_loss         | 1.43e+07  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -0.00017 |
# | fps                | 267      |
# | nupdates           | 600      |
# | policy_entropy     | 0.548    |
# | total_timesteps    | 3000     |
# | value_loss         | 2.03e+05 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.31e-05 |
# | fps                | 263       |
# | nupdates           | 700       |
# | policy_entropy     | 0.348     |
# | total_timesteps    | 3500      |
# | value_loss         | 5.04e+07  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 3.4e-06  |
# | fps                | 258      |
# | nupdates           | 800      |
# | policy_entropy     | 0.226    |
# | total_timesteps    | 4000     |
# | value_loss         | 1.37e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000818 |
# | fps                | 256      |
# | nupdates           | 900      |
# | policy_entropy     | 0.167    |
# | total_timesteps    | 4500     |
# | value_loss         | 5.23e+04 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 7.45e-06 |
# | fps                | 254      |
# | nupdates           | 1000     |
# | policy_entropy     | 0.138    |
# | total_timesteps    | 5000     |
# | value_loss         | 5.29e+06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.91e-05 |
# | fps                | 252      |
# | nupdates           | 1100     |
# | policy_entropy     | 0.0229   |
# | total_timesteps    | 5500     |
# | value_loss         | 1.21e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00326  |
# | fps                | 250      |
# | nupdates           | 1200     |
# | policy_entropy     | 0.0167   |
# | total_timesteps    | 6000     |
# | value_loss         | 1.13e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000137 |
# | fps                | 249      |
# | nupdates           | 1300     |
# | policy_entropy     | 0.0091   |
# | total_timesteps    | 6500     |
# | value_loss         | 5.3e+06  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000201 |
# | fps                | 247      |
# | nupdates           | 1400     |
# | policy_entropy     | 0.0214   |
# | total_timesteps    | 7000     |
# | value_loss         | 2.48e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00562  |
# | fps                | 244      |
# | nupdates           | 1500     |
# | policy_entropy     | 0.0206   |
# | total_timesteps    | 7500     |
# | value_loss         | 8.16e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00423 |
# | fps                | 242      |
# | nupdates           | 1600     |
# | policy_entropy     | 0.0105   |
# | total_timesteps    | 8000     |
# | value_loss         | 3.27e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000727 |
# | fps                | 241      |
# | nupdates           | 1700     |
# | policy_entropy     | 0.0135   |
# | total_timesteps    | 8500     |
# | value_loss         | 4.89e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000279 |
# | fps                | 238      |
# | nupdates           | 1800     |
# | policy_entropy     | 0.0213   |
# | total_timesteps    | 9000     |
# | value_loss         | 8.32e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000539 |
# | fps                | 236      |
# | nupdates           | 1900     |
# | policy_entropy     | 0.0164   |
# | total_timesteps    | 9500     |
# | value_loss         | 3.26e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 7.75e-07 |
# | fps                | 234      |
# | nupdates           | 2000     |
# | policy_entropy     | 0.00953  |
# | total_timesteps    | 10000    |
# | value_loss         | 7.98e+06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00338  |
# | fps                | 231      |
# | nupdates           | 2100     |
# | policy_entropy     | 0.0155   |
# | total_timesteps    | 10500    |
# | value_loss         | 6.96e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000174 |
# | fps                | 229      |
# | nupdates           | 2200     |
# | policy_entropy     | 0.0202   |
# | total_timesteps    | 11000    |
# | value_loss         | 2.93e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 3.42e-05 |
# | fps                | 229      |
# | nupdates           | 2300     |
# | policy_entropy     | 0.00878  |
# | total_timesteps    | 11500    |
# | value_loss         | 9.83e+06 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.51e-05 |
# | fps                | 230       |
# | nupdates           | 2400      |
# | policy_entropy     | 0.0199    |
# | total_timesteps    | 12000     |
# | value_loss         | 4.68e+06  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -0.000216 |
# | fps                | 230       |
# | nupdates           | 2500      |
# | policy_entropy     | 0.0101    |
# | total_timesteps    | 12500     |
# | value_loss         | 2.63e+05  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -1.67e-06 |
# | fps                | 230       |
# | nupdates           | 2600      |
# | policy_entropy     | 0.0352    |
# | total_timesteps    | 13000     |
# | value_loss         | 4.44e+07  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.00082  |
# | fps                | 230      |
# | nupdates           | 2700     |
# | policy_entropy     | 0.00505  |
# | total_timesteps    | 13500    |
# | value_loss         | 9.17e+06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0377   |
# | fps                | 230      |
# | nupdates           | 2800     |
# | policy_entropy     | 0.00824  |
# | total_timesteps    | 14000    |
# | value_loss         | 1.96e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 8.42e-05 |
# | fps                | 230      |
# | nupdates           | 2900     |
# | policy_entropy     | 0.00531  |
# | total_timesteps    | 14500    |
# | value_loss         | 7.51e+06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.62e-06 |
# | fps                | 230      |
# | nupdates           | 3000     |
# | policy_entropy     | 0.0303   |
# | total_timesteps    | 15000    |
# | value_loss         | 6.11e+07 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -3.24e-05 |
# | fps                | 230       |
# | nupdates           | 3100      |
# | policy_entropy     | 0.00625   |
# | total_timesteps    | 15500     |
# | value_loss         | 1.39e+05  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 6.78e-05 |
# | fps                | 230      |
# | nupdates           | 3200     |
# | policy_entropy     | 0.00643  |
# | total_timesteps    | 16000    |
# | value_loss         | 2.02e+06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 3.08e-05 |
# | fps                | 229      |
# | nupdates           | 3300     |
# | policy_entropy     | 0.0102   |
# | total_timesteps    | 16500    |
# | value_loss         | 1.67e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0395   |
# | fps                | 230      |
# | nupdates           | 3400     |
# | policy_entropy     | 0.00677  |
# | total_timesteps    | 17000    |
# | value_loss         | 7.57e+04 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0243  |
# | fps                | 230      |
# | nupdates           | 3500     |
# | policy_entropy     | 0.00535  |
# | total_timesteps    | 17500    |
# | value_loss         | 1.02e+07 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.62e-06 |
# | fps                | 230       |
# | nupdates           | 3600      |
# | policy_entropy     | 0.0173    |
# | total_timesteps    | 18000     |
# | value_loss         | 2.04e+07  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -0.000256 |
# | fps                | 231       |
# | nupdates           | 3700      |
# | policy_entropy     | 0.0114    |
# | total_timesteps    | 18500     |
# | value_loss         | 9.49e+06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 6.91e-06 |
# | fps                | 231      |
# | nupdates           | 3800     |
# | policy_entropy     | 0.0109   |
# | total_timesteps    | 19000    |
# | value_loss         | 1.4e+08  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.014    |
# | fps                | 231      |
# | nupdates           | 3900     |
# | policy_entropy     | 0.00602  |
# | total_timesteps    | 19500    |
# | value_loss         | 1.13e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0469   |
# | fps                | 232      |
# | nupdates           | 4000     |
# | policy_entropy     | 0.00912  |
# | total_timesteps    | 20000    |
# | value_loss         | 8.21e+04 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0246   |
# | fps                | 232      |
# | nupdates           | 4100     |
# | policy_entropy     | 0.0067   |
# | total_timesteps    | 20500    |
# | value_loss         | 2.54e+07 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000582 |
# | fps                | 232       |
# | nupdates           | 4200      |
# | policy_entropy     | 0.00649   |
# | total_timesteps    | 21000     |
# | value_loss         | 1.66e+08  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.0142   |
# | fps                | 232      |
# | nupdates           | 4300     |
# | policy_entropy     | 0.00832  |
# | total_timesteps    | 21500    |
# | value_loss         | 1.11e+06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0181  |
# | fps                | 232      |
# | nupdates           | 4400     |
# | policy_entropy     | 0.00564  |
# | total_timesteps    | 22000    |
# | value_loss         | 8.49e+06 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -7.51e-06 |
# | fps                | 231       |
# | nupdates           | 4500      |
# | policy_entropy     | 0.00405   |
# | total_timesteps    | 22500     |
# | value_loss         | 2.03e+07  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.000451 |
# | fps                | 231      |
# | nupdates           | 4600     |
# | policy_entropy     | 0.00662  |
# | total_timesteps    | 23000    |
# | value_loss         | 2.33e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.111    |
# | fps                | 231      |
# | nupdates           | 4700     |
# | policy_entropy     | 0.00593  |
# | total_timesteps    | 23500    |
# | value_loss         | 8.17e+04 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00287  |
# | fps                | 231      |
# | nupdates           | 4800     |
# | policy_entropy     | 0.00798  |
# | total_timesteps    | 24000    |
# | value_loss         | 4.71e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0285  |
# | fps                | 230      |
# | nupdates           | 4900     |
# | policy_entropy     | 0.00781  |
# | total_timesteps    | 24500    |
# | value_loss         | 1.37e+06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.025    |
# | fps                | 230      |
# | nupdates           | 5000     |
# | policy_entropy     | 0.00903  |
# | total_timesteps    | 25000    |
# | value_loss         | 5.98e+06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00221  |
# | fps                | 230      |
# | nupdates           | 5100     |
# | policy_entropy     | 0.00385  |
# | total_timesteps    | 25500    |
# | value_loss         | 5.32e+07 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -5.36e-06 |
# | fps                | 230       |
# | nupdates           | 5200      |
# | policy_entropy     | 0.00751   |
# | total_timesteps    | 26000     |
# | value_loss         | 2.92e+07  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 4.89e-06 |
# | fps                | 231      |
# | nupdates           | 5300     |
# | policy_entropy     | 0.00979  |
# | total_timesteps    | 26500    |
# | value_loss         | 2.54e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.38e-07 |
# | fps                | 231      |
# | nupdates           | 5400     |
# | policy_entropy     | 0.00533  |
# | total_timesteps    | 27000    |
# | value_loss         | 4.59e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.19e-07 |
# | fps                | 231      |
# | nupdates           | 5500     |
# | policy_entropy     | 0.0124   |
# | total_timesteps    | 27500    |
# | value_loss         | 1.79e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0733   |
# | fps                | 231      |
# | nupdates           | 5600     |
# | policy_entropy     | 0.00741  |
# | total_timesteps    | 28000    |
# | value_loss         | 2.6e+05  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.79e-07 |
# | fps                | 231      |
# | nupdates           | 5700     |
# | policy_entropy     | 0.00919  |
# | total_timesteps    | 28500    |
# | value_loss         | 8.25e+06 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -7.15e-07 |
# | fps                | 232       |
# | nupdates           | 5800      |
# | policy_entropy     | 0.00633   |
# | total_timesteps    | 29000     |
# | value_loss         | 1.26e+09  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -0.00131 |
# | fps                | 232      |
# | nupdates           | 5900     |
# | policy_entropy     | 0.0234   |
# | total_timesteps    | 29500    |
# | value_loss         | 1.04e+04 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0157  |
# | fps                | 232      |
# | nupdates           | 6000     |
# | policy_entropy     | 0.00881  |
# | total_timesteps    | 30000    |
# | value_loss         | 1.13e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0159   |
# | fps                | 232      |
# | nupdates           | 6100     |
# | policy_entropy     | 0.00744  |
# | total_timesteps    | 30500    |
# | value_loss         | 2.77e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0459   |
# | fps                | 233      |
# | nupdates           | 6200     |
# | policy_entropy     | 0.00517  |
# | total_timesteps    | 31000    |
# | value_loss         | 5.87e+05 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.19e-07 |
# | fps                | 233       |
# | nupdates           | 6300      |
# | policy_entropy     | 0.00342   |
# | total_timesteps    | 31500     |
# | value_loss         | 1.28e+07  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -1.19e-07 |
# | fps                | 233       |
# | nupdates           | 6400      |
# | policy_entropy     | 0.00188   |
# | total_timesteps    | 32000     |
# | value_loss         | 9.55e+06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.265    |
# | fps                | 233      |
# | nupdates           | 6500     |
# | policy_entropy     | 0.00632  |
# | total_timesteps    | 32500    |
# | value_loss         | 5.96e+04 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.103    |
# | fps                | 234      |
# | nupdates           | 6600     |
# | policy_entropy     | 0.00516  |
# | total_timesteps    | 33000    |
# | value_loss         | 2.34e+06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00018 |
# | fps                | 234      |
# | nupdates           | 6700     |
# | policy_entropy     | 0.00782  |
# | total_timesteps    | 33500    |
# | value_loss         | 8.71e+07 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.31e-06 |
# | fps                | 234       |
# | nupdates           | 6800      |
# | policy_entropy     | 0.00628   |
# | total_timesteps    | 34000     |
# | value_loss         | 3.23e+06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.0514   |
# | fps                | 234      |
# | nupdates           | 6900     |
# | policy_entropy     | 0.0124   |
# | total_timesteps    | 34500    |
# | value_loss         | 1.11e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00175  |
# | fps                | 234      |
# | nupdates           | 7000     |
# | policy_entropy     | 0.0122   |
# | total_timesteps    | 35000    |
# | value_loss         | 2.19e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 4.89e-06 |
# | fps                | 234      |
# | nupdates           | 7100     |
# | policy_entropy     | 0.0486   |
# | total_timesteps    | 35500    |
# | value_loss         | 2.92e+05 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000522 |
# | fps                | 235       |
# | nupdates           | 7200      |
# | policy_entropy     | 0.0381    |
# | total_timesteps    | 36000     |
# | value_loss         | 1.26e+06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 235      |
# | nupdates           | 7300     |
# | policy_entropy     | 0.00152  |
# | total_timesteps    | 36500    |
# | value_loss         | 1.38e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.12     |
# | fps                | 235      |
# | nupdates           | 7400     |
# | policy_entropy     | 0.00313  |
# | total_timesteps    | 37000    |
# | value_loss         | 1.76e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00304  |
# | fps                | 235      |
# | nupdates           | 7500     |
# | policy_entropy     | 0.0258   |
# | total_timesteps    | 37500    |
# | value_loss         | 2.54e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00587  |
# | fps                | 235      |
# | nupdates           | 7600     |
# | policy_entropy     | 0.00554  |
# | total_timesteps    | 38000    |
# | value_loss         | 2.55e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0162   |
# | fps                | 235      |
# | nupdates           | 7700     |
# | policy_entropy     | 0.00387  |
# | total_timesteps    | 38500    |
# | value_loss         | 2.32e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.925   |
# | fps                | 236      |
# | nupdates           | 7800     |
# | policy_entropy     | 0.00637  |
# | total_timesteps    | 39000    |
# | value_loss         | 5.99e+04 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -5.96e-07 |
# | fps                | 236       |
# | nupdates           | 7900      |
# | policy_entropy     | 0.00625   |
# | total_timesteps    | 39500     |
# | value_loss         | 1.89e+07  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 236      |
# | nupdates           | 8000     |
# | policy_entropy     | 0.00423  |
# | total_timesteps    | 40000    |
# | value_loss         | 2.55e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000154 |
# | fps                | 236      |
# | nupdates           | 8100     |
# | policy_entropy     | 0.00292  |
# | total_timesteps    | 40500    |
# | value_loss         | 2.29e+04 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 9.3e-06  |
# | fps                | 236      |
# | nupdates           | 8200     |
# | policy_entropy     | 0.00588  |
# | total_timesteps    | 41000    |
# | value_loss         | 1.13e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00848 |
# | fps                | 236      |
# | nupdates           | 8300     |
# | policy_entropy     | 0.00246  |
# | total_timesteps    | 41500    |
# | value_loss         | 1e+08    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.97e-06 |
# | fps                | 237      |
# | nupdates           | 8400     |
# | policy_entropy     | 0.003    |
# | total_timesteps    | 42000    |
# | value_loss         | 3.44e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 3.1e-06  |
# | fps                | 237      |
# | nupdates           | 8500     |
# | policy_entropy     | 0.00437  |
# | total_timesteps    | 42500    |
# | value_loss         | 1.73e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.79e-07 |
# | fps                | 237      |
# | nupdates           | 8600     |
# | policy_entropy     | 0.00619  |
# | total_timesteps    | 43000    |
# | value_loss         | 8.21e+07 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -3.58e-07 |
# | fps                | 237       |
# | nupdates           | 8700      |
# | policy_entropy     | 0.00755   |
# | total_timesteps    | 43500     |
# | value_loss         | 3.32e+05  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -0.00286 |
# | fps                | 237      |
# | nupdates           | 8800     |
# | policy_entropy     | 0.00513  |
# | total_timesteps    | 44000    |
# | value_loss         | 7.48e+06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0906   |
# | fps                | 237      |
# | nupdates           | 8900     |
# | policy_entropy     | 0.00208  |
# | total_timesteps    | 44500    |
# | value_loss         | 8.25e+06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0985   |
# | fps                | 237      |
# | nupdates           | 9000     |
# | policy_entropy     | 0.00369  |
# | total_timesteps    | 45000    |
# | value_loss         | 2.75e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.278    |
# | fps                | 237      |
# | nupdates           | 9100     |
# | policy_entropy     | 0.0106   |
# | total_timesteps    | 45500    |
# | value_loss         | 1.36e+06 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.14e-05 |
# | fps                | 238       |
# | nupdates           | 9200      |
# | policy_entropy     | 0.00787   |
# | total_timesteps    | 46000     |
# | value_loss         | 3.77e+07  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 5.96e-07 |
# | fps                | 238      |
# | nupdates           | 9300     |
# | policy_entropy     | 0.00377  |
# | total_timesteps    | 46500    |
# | value_loss         | 1.77e+07 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.19e-07 |
# | fps                | 238       |
# | nupdates           | 9400      |
# | policy_entropy     | 0.0069    |
# | total_timesteps    | 47000     |
# | value_loss         | 4.97e+04  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -1.19e-07 |
# | fps                | 238       |
# | nupdates           | 9500      |
# | policy_entropy     | 0.00696   |
# | total_timesteps    | 47500     |
# | value_loss         | 9.6e+07   |
# ----------------------------------
# ---------------------------------
# | explained_variance | -0.138   |
# | fps                | 238      |
# | nupdates           | 9600     |
# | policy_entropy     | 0.0161   |
# | total_timesteps    | 48000    |
# | value_loss         | 1.09e+06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.341    |
# | fps                | 238      |
# | nupdates           | 9700     |
# | policy_entropy     | 0.00252  |
# | total_timesteps    | 48500    |
# | value_loss         | 2.93e+05 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.86e-06 |
# | fps                | 238       |
# | nupdates           | 9800      |
# | policy_entropy     | 0.0081    |
# | total_timesteps    | 49000     |
# | value_loss         | 2.13e+07  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 4.17e-07 |
# | fps                | 238      |
# | nupdates           | 9900     |
# | policy_entropy     | 0.00219  |
# | total_timesteps    | 49500    |
# | value_loss         | 2.11e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.38e-07 |
# | fps                | 239       |
# | nupdates           | 10000     |
# | policy_entropy     | 0.00713   |
# | total_timesteps    | 50000     |
# | value_loss         | 2.46e+05  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.0149   |
# | fps                | 239      |
# | nupdates           | 10100    |
# | policy_entropy     | 0.00515  |
# | total_timesteps    | 50500    |
# | value_loss         | 2.05e+06 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000895 |
# | fps                | 239       |
# | nupdates           | 10200     |
# | policy_entropy     | 0.00755   |
# | total_timesteps    | 51000     |
# | value_loss         | 6.37e+07  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -2.03e-06 |
# | fps                | 239       |
# | nupdates           | 10300     |
# | policy_entropy     | 0.0026    |
# | total_timesteps    | 51500     |
# | value_loss         | 9.63e+04  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.0435   |
# | fps                | 239      |
# | nupdates           | 10400    |
# | policy_entropy     | 0.00178  |
# | total_timesteps    | 52000    |
# | value_loss         | 1.88e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 239      |
# | nupdates           | 10500    |
# | policy_entropy     | 0.0112   |
# | total_timesteps    | 52500    |
# | value_loss         | 4.68e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 239      |
# | nupdates           | 10600    |
# | policy_entropy     | 0.0108   |
# | total_timesteps    | 53000    |
# | value_loss         | 5.6e+06  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0271   |
# | fps                | 239      |
# | nupdates           | 10700    |
# | policy_entropy     | 0.0104   |
# | total_timesteps    | 53500    |
# | value_loss         | 2.19e+07 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.31e-06 |
# | fps                | 239       |
# | nupdates           | 10800     |
# | policy_entropy     | 0.00544   |
# | total_timesteps    | 54000     |
# | value_loss         | 2.39e+07  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.0276   |
# | fps                | 240      |
# | nupdates           | 10900    |
# | policy_entropy     | 0.0128   |
# | total_timesteps    | 54500    |
# | value_loss         | 5.95e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.98e-07 |
# | fps                | 240      |
# | nupdates           | 11000    |
# | policy_entropy     | 0.00352  |
# | total_timesteps    | 55000    |
# | value_loss         | 7.82e+06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.014   |
# | fps                | 240      |
# | nupdates           | 11100    |
# | policy_entropy     | 0.00592  |
# | total_timesteps    | 55500    |
# | value_loss         | 8.89e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.3      |
# | fps                | 240      |
# | nupdates           | 11200    |
# | policy_entropy     | 0.00192  |
# | total_timesteps    | 56000    |
# | value_loss         | 1.98e+05 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.24e-05 |
# | fps                | 240       |
# | nupdates           | 11300     |
# | policy_entropy     | 0.121     |
# | total_timesteps    | 56500     |
# | value_loss         | 2.97e+06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -0.0252  |
# | fps                | 240      |
# | nupdates           | 11400    |
# | policy_entropy     | 0.000576 |
# | total_timesteps    | 57000    |
# | value_loss         | 5.59e+06 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.04e-05 |
# | fps                | 240       |
# | nupdates           | 11500     |
# | policy_entropy     | 0.000671  |
# | total_timesteps    | 57500     |
# | value_loss         | 4.92e+06  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -7.27e-06 |
# | fps                | 240       |
# | nupdates           | 11600     |
# | policy_entropy     | 0.064     |
# | total_timesteps    | 58000     |
# | value_loss         | 2.33e+06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -0.0279  |
# | fps                | 241      |
# | nupdates           | 11700    |
# | policy_entropy     | 0.00177  |
# | total_timesteps    | 58500    |
# | value_loss         | 4.39e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 7.15e-07 |
# | fps                | 241      |
# | nupdates           | 11800    |
# | policy_entropy     | 0.00445  |
# | total_timesteps    | 59000    |
# | value_loss         | 1.3e+06  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0639   |
# | fps                | 241      |
# | nupdates           | 11900    |
# | policy_entropy     | 0.002    |
# | total_timesteps    | 59500    |
# | value_loss         | 6.12e+06 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.67e-06 |
# | fps                | 241       |
# | nupdates           | 12000     |
# | policy_entropy     | 0.000867  |
# | total_timesteps    | 60000     |
# | value_loss         | 3.48e+08  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 241      |
# | nupdates           | 12100    |
# | policy_entropy     | 0.000719 |
# | total_timesteps    | 60500    |
# | value_loss         | 1.01e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.19e-07 |
# | fps                | 241      |
# | nupdates           | 12200    |
# | policy_entropy     | 0.00763  |
# | total_timesteps    | 61000    |
# | value_loss         | 4.26e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 241      |
# | nupdates           | 12300    |
# | policy_entropy     | 0.000613 |
# | total_timesteps    | 61500    |
# | value_loss         | 3.15e+07 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -3.58e-07 |
# | fps                | 241       |
# | nupdates           | 12400     |
# | policy_entropy     | 0.000781  |
# | total_timesteps    | 62000     |
# | value_loss         | 6.02e+07  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.157    |
# | fps                | 241      |
# | nupdates           | 12500    |
# | policy_entropy     | 0.00181  |
# | total_timesteps    | 62500    |
# | value_loss         | 3.25e+04 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 241      |
# | nupdates           | 12600    |
# | policy_entropy     | 0.000689 |
# | total_timesteps    | 63000    |
# | value_loss         | 1.01e+08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.19e-07 |
# | fps                | 241       |
# | nupdates           | 12700     |
# | policy_entropy     | 0.00278   |
# | total_timesteps    | 63500     |
# | value_loss         | 8.45e+08  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 1.55e-06 |
# | fps                | 241      |
# | nupdates           | 12800    |
# | policy_entropy     | 0.00336  |
# | total_timesteps    | 64000    |
# | value_loss         | 3.65e+04 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0185  |
# | fps                | 241      |
# | nupdates           | 12900    |
# | policy_entropy     | 0.000673 |
# | total_timesteps    | 64500    |
# | value_loss         | 7.85e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0469   |
# | fps                | 241      |
# | nupdates           | 13000    |
# | policy_entropy     | 0.000583 |
# | total_timesteps    | 65000    |
# | value_loss         | 3.24e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.426   |
# | fps                | 242      |
# | nupdates           | 13100    |
# | policy_entropy     | 0.00198  |
# | total_timesteps    | 65500    |
# | value_loss         | 1.42e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 242      |
# | nupdates           | 13200    |
# | policy_entropy     | 0.00104  |
# | total_timesteps    | 66000    |
# | value_loss         | 8.1e+06  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0521  |
# | fps                | 242      |
# | nupdates           | 13300    |
# | policy_entropy     | 0.00128  |
# | total_timesteps    | 66500    |
# | value_loss         | 2.7e+06  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.616   |
# | fps                | 242      |
# | nupdates           | 13400    |
# | policy_entropy     | 0.00447  |
# | total_timesteps    | 67000    |
# | value_loss         | 7.62e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0908  |
# | fps                | 242      |
# | nupdates           | 13500    |
# | policy_entropy     | 0.00274  |
# | total_timesteps    | 67500    |
# | value_loss         | 2e+06    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0263  |
# | fps                | 242      |
# | nupdates           | 13600    |
# | policy_entropy     | 0.00283  |
# | total_timesteps    | 68000    |
# | value_loss         | 1.81e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 5.96e-08 |
# | fps                | 242      |
# | nupdates           | 13700    |
# | policy_entropy     | 0.00203  |
# | total_timesteps    | 68500    |
# | value_loss         | 3.36e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.73e-05 |
# | fps                | 242      |
# | nupdates           | 13800    |
# | policy_entropy     | 0.00554  |
# | total_timesteps    | 69000    |
# | value_loss         | 3.64e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0246   |
# | fps                | 242      |
# | nupdates           | 13900    |
# | policy_entropy     | 0.00247  |
# | total_timesteps    | 69500    |
# | value_loss         | 3.36e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 3.58e-07 |
# | fps                | 242      |
# | nupdates           | 14000    |
# | policy_entropy     | 0.00281  |
# | total_timesteps    | 70000    |
# | value_loss         | 1e+07    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.19e-07 |
# | fps                | 242       |
# | nupdates           | 14100     |
# | policy_entropy     | 0.00286   |
# | total_timesteps    | 70500     |
# | value_loss         | 2.07e+05  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.0262   |
# | fps                | 242      |
# | nupdates           | 14200    |
# | policy_entropy     | 0.0015   |
# | total_timesteps    | 71000    |
# | value_loss         | 4.61e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0227  |
# | fps                | 242      |
# | nupdates           | 14300    |
# | policy_entropy     | 0.00112  |
# | total_timesteps    | 71500    |
# | value_loss         | 2.7e+07  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.55e-06 |
# | fps                | 242      |
# | nupdates           | 14400    |
# | policy_entropy     | 0.0103   |
# | total_timesteps    | 72000    |
# | value_loss         | 3.73e+04 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00321  |
# | fps                | 242      |
# | nupdates           | 14500    |
# | policy_entropy     | 0.00635  |
# | total_timesteps    | 72500    |
# | value_loss         | 3.64e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0235   |
# | fps                | 242      |
# | nupdates           | 14600    |
# | policy_entropy     | 0.00149  |
# | total_timesteps    | 73000    |
# | value_loss         | 2.15e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -3.14    |
# | fps                | 242      |
# | nupdates           | 14700    |
# | policy_entropy     | 0.00495  |
# | total_timesteps    | 73500    |
# | value_loss         | 6.47e+04 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.38e-07 |
# | fps                | 242       |
# | nupdates           | 14800     |
# | policy_entropy     | 0.00531   |
# | total_timesteps    | 74000     |
# | value_loss         | 5.51e+07  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 2.38e-07 |
# | fps                | 242      |
# | nupdates           | 14900    |
# | policy_entropy     | 0.00265  |
# | total_timesteps    | 74500    |
# | value_loss         | 4.08e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.4     |
# | fps                | 242      |
# | nupdates           | 15000    |
# | policy_entropy     | 0.000615 |
# | total_timesteps    | 75000    |
# | value_loss         | 1.23e+05 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.19e-07 |
# | fps                | 242       |
# | nupdates           | 15100     |
# | policy_entropy     | 0.00255   |
# | total_timesteps    | 75500     |
# | value_loss         | 5.01e+06  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -1.65e-05 |
# | fps                | 242       |
# | nupdates           | 15200     |
# | policy_entropy     | 0.00144   |
# | total_timesteps    | 76000     |
# | value_loss         | 3.18e+08  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.0978   |
# | fps                | 242      |
# | nupdates           | 15300    |
# | policy_entropy     | 0.00237  |
# | total_timesteps    | 76500    |
# | value_loss         | 7.51e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00212  |
# | fps                | 242      |
# | nupdates           | 15400    |
# | policy_entropy     | 0.00105  |
# | total_timesteps    | 77000    |
# | value_loss         | 1.05e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0241   |
# | fps                | 242      |
# | nupdates           | 15500    |
# | policy_entropy     | 0.0037   |
# | total_timesteps    | 77500    |
# | value_loss         | 6.65e+07 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.07e-06 |
# | fps                | 242       |
# | nupdates           | 15600     |
# | policy_entropy     | 0.00124   |
# | total_timesteps    | 78000     |
# | value_loss         | 7e+04     |
# ----------------------------------
# ---------------------------------
# | explained_variance | 1.19e-07 |
# | fps                | 242      |
# | nupdates           | 15700    |
# | policy_entropy     | 0.00188  |
# | total_timesteps    | 78500    |
# | value_loss         | 2.13e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.12     |
# | fps                | 242      |
# | nupdates           | 15800    |
# | policy_entropy     | 0.000422 |
# | total_timesteps    | 79000    |
# | value_loss         | 6.65e+06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.21     |
# | fps                | 242      |
# | nupdates           | 15900    |
# | policy_entropy     | 0.00053  |
# | total_timesteps    | 79500    |
# | value_loss         | 1.81e+07 |
# ...
# | nupdates           | 994200   |
# | policy_entropy     | 1.15e-08 |
# | total_timesteps    | 4971000  |
# | value_loss         | 2e+06    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 219      |
# | nupdates           | 994300   |
# | policy_entropy     | 1.33e-10 |
# | total_timesteps    | 4971500  |
# | value_loss         | 1.1e+04  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.991    |
# | fps                | 219      |
# | nupdates           | 994400   |
# | policy_entropy     | 8.47e-09 |
# | total_timesteps    | 4972000  |
# | value_loss         | 4.02e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.959    |
# | fps                | 219      |
# | nupdates           | 994500   |
# | policy_entropy     | 6.73e-09 |
# | total_timesteps    | 4972500  |
# | value_loss         | 9.88e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.948    |
# | fps                | 219      |
# | nupdates           | 994600   |
# | policy_entropy     | 0.000294 |
# | total_timesteps    | 4973000  |
# | value_loss         | 1.61e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 219      |
# | nupdates           | 994700   |
# | policy_entropy     | 0.00018  |
# | total_timesteps    | 4973500  |
# | value_loss         | 1.9e+03  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.998    |
# | fps                | 219      |
# | nupdates           | 994800   |
# | policy_entropy     | 0.00173  |
# | total_timesteps    | 4974000  |
# | value_loss         | 2.05e+04 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 219      |
# | nupdates           | 994900   |
# | policy_entropy     | 0.00959  |
# | total_timesteps    | 4974500  |
# | value_loss         | 2.83e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.999    |
# | fps                | 219      |
# | nupdates           | 995000   |
# | policy_entropy     | 5.82e-06 |
# | total_timesteps    | 4975000  |
# | value_loss         | 3.05e+04 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 219      |
# | nupdates           | 995100   |
# | policy_entropy     | 7.73e-10 |
# | total_timesteps    | 4975500  |
# | value_loss         | 1.46e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000256 |
# | fps                | 219      |
# | nupdates           | 995200   |
# | policy_entropy     | 1.5e-05  |
# | total_timesteps    | 4976000  |
# | value_loss         | 6.69e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 219      |
# | nupdates           | 995300   |
# | policy_entropy     | 0.000414 |
# | total_timesteps    | 4976500  |
# | value_loss         | 9.7e+03  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.053    |
# | fps                | 219      |
# | nupdates           | 995400   |
# | policy_entropy     | 1.77e-07 |
# | total_timesteps    | 4977000  |
# | value_loss         | 1.45e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.842    |
# | fps                | 219      |
# | nupdates           | 995500   |
# | policy_entropy     | 4.51e-09 |
# | total_timesteps    | 4977500  |
# | value_loss         | 1.55e+06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.977    |
# | fps                | 219      |
# | nupdates           | 995600   |
# | policy_entropy     | 4.68e-05 |
# | total_timesteps    | 4978000  |
# | value_loss         | 2.82e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0        |
# | fps                | 219      |
# | nupdates           | 995700   |
# | policy_entropy     | 2.3e-05  |
# | total_timesteps    | 4978500  |
# | value_loss         | 3.76e+07 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.38e-07 |
# | fps                | 219       |
# | nupdates           | 995800    |
# | policy_entropy     | 0.000362  |
# | total_timesteps    | 4979000   |
# | value_loss         | 8.07e+06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 219      |
# | nupdates           | 995900   |
# | policy_entropy     | 0.00535  |
# | total_timesteps    | 4979500  |
# | value_loss         | 2.01e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 219      |
# | nupdates           | 996000   |
# | policy_entropy     | 6.26e-06 |
# | total_timesteps    | 4980000  |
# | value_loss         | 6.18e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000207 |
# | fps                | 219      |
# | nupdates           | 996100   |
# | policy_entropy     | 1.95e-08 |
# | total_timesteps    | 4980500  |
# | value_loss         | 2.18e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.998    |
# | fps                | 219      |
# | nupdates           | 996200   |
# | policy_entropy     | 0.000274 |
# | total_timesteps    | 4981000  |
# | value_loss         | 9.61e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.715    |
# | fps                | 219      |
# | nupdates           | 996300   |
# | policy_entropy     | 0.000639 |
# | total_timesteps    | 4981500  |
# | value_loss         | 1.08e+07 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.38e-07 |
# | fps                | 219       |
# | nupdates           | 996400    |
# | policy_entropy     | 5.31e-06  |
# | total_timesteps    | 4982000   |
# | value_loss         | 1.6e+08   |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.981    |
# | fps                | 219      |
# | nupdates           | 996500   |
# | policy_entropy     | 0.0287   |
# | total_timesteps    | 4982500  |
# | value_loss         | 1.74e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.685    |
# | fps                | 219      |
# | nupdates           | 996600   |
# | policy_entropy     | 2.79e-06 |
# | total_timesteps    | 4983000  |
# | value_loss         | 3.77e+06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 5.96e-08 |
# | fps                | 219      |
# | nupdates           | 996700   |
# | policy_entropy     | 3.36e-05 |
# | total_timesteps    | 4983500  |
# | value_loss         | 1.32e+09 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 219      |
# | nupdates           | 996800   |
# | policy_entropy     | 2.36e-09 |
# | total_timesteps    | 4984000  |
# | value_loss         | 9.72e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00392  |
# | fps                | 219      |
# | nupdates           | 996900   |
# | policy_entropy     | 9.15e-06 |
# | total_timesteps    | 4984500  |
# | value_loss         | 1.34e+06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.991    |
# | fps                | 219      |
# | nupdates           | 997000   |
# | policy_entropy     | 1.53e-10 |
# | total_timesteps    | 4985000  |
# | value_loss         | 1.51e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.971    |
# | fps                | 219      |
# | nupdates           | 997100   |
# | policy_entropy     | 0.058    |
# | total_timesteps    | 4985500  |
# | value_loss         | 4.57e+04 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 219      |
# | nupdates           | 997200   |
# | policy_entropy     | 4.61e-07 |
# | total_timesteps    | 4986000  |
# | value_loss         | 5.28e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.541    |
# | fps                | 219      |
# | nupdates           | 997300   |
# | policy_entropy     | 0.00672  |
# | total_timesteps    | 4986500  |
# | value_loss         | 2.05e+06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.756    |
# | fps                | 219      |
# | nupdates           | 997400   |
# | policy_entropy     | 0.000441 |
# | total_timesteps    | 4987000  |
# | value_loss         | 2.57e+04 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.998    |
# | fps                | 219      |
# | nupdates           | 997500   |
# | policy_entropy     | 7.55e-07 |
# | total_timesteps    | 4987500  |
# | value_loss         | 9.88e+03 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.38e-07 |
# | fps                | 219       |
# | nupdates           | 997600    |
# | policy_entropy     | 5.68e-08  |
# | total_timesteps    | 4988000   |
# | value_loss         | 7.36e+07  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 2.31e-05 |
# | fps                | 219      |
# | nupdates           | 997700   |
# | policy_entropy     | 4.8e-10  |
# | total_timesteps    | 4988500  |
# | value_loss         | 1.1e+06  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 219      |
# | nupdates           | 997800   |
# | policy_entropy     | 5.18e-08 |
# | total_timesteps    | 4989000  |
# | value_loss         | 1.25e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 4.17e-07 |
# | fps                | 219      |
# | nupdates           | 997900   |
# | policy_entropy     | 0.000175 |
# | total_timesteps    | 4989500  |
# | value_loss         | 2.58e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 219      |
# | nupdates           | 998000   |
# | policy_entropy     | 4.99e-06 |
# | total_timesteps    | 4990000  |
# | value_loss         | 3.01e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.797    |
# | fps                | 219      |
# | nupdates           | 998100   |
# | policy_entropy     | 0.00895  |
# | total_timesteps    | 4990500  |
# | value_loss         | 8.25e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 219      |
# | nupdates           | 998200   |
# | policy_entropy     | 0.00574  |
# | total_timesteps    | 4991000  |
# | value_loss         | 8.01e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.91e-06 |
# | fps                | 219      |
# | nupdates           | 998300   |
# | policy_entropy     | 8.07e-05 |
# | total_timesteps    | 4991500  |
# | value_loss         | 1.19e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.795    |
# | fps                | 219      |
# | nupdates           | 998400   |
# | policy_entropy     | 0.0122   |
# | total_timesteps    | 4992000  |
# | value_loss         | 2.09e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 5.96e-07 |
# | fps                | 219      |
# | nupdates           | 998500   |
# | policy_entropy     | 5.8e-08  |
# | total_timesteps    | 4992500  |
# | value_loss         | 1.58e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 4.5e-05  |
# | fps                | 219      |
# | nupdates           | 998600   |
# | policy_entropy     | 3.23e-05 |
# | total_timesteps    | 4993000  |
# | value_loss         | 2.13e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.985    |
# | fps                | 219      |
# | nupdates           | 998700   |
# | policy_entropy     | 7.36e-08 |
# | total_timesteps    | 4993500  |
# | value_loss         | 653      |
# ---------------------------------
# ----------------------------------
# | explained_variance | -8.34e-07 |
# | fps                | 219       |
# | nupdates           | 998800    |
# | policy_entropy     | 1.75e-09  |
# | total_timesteps    | 4994000   |
# | value_loss         | 1.31e+07  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.653    |
# | fps                | 219      |
# | nupdates           | 998900   |
# | policy_entropy     | 1.43e-10 |
# | total_timesteps    | 4994500  |
# | value_loss         | 1.31e+08 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.993    |
# | fps                | 219      |
# | nupdates           | 999000   |
# | policy_entropy     | 1.59e-10 |
# | total_timesteps    | 4995000  |
# | value_loss         | 354      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 219      |
# | nupdates           | 999100   |
# | policy_entropy     | 3.26e-06 |
# | total_timesteps    | 4995500  |
# | value_loss         | 1.49e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.892    |
# | fps                | 219      |
# | nupdates           | 999200   |
# | policy_entropy     | 0.000314 |
# | total_timesteps    | 4996000  |
# | value_loss         | 1.55e+07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.955    |
# | fps                | 219      |
# | nupdates           | 999300   |
# | policy_entropy     | 0.0344   |
# | total_timesteps    | 4996500  |
# | value_loss         | 8.76e+04 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1        |
# | fps                | 219      |
# | nupdates           | 999400   |
# | policy_entropy     | 8.33e-07 |
# | total_timesteps    | 4997000  |
# | value_loss         | 6.92e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.09e-06 |
# | fps                | 219      |
# | nupdates           | 999500   |
# | policy_entropy     | 0.000136 |
# | total_timesteps    | 4997500  |
# | value_loss         | 3.4e+08  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 219      |
# | nupdates           | 999600   |
# | policy_entropy     | 0.0101   |
# | total_timesteps    | 4998000  |
# | value_loss         | 497      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.999    |
# | fps                | 219      |
# | nupdates           | 999700   |
# | policy_entropy     | 3.56e-07 |
# | total_timesteps    | 4998500  |
# | value_loss         | 1.07e+04 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.158    |
# | fps                | 219      |
# | nupdates           | 999800   |
# | policy_entropy     | 1.02e-07 |
# | total_timesteps    | 4999000  |
# | value_loss         | 4.45e+06 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.01    |
# | fps                | 219      |
# | nupdates           | 999900   |
# | policy_entropy     | 1.28e-07 |
# | total_timesteps    | 4999500  |
# | value_loss         | 1.15e+05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 219      |
# | nupdates           | 1000000  |
# | policy_entropy     | 0.000176 |
# | total_timesteps    | 5000000  |
# | value_loss         | 904      |
# ---------------------------------

# %%
model.save("2603TW_5MTimestep_20200102_20220831Training_128_64_64_volume")

# %%
model = A2C.load("2603TW_5MTimestep_20200102_20220831Training_128_64_64_volume")
# Out:
# Loading a model without an environment, this model cannot be trained until it has a valid environment.
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\policies.py:442: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From C:\Users\cherr\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\layers\core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:160: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From C:\Users\cherr\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\ops\clip_ops.py:301: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:184: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From C:\Users\cherr\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\training\rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:194: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:196: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.

# %% [markdown]
# # 獲取今天的Dataframe索引，方便填寫frame_bound

# %%
# today = df2330.iloc[-1:]
# today = today.index.values
# totay = today[0]

# %%
dfStartDate_Test = df[(df['index']=='2023-01-03')].index.values
dfStartDate_Test = dfStartDate_Test[0]

dfEndDate_Test = df[(df['index']=='2023-02-24')].index.values
dfEndDate_Test = dfEndDate_Test[0]

# %%
dfStartDate_Test
# Out:
# 5727

# %%
dfEndDate_Test
# Out:
# 5757

# %%
df[dfStartDate_Test:dfEndDate_Test+1]
# Out:
#           index    open    high     low   close  adjclose       volume  \
# 5727 2023-01-03 163.000 164.000 160.000 160.000   160.000 23603780.000
# 5728 2023-01-04 161.000 161.500 156.000 156.000   156.000 25203463.000
# 5729 2023-01-05 158.000 160.500 156.500 156.500   156.500 20371487.000
# 5730 2023-01-06 158.000 159.500 156.000 159.000   159.000 12082461.000
# 5731 2023-01-09 158.000 158.500 154.500 155.000   155.000 33000304.000
# 5732 2023-01-10 155.500 157.500 155.000 155.500   155.500 12539289.000
# 5733 2023-01-11 157.000 160.000 156.500 156.500   156.500 19372242.000
# 5734 2023-01-12 157.500 158.000 152.500 152.500   152.500 21891580.000
# 5735 2023-01-13 154.000 154.500 152.500 152.500   152.500 13580480.000
# 5736 2023-01-16 153.000 153.500 149.500 151.500   151.500 17000205.000
# 5737 2023-01-17 153.500 155.500 152.000 152.500   152.500 17135992.000
# 5738 2023-01-30 153.000 153.500 150.000 150.500   150.500 20560721.000
# 5739 2023-01-31 152.000 153.500 151.000 152.000   152.000 13682310.000
# 5740 2023-02-01 152.500 153.500 151.000 152.000   152.000 14204870.000
# 5741 2023-02-02 154.000 156.000 154.000 156.000   156.000 26405172.000
# 5742 2023-02-03 158.500 160.000 156.000 157.000   157.000 33929688.000
# 5743 2023-02-06 156.000 156.500 150.500 151.000   151.000 27857547.000
# 5744 2023-02-07 152.000 152.000 150.500 151.000   151.000 10225713.000
# 5745 2023-02-08 152.000 152.000 151.000 151.500   151.500  8760868.000
# 5746 2023-02-09 151.500 152.000 150.000 150.000   150.000 11986342.000
# 5747 2023-02-10 151.000 151.500 146.500 147.000   147.000 25130873.000
# 5748 2023-02-13 146.000 146.500 142.500 143.500   143.500 20851631.000
# 5749 2023-02-14 145.500 149.000 145.000 149.000   149.000 24410678.000
# 5750 2023-02-15 149.000 149.000 146.000 146.500   146.500 16260716.000
# 5751 2023-02-16 147.000 148.000 145.500 148.000   148.000  9969020.000
# 5752 2023-02-17 146.500 147.000 145.500 146.000   146.000 10223590.000
# 5753 2023-02-20 146.000 147.500 145.000 147.000   147.000  8806970.000
# 5754 2023-02-21 148.500 155.000 147.000 155.000   155.000 42223916.000
# 5755 2023-02-22 154.000 156.000 152.000 152.500   152.500 35219109.000
# 5756 2023-02-23 153.500 158.500 153.500 158.000   158.000 34299954.000
# 5757 2023-02-24 158.500 159.500 155.500 157.000   157.000 32154792.000
#
#        ticker  MinLow  MaxHigh  ...    RSI  K_Value  D_Value    DIF   MACD  \
# 5727  2603.TW 157.500  172.000  ... 53.333   31.710   42.626  1.960  2.312
# 5728  2603.TW 156.000  172.000  ... 40.476   21.140   35.464  1.399  2.129
# 5729  2603.TW 156.000  170.500  ... 43.210   15.243   28.724  0.983  1.900
# 5730  2603.TW 156.000  168.500  ... 50.633   18.162   25.203  0.846  1.689
# 5731  2603.TW 154.500  167.000  ... 38.158   13.441   21.282  0.409  1.433
# 5732  2603.TW 154.500  164.500  ... 24.194   12.294   18.286  0.103  1.167
# 5733  2603.TW 154.500  164.500  ... 30.357   14.863   17.145 -0.059  0.922
# 5734  2603.TW 152.500  164.500  ... 31.481    9.909   14.733 -0.504  0.637
# 5735  2603.TW 152.500  164.000  ... 31.481    6.606   12.024 -0.847  0.340
# 5736  2603.TW 149.500  161.500  ... 34.694    9.959   11.336 -1.186  0.035
# 5737  2603.TW 149.500  160.500  ... 34.694   15.730   12.801 -1.358 -0.244
# 5738  2603.TW 149.500  160.000  ... 23.404   13.662   13.088 -1.637 -0.523
# 5739  2603.TW 149.500  160.000  ... 31.818   17.044   14.406 -1.718 -0.762
# 5740  2603.TW 149.500  160.000  ... 38.889   19.299   16.037 -1.761 -0.961
# 5741  2603.TW 149.500  160.000  ... 48.837   33.501   21.859 -1.456 -1.060
# 5742  2603.TW 149.500  160.000  ... 45.000   46.144   29.954 -1.120 -1.072
# 5743  2603.TW 149.500  160.000  ... 40.909   35.524   31.811 -1.323 -1.122
# 5744  2603.TW 149.500  160.000  ... 39.535   28.445   30.689 -1.467 -1.191
# 5745  2603.TW 150.000  160.000  ... 38.095   23.963   28.447 -1.523 -1.258
# 5746  2603.TW 150.000  160.000  ... 43.243   15.975   24.290 -1.670 -1.340
# 5747  2603.TW 146.500  160.000  ... 37.209   11.885   20.155 -2.005 -1.473
# 5748  2603.TW 142.500  160.000  ... 33.333    9.828   16.713 -2.523 -1.683
# 5749  2603.TW 142.500  160.000  ... 43.860   18.933   17.453 -2.462 -1.839
# 5750  2603.TW 142.500  160.000  ... 43.103   20.241   18.382 -2.586 -1.988
# 5751  2603.TW 142.500  156.500  ... 43.103   26.589   21.118 -2.533 -2.097
# 5752  2603.TW 142.500  152.000  ... 40.323   30.007   24.081 -2.623 -2.202
# 5753  2603.TW 142.500  152.000  ... 33.929   35.794   27.985 -2.584 -2.279
# 5754  2603.TW 142.500  155.000  ... 47.143   57.196   37.722 -1.885 -2.200
# 5755  2603.TW 142.500  156.000  ... 52.381   62.822   46.089 -1.516 -2.063
# 5756  2603.TW 142.500  158.500  ... 59.459   74.173   55.450 -0.771 -1.805
# 5757  2603.TW 145.000  159.500  ... 57.333   77.035   62.645 -0.258 -1.495
#
#       Up_Track  Mid_Track  Down_Track  Volume_lower  Volume_greater
# 5727   170.097    159.125     148.153             0               1
# 5728   169.951    159.300     148.649             0               1
# 5729   169.679    159.550     149.421             0               1
# 5730   169.298    159.950     150.602             0               1
# 5731   169.267    159.975     150.683             1               0
# 5732   169.209    160.025     150.841             0               1
# 5733   169.142    160.100     151.058             0               1
# 5734   169.080    160.125     151.170             0               1
# 5735   169.369    159.900     150.431             0               1
# 5736   169.217    159.275     149.333             0               1
# 5737   169.078    158.800     148.522             0               1
# 5738   169.298    158.400     147.502             1               0
# 5739   168.720    157.800     146.880             0               1
# 5740   166.024    156.825     147.626             0               1
# 5741   164.038    156.250     148.462             1               0
# 5742   163.231    155.975     148.719             1               0
# 5743   162.311    155.400     148.489             1               0
# 5744   161.957    155.000     148.043             0               1
# 5745   161.293    154.575     147.857             0               1
# 5746   159.707    153.925     148.143             0               1
# 5747   159.101    153.275     147.449             1               0
# 5748   159.722    152.650     145.578             1               0
# 5749   159.286    152.275     145.264             1               0
# 5750   158.374    151.650     144.926             0               1
# 5751   158.019    151.300     144.581             0               1
# 5752   157.631    150.825     144.019             0               1
# 5753   156.824    150.350     143.876             0               1
# 5754   157.202    150.475     143.748             1               0
# 5755   157.202    150.475     143.748             1               0
# 5756   158.279    150.800     143.321             1               0
# 5757   158.953    151.025     143.097             1               0
#
# [31 rows x 25 columns]

# %% [markdown]
# # 在今天早上開盤時進行交易

# %%
open, close, high, low, volume, date,signal_features = my_process_data(df=df, window_size=10, frame_bound=(dfStartDate_Test, dfEndDate_Test))#Close與特徵資料
env = MyStocksEnv(open, close, high, low, volume, date,signal_features, df=df, window_size=10, frame_bound=(dfStartDate_Test, dfEndDate_Test))#「環境」整合
obs = env.reset()#初始化「環境」（特徵初始化）
env.seed()
Day = 0
while True: 
    obs = obs[np.newaxis, ...]#1.先抓取【0】~【9】的特徵
    action, _states = model.predict(obs)#2.Agent觀看obs, 進行action的行為，即買【1】賣【0】
    obs, rewards, done, info = env.step(action)#3.使用【1】~【10】的特徵'記錄'獎罰，驗證是否完成，輸出資料
    Day+=1
    print("Day",Day, "Rewards", rewards, end="\n")
    if done:#4.如果完成迴圈，則輸出資料
        print("info", info)
        break
# Out:
# Day 1 Rewards 288.2875000000058
# Day 2 Rewards 1302.2749999999942
# Day 3 Rewards -2198.0812500000175
# Day 4 Rewards -1699.8625000000175
# Day 5 Rewards -187.73125000001164
# Day 6 Rewards 806.34375
# Day 7 Rewards 303.7749999999942
# Day 8 Rewards 819.6187499999942
# Day 9 Rewards -176.66875000001164
# Day 10 Rewards 1322.1875
# Day 11 Rewards -176.66875000001164
# Day 12 Rewards 828.46875
# Day 13 Rewards -174.45624999998836
# Day 14 Rewards 1319.9750000000058
# Day 15 Rewards 1800.4187500000116
# Day 16 Rewards -1691.0124999999825
# Day 17 Rewards 328.11250000001746
# Day 18 Rewards 328.11250000001746
# Day 19 Rewards -670.3875000000116
# Day 20 Rewards 332.5375000000058
# Day 21 Rewards 353.23750000001746
# Day 22 Rewards 1357.5874999999942
# Day 23 Rewards -659.3250000000116
# Day 24 Rewards -150.11874999999418
# Day 25 Rewards 850.6687499999825
# Day 26 Rewards -646.0499999999884
# Day 27 Rewards 843.9562500000175
# Day 28 Rewards -1682.1625000000058
# Day 29 Rewards 321.4750000000058
# Day 30 Rewards 0
# info {'total_reward': 3394.5125000000116, 'total_profit': 1.023987707271183, 'position': 1}

# %%
plt.figure(figsize=(16, 6))
env.render_Close()#將「環境」畫出來
# Out:
# ↓↓↓ 台積電(2330)在交易當天收盤時進行的交易策略(Long Or Short) ↓↓↓

# %% [markdown]
# # 根據模型預測，position為今天收盤時需要進行的交易策略(Long or Short)

# %%
plt.figure(figsize=(16, 6))
env.render_Reward()
# Out:
# ↓↓↓ 台積電(2330)在使用交易策略(Long Or Short)後，隔日早上平倉時的盈虧(含手續費) ↓↓↓

# %%
plt.figure(figsize=(16, 6))
env.render_TotalProfit()
# Out:
# ↓↓↓ 根據預測出的交易策略交易台積電(2330)，所得到的累積利潤(含手續費) ↓↓↓

# %% [markdown]
# # ------------------------------------------------

# %% [markdown]
# # 不同技術分析合併進行資料萃取，需要轉換矩陣格式，解釋如下：

# %%
# a = np.array([
#     [
#         [1,2,3,4,5,6],
#         [2,4,5,6,5,6],
#         [2,4,5,6,5,6],
#         [2,4,5,6,5,6]
#     ]
# ])
# #-----------------------
# b = np.array([
#     [
#         [1,2],[3,4],[5,6]
#     ],
#     [
#         [2,4],[5,6],[5,6]
#     ],
#     [
#         [2,4],[5,6],[5,6]
#     ],
#     [
#         [2,4],[5,6],[5,6]
#     ]
# ])
# #-----------------------
# print('目的：將原本矩陣a，變成矩陣b。因為在機器訓練時，需要讓機器意識到為兩組獨立的參數')
# print('注意：入面組嘅大小必須相同，例如[1,2],[3,4]，但不可以[1,2],[3,4,5]\n\n')
# print('第一個數字：大括號\n第二個數字：有四個打橫\n第三個數字：打橫入面有幾多個數字')
# print(a.shape)
# print(a,'\n')
# print('第一個數字：有幾多大組嘅數字\n第二個數字：入面有幾多個小組\n第三個數字：每個小組入面有幾多個數字')
# print(b.shape)
# print(b)
