# %%
import gym
from gym import spaces
from gym.utils import seeding
import numpy as np
from enum import Enum
import matplotlib.pyplot as plt


#Agent的行動
class Actions(Enum):
    Sell = 0
    Buy = 1

#在Env裡面所代表的
class Positions(Enum):
    Short = 0
    Long = 1

    def opposite(self):
        return Positions.Short if self == Positions.Long else Positions.Long

    
class TradingEnv(gym.Env):

    metadata = {'render.modes': ['human']}
    
    #__init__為魔法函數，意義為：無論你願不願意，只要你執行TradingEnv，就會把__init__底下的資料執行，可以用作變數定義？
    def __init__(self, df, window_size): 
        assert df.ndim == 2 #判斷所輸入的df維度是否等於2

        self.seed() #隨機種子設定
        self.df = df #輸入df
        self.window_size = window_size #輸入Windows size
        self.open, self.close, self.high, self.low, self.volume, self.signal_features = self._process_data() #輸入【價錢, 特征資料】
        self.shape = (window_size, self.signal_features.shape[1]) #輸入【Windows size, 特征資料的長度】

        # spaces
        self.action_space = spaces.Discrete(len(Actions)) # 行動空間為：2（Sell、Buy）
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=self.shape, dtype=np.float64) #觀察空間最低和最高為無限（因為不知股票價錢為多少）

        # episode
        #「_」為私有化，即import的時候不會引入參數
        self._start_tick = self.window_size #開始日期：Windows_size設定的數字
        self._end_tick = len(self.close)-1 #結束日期：【價錢】的長度-1
        self._done = None 
        self._current_tick = None
        self._last_trade_tick = None
        self._position = None
        self._position_history = None
#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓        
        self._reward_history = []#記錄Reward獎勵，方便畫圖
        self._Total_profit = []#記錄Profit，方便畫圖
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑
        self._total_reward = None
        self._total_profit = None
        self._first_rendering = None
        self.history = None

    #定義一個隨機種子   
    def seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    #重設
    def reset(self):
        self._done = False #尚未完成
        self._current_tick = self._start_tick # Windows_size設定的數字
        self._last_trade_tick = self._current_tick -1 #Windows_size設定的數字-1
        self._position = Positions.Short #第一天交易必定為Short
        self._position_history = (self.window_size * [None]) + [self._position] #記錄位置
        self._total_reward = 0. #初始化的reward為：0
        self._total_profit = 1. #初始化的Profit為：1
        self._first_rendering = True
        self.history = {}
        return self._get_observation()

    #交易中的步驟
    def step(self, action):
        self._done = False #尚未完成動作
        
        
        #如果當前日期 = 完結日期，就結束步驟
        if self._current_tick == self._end_tick:
            self._done = True

#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓
#如果機器人進行買的動作，他的Position就會變成Long，反之亦然
        if(action == Actions.Buy.value):
            self._position = Positions.Long
#             print("action: ", action)
#             print("position: ", self._position)
        elif(action == Actions.Sell.value):
            self._position = Positions.Short
#             print("action: ", action)
#             print("position: ", self._position)
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑               
        self._last_trade_tick = self._current_tick      
        #記錄步驟
        self._position_history.append(self._position)
        
        #獎勵：調用計算獎勵的function，然後將它累積起來計算總和
        step_reward = self._calculate_reward(action)
        step_profit = self._update_profit(action)#記錄profit，方便畫圖
#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓
        self._reward_history.append(step_reward)#記錄Reward獎勵，方便畫圖
        self._Total_profit.append(step_profit)#記錄profit，方便畫圖
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑ 
        self._total_reward += step_reward
        #根據agent的action更新他的 profit
        
        
        observation = self._get_observation()
        info = dict(
            total_reward = self._total_reward,
            total_profit = self._total_profit,
            position = self._position.value
        )
        self._update_history(info)
        
        self._current_tick += 1 #當前日期+1

        return observation, step_reward, self._done, info

    #取得觀察值，觀察值為signal_features
    #若window_size為10
    #則使用0 ~ 9日的觀察值，下一次交易則使用1 ~ 10日的觀察值
    def _get_observation(self):
        return self.signal_features[(self._current_tick-self.window_size+1):self._current_tick+1]

    #更新歷史資料
    def _update_history(self, info):
        if not self.history:
            self.history = {key: [] for key in info.keys()}

        for key, value in info.items():
            self.history[key].append(value)

    #render：將環境實體化，以股票交易為例即是畫圖
    def render(self, mode='human'):
        pass


    #畫圖
#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓    
    def render_Close(self, mode='human'):
            window_ticks = np.arange(len(self._position_history))#[1,2,3,4,5,....]矩陣
            plt.plot(self.close)#根據收盤價進行繪畫

            short_ticks = []
            long_ticks = []
            # i：控制position_history的位置
            # tick：控制要塞進Long還是Short的位置
            #如果機器人在之前就是做Long的話就把它記錄在long_ticks裡面，反之亦然
            for i, tick in enumerate(window_ticks-1):
                if self._position_history[i] == Positions.Short:
                    short_ticks.append(tick)
                elif self._position_history[i] == Positions.Long:
                    long_ticks.append(tick)      

            del(short_ticks[0])

            plt.plot(short_ticks, self.close[short_ticks], 'ro', label = 'Short')#根據收盤價進行畫圖
            plt.plot(long_ticks, self.close[long_ticks], 'go', label = 'Long')#根據收盤價進行畫圖
            
            plt.legend()
            plt.title("Close", fontsize=20)
            plt.suptitle(
                "Total Reward: %.6f" % self._total_reward + ' ~ ' +
                "Total Profit: %.6f" % self._total_profit
            )
            print("↓↓↓ 台積電(2330)在交易當天收盤時進行的交易策略(Long Or Short) ↓↓↓")
        
        
    #畫圖2   
    def render_Reward(self, mode='human'):
        window_ticks = np.arange(len(self._position_history))
        short_ticks = []
        long_ticks = []
        for i, tick in enumerate(window_ticks-1):
            if self._position_history[i] == Positions.Short:
                short_ticks.append(tick)
            elif self._position_history[i] == Positions.Long:
                long_ticks.append(tick)
        
        del(short_ticks[0])
        self._reward_history = np.array(self._reward_history)
        short_ticks = (np.array(short_ticks)-5).tolist()
        long_ticks = (np.array(long_ticks)-5).tolist()
        
        plt.bar(short_ticks,self._reward_history[short_ticks], color='r', label = 'Short')#根據獎勵進行繪畫
        plt.bar(long_ticks,self._reward_history[long_ticks], color='g', label = 'Long')#根據獎勵進行繪畫
            
        plt.legend()   
        plt.title("Reward", fontsize=20)
        plt.suptitle(
            "Total Reward: %.6f" % self._total_reward + ' ~ ' +
            "Total Profit: %.6f" % self._total_profit
        )
        print("↓↓↓ 台積電(2330)在使用交易策略(Long Or Short)後，隔日早上平倉時的盈虧(未含手續費) ↓↓↓")
        
        
    def render_TotalProfit(self, mode='human'):
        window_ticks = np.arange(len(self._position_history))
        
        del self._Total_profit[-1]
        plt.plot(self._Total_profit)
        
        
#         short_ticks = []
#         long_ticks = []
#         for i, tick in enumerate(window_ticks-1):
#             if self._position_history[i] == Positions.Short:
#                 short_ticks.append(tick)
#             elif self._position_history[i] == Positions.Long:
#                 long_ticks.append(tick)
        
#         del(short_ticks[0])
#         self._Total_profit = np.array(self._Total_profit)
#         short_ticks = (np.array(short_ticks)-10).tolist()
#         long_ticks = (np.array(long_ticks)-10).tolist()
        
#         plt.plot(short_ticks, self._Total_profit[short_ticks], 'ro', label = 'Short')#根據獎勵進行畫圖
#         plt.plot(long_ticks, self._Total_profit[long_ticks], 'go', label = 'Long')#根據獎勵進行畫圖
            
#         plt.legend() 

        plt.title("TotalProfit", fontsize=20)
        plt.suptitle(
            "Total Reward: %.6f" % self._total_reward + ' ~ ' +
            "Total Profit: %.6f" % self._total_profit
        )
        print("↓↓↓ 根據預測出的交易策略交易台積電(2330)，所得到的累積利潤(含手續費) ↓↓↓")

        
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑         
        


    
    
    #關閉環境，即關閉畫圖    
    def close(self):
        plt.close()

    #保存圖片
    def save_rendering(self, filepath):
        plt.savefig(filepath)

    #暫停畫圖
    def pause_rendering(self):
        plt.show()

    #在TradingEnv中，為了保持結構完整，因此使用pass不做任何事情
    def _process_data(self):
        pass

    #在TradingEnv中，為了保持結構完整，因此使用pass不做任何事情
    def _calculate_reward(self, action):
        pass

    #在TradingEnv中，為了保持結構完整，因此使用pass不做任何事情
    def _update_profit(self, action):
        pass

    #在TradingEnv中，為了保持結構完整，因此使用pass不做任何事情
    def max_possible_profit(self):  # trade fees are ignored
        pass

# %%
import numpy as np

class StocksEnv(TradingEnv):
    

    def __init__(self, df, window_size, frame_bound):
        assert len(frame_bound) == 2 #判斷所輸入的df維度是否等於2

        self.frame_bound = frame_bound #輸入範圍值
        super().__init__(df, window_size)

        self.trade_fee_percent = 0.001425+0.003
        #https://rich01.com/what-is-next-day-trading/
        
    #資料處理
    def _process_data(self):
        open = self.df.loc[:, 'open'].to_numpy() #prices：開市價
        close = self.df.loc[:, 'close'].to_numpy() #prices：收盤價
        high = self.df.loc[:, 'high'].to_numpy() #prices：最高
        low = self.df.loc[:, 'low'].to_numpy() #prices：最低
        volume = self.df.loc[:, 'volume'].to_numpy() #prices：成交量
        close[self.frame_bound[0] - self.window_size] # validate index (TODO: Improve validation)#驗證資料：10-10
        close = close[self.frame_bound[0]-self.window_size:self.frame_bound[1]]#【10-10:5600】

        diff = np.insert(np.diff(close), 0, 0)#計算價差【今天 - 昨天】
        signal_features = np.column_stack((close, diff))#默認的signal_features為：收盤價，價差

        return open, close ,high, low, volume, signal_features

#↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓↓
    #計算獎勵
    def _calculate_reward(self, action):
        step_reward = 0
        price_diff = 0
        
        if(self._current_tick < self._end_tick):
            if(action == Actions.Buy.value):
                current_price = self.close[self._current_tick]#【今天收盤】
                last_trade_price = self.open[self._current_tick+1]#【明天開盤】
                price_diff = last_trade_price - current_price#【明天開盤 - 今天收盤】

            elif(action == Actions.Sell.value):
                current_price = self.close[self._current_tick]#【今天收盤】
                last_trade_price = self.open[self._current_tick+1]#【明天開盤】
                price_diff = -(last_trade_price - current_price)#【-(明天開盤 - 今天收盤)】
        
        step_reward =  step_reward + price_diff
        
        return step_reward


    def _update_profit(self, action):
        
        long_profit_percentage = 0.0
        short_profit_percentage = 0.0
        Total_long_profit_percentage = 0.0
        Total_short_profit_percentage = 0.0
        
        step_profit = 0
        if(self._current_tick < self._end_tick):
            if(action == Actions.Buy.value):
                current_price = self.close[self._current_tick]#【今天收盤】
                last_trade_price = self.open[self._current_tick+1]#【明天開盤】
                long_profit_percentage = ((last_trade_price - current_price)/current_price) - self.trade_fee_percent
                self._total_profit += long_profit_percentage
            elif(action == Actions.Sell.value):

                current_price = self.close[self._current_tick]#【今天收盤】
                last_trade_price = self.open[self._current_tick+1]#【明天開盤】
                short_profit_percentage = ((-(last_trade_price - current_price)) / current_price) - self.trade_fee_percent
                self._total_profit += short_profit_percentage   
                
        step_profit += self._total_profit #記錄profit，方便畫圖
        return step_profit#記錄profit，方便畫圖
        
#↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑  
                
    #https://github.com/AminHP/gym-anytrading/blob/master/README.ipynb
    #不論交易費用如何，agent在股票交易中所獲得的profit
    def max_possible_profit(self):
        pass

# %%
# import gym_anytrading
import numpy as np
import pandas as pd
import quantstats as qs
from stable_baselines import A2C
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\__init__.py:33: UserWarning: stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation.
#   "stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation."

# %%
from yahoo_fin import stock_info as si
from sklearn.preprocessing import Normalizer
if isinstance('2330.TW', str):
    # load it from yahoo_fin library
    df = si.get_data('2330.TW')
df = df.dropna()#丟棄空值
df = df.reset_index()

#---------------------------------------------------------------------------
#定義參數

open = df['open']
close = df['close']
high = df['high']
low = df['low']
UpLine_max = []
UpLine = [] #上引線
DownLine_min = []
DownLine = [] #下引線
UpMean = []#計算RSI——上漲平均5天
DownMean = []#計算RSI——下跌平均5天
RSI = []#計算RSI
#---------------------------------------------------------------------------
#上引線；下引線

for i in range(close.size):
    UpLine_max.append(max(open[i], close[i]))
for i in range(close.size):
    UpLine.append(high[i] - UpLine_max[i])#上影線
for i in range(close.size):
    DownLine_min.append(min(open[i], close[i]))
for i in range(close.size):
    DownLine.append(DownLine_min[i] - low[i])#下影線
#---------------------------------------------------------------------------
#RSI

UpDownValue = close - close.shift(1) #計算漲跌值
Only_UpValue = pd.Series(index=UpDownValue.index, data=UpDownValue[UpDownValue>0])#將上漲日子篩出
Only_UpValue = Only_UpValue.fillna(0)#下跌的日子為0
Only_DownValue = pd.Series(index=UpDownValue.index, data=-UpDownValue[UpDownValue<0])#將下跌日子篩出
Only_DownValue = Only_DownValue.fillna(0)#上漲的日子為0
for i in range(13, len(Only_UpValue)+1):#由第六日開始，直到現在
    UpMean.append(np.mean(Only_UpValue.values[i-12:i]))#計算出最近五日的平均，因為有補0，所以可以計算出。
    DownMean.append(np.mean(Only_DownValue.values[i-12:i]))#計算出最近五日的平均
for i in range(len(UpMean)):
    RSI.append( (UpMean[i] / ( UpMean[i] + DownMean[i] )) * 100  )#計算RSI
RSI = pd.Series(index = close.index[12:], data = RSI) #轉換格式
#---------------------------------------------------------------------------
#FH；FL
FH = ((high - open) / open) #FH
FL = ((open - low) / open) #FL
FH = pd.DataFrame(FH, columns=['FH'])#FH參數
FL = pd.DataFrame(FL, columns=['FL'])#FL參數
#---------------------------------------------------------------------------
# KD
K = []
D = []
K_Value = []
D_Value = []
def RSV(df):
    df['MinLow'] = df['low'].rolling(9, min_periods=9).min()#9天最低位
    df['MinLow'].fillna(value = df['low'].expanding().min(), inplace = True)#填滿NA
    df['MaxHigh'] = df['high'].rolling(9, min_periods=9).max()#9天最高位
    df['MaxHigh'].fillna(value = df['high'].expanding().max(), inplace = True)#填滿NA
    df['RSV'] = (df['close'] - df['MinLow']) / (df['MaxHigh'] - df['MinLow']) * 100 #計算RSV
    return df
RSV_df = RSV(df)#使用RSV函數計算
RSV = RSV_df['RSV']#獲得RSV
for i in range(len(RSV)):
    if i<=9 :
        K.append(50)
        D.append(50)
    elif i > 9:
        K.append((K[i-1] * 2/3) + (1/3 * RSV[i]))
        D.append((D[i-1] * 2/3) + (1/3 * K[i]))
K_Value = pd.Series(index = close.index[0:], data = K) #轉換格式
D_Value = pd.Series(index = close.index[0:], data = D) #轉換格式
#---------------------------------------------------------------------------
# MACD
DIF = []
MACD = []
ShortEMA=close.ewm(span=12,adjust=False).mean()#12日移動平均
LongEMA=close.ewm(span=26,adjust=False).mean()#26日移動平均
FastLine_DIF=ShortEMA-LongEMA#DIF = （12日移動平均 - 26日移動平均）
SlowLine_MACD=FastLine_DIF.ewm(span=9,adjust=False).mean()#取DIF數值得到9日移動平均
FastLine_DIF = pd.DataFrame(FastLine_DIF)#轉換格式
SlowLine_MACD = pd.DataFrame(SlowLine_MACD)#轉換格式
FastLine_DIF = FastLine_DIF.rename(columns={'close':'DIF'})#轉換格式
SlowLine_MACD = SlowLine_MACD.rename(columns={'close':'MACD'})#轉換格式
#---------------------------------------------------------------------------                                                             
#BBands
def BBands(df,Day=20,Times=2):#20天平均, 2倍標準差
    Up_Track=pd.Series(0.0,index=df.index)#建立全0的陣列
    Mid_Track=pd.Series(0.0,index=df.index)#建立全0的陣列
    Down_Track=pd.Series(0.0,index=df.index)#建立全0的陣列
    SD=pd.Series(0.0,index=df.index)#建立全0的陣列
    
    for i in range(Day-1,len(df)):#19~5600   
        Mid_Track[i]=np.mean(df[i-(Day-1):(i+1)])#中軌 = 0-20平均 -> 1-21平均 -> 2-22平均...（移動平均線）
        SD[i]=np.std(df[i-(Day-1):(i+1)])#0-20標準差 -> 1-21標準差 ->2-22標準差...（標準差）
        Up_Track[i]=Mid_Track[i]+(Times*SD[i])#上軌 = 中軌+（2倍標準差）
        Down_Track[i]=Mid_Track[i]-(Times*SD[i])#下軌 = 中軌-（2倍標準差）
        
        #慢慢地將上半部分建立的全0函式更新
        df_BBands=pd.DataFrame({'Up_Track':Up_Track[(Day-1):],#由第19日開始載入布林通道（上）
                             'Mid_Track':Mid_Track[(Day-1):],#由第19日開始載入布林通道（中）
                             'Down_Track':Down_Track[(Day-1):]#由第19日開始載入布林通道（下）
                            })
    return(df_BBands)
BBands_Up_Mid_Down_Trak = BBands(close, 20, 2)
#---------------------------------------------------------------------------
#合拼df
df2330 = pd.merge(df, FH,left_index=True,right_index=True) #合拼FH
df2330 = pd.merge(df2330, FL,left_index=True,right_index=True) #合拼FL
df2330 = pd.merge(df2330, pd.DataFrame(UpLine, columns=['UpLine']),left_index=True,right_index=True) #合併上影線
df2330 = pd.merge(df2330, pd.DataFrame(DownLine, columns=['DownLine']),left_index=True,right_index=True) #合併下影線
df2330 = pd.merge(df2330, pd.DataFrame(RSI, columns=['RSI']),left_index=True,right_index=True) #合併RSI
df2330 = pd.merge(df2330, pd.DataFrame(K_Value, columns=['K_Value']),left_index=True,right_index=True) #合併K值
df2330 = pd.merge(df2330, pd.DataFrame(D_Value, columns=['D_Value']),left_index=True,right_index=True) #合併D值
df2330 = pd.merge(df2330, pd.DataFrame(FastLine_DIF),left_index=True,right_index=True) #合併DIF
df2330 = pd.merge(df2330, pd.DataFrame(SlowLine_MACD),left_index=True,right_index=True) #合併MACD
df2330 = pd.merge(df2330,BBands_Up_Mid_Down_Trak,left_index=True,right_index=True) #合併布林通道
df2330.index = range(len(df2330))#更新index

# %% [markdown]
# # 是否將特徵資料標準化？

# %%
#---------------------------------------------------------------------------
normalizer = Normalizer()#創建標準化函數
df2330_AllFeatures = df2330[['MinLow','MaxHigh','RSV','FH','FL','UpLine','DownLine','RSI','K_Value','D_Value','DIF','MACD','Up_Track','Mid_Track','Down_Track']]#取得需要標準化的特徵
df2330_FeaturesNormalize = normalizer.fit_transform(df2330_AllFeatures)#進行標準化
df2330_FeaturesNormalize = pd.DataFrame(df2330_FeaturesNormalize)#將array變成df
df2330_FeaturesNormalize = df2330_FeaturesNormalize.rename(columns={0:'MinLow',1:'MaxHigh',2:'RSV',
                                                      3:'FH',4:'FL',
                                                      5:'UpLine',6:'DownLine',
                                                      7:'RSI',
                                                      8:'K_Value',9:'D_Value',
                                                      10:'DIF',11:'MACD',
                                                      12:'Up_Track',13:'Mid_Track',14:'Down_Track'})#更改名字
df2330_OriginData = df2330[['index','open','high','low','close','adjclose','volume','ticker']]#取得市場基本資料
df2330_Normalized = pd.merge(df2330_OriginData, df2330_FeaturesNormalize, left_index=True,right_index=True) #基本資料與標準化後特徵資料合併
df2330 = df2330_Normalized
#---------------------------------------------------------------------------

#---------------------------------------------------------------------------
#輸出最終Dataframe
df2330
# Out:
#           index        open        high         low       close    adjclose  \
# 0    2000-01-31   77.474449   79.822517   77.083290   79.430984   40.596725
# 1    2000-02-01   80.213676   80.213676   78.648293   79.039825   40.396801
# 2    2000-02-02   79.039825   79.039825   79.039825   79.039825   40.396801
# 3    2000-02-03   79.039825   79.039825   79.039825   79.039825   40.396801
# 4    2000-02-04   79.039825   79.039825   79.039825   79.039825   40.396801
# ...         ...         ...         ...         ...         ...         ...
# 5646 2022-09-08  473.000000  475.000000  472.000000  475.000000  472.278656
# 5647 2022-09-12  485.000000  491.000000  485.000000  486.500000  483.712769
# 5648 2022-09-13  495.000000  495.000000  491.000000  493.000000  490.175537
# 5649 2022-09-14  478.500000  482.500000  476.000000  480.000000  477.250000
# 5650 2022-09-15  476.000000  480.000000  476.000000  479.000000  479.000000
#
#             volume   ticker    MinLow   MaxHigh  ...    UpLine  DownLine  \
# 0     1.680593e+11  2330.TW  0.309921  0.361288  ...  0.001713  0.001712
# 1     1.530819e+11  2330.TW  0.314672  0.366827  ...  0.000000  0.001740
# 2     0.000000e+00  2330.TW  0.319760  0.370711  ...  0.000000  0.000000
# 3     0.000000e+00  2330.TW  0.329770  0.372094  ...  0.000000  0.000000
# 4     0.000000e+00  2330.TW  0.339458  0.376977  ...  0.000000  0.000000
# ...            ...      ...       ...       ...  ...       ...       ...
# 5646  2.793155e+07  2330.TW  0.423638  0.453257  ...  0.000000  0.000898
# 5647  2.159721e+07  2330.TW  0.423915  0.453553  ...  0.004042  0.000000
# 5648  1.650704e+07  2330.TW  0.424165  0.453820  ...  0.000000  0.001797
# 5649  2.264571e+07  2330.TW  0.427568  0.448856  ...  0.002265  0.002265
# 5650  1.300420e+07  2330.TW  0.428930  0.449831  ...  0.000909  0.000000
#
#            RSI   K_Value   D_Value       DIF      MACD  Up_Track  Mid_Track  \
# 0     0.340351  0.351078  0.349870  0.011103  0.006873  0.354890   0.319509
# 1     0.327941  0.341312  0.350593  0.011484  0.007879  0.363530   0.326493
# 2     0.315521  0.333172  0.347261  0.011640  0.008698  0.370338   0.331708
# 3     0.344641  0.316836  0.337983  0.011578  0.009300  0.374065   0.335061
# 4     0.349164  0.300968  0.328601  0.011512  0.009840  0.380023   0.342048
# ...        ...       ...       ...       ...       ...       ...        ...
# 5646  0.028192  0.007732  0.010367 -0.005827 -0.002053  0.480573   0.451798
# 5647  0.036534  0.018312  0.013020 -0.005704 -0.002784  0.479664   0.450724
# 5648  0.037444  0.031278  0.019111 -0.005078 -0.003244  0.477420   0.449642
# 5649  0.030653  0.031298  0.023276 -0.005502 -0.003717  0.478336   0.451212
# 5650  0.035194  0.030151  0.025617 -0.005831 -0.004149  0.475838   0.450467
#
#       Down_Track
# 0       0.284129
# 1       0.289457
# 2       0.293078
# 3       0.296056
# 4       0.304073
# ...          ...
# 5646    0.423024
# 5647    0.421784
# 5648    0.421863
# 5649    0.424088
# 5650    0.425096
#
# [5651 rows x 23 columns]

# %% [markdown]
# # 查找DF的標籤

# %%
dfStartDate_Train = df2330[(df2330['index']=='2007-01-02')].index.values
dfStartDate_Train = dfStartDate_Train[0]
dfStartDate_Train
# Out:
# 1793

# %%
dfEndDate_Train = df2330[(df2330['index']=='2022-06-30')].index.values
dfEndDate_Train = dfEndDate_Train[0]
dfEndDate_Train
# Out:
# 5596

# %%
df2330[dfStartDate_Train:dfEndDate_Train+1]
# Out:
#           index        open        high         low       close    adjclose  \
# 1793 2007-01-02   66.790359   66.987381   66.297806   66.691849   37.359818
# 1794 2007-01-03   66.790359   67.676956   66.494827   66.987381   37.525372
# 1795 2007-01-04   66.691849   67.085892   66.593338   66.691849   37.359818
# 1796 2007-01-05   66.494827   66.691849   65.509720   65.903763   36.918346
# 1797 2007-01-08   65.115677   65.509720   64.721634   64.820145   36.311317
# ...         ...         ...         ...         ...         ...         ...
# 5592 2022-06-24  489.500000  492.500000  485.500000  486.500000  483.712769
# 5593 2022-06-27  496.000000  506.000000  495.500000  498.500000  495.644012
# 5594 2022-06-28  496.000000  500.000000  496.000000  497.500000  494.649750
# 5595 2022-06-29  496.000000  498.500000  491.000000  491.000000  488.186981
# 5596 2022-06-30  484.500000  486.500000  476.000000  476.000000  473.272919
#
#           volume   ticker    MinLow   MaxHigh  ...    UpLine  DownLine  \
# 1793  26292533.0  2330.TW  0.298317  0.314018  ...  0.000924  0.001847
# 1794  42463339.0  2330.TW  0.302538  0.320747  ...  0.003268  0.001401
# 1795  22444226.0  2330.TW  0.312725  0.331035  ...  0.001927  0.000482
# 1796  30905222.0  2330.TW  0.326070  0.345162  ...  0.001005  0.002010
# 1797  24350615.0  2330.TW  0.355820  0.376074  ...  0.002190  0.000547
# ...          ...      ...       ...       ...  ...       ...       ...
# 5592  27911980.0  2330.TW  0.421797  0.448757  ...  0.002609  0.000870
# 5593  37909718.0  2330.TW  0.422116  0.449096  ...  0.006528  0.000435
# 5594  15274062.0  2330.TW  0.423326  0.450384  ...  0.002182  0.000000
# 5595  30533789.0  2330.TW  0.426897  0.445382  ...  0.002201  0.000000
# 5596  46311432.0  2330.TW  0.422485  0.449112  ...  0.001775  0.000000
#
#            RSI   K_Value   D_Value       DIF      MACD  Up_Track  Mid_Track  \
# 1793  0.330271  0.375104  0.318968  0.003697  0.003264  0.314696   0.304389
# 1794  0.325475  0.382450  0.342472  0.004142  0.003468  0.319093   0.308001
# 1795  0.283559  0.383284  0.363400  0.004437  0.003751  0.329130   0.317832
# 1796  0.329041  0.355903  0.371239  0.004386  0.004006  0.343108   0.331370
# 1797  0.317538  0.298569  0.369181  0.004038  0.004299  0.373754   0.360966
# ...        ...       ...       ...       ...       ...       ...        ...
# 5592  0.009466  0.004935  0.007676 -0.010773 -0.007574  0.491998   0.453649
# 5593  0.021099  0.015926  0.010430 -0.010414 -0.008147  0.491810   0.452621
# 5594  0.024078  0.022380  0.014433 -0.010106 -0.008557  0.490394   0.451758
# 5595  0.027083  0.023429  0.017513 -0.010265 -0.008956  0.488750   0.452533
# 5596  0.023054  0.015750  0.017023 -0.011353 -0.009496  0.489541   0.453084
#
#       Down_Track
# 1793    0.294083
# 1794    0.296909
# 1795    0.306534
# 1796    0.319633
# 1797    0.348177
# ...          ...
# 5592    0.415300
# 5593    0.413433
# 5594    0.413123
# 5595    0.416316
# 5596    0.416627
#
# [3804 rows x 23 columns]

# %%
def my_process_data(df, window_size, frame_bound):
    start = frame_bound[0] - window_size #start = 5 - 5
    end = frame_bound[1] #end = 5600 
    close = df.loc[:, 'close'].to_numpy()[start:end]#抓取Close
    open = df.loc[:, 'open'].to_numpy()[start:end]#抓取open
    high = df.loc[:, 'high'].to_numpy()[start:end]#抓取high
    low = df.loc[:, 'low'].to_numpy()[start:end]#抓取low
    volnume = df.loc[:, 'volume'].to_numpy()[start:end]#抓取volume
    signal_features = df.loc[:, ['RSI']].to_numpy()[start:end]#抓取特徵資料
    return open, close, high, low, volnume, signal_features


class MyStocksEnv(StocksEnv):
    
    def __init__(self, open, close, high, low, volnume, signal_features, **kwargs):
        self._open = open
        self._close = close
        self._high = high
        self._low = low
        self._volnume = volnume
        self._signal_features = signal_features
        super().__init__(**kwargs)

    def _process_data(self):
        return self._open, self._close, self._high, self._low, self._volnume, self._signal_features

    
open, close, high, low, volume, signal_features = my_process_data(df=df2330, window_size=5, frame_bound=(dfStartDate_Train, dfEndDate_Train+1))#Close與特徵資料
env = MyStocksEnv(open, close, high, low, volume, signal_features, df=df2330, window_size=5, frame_bound=(dfStartDate_Train, dfEndDate_Train+1))#「環境」整合

# %%
policy_kwargs = dict(net_arch=[256, 'lstm', dict(vf=[128], pi=[128])])#要傳遞給policy的參數

model = A2C('MlpLstmPolicy', env, verbose=1, policy_kwargs=policy_kwargs, gamma=0.1, learning_rate=0.0000001)
# model = A2C('MlpLstmPolicy', env, verbose=1)
#policy: The policy model to use (MlpPolicy, CnnPolicy, …)""
#verbose: 0 no output, 1 info, 2 debug
#policy_kwargs: additional arguments to be passed to the policy on creation要傳遞給policy的參數
model.learn(total_timesteps=1000000)
# Out:
# Wrapping the env in a DummyVecEnv.
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\policies.py:442: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From C:\Users\cherr\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\layers\core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:160: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\common\tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From C:\Users\cherr\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\ops\clip_ops.py:301: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:184: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From C:\Users\cherr\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\training\rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:194: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From C:\Users\cherr\.conda\envs\Python37TensorFlow20V2\lib\site-packages\stable_baselines\a2c\a2c.py:196: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# ---------------------------------
# | explained_variance | 0.0124   |
# | fps                | 1        |
# | nupdates           | 1        |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 5        |
# | value_loss         | 0.151    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000314 |
# | fps                | 51       |
# | nupdates           | 100      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 500      |
# | value_loss         | 5.63     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00855 |
# | fps                | 61       |
# | nupdates           | 200      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 1000     |
# | value_loss         | 0.208    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000628 |
# | fps                | 67       |
# | nupdates           | 300      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 1500     |
# | value_loss         | 1.2      |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000631 |
# | fps                | 69        |
# | nupdates           | 400       |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 2000      |
# | value_loss         | 2.02      |
# ----------------------------------
# ---------------------------------
# | explained_variance | -0.00181 |
# | fps                | 70       |
# | nupdates           | 500      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 2500     |
# | value_loss         | 0.514    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 3.82e-05 |
# | fps                | 70       |
# | nupdates           | 600      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 3000     |
# | value_loss         | 5.15     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.34e-05 |
# | fps                | 70        |
# | nupdates           | 700       |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 3500      |
# | value_loss         | 65.4      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.000939 |
# | fps                | 70       |
# | nupdates           | 800      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 4000     |
# | value_loss         | 0.798    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00585 |
# | fps                | 69       |
# | nupdates           | 900      |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 4500     |
# | value_loss         | 0.0961   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000249 |
# | fps                | 68       |
# | nupdates           | 1000     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 5000     |
# | value_loss         | 0.564    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000858 |
# | fps                | 68        |
# | nupdates           | 1100      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 5500      |
# | value_loss         | 1.48      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.000677 |
# | fps                | 68       |
# | nupdates           | 1200     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 6000     |
# | value_loss         | 3.7      |
# ---------------------------------
# ----------------------------------
# | explained_variance | -4.82e-05 |
# | fps                | 68        |
# | nupdates           | 1300      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 6500      |
# | value_loss         | 3.95      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.000293 |
# | fps                | 68       |
# | nupdates           | 1400     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 7000     |
# | value_loss         | 0.863    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.35e-05 |
# | fps                | 68        |
# | nupdates           | 1500      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 7500      |
# | value_loss         | 47.7      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.00119  |
# | fps                | 68       |
# | nupdates           | 1600     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 8000     |
# | value_loss         | 0.84     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00248  |
# | fps                | 68       |
# | nupdates           | 1700     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 8500     |
# | value_loss         | 0.2      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00148  |
# | fps                | 68       |
# | nupdates           | 1800     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 9000     |
# | value_loss         | 0.77     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -7.02e-05 |
# | fps                | 68        |
# | nupdates           | 1900      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 9500      |
# | value_loss         | 0.23      |
# ----------------------------------
# ----------------------------------
# | explained_variance | -0.000119 |
# | fps                | 69        |
# | nupdates           | 2000      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 10000     |
# | value_loss         | 4.18      |
# ----------------------------------
# ----------------------------------
# | explained_variance | -0.000656 |
# | fps                | 69        |
# | nupdates           | 2100      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 10500     |
# | value_loss         | 3.22      |
# ----------------------------------
# ---------------------------------
# | explained_variance | -0.00032 |
# | fps                | 69       |
# | nupdates           | 2200     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 11000    |
# | value_loss         | 8.61     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0013   |
# | fps                | 69       |
# | nupdates           | 2300     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 11500    |
# | value_loss         | 0.336    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000878 |
# | fps                | 69        |
# | nupdates           | 2400      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 12000     |
# | value_loss         | 8.44      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.000742 |
# | fps                | 68       |
# | nupdates           | 2500     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 12500    |
# | value_loss         | 0.188    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000788 |
# | fps                | 69        |
# | nupdates           | 2600      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 13000     |
# | value_loss         | 1.65      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.000534 |
# | fps                | 68       |
# | nupdates           | 2700     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 13500    |
# | value_loss         | 0.324    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 7.95e-05 |
# | fps                | 68       |
# | nupdates           | 2800     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 14000    |
# | value_loss         | 3.29     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000444 |
# | fps                | 68       |
# | nupdates           | 2900     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 14500    |
# | value_loss         | 11.1     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000231 |
# | fps                | 68       |
# | nupdates           | 3000     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 15000    |
# | value_loss         | 1.5      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00184 |
# | fps                | 68       |
# | nupdates           | 3100     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 15500    |
# | value_loss         | 0.963    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -8.67e-05 |
# | fps                | 68        |
# | nupdates           | 3200      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 16000     |
# | value_loss         | 0.12      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.000566 |
# | fps                | 68       |
# | nupdates           | 3300     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 16500    |
# | value_loss         | 0.374    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000105 |
# | fps                | 68        |
# | nupdates           | 3400      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 17000     |
# | value_loss         | 2.62      |
# ----------------------------------
# ----------------------------------
# | explained_variance | -0.000394 |
# | fps                | 68        |
# | nupdates           | 3500      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 17500     |
# | value_loss         | 2.61      |
# ----------------------------------
# ----------------------------------
# | explained_variance | -9.99e-05 |
# | fps                | 68        |
# | nupdates           | 3600      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 18000     |
# | value_loss         | 61.4      |
# ----------------------------------
# ----------------------------------
# | explained_variance | -4.41e-06 |
# | fps                | 68        |
# | nupdates           | 3700      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 18500     |
# | value_loss         | 12.1      |
# ----------------------------------
# ----------------------------------
# | explained_variance | -1.19e-06 |
# | fps                | 68        |
# | nupdates           | 3800      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 19000     |
# | value_loss         | 68.4      |
# ----------------------------------
# ----------------------------------
# | explained_variance | -0.000201 |
# | fps                | 68        |
# | nupdates           | 3900      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 19500     |
# | value_loss         | 6.53      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.00333  |
# | fps                | 68       |
# | nupdates           | 4000     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 20000    |
# | value_loss         | 0.315    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000519 |
# | fps                | 68       |
# | nupdates           | 4100     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 20500    |
# | value_loss         | 1.72     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00106  |
# | fps                | 68       |
# | nupdates           | 4200     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 21000    |
# | value_loss         | 0.513    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000348 |
# | fps                | 68       |
# | nupdates           | 4300     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 21500    |
# | value_loss         | 3.99     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000183 |
# | fps                | 68       |
# | nupdates           | 4400     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 22000    |
# | value_loss         | 23.8     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.79e-06 |
# | fps                | 68        |
# | nupdates           | 4500      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 22500     |
# | value_loss         | 207       |
# ----------------------------------
# ---------------------------------
# | explained_variance | -0.00279 |
# | fps                | 68       |
# | nupdates           | 4600     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 23000    |
# | value_loss         | 0.558    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00193 |
# | fps                | 68       |
# | nupdates           | 4700     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 23500    |
# | value_loss         | 0.415    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000484 |
# | fps                | 68        |
# | nupdates           | 4800      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 24000     |
# | value_loss         | 0.801     |
# ----------------------------------
# ----------------------------------
# | explained_variance | -0.000148 |
# | fps                | 68        |
# | nupdates           | 4900      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 24500     |
# | value_loss         | 0.726     |
# ----------------------------------
# ----------------------------------
# | explained_variance | -0.000254 |
# | fps                | 68        |
# | nupdates           | 5000      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 25000     |
# | value_loss         | 1.66      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.000161 |
# | fps                | 68       |
# | nupdates           | 5100     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 25500    |
# | value_loss         | 5.72     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 7.67e-05 |
# | fps                | 68       |
# | nupdates           | 5200     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 26000    |
# | value_loss         | 2.32     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -5.96e-07 |
# | fps                | 68        |
# | nupdates           | 5300      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 26500     |
# | value_loss         | 12.1      |
# ----------------------------------
# ----------------------------------
# | explained_variance | -0.000378 |
# | fps                | 68        |
# | nupdates           | 5400      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 27000     |
# | value_loss         | 0.432     |
# ----------------------------------
# ---------------------------------
# | explained_variance | -0.00622 |
# | fps                | 68       |
# | nupdates           | 5500     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 27500    |
# | value_loss         | 0.138    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000271 |
# | fps                | 68       |
# | nupdates           | 5600     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 28000    |
# | value_loss         | 1.15     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00284  |
# | fps                | 68       |
# | nupdates           | 5700     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 28500    |
# | value_loss         | 0.563    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00071  |
# | fps                | 68       |
# | nupdates           | 5800     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 29000    |
# | value_loss         | 2.18     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000208 |
# | fps                | 68       |
# | nupdates           | 5900     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 29500    |
# | value_loss         | 7.03     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.39e-05 |
# | fps                | 68       |
# | nupdates           | 6000     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 30000    |
# | value_loss         | 54.8     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000652 |
# | fps                | 68        |
# | nupdates           | 6100      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 30500     |
# | value_loss         | 0.312     |
# ----------------------------------
# ---------------------------------
# | explained_variance | -0.00031 |
# | fps                | 68       |
# | nupdates           | 6200     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 31000    |
# | value_loss         | 9.05     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0023  |
# | fps                | 68       |
# | nupdates           | 6300     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 31500    |
# | value_loss         | 0.846    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000243 |
# | fps                | 68       |
# | nupdates           | 6400     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 32000    |
# | value_loss         | 1.19     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000656 |
# | fps                | 68        |
# | nupdates           | 6500      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 32500     |
# | value_loss         | 0.5       |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.000862 |
# | fps                | 68       |
# | nupdates           | 6600     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 33000    |
# | value_loss         | 2.14     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.9e-05 |
# | fps                | 68       |
# | nupdates           | 6700     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 33500    |
# | value_loss         | 23.2     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -8.17e-05 |
# | fps                | 68        |
# | nupdates           | 6800      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 34000     |
# | value_loss         | 57.3      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.000296 |
# | fps                | 68       |
# | nupdates           | 6900     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 34500    |
# | value_loss         | 3.19     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00246  |
# | fps                | 68       |
# | nupdates           | 7000     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 35000    |
# | value_loss         | 0.361    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000585 |
# | fps                | 68        |
# | nupdates           | 7100      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 35500     |
# | value_loss         | 0.138     |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.000607 |
# | fps                | 68       |
# | nupdates           | 7200     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 36000    |
# | value_loss         | 0.578    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000389 |
# | fps                | 68       |
# | nupdates           | 7300     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 36500    |
# | value_loss         | 1.29     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 3.42e-05 |
# | fps                | 68       |
# | nupdates           | 7400     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 37000    |
# | value_loss         | 12.6     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000358 |
# | fps                | 68       |
# | nupdates           | 7500     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 37500    |
# | value_loss         | 8.22     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -3.81e-06 |
# | fps                | 68        |
# | nupdates           | 7600      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 38000     |
# | value_loss         | 73.9      |
# ----------------------------------
# ----------------------------------
# | explained_variance | -4.99e-05 |
# | fps                | 68        |
# | nupdates           | 7700      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 38500     |
# | value_loss         | 6.82      |
# ----------------------------------
# ---------------------------------
# | explained_variance | -0.00101 |
# | fps                | 68       |
# | nupdates           | 7800     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 39000    |
# | value_loss         | 0.209    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00131 |
# | fps                | 68       |
# | nupdates           | 7900     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 39500    |
# | value_loss         | 0.284    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 4.81e-05 |
# | fps                | 68       |
# | nupdates           | 8000     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 40000    |
# | value_loss         | 1.67     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 7.17e-05 |
# | fps                | 68       |
# | nupdates           | 8100     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 40500    |
# | value_loss         | 2.61     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1e-05    |
# | fps                | 68       |
# | nupdates           | 8200     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 41000    |
# | value_loss         | 15       |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.06e-05 |
# | fps                | 68        |
# | nupdates           | 8300      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 41500     |
# | value_loss         | 145       |
# ----------------------------------
# ---------------------------------
# | explained_variance | -0.00065 |
# | fps                | 68       |
# | nupdates           | 8400     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 42000    |
# | value_loss         | 0.775    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0041   |
# | fps                | 68       |
# | nupdates           | 8500     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 42500    |
# | value_loss         | 0.14     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00467 |
# | fps                | 68       |
# | nupdates           | 8600     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 43000    |
# | value_loss         | 0.448    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00169  |
# | fps                | 68       |
# | nupdates           | 8700     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 43500    |
# | value_loss         | 1.08     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 3.3e-05  |
# | fps                | 68       |
# | nupdates           | 8800     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 44000    |
# | value_loss         | 1.97     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0002  |
# | fps                | 68       |
# | nupdates           | 8900     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 44500    |
# | value_loss         | 1.95     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000204 |
# | fps                | 68        |
# | nupdates           | 9000      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 45000     |
# | value_loss         | 2.13      |
# ----------------------------------
# ----------------------------------
# | explained_variance | -5.22e-05 |
# | fps                | 68        |
# | nupdates           | 9100      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 45500     |
# | value_loss         | 18.5      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.000363 |
# | fps                | 68       |
# | nupdates           | 9200     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 46000    |
# | value_loss         | 0.838    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000547 |
# | fps                | 68        |
# | nupdates           | 9300      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 46500     |
# | value_loss         | 0.574     |
# ----------------------------------
# ----------------------------------
# | explained_variance | -9.58e-05 |
# | fps                | 68        |
# | nupdates           | 9400      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 47000     |
# | value_loss         | 1.08      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.00108  |
# | fps                | 68       |
# | nupdates           | 9500     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 47500    |
# | value_loss         | 0.829    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000119 |
# | fps                | 68       |
# | nupdates           | 9600     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 48000    |
# | value_loss         | 7.44     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -6.95e-05 |
# | fps                | 68        |
# | nupdates           | 9700      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 48500     |
# | value_loss         | 1.16      |
# ----------------------------------
# ----------------------------------
# | explained_variance | -0.000142 |
# | fps                | 68        |
# | nupdates           | 9800      |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 49000     |
# | value_loss         | 16        |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.00339  |
# | fps                | 68       |
# | nupdates           | 9900     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 49500    |
# | value_loss         | 0.15     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000126 |
# | fps                | 68        |
# | nupdates           | 10000     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 50000     |
# | value_loss         | 7.69      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 7.23e-05 |
# | fps                | 68       |
# | nupdates           | 10100    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 50500    |
# | value_loss         | 0.345    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.65e-05 |
# | fps                | 68       |
# | nupdates           | 10200    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 51000    |
# | value_loss         | 1.05     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 8.52e-05 |
# | fps                | 68       |
# | nupdates           | 10300    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 51500    |
# | value_loss         | 4.12     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000112 |
# | fps                | 68        |
# | nupdates           | 10400     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 52000     |
# | value_loss         | 4.1       |
# ----------------------------------
# ---------------------------------
# | explained_variance | 3.16e-06 |
# | fps                | 68       |
# | nupdates           | 10500    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 52500    |
# | value_loss         | 9.73     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.62e-05 |
# | fps                | 68       |
# | nupdates           | 10600    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 53000    |
# | value_loss         | 12       |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00223 |
# | fps                | 68       |
# | nupdates           | 10700    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 53500    |
# | value_loss         | 1.58     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000609 |
# | fps                | 68        |
# | nupdates           | 10800     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 54000     |
# | value_loss         | 0.105     |
# ----------------------------------
# ---------------------------------
# | explained_variance | -0.00012 |
# | fps                | 68       |
# | nupdates           | 10900    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 54500    |
# | value_loss         | 21.7     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000977 |
# | fps                | 68       |
# | nupdates           | 11000    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 55000    |
# | value_loss         | 0.609    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000428 |
# | fps                | 68        |
# | nupdates           | 11100     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 55500     |
# | value_loss         | 2.88      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.000199 |
# | fps                | 68       |
# | nupdates           | 11200    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 56000    |
# | value_loss         | 29.9     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.19e-06 |
# | fps                | 68        |
# | nupdates           | 11300     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 56500     |
# | value_loss         | 117       |
# ----------------------------------
# ---------------------------------
# | explained_variance | -1.6e-05 |
# | fps                | 68       |
# | nupdates           | 11400    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 57000    |
# | value_loss         | 69.5     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00169 |
# | fps                | 68       |
# | nupdates           | 11500    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 57500    |
# | value_loss         | 9.03     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00263  |
# | fps                | 68       |
# | nupdates           | 11600    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 58000    |
# | value_loss         | 0.128    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000983 |
# | fps                | 68        |
# | nupdates           | 11700     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 58500     |
# | value_loss         | 0.944     |
# ----------------------------------
# ---------------------------------
# | explained_variance | -0.00116 |
# | fps                | 68       |
# | nupdates           | 11800    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 59000    |
# | value_loss         | 0.805    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 2.53e-05 |
# | fps                | 68       |
# | nupdates           | 11900    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 59500    |
# | value_loss         | 1.12     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -8.88e-05 |
# | fps                | 68        |
# | nupdates           | 12000     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 60000     |
# | value_loss         | 24.4      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 6.05e-05 |
# | fps                | 68       |
# | nupdates           | 12100    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 60500    |
# | value_loss         | 8.42     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00119 |
# | fps                | 68       |
# | nupdates           | 12200    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 61000    |
# | value_loss         | 2.58     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000761 |
# | fps                | 68       |
# | nupdates           | 12300    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 61500    |
# | value_loss         | 1.13     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000527 |
# | fps                | 68        |
# | nupdates           | 12400     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 62000     |
# | value_loss         | 3.67      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.00164  |
# | fps                | 68       |
# | nupdates           | 12500    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 62500    |
# | value_loss         | 3.26     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 4.92e-05 |
# | fps                | 69       |
# | nupdates           | 12600    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 63000    |
# | value_loss         | 4.88     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -3.6e-05 |
# | fps                | 69       |
# | nupdates           | 12700    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 63500    |
# | value_loss         | 0.949    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 5.59e-05 |
# | fps                | 69       |
# | nupdates           | 12800    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 64000    |
# | value_loss         | 5.46     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 5.6e-06  |
# | fps                | 69       |
# | nupdates           | 12900    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 64500    |
# | value_loss         | 88.4     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000299 |
# | fps                | 69       |
# | nupdates           | 13000    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 65000    |
# | value_loss         | 0.141    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00332 |
# | fps                | 69       |
# | nupdates           | 13100    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 65500    |
# | value_loss         | 0.319    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00271 |
# | fps                | 69       |
# | nupdates           | 13200    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 66000    |
# | value_loss         | 0.814    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00385 |
# | fps                | 69       |
# | nupdates           | 13300    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 66500    |
# | value_loss         | 0.408    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000114 |
# | fps                | 69        |
# | nupdates           | 13400     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 67000     |
# | value_loss         | 5.54      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.000132 |
# | fps                | 69       |
# | nupdates           | 13500    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 67500    |
# | value_loss         | 3.08     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -4.55e-05 |
# | fps                | 69        |
# | nupdates           | 13600     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 68000     |
# | value_loss         | 25.8      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.00625  |
# | fps                | 69       |
# | nupdates           | 13700    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 68500    |
# | value_loss         | 0.0703   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 9.96e-05 |
# | fps                | 69       |
# | nupdates           | 13800    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 69000    |
# | value_loss         | 9.56     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000664 |
# | fps                | 69       |
# | nupdates           | 13900    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 69500    |
# | value_loss         | 0.314    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000102 |
# | fps                | 69        |
# | nupdates           | 14000     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 70000     |
# | value_loss         | 0.979     |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.000293 |
# | fps                | 69       |
# | nupdates           | 14100    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 70500    |
# | value_loss         | 3.52     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00078  |
# | fps                | 69       |
# | nupdates           | 14200    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 71000    |
# | value_loss         | 0.34     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000474 |
# | fps                | 69       |
# | nupdates           | 14300    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 71500    |
# | value_loss         | 6.09     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -4.34e-05 |
# | fps                | 69        |
# | nupdates           | 14400     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 72000     |
# | value_loss         | 143       |
# ----------------------------------
# ----------------------------------
# | explained_variance | -0.000449 |
# | fps                | 69        |
# | nupdates           | 14500     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 72500     |
# | value_loss         | 0.257     |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.0057   |
# | fps                | 69       |
# | nupdates           | 14600    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 73000    |
# | value_loss         | 0.33     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00022 |
# | fps                | 69       |
# | nupdates           | 14700    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 73500    |
# | value_loss         | 0.291    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000777 |
# | fps                | 69       |
# | nupdates           | 14800    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 74000    |
# | value_loss         | 0.857    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000225 |
# | fps                | 69       |
# | nupdates           | 14900    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 74500    |
# | value_loss         | 0.548    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000702 |
# | fps                | 69        |
# | nupdates           | 15000     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 75000     |
# | value_loss         | 2.27      |
# ----------------------------------
# ----------------------------------
# | explained_variance | -0.000118 |
# | fps                | 69        |
# | nupdates           | 15100     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 75500     |
# | value_loss         | 7.81      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 2.84e-05 |
# | fps                | 69       |
# | nupdates           | 15200    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 76000    |
# | value_loss         | 57.6     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000814 |
# | fps                | 69       |
# | nupdates           | 15300    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 76500    |
# | value_loss         | 1.92     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00339  |
# | fps                | 69       |
# | nupdates           | 15400    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 77000    |
# | value_loss         | 0.136    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00138 |
# | fps                | 69       |
# | nupdates           | 15500    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 77500    |
# | value_loss         | 0.125    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000401 |
# | fps                | 69       |
# | nupdates           | 15600    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 78000    |
# | value_loss         | 1.24     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000457 |
# | fps                | 69        |
# | nupdates           | 15700     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 78500     |
# | value_loss         | 1.41      |
# ----------------------------------
# ----------------------------------
# | explained_variance | -3.15e-05 |
# | fps                | 69        |
# | nupdates           | 15800     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 79000     |
# | value_loss         | 4.4       |
# ----------------------------------
# ----------------------------------
# | explained_variance | -2.32e-05 |
# | fps                | 69        |
# ...
# ---------------------------------
# ---------------------------------
# | explained_variance | 5.11e-05 |
# | fps                | 71       |
# | nupdates           | 194300   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 971500   |
# | value_loss         | 1.59     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 3.7e-06  |
# | fps                | 71       |
# | nupdates           | 194400   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 972000   |
# | value_loss         | 0.501    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000415 |
# | fps                | 71       |
# | nupdates           | 194500   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 972500   |
# | value_loss         | 3.86     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -9.49e-05 |
# | fps                | 71        |
# | nupdates           | 194600    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 973000    |
# | value_loss         | 22.7      |
# ----------------------------------
# ----------------------------------
# | explained_variance | -1.69e-05 |
# | fps                | 71        |
# | nupdates           | 194700    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 973500    |
# | value_loss         | 249       |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.00228  |
# | fps                | 71       |
# | nupdates           | 194800   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 974000   |
# | value_loss         | 0.607    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000417 |
# | fps                | 71       |
# | nupdates           | 194900   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 974500   |
# | value_loss         | 0.364    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000111 |
# | fps                | 71        |
# | nupdates           | 195000    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 975000    |
# | value_loss         | 0.923     |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.000147 |
# | fps                | 71       |
# | nupdates           | 195100   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 975500   |
# | value_loss         | 0.726    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000129 |
# | fps                | 71        |
# | nupdates           | 195200    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 976000    |
# | value_loss         | 1.76      |
# ----------------------------------
# ---------------------------------
# | explained_variance | -1.8e-05 |
# | fps                | 71       |
# | nupdates           | 195300   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 976500   |
# | value_loss         | 6.03     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000579 |
# | fps                | 71       |
# | nupdates           | 195400   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 977000   |
# | value_loss         | 2.82     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 7.09e-05 |
# | fps                | 71       |
# | nupdates           | 195500   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 977500   |
# | value_loss         | 14.5     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00163 |
# | fps                | 71       |
# | nupdates           | 195600   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 978000   |
# | value_loss         | 0.446    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00533 |
# | fps                | 71       |
# | nupdates           | 195700   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 978500   |
# | value_loss         | 0.141    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.96e-05 |
# | fps                | 71       |
# | nupdates           | 195800   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 979000   |
# | value_loss         | 1.15     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00106  |
# | fps                | 71       |
# | nupdates           | 195900   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 979500   |
# | value_loss         | 0.521    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000256 |
# | fps                | 71        |
# | nupdates           | 196000    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 980000    |
# | value_loss         | 2.04      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 6.6e-05  |
# | fps                | 71       |
# | nupdates           | 196100   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 980500   |
# | value_loss         | 6.44     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 3.26e-05 |
# | fps                | 71       |
# | nupdates           | 196200   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 981000   |
# | value_loss         | 53.4     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00364 |
# | fps                | 71       |
# | nupdates           | 196300   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 981500   |
# | value_loss         | 0.392    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000271 |
# | fps                | 71       |
# | nupdates           | 196400   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 982000   |
# | value_loss         | 9.9      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000442 |
# | fps                | 71       |
# | nupdates           | 196500   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 982500   |
# | value_loss         | 0.648    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000269 |
# | fps                | 71       |
# | nupdates           | 196600   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 983000   |
# | value_loss         | 1.07     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000908 |
# | fps                | 71       |
# | nupdates           | 196700   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 983500   |
# | value_loss         | 0.497    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00107 |
# | fps                | 71       |
# | nupdates           | 196800   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 984000   |
# | value_loss         | 2.42     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 1.17e-05 |
# | fps                | 71       |
# | nupdates           | 196900   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 984500   |
# | value_loss         | 24.3     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -8.45e-05 |
# | fps                | 71        |
# | nupdates           | 197000    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 985000    |
# | value_loss         | 57.3      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.000268 |
# | fps                | 71       |
# | nupdates           | 197100   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 985500   |
# | value_loss         | 3.2      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00272  |
# | fps                | 71       |
# | nupdates           | 197200   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 986000   |
# | value_loss         | 0.337    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00012  |
# | fps                | 71       |
# | nupdates           | 197300   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 986500   |
# | value_loss         | 0.146    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000406 |
# | fps                | 71        |
# | nupdates           | 197400    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 987000    |
# | value_loss         | 0.527     |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.000646 |
# | fps                | 71       |
# | nupdates           | 197500   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 987500   |
# | value_loss         | 1.44     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -6.46e-05 |
# | fps                | 71        |
# | nupdates           | 197600    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 988000    |
# | value_loss         | 12.9      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 6.65e-05 |
# | fps                | 71       |
# | nupdates           | 197700   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 988500   |
# | value_loss         | 8.28     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -8.11e-06 |
# | fps                | 71        |
# | nupdates           | 197800    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 989000    |
# | value_loss         | 75.2      |
# ----------------------------------
# ----------------------------------
# | explained_variance | -0.000359 |
# | fps                | 71        |
# | nupdates           | 197900    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 989500    |
# | value_loss         | 6.72      |
# ----------------------------------
# ----------------------------------
# | explained_variance | -0.000367 |
# | fps                | 71        |
# | nupdates           | 198000    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 990000    |
# | value_loss         | 0.182     |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.000827 |
# | fps                | 71       |
# | nupdates           | 198100   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 990500   |
# | value_loss         | 0.332    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000389 |
# | fps                | 71       |
# | nupdates           | 198200   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 991000   |
# | value_loss         | 1.56     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 5.54e-05 |
# | fps                | 71       |
# | nupdates           | 198300   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 991500   |
# | value_loss         | 2.32     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -5.6e-06 |
# | fps                | 71       |
# | nupdates           | 198400   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 992000   |
# | value_loss         | 16.2     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -5.13e-06 |
# | fps                | 71        |
# | nupdates           | 198500    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 992500    |
# | value_loss         | 146       |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.00102  |
# | fps                | 71       |
# | nupdates           | 198600   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 993000   |
# | value_loss         | 0.77     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000306 |
# | fps                | 71       |
# | nupdates           | 198700   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 993500   |
# | value_loss         | 0.133    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00215  |
# | fps                | 71       |
# | nupdates           | 198800   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 994000   |
# | value_loss         | 0.403    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000721 |
# | fps                | 71        |
# | nupdates           | 198900    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 994500    |
# | value_loss         | 1.09      |
# ----------------------------------
# ----------------------------------
# | explained_variance | -0.000988 |
# | fps                | 71        |
# | nupdates           | 199000    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 995000    |
# | value_loss         | 2.22      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.000409 |
# | fps                | 71       |
# | nupdates           | 199100   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 995500   |
# | value_loss         | 2.01     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -3.46e-05 |
# | fps                | 71        |
# | nupdates           | 199200    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 996000    |
# | value_loss         | 2.09      |
# ----------------------------------
# ----------------------------------
# | explained_variance | -6.44e-05 |
# | fps                | 71        |
# | nupdates           | 199300    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 996500    |
# | value_loss         | 19.6      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.000221 |
# | fps                | 71       |
# | nupdates           | 199400   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 997000   |
# | value_loss         | 0.865    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000167 |
# | fps                | 71       |
# | nupdates           | 199500   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 997500   |
# | value_loss         | 0.551    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.49e-05 |
# | fps                | 71        |
# | nupdates           | 199600    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 998000    |
# | value_loss         | 1.13      |
# ----------------------------------
# ----------------------------------
# | explained_variance | -0.000354 |
# | fps                | 71        |
# | nupdates           | 199700    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 998500    |
# | value_loss         | 0.69      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.000303 |
# | fps                | 71       |
# | nupdates           | 199800   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 999000   |
# | value_loss         | 7.71     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000375 |
# | fps                | 71        |
# | nupdates           | 199900    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 999500    |
# | value_loss         | 1.36      |
# ----------------------------------
# ----------------------------------
# | explained_variance | -0.000146 |
# | fps                | 71        |
# | nupdates           | 200000    |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 1000000   |
# | value_loss         | 15.1      |
# ----------------------------------

# %%
model.save("2022.09.14_2330TW_5MTimestep_3YearTraining_128_64_64_RSI_5Day_NormalizeVersion")

# %%
model = A2C.load("2022.09.14_2330TW_5MTimestep_3YearTraining_128_64_64_RSI_5Day_NormalizeVersion")
# Out:
# Loading a model without an environment, this model cannot be trained until it has a valid environment.

# %% [markdown]
# # 獲取今天的Dataframe索引，方便填寫frame_bound

# %%
# today = df2330.iloc[-1:]
# today = today.index.values
# totay = today[0]

# %%
dfStartDate_Test = df2330[(df2330['index']=='2022-07-01')].index.values
dfStartDate_Test = dfStartDate_Test[0]

dfEndDate_Test = df2330[(df2330['index']=='2022-08-01')].index.values
dfEndDate_Test = dfEndDate_Test[0]

# %% [markdown]
# # 在今天早上開盤時進行交易

# %%
open, close, high, low, volume, signal_features = my_process_data(df=df2330, window_size=5, frame_bound=(dfStartDate_Test, dfEndDate_Test))#Close與特徵資料
env = MyStocksEnv(open, close, high, low, volume, signal_features, df=df2330, window_size=5, frame_bound=(dfStartDate_Test, dfEndDate_Test))#「環境」整合
obs = env.reset()#初始化「環境」（特徵初始化）
env.seed()
Day = 0
while True: 
    obs = obs[np.newaxis, ...]#1.先抓取【0】~【9】的特徵
    action_pro = model.action_probability(obs)
    print(action_pro)
    action, _states = model.predict(obs)#2.Agent觀看obs, 進行action的行為，即買【1】賣【0】
    print(action)
    obs, rewards, done, info = env.step(action)#3.使用【1】~【10】的特徵'記錄'獎罰，驗證是否完成，輸出資料
    Day+=1
    print("Day",Day, "Rewards", rewards, end="\n")
    if done:#4.如果完成迴圈，則輸出資料
        print("info", info)
        break
# Out:
# [[0.484036 0.515964]]
# [1]
# Day 1 Rewards -10.5
# [[0.484036 0.515964]]
# [0]
# Day 2 Rewards -9.5
# [[0.48407722 0.5159228 ]]
# [0]
# Day 3 Rewards 4.0
# [[0.48415896 0.51584095]]
# [1]
# Day 4 Rewards 6.5
# [[0.48414862 0.5158513 ]]
# [1]
# Day 5 Rewards 12.5
# [[0.48411426 0.5158858 ]]
# [1]
# Day 6 Rewards 1.0
# [[0.48408115 0.5159189 ]]
# [1]
# Day 7 Rewards -4.0
# [[0.484044   0.51595604]]
# [1]
# Day 8 Rewards 21.0
# [[0.48393843 0.5160616 ]]
# [0]
# Day 9 Rewards 4.5
# [[0.48396766 0.51603234]]
# [1]
# Day 10 Rewards 6.0
# [[0.48402554 0.5159744 ]]
# [0]
# Day 11 Rewards -3.0
# [[0.48403135 0.51596874]]
# [0]
# Day 12 Rewards 8.0
# [[0.48397186 0.5160281 ]]
# [1]
# Day 13 Rewards 11.0
# [[0.4839369  0.51606303]]
# [0]
# Day 14 Rewards -1.0
# [[0.48387533 0.51612467]]
# [0]
# Day 15 Rewards -4.0
# [[0.4838248 0.5161752]]
# [0]
# Day 16 Rewards 3.0
# [[0.48379034 0.5162097 ]]
# [1]
# Day 17 Rewards 0.0
# [[0.48377284 0.5162271 ]]
# [0]
# Day 18 Rewards 1.0
# [[0.48377973 0.51622033]]
# [0]
# Day 19 Rewards -7.0
# [[0.48383015 0.51616985]]
# [1]
# Day 20 Rewards 7.0
# [[0.48394898 0.516051  ]]
# [1]
# Day 21 Rewards 0
# info {'total_reward': 46.5, 'total_profit': 1.010835204636637, 'position': 1}

# %% [markdown]
# # 根據模型預測，position為今天收盤時需要進行的交易策略(Long or Short)

# %%
plt.figure(figsize=(16, 6))
env.render_Close()#將「環境」畫出來
# Out:
# ↓↓↓ 台積電(2330)在交易當天收盤時進行的交易策略(Long Or Short) ↓↓↓

# %%
plt.figure(figsize=(16, 6))
env.render_Reward()
# Out:
# ↓↓↓ 台積電(2330)在使用交易策略(Long Or Short)後，隔日早上平倉時的盈虧(未含手續費) ↓↓↓

# %%
plt.figure(figsize=(16, 6))
env.render_TotalProfit()
# Out:
# ↓↓↓ 根據預測出的交易策略交易台積電(2330)，所得到的累積利潤(含手續費) ↓↓↓

# %% [markdown]
# # ------------------------------------------------

# %% [markdown]
# # 不同技術分析合併進行資料萃取，需要轉換矩陣格式，解釋如下：

# %%
# a = np.array([
#     [
#         [1,2,3,4,5,6],
#         [2,4,5,6,5,6],
#         [2,4,5,6,5,6],
#         [2,4,5,6,5,6]
#     ]
# ])
# #-----------------------
# b = np.array([
#     [
#         [1,2],[3,4],[5,6]
#     ],
#     [
#         [2,4],[5,6],[5,6]
#     ],
#     [
#         [2,4],[5,6],[5,6]
#     ],
#     [
#         [2,4],[5,6],[5,6]
#     ]
# ])
# #-----------------------
# print('目的：將原本矩陣a，變成矩陣b。因為在機器訓練時，需要讓機器意識到為兩組獨立的參數')
# print('注意：入面組嘅大小必須相同，例如[1,2],[3,4]，但不可以[1,2],[3,4,5]\n\n')
# print('第一個數字：大括號\n第二個數字：有四個打橫\n第三個數字：打橫入面有幾多個數字')
# print(a.shape)
# print(a,'\n')
# print('第一個數字：有幾多大組嘅數字\n第二個數字：入面有幾多個小組\n第三個數字：每個小組入面有幾多個數字')
# print(b.shape)
# print(b)
